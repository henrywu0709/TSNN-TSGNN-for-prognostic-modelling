# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score, precision_score
from imblearn.over_sampling import RandomOverSampler, ADASYN, SMOTE
import optuna
from joblib import Parallel, delayed
from tqdm import tqdm
import random
import warnings
from optuna.exceptions import TrialPruned

import os

# Limit each parallel process to one thread per library
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'
os.environ['NUMEXPR_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['VECLIB_MAXIMUM_THREADS'] = '1'
os.environ['TORCH_NUM_THREADS'] = '1'  # For PyTorch

# Additional control for PyTorch if needed
import torch
torch.set_num_threads(1)

# # For reproducibility
# def set_seed(seed=42):
#     random.seed(seed)
#     np.random.seed(seed)
#     torch.manual_seed(seed)

# set_seed()

# Suppress warnings for cleaner output
warnings.filterwarnings("ignore")

# Load the dataset
data = pd.read_excel("class1_dataset.xlsx")

# Define feature groups (as provided)
feature_groups = {
    'Genotype': [
        'rs11225395', 'rs1144393', 'rs650108', 'rs591058', 'rs2252070', 'rs4986938', 'rs1800012', 'rs4789932', 'rs9340799', 'rs970547', 
        'rs1800795', 'rs13946', 'rs12722', 'class1_SNP_risk_score', 'rs7528684', 'rs4919510', 'rs1937810', 'rs6481512', 'rs1249269', 
        'rs12574452', 'rs12429486', 'rs4454832', 'rs2761884', 'rs62051384', 'rs4362400', 'rs2586488', 'rs2277698', 'rs1045485', 
        'rs143383', 'rs17576', 'rs2305948', 'rs1011814', 'rs11154027', 'rs2234693', 'rs1643821', 'rs2010963', 'rs10263021', 'rs149047058', 
        'rs420257', 'rs42517', 'rs42522', 'rs42531', 'rs413826', 'rs2104772', 'rs1330363', 'class12_SNP_risk_score', 'rs3753841', 
        'rs57104447', 'rs1887632', 'rs4654760', 'rs1137101', 'rs2306033', 'rs2277268', 'rs4988321', 'rs11232681', 'rs1718119', 'rs3751143', 
        'rs1544410', 'rs2228570', 'rs4328262', 'rs1021188', 'rs74544784', 'rs78391032', 'rs77569527', 'rs117544024', 'rs912336', 
        'rs3218791', 'rs911263', 'rs2525504', 'rs17756404', 'rs4903399', 'rs10132091', 'rs17583842', 'rs1676303', 'rs11629171', 
        'rs2281518', 'rs2285053', 'rs71404070', 'rs710079', 'rs2858056', 'rs820218', 'rs3018362', 'rs1800470', 'rs1800469', 'rs25487', 
        'rs25489', 'rs2289360', 'rs183364169', 'rs11177', 'rs6617', 'rs3219008', 'rs13107325', 'rs60713544', 'rs145648292', 'rs4244032', 
        'rs12656106', 'rs3045', 'rs187483', 'rs4701616', 'rs144414988', 'rs1800629', 'rs10484958', 'rs4730153', 'rs1800797', 'rs1554606', 
        'rs2237352', 'rs4725069', 'rs12154667', 'rs1548456', 'rs3216902', 'rs35360670', 'rs13317', 'rs1800972', 'rs7035322', 'rs7021589', 
        'rs72758637', 'rs10759753', 'rs3789870', 'rs1138545', 'rs3196378', 'rs1134170', 'rs10992075', 'rs1590', 'rs144371252', 
        'rs761804508', 'class123_SNP_risk_score', 'sex'
    ],
    'History': [
        'Age', 'lower_limb_days_total', 'average_run_hours', 'average_interval_training_frequency', 'EDEQ_total', 'tracking_period_injury',
        'past_stress_injury', 'LEAF-Q', 'Athlete_Score', 'average_run_frequency', 'past_month_injury'
    ],
    'Phenotype': [
        'hip_abduction_peak_torque', 'total_ad_ab_ratio', 'knee_extension_peak_torque', 'knee_flexion_peak_torque', 'navicular_drop', 
        'navicular_drop_asymmetry', 'Q_angle', 'Q_angle_asymmetry', 'VALR_12', 'Impact_peak_12', 'Duty_factor_12', 'BMI', 'BMD_spine',
        'hip_abduction_peak_torque_asymmetry', 'hip_adduction_peak_torque', 'hip_adduction_peak_torque_asymmetry', 
        'knee_extension_peak_torque_asymmetry', 'knee_flexion_peak_torque_asymmetry', 'total_fl_ex_ratio', 'leg_lean_mass', 
        'hip_abduction_peak_angle', 'hip_abduction_peak_angle_asymmetry', 'hip_adduction_peak_angle', 'hip_adduction_peak_angle_asymmetry', 
        'ad_ab_ratio_asymmetry', 'knee_extension_peak_angle', 'knee_extension_peak_angle_asymmetry', 'knee_flexion_peak_angle', 
        'knee_flexion_peak_angle_asymmetry', 'fl_ex_ratio_asymmetry', 'VILR_10', 'VALR_10', 'VILR_asymmetry_10', 'VALR_asymmetry_10', 
        'Impact_peak_10', 'Impact_peak_asymmetry_10', 'Flight_time_10', 'Contact_time_10', 'Duty_factor_10', 'Step_frequency_10', 
        'Cadence_asymmetry_10', 'Duty_factor_asymmetry_10', 'VILR_12', 'VILR_asymmetry_12', 'VALR_asymmetry_12', 
        'Impact_peak_asymmetry_12', 'Flight_time_12', 'Contact_time_12', 'Step_frequency_12', 'Cadence_asymmetry_12', 
        'Duty_factor_asymmetry_12', 'Alt_strike', 'height', 'Mass', 'thigh_lean_mass', 'thigh_ffmi', 'lower_leg_lean_mass', 
        'lower_leg_ffmi', 'leg_ffmi', 'total_lean_mass', 'total_ffmi', 'calf_size', 'BMD_hip', 'BMD_body',
    ],
    'Behaviour': [
        'fat_intake_avg', 'past_month_distance', 'past_month_ratio', 'SC_past_season', 'non_running_past_season', 'fat_intake_BW', 
        'fat_percentage_avg', 'average_energy_availability', 'protein_intake_BW', 'omega3_intake_BW', 'vitaminD_intake_BW', 
        'vitaminC_intake_BW', 'vitaminE_intake_BW', 'calcium_intake_BW', 'copper_intake_BW', 'iron_intake_BW', 'glycine_intake_BW', 
        'arginine_intake_BW', 'past_month_min', 'past_week_ratio', 'past_month_volume_low', 'past_week_ratio_low', 'past_month_ratio_low', 
        'past_month_volume_moderate', 'past_week_ratio_moderate', 'past_month_ratio_moderate', 'past_month_volume_high', 
        'past_week_ratio_high', 'past_month_ratio_high', 'past_month_volume_very_high', 'past_week_ratio_very_high', 
        'past_month_ratio_very_high', 'past_month_calculated_volume', 'past_week_ratio_calculated_volume', 
        'past_month_ratio_calculated_volume', 'resistance_training_past_month', 'resistance_training_past_season', 
        'bodyweight_exercises_past_month', 'bodyweight_exercises_past_season', 'core_stability_past_month', 'core_stability_past_season', 
        'balance_training_past_month', 'balance_training_past_season', 'plyometrics_past_month', 'plyometrics_past_season', 
        'drills_past_month', 'drills_past_season', 'circuit_training_past_month', 'circuit_training_past_season', 'barefoot_past_month', 
        'barefoot_past_season', 'stretching_past_month', 'stretching_past_season', 'SC_past_month', 'non_running_past_month'
    ]
}

# Define predictors and outcome
X = data.drop(columns=['RRI'])  # Predictors
y = data['RRI']  # Outcome

# Ensure that the feature groups exist in the dataset
for group in feature_groups:
    feature_groups[group] = [feature for feature in feature_groups[group] if feature in X.columns]

num_features = len(X.columns)
feature_to_idx = {feature: idx for idx, feature in enumerate(X)}

# Initialize adjacency matrix with zeros
adjacency = np.zeros((num_features, num_features), dtype=np.float32)

# Define groups
genotype_features = feature_groups['Genotype']
history_features = feature_groups['History']
phenotype_features = feature_groups['Phenotype']
behaviour_features = feature_groups['Behaviour']

# Get indices for each group
genotype_indices = [feature_to_idx[feat] for feat in genotype_features]
history_indices = [feature_to_idx[feat] for feat in history_features]
phenotype_indices = [feature_to_idx[feat] for feat in phenotype_features]
behaviour_indices = [feature_to_idx[feat] for feat in behaviour_features]

# Genotype nodes: connect to every node except themselves
for i in genotype_indices:
    for j in range(num_features):
        if j != i:
            adjacency[i, j] = 1.0

# History nodes: connect to every node except genotype nodes and themselves
for i in history_indices:
    for j in range(num_features):
        if j not in genotype_indices and j != i:
            adjacency[i, j] = 1.0

# Phenotype nodes: connect to every node except genotype, history nodes, and themselves
for i in phenotype_indices:
    for j in range(num_features):
        if j not in genotype_indices and j not in history_indices and j != i:
            adjacency[i, j] = 1.0

# Behaviour nodes: connect to all other behaviour nodes except themselves
for i in behaviour_indices:
    for j in behaviour_indices:
        if j != i:
            adjacency[i, j] = 1.0

# Convert adjacency to tensor
adjacency_mask = torch.tensor(adjacency, dtype=torch.float32)

class CustomDataset(Dataset):
    def __init__(self, X, y):
        if isinstance(X, pd.DataFrame):
            self.X = X.values.astype(np.float32)
        elif isinstance(X, np.ndarray):
            self.X = X.astype(np.float32)
        else:
            raise TypeError("X should be a pandas DataFrame or a NumPy array.")
        self.y = y.astype(np.float32)
    
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

class CustomNetwork(nn.Module):
    def __init__(self, num_features, adjacency_mask):
        super(CustomNetwork, self).__init__()
        self.num_features = num_features

        # Register the fixed adjacency mask as a buffer (non-trainable)
        self.register_buffer('mask', adjacency_mask.float())  # Shape: (num_features, num_features)

        # Initialize connection weights (W_ij: from node j to node i)
        self.W = nn.Parameter(torch.randn(num_features, num_features) * 0.01)

        # Initialize bias for each node
        self.bias = nn.Parameter(torch.zeros(num_features))

        # Initialize output weights (from each node to the final output)
        self.output_weights = nn.Parameter(torch.randn(num_features) * 0.01)

        # Add Batch Normalization
        self.batch_norm = nn.BatchNorm1d(num_features)

    def forward(self, x, threshold=None):
        """
        x: input tensor of shape (batch_size, num_features)
        threshold: if provided, apply binary thresholding to gating
        """
        # Use the fixed mask directly
        learnable_mask = self.mask

        # Apply the learnable mask to connection weights
        W_masked = self.W * learnable_mask  # Shape: (num_features, num_features)

        # Compute incoming messages: (batch_size, num_features) @ (num_features, num_features) = (batch_size, num_features)
        incoming = torch.matmul(x, W_masked)

        # Element-wise multiplication with own feature value
        node_input = incoming * x  # Shape: (batch_size, num_features)

        node_input = self.batch_norm(node_input)

        # Add bias
        node_input += self.bias  # Broadcasting over batch

        # Apply Leaky ReLU activation
        node_output = F.leaky_relu(node_input)  # Shape: (batch_size, num_features)

        # Aggregate node outputs to final output
        output = torch.matmul(node_output, self.output_weights)  # Shape: (batch_size,)

        return output  # Raw scores (logits)

# Remove the import for ReliefF as it's no longer needed
# from skrebate import ReliefF

from sklearn.linear_model import LogisticRegression

def train_evaluate_fold(fold, train_index, val_index, X, y, selected_features, adjacency, feature_to_idx, 
                       n_epochs, lr, weight_decay, batch_size, threshold):
    """
    Function to train and evaluate the model on a single fold.
    This function is intended to be run in parallel.
    """
    # Split data
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]

    # Encode labels for binary classification
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y_train_enc = le.fit_transform(y_train)
    y_val_enc = le.transform(y_val)
    y_train_final = y_train_enc
    y_val_final = y_val_enc

    # Create datasets
    train_dataset = CustomDataset(X_train[selected_features], y_train_final)
    val_dataset = CustomDataset(X_val[selected_features], y_val_final)

    # Create dataloaders with drop_last=True for training and drop_last=False for validation
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

    # Map selected_features to their indices
    selected_feature_indices = [feature_to_idx[feat] for feat in selected_features]

    # Select the corresponding adjacency submatrix using integer indices
    selected_adjacency = adjacency[np.ix_(selected_feature_indices, selected_feature_indices)]
    selected_adjacency_mask = torch.tensor(selected_adjacency, dtype=torch.float32)

    device = torch.device('cpu')

    # Initialize the model with the number of selected features and the selected adjacency mask
    model = CustomNetwork(num_features=len(selected_features), 
                          adjacency_mask=selected_adjacency_mask).to(device)

    # Define loss and optimizer
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    # Training Loop
    for epoch in range(1, n_epochs + 1):
        model.train()
        epoch_loss = 0.0

        for batch_X, batch_y in train_loader:
            batch_X = batch_X.to(device).float()  # Ensure float type
            batch_y = batch_y.to(device).float()  # BCEWithLogitsLoss expects float targets

            optimizer.zero_grad()
            outputs = model(batch_X)  # Forward pass
            loss = criterion(outputs, batch_y)

            # Total loss
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item() * batch_X.size(0)

        epoch_loss /= len(train_loader.dataset)

    # Validation
    model.eval()
    all_outputs = []
    all_labels = []
    all_preds = []  # Initialize a list to accumulate predictions

    with torch.no_grad():
        for batch_X, batch_y in val_loader:
            batch_X = batch_X.to(device).float()

            outputs = model(batch_X)  # Forward pass
            probs = torch.sigmoid(outputs).cpu().numpy()
            preds = (probs >= threshold).astype(int).flatten()

            all_outputs.extend(probs)
            all_labels.extend(batch_y.numpy())
            all_preds.extend(preds)  # Accumulate predictions

    # Compute metrics
    roc_auc = roc_auc_score(all_labels, all_outputs)
    f1 = f1_score(all_labels, all_preds, average='binary')
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='binary')

    return {
        'roc_auc': roc_auc,
        'f1': f1,
        'accuracy': accuracy,
        'precision': precision
    }

def group_feature_ranking_logistic_lasso(X, y, feature_groups, C=25):
    """
    Perform group-wise feature ranking using Logistic Lasso (Logistic Regression with L1 penalty).
    Returns a dictionary with group names as keys and DataFrames with feature and score sorted descendingly.
    """
    from sklearn.preprocessing import StandardScaler
    from sklearn.preprocessing import LabelEncoder
    
    group_rankings = {}
    
    # Encode labels if they are not binary
    if y.nunique() > 2:
        raise ValueError("Logistic Lasso is only applicable for binary classification.")
    
    y_encoded = y.copy()
    if y.dtype != int and y.dtype != float:
        le = LabelEncoder()
        y_encoded = le.fit_transform(y)
    
    for group, features in feature_groups.items():
        # Ensure features are in X
        valid_features = [feat for feat in features if feat in X.columns]
        if not valid_features:
            continue
        X_group = X[valid_features].values
        
        # Initialize Logistic Regression with L1 penalty
        clf = LogisticRegression(penalty='l1', C=C, solver='liblinear', max_iter=1000)
        
        # Fit the model
        clf.fit(X_group, y_encoded)
        
        # Get absolute coefficients as feature scores
        feature_scores = np.abs(clf.coef_[0])
        
        # Create a DataFrame for feature scores
        group_score_df = pd.DataFrame({
            'feature': valid_features,
            'score': feature_scores
        }).sort_values(by='score', ascending=False)
        
        group_rankings[group] = group_score_df
    
    return group_rankings

def objective(trial, X, y, feature_groups, feature_to_idx, group_feature_rankings, adjacency, threshold=0.5):
    # ====================
    # Hyperparameters to Tune
    # ====================

    # 1. Number of Epochs
    n_epochs = trial.suggest_int('n_epochs', 500, 3000)

    # 2. Learning Rate
    lr = trial.suggest_loguniform('lr', 1e-6, 1e-2)

    # 3. Weight Decay
    weight_decay = trial.suggest_loguniform('weight_decay', 1e-8, 1e-3)

    # 4. Batch Size
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128, 256, 512])

    # 5. Number of Features per Group
    n_genotype = trial.suggest_int('n_genotype', 1, len(feature_groups['Genotype']))
    n_history = trial.suggest_int('n_history', 1, len(feature_groups['History']))
    n_phenotype = trial.suggest_int('n_phenotype', 1, len(feature_groups['Phenotype']))
    n_behaviour = trial.suggest_int('n_behaviour', 1, len(feature_groups['Behaviour']))

    # ====================
    # Feature Selection Using Group-wise Logistic Lasso Rankings
    # ====================

    # Initialize selected features list
    selected_features = []
    
    # For each group, select the top N features based on group-specific Logistic Lasso scores
    for group, n_select in zip(['Genotype', 'History', 'Phenotype', 'Behaviour'],
                               [n_genotype, n_history, n_phenotype, n_behaviour]):
        if group not in group_feature_rankings:
            continue  # Skip if the group has no features
        group_feature_scores = group_feature_rankings[group]
        # Select top N features
        top_features = group_feature_scores.head(n_select)['feature'].tolist()
        selected_features.extend(top_features)
    
    # Ensure that selected_features are unique
    selected_features = list(dict.fromkeys(selected_features))

    # ====================
    # Data Preparation
    # ====================

    X_selected = X[selected_features].copy()
    y_selected = y.copy()

    # Initialize Stratified K-Fold
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

    # Get all fold indices
    fold_indices = list(skf.split(X_selected, y_selected))

    # ====================
    # Parallel Training and Evaluation
    # ====================

    # Define a wrapper for joblib's Parallel
    results = Parallel(n_jobs=10)(
        delayed(train_evaluate_fold)(
            fold=fold,
            train_index=train_idx,
            val_index=val_idx,
            X=X_selected,
            y=y_selected,
            selected_features=selected_features,
            adjacency=adjacency,  # Pass the numpy adjacency matrix
            feature_to_idx=feature_to_idx,  # Pass the feature_to_idx mapping
            n_epochs=n_epochs,
            lr=lr,
            weight_decay=weight_decay,
            batch_size=batch_size,
            threshold=threshold
        )
        for fold, (train_idx, val_idx) in enumerate(fold_indices)
    )

    # ====================
    # Collect Metrics
    # ====================

    aucs = []
    f1s = []
    accuracies = []
    precisions = []

    for res in results:
        aucs.append(res['roc_auc'])
        f1s.append(res['f1'])
        accuracies.append(res['accuracy'])
        precisions.append(res['precision'])

    # ====================
    # Final Metrics Calculation
    # ====================

    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_f1 = np.mean(f1s)
    std_f1 = np.std(f1s)
    mean_accuracy = np.mean(accuracies)
    std_accuracy = np.std(accuracies)
    mean_precision = np.mean(precisions)
    std_precision = np.std(precisions)

    # ====================
    # Objective Metric
    # ====================

    # Since it's binary classification, we aim to maximize the mean AUC
    trial.set_user_attr("mean_auc", mean_auc)
    trial.set_user_attr("std_auc", std_auc)
    trial.set_user_attr("mean_f1", mean_f1)
    trial.set_user_attr("std_f1", std_f1)
    trial.set_user_attr("mean_accuracy", mean_accuracy)
    trial.set_user_attr("std_accuracy", std_accuracy)
    trial.set_user_attr("mean_precision", mean_precision)
    trial.set_user_attr("std_precision", std_precision)
    trial.set_user_attr("selected_features", selected_features)

    return mean_auc

def run_hyperparameter_tuning(X, y, feature_groups, feature_to_idx, adjacency, threshold=0.5):
    # Generate the group-wise feature ranking before the study starts using Logistic Lasso
    group_feature_rankings = group_feature_ranking_logistic_lasso(X, y, feature_groups, C=25)

    def objective_wrapper(trial):
        return objective(trial, X, y, feature_groups, feature_to_idx, group_feature_rankings, adjacency, threshold)

    study = optuna.create_study(
        direction='maximize',
        study_name='CustomNetwork_Hyperparameter_Tuning',
        sampler=optuna.samplers.TPESampler(seed=42)
    )

    # Integrate a progress bar for the Optuna study
    with tqdm(total=200, desc="Optuna Trials") as pbar:
        def callback(study, trial):
            pbar.update(1)

        # Set n_jobs=1 to ensure serial execution of hyperparameter trials
        study.optimize(objective_wrapper, n_trials=200, timeout=None, callbacks=[callback], n_jobs=1)

    print("Number of finished trials: ", len(study.trials))
    print("Best trial:")
    trial = study.best_trial

    print("  Value (Mean AUC): ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

    # Extract additional metrics from the best trial
    best_trial_metrics = trial.user_attrs
    mean_auc = best_trial_metrics.get("mean_auc", None)
    std_auc = best_trial_metrics.get("std_auc", None)
    mean_f1 = best_trial_metrics.get("mean_f1", None)
    std_f1 = best_trial_metrics.get("std_f1", None)
    mean_accuracy = best_trial_metrics.get("mean_accuracy", None)
    std_accuracy = best_trial_metrics.get("std_accuracy", None)
    mean_precision = best_trial_metrics.get("mean_precision", None)
    std_precision = best_trial_metrics.get("std_precision", None)
    selected_features = best_trial_metrics.get("selected_features", None)

    print(f"\nBest Trial Metrics:")
    print(f"Selected Features: {selected_features}")
    print(f"Average AUC: {mean_auc:.4f} ± {std_auc:.4f}")
    print(f"Average F1 Score: {mean_f1:.4f} ± {std_f1:.4f}")
    print(f"Average Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}")
    print(f"Average Precision: {mean_precision:.4f} ± {std_precision:.4f}")

    return study

if __name__ == "__main__":
    # Run hyperparameter tuning
    study = run_hyperparameter_tuning(X, y, feature_groups, feature_to_idx, adjacency)
# Out:
# [I 2024-12-15 18:33:50,699] A new study created in memory with name: CustomNetwork_Hyperparameter_Tuning
# Optuna Trials:   0%|          | 0/200 [00:00<?, ?it/s][I 2024-12-15 18:35:40,988] Trial 0 finished with value: 0.7186211998634185 and parameters: {'n_epochs': 1436, 'lr': 0.006351221010640704, 'weight_decay': 4.570563099801451e-05, 'batch_size': 512, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 1, 'n_behaviour': 5}. Best is trial 0 with value: 0.7186211998634185.
# Optuna Trials:   0%|          | 1/200 [01:50<6:05:42, 110.26s/it][I 2024-12-15 18:42:31,354] Trial 1 finished with value: 0.6914883208387307 and parameters: {'n_epochs': 2581, 'lr': 7.068974950624607e-06, 'weight_decay': 8.111941985431907e-08, 'batch_size': 128, 'n_genotype': 10, 'n_history': 1, 'n_phenotype': 4, 'n_behaviour': 2}. Best is trial 0 with value: 0.7186211998634185.
# Optuna Trials:   1%|          | 2/200 [08:40<15:46:25, 286.79s/it][I 2024-12-15 18:45:38,477] Trial 2 finished with value: 0.7311923805205759 and parameters: {'n_epochs': 1640, 'lr': 0.0013826232179369874, 'weight_decay': 9.9625132220551e-08, 'batch_size': 256, 'n_genotype': 1, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 2 with value: 0.7311923805205759.
# Optuna Trials:   2%|▏         | 3/200 [11:47<13:12:12, 241.28s/it][I 2024-12-15 18:47:22,470] Trial 3 finished with value: 0.5773472515471251 and parameters: {'n_epochs': 1261, 'lr': 2.4586032763280077e-06, 'weight_decay': 2.6373339933815247e-05, 'batch_size': 512, 'n_genotype': 4, 'n_history': 4, 'n_phenotype': 5, 'n_behaviour': 3}. Best is trial 2 with value: 0.7311923805205759.
# Optuna Trials:   2%|▏         | 4/200 [13:31<10:11:07, 187.08s/it][I 2024-12-15 18:55:49,052] Trial 4 finished with value: 0.6440848817064896 and parameters: {'n_epochs': 1867, 'lr': 5.4880470007660465e-06, 'weight_decay': 0.00070456836384545, 'batch_size': 64, 'n_genotype': 2, 'n_history': 2, 'n_phenotype': 1, 'n_behaviour': 2}. Best is trial 2 with value: 0.7311923805205759.
# Optuna Trials:   2%|▎         | 5/200 [21:58<16:22:27, 302.30s/it][I 2024-12-15 18:57:55,607] Trial 5 finished with value: 0.6752309361938286 and parameters: {'n_epochs': 1472, 'lr': 1.2172958098369984e-05, 'weight_decay': 0.00013921548533046482, 'batch_size': 512, 'n_genotype': 2, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 2 with value: 0.7311923805205759.
# Optuna Trials:   3%|▎         | 6/200 [24:04<13:04:13, 242.54s/it][I 2024-12-15 19:00:22,756] Trial 6 finished with value: 0.722273787379096 and parameters: {'n_epochs': 513, 'lr': 0.0018274508859816032, 'weight_decay': 3.422052903270691e-05, 'batch_size': 64, 'n_genotype': 13, 'n_history': 4, 'n_phenotype': 5, 'n_behaviour': 1}. Best is trial 2 with value: 0.7311923805205759.
# Optuna Trials:   4%|▎         | 7/200 [26:32<11:19:51, 211.36s/it][I 2024-12-15 19:06:14,048] Trial 7 finished with value: 0.7130592250635661 and parameters: {'n_epochs': 1277, 'lr': 1.99863407785289e-05, 'weight_decay': 4.446628955475447e-05, 'batch_size': 64, 'n_genotype': 12, 'n_history': 4, 'n_phenotype': 11, 'n_behaviour': 3}. Best is trial 2 with value: 0.7311923805205759.
# Optuna Trials:   4%|▍         | 8/200 [32:23<13:38:53, 255.91s/it][I 2024-12-15 19:11:34,198] Trial 8 finished with value: 0.7154228584422468 and parameters: {'n_epochs': 1807, 'lr': 5.1305517605898387e-05, 'weight_decay': 1.3399717231179682e-08, 'batch_size': 128, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 6, 'n_behaviour': 4}. Best is trial 2 with value: 0.7311923805205759.
# Optuna Trials:   4%|▍         | 9/200 [37:43<14:38:33, 275.99s/it][I 2024-12-15 19:16:38,187] Trial 9 finished with value: 0.685985310636256 and parameters: {'n_epochs': 1072, 'lr': 2.031980983842497e-06, 'weight_decay': 2.810329644763601e-07, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 3}. Best is trial 2 with value: 0.7311923805205759.
# Optuna Trials:   5%|▌         | 10/200 [42:47<15:01:20, 284.63s/it][I 2024-12-15 19:21:25,091] Trial 10 finished with value: 0.7154241924312053 and parameters: {'n_epochs': 2443, 'lr': 0.0005002513525471881, 'weight_decay': 1.412166785354856e-06, 'batch_size': 256, 'n_genotype': 6, 'n_history': 6, 'n_phenotype': 9, 'n_behaviour': 5}. Best is trial 2 with value: 0.7311923805205759.
# Optuna Trials:   6%|▌         | 11/200 [47:34<14:58:47, 285.33s/it][I 2024-12-15 19:26:50,468] Trial 11 finished with value: 0.717671094124846 and parameters: {'n_epochs': 683, 'lr': 0.0010137180733781348, 'weight_decay': 3.888232517505351e-06, 'batch_size': 32, 'n_genotype': 7, 'n_history': 5, 'n_phenotype': 8, 'n_behaviour': 1}. Best is trial 2 with value: 0.7311923805205759.
# Optuna Trials:   6%|▌         | 12/200 [52:59<15:32:12, 297.51s/it][I 2024-12-15 19:27:56,667] Trial 12 finished with value: 0.7175087670449906 and parameters: {'n_epochs': 560, 'lr': 0.009819932255387066, 'weight_decay': 3.552819905163416e-06, 'batch_size': 256, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 3, 'n_behaviour': 4}. Best is trial 2 with value: 0.7311923805205759.
# Optuna Trials:   6%|▋         | 13/200 [54:05<11:48:51, 227.44s/it][I 2024-12-15 19:32:25,330] Trial 13 finished with value: 0.7283383160628019 and parameters: {'n_epochs': 2253, 'lr': 0.0004908583115188453, 'weight_decay': 1.2973916755641072e-08, 'batch_size': 256, 'n_genotype': 15, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 2 with value: 0.7311923805205759.
# Optuna Trials:   7%|▋         | 14/200 [58:34<12:23:39, 239.89s/it][I 2024-12-15 19:36:38,903] Trial 14 finished with value: 0.7239012336872974 and parameters: {'n_epochs': 2115, 'lr': 0.00016671229135810703, 'weight_decay': 1.8508743708673157e-08, 'batch_size': 256, 'n_genotype': 15, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 2 with value: 0.7311923805205759.
# Optuna Trials:   8%|▊         | 15/200 [1:02:48<12:32:22, 244.01s/it][I 2024-12-15 19:42:26,016] Trial 15 finished with value: 0.7239939630605431 and parameters: {'n_epochs': 2996, 'lr': 0.0002327293930526458, 'weight_decay': 9.575681442212774e-08, 'batch_size': 256, 'n_genotype': 5, 'n_history': 3, 'n_phenotype': 10, 'n_behaviour': 5}. Best is trial 2 with value: 0.7311923805205759.
# Optuna Trials:   8%|▊         | 16/200 [1:08:35<14:03:28, 275.05s/it][I 2024-12-15 19:46:33,638] Trial 16 finished with value: 0.7247461792131702 and parameters: {'n_epochs': 2156, 'lr': 0.0018941219340260084, 'weight_decay': 4.002958169264477e-07, 'batch_size': 256, 'n_genotype': 1, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 2 with value: 0.7311923805205759.
# Optuna Trials:   8%|▊         | 17/200 [1:12:42<13:33:44, 266.80s/it][I 2024-12-15 20:06:50,896] Trial 17 finished with value: 0.7117229889921198 and parameters: {'n_epochs': 2571, 'lr': 6.177562735490056e-05, 'weight_decay': 4.8737317858632984e-08, 'batch_size': 32, 'n_genotype': 8, 'n_history': 1, 'n_phenotype': 9, 'n_behaviour': 5}. Best is trial 2 with value: 0.7311923805205759.
# Optuna Trials:   9%|▉         | 18/200 [1:33:00<27:55:37, 552.40s/it][I 2024-12-15 20:10:56,384] Trial 18 finished with value: 0.7356157498870526 and parameters: {'n_epochs': 2054, 'lr': 0.0004054590690027931, 'weight_decay': 3.103894983597698e-07, 'batch_size': 256, 'n_genotype': 4, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 18 with value: 0.7356157498870526.
# Optuna Trials:  10%|▉         | 19/200 [1:37:05<23:08:20, 460.22s/it][I 2024-12-15 20:12:43,061] Trial 19 finished with value: 0.7236830852060214 and parameters: {'n_epochs': 916, 'lr': 0.00450697951150122, 'weight_decay': 7.67325893618266e-07, 'batch_size': 256, 'n_genotype': 3, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 5}. Best is trial 18 with value: 0.7356157498870526.
# Optuna Trials:  10%|█         | 20/200 [1:38:52<17:42:13, 354.07s/it][I 2024-12-15 20:15:40,402] Trial 20 finished with value: 0.7100928858349971 and parameters: {'n_epochs': 1534, 'lr': 0.0004569579673966109, 'weight_decay': 2.905858629844029e-07, 'batch_size': 256, 'n_genotype': 1, 'n_history': 5, 'n_phenotype': 7, 'n_behaviour': 4}. Best is trial 18 with value: 0.7356157498870526.
# Optuna Trials:  10%|█         | 21/200 [1:41:49<14:58:03, 301.03s/it][I 2024-12-15 20:19:46,587] Trial 21 finished with value: 0.7226688191693893 and parameters: {'n_epochs': 2107, 'lr': 0.0006390133400227203, 'weight_decay': 3.274836969099782e-08, 'batch_size': 256, 'n_genotype': 5, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 18 with value: 0.7356157498870526.
# Optuna Trials:  11%|█         | 22/200 [1:45:55<14:04:12, 284.57s/it][I 2024-12-15 20:24:12,632] Trial 22 finished with value: 0.7246273918933758 and parameters: {'n_epochs': 2336, 'lr': 0.0002280524561626937, 'weight_decay': 1.5536420538886636e-07, 'batch_size': 256, 'n_genotype': 3, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 18 with value: 0.7356157498870526.
# Optuna Trials:  12%|█▏        | 23/200 [1:50:21<13:43:04, 279.01s/it][I 2024-12-15 20:27:33,518] Trial 23 finished with value: 0.7304763217784631 and parameters: {'n_epochs': 1719, 'lr': 0.0019529632055062607, 'weight_decay': 1.1941067057823054e-08, 'batch_size': 256, 'n_genotype': 3, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 3}. Best is trial 18 with value: 0.7356157498870526.
# Optuna Trials:  12%|█▏        | 24/200 [1:53:42<12:29:39, 255.57s/it][I 2024-12-15 20:30:51,187] Trial 24 finished with value: 0.7335010408353208 and parameters: {'n_epochs': 1709, 'lr': 0.0025354372591798436, 'weight_decay': 3.5611144510565474e-08, 'batch_size': 256, 'n_genotype': 4, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 3}. Best is trial 18 with value: 0.7356157498870526.
# Optuna Trials:  12%|█▎        | 25/200 [1:57:00<11:34:44, 238.20s/it][I 2024-12-15 20:45:30,369] Trial 25 finished with value: 0.7318959111935738 and parameters: {'n_epochs': 1852, 'lr': 0.0034777556694245856, 'weight_decay': 1.2673514458032876e-06, 'batch_size': 32, 'n_genotype': 5, 'n_history': 6, 'n_phenotype': 10, 'n_behaviour': 2}. Best is trial 18 with value: 0.7356157498870526.
# Optuna Trials:  13%|█▎        | 26/200 [2:11:39<20:48:28, 430.51s/it][I 2024-12-15 21:01:09,749] Trial 26 finished with value: 0.7259992494446512 and parameters: {'n_epochs': 1964, 'lr': 0.003553006800069984, 'weight_decay': 1.4927181992816196e-06, 'batch_size': 32, 'n_genotype': 6, 'n_history': 5, 'n_phenotype': 10, 'n_behaviour': 2}. Best is trial 18 with value: 0.7356157498870526.
# Optuna Trials:  14%|█▎        | 27/200 [2:27:19<28:01:30, 583.18s/it][I 2024-12-15 21:16:41,811] Trial 27 finished with value: 0.7333540698811721 and parameters: {'n_epochs': 1943, 'lr': 0.0033475675097702196, 'weight_decay': 7.03375197968575e-06, 'batch_size': 32, 'n_genotype': 8, 'n_history': 6, 'n_phenotype': 10, 'n_behaviour': 2}. Best is trial 18 with value: 0.7356157498870526.
# Optuna Trials:  14%|█▍        | 28/200 [2:42:51<32:51:50, 687.85s/it][I 2024-12-15 21:33:06,389] Trial 28 finished with value: 0.733781045763558 and parameters: {'n_epochs': 2048, 'lr': 0.0009672206798278637, 'weight_decay': 8.378773860426723e-06, 'batch_size': 32, 'n_genotype': 8, 'n_history': 5, 'n_phenotype': 8, 'n_behaviour': 2}. Best is trial 18 with value: 0.7356157498870526.
# Optuna Trials:  14%|█▍        | 29/200 [2:59:15<36:54:04, 776.87s/it][I 2024-12-15 21:41:10,264] Trial 29 finished with value: 0.729295469684863 and parameters: {'n_epochs': 2846, 'lr': 8.127074723656783e-05, 'weight_decay': 6.027516080898291e-07, 'batch_size': 128, 'n_genotype': 9, 'n_history': 5, 'n_phenotype': 8, 'n_behaviour': 3}. Best is trial 18 with value: 0.7356157498870526.
# Optuna Trials:  15%|█▌        | 30/200 [3:07:19<32:32:04, 688.97s/it][I 2024-12-15 21:43:04,038] Trial 30 finished with value: 0.7119975369863816 and parameters: {'n_epochs': 1320, 'lr': 0.00092364657442326, 'weight_decay': 0.0001394063494092344, 'batch_size': 512, 'n_genotype': 11, 'n_history': 4, 'n_phenotype': 2, 'n_behaviour': 3}. Best is trial 18 with value: 0.7356157498870526.
# Optuna Trials:  16%|█▌        | 31/200 [3:09:13<24:14:33, 516.41s/it][I 2024-12-15 21:58:56,213] Trial 31 finished with value: 0.728380222990568 and parameters: {'n_epochs': 1974, 'lr': 0.007799363434711742, 'weight_decay': 1.1710596359901269e-05, 'batch_size': 32, 'n_genotype': 8, 'n_history': 6, 'n_phenotype': 9, 'n_behaviour': 2}. Best is trial 18 with value: 0.7356157498870526.
# Optuna Trials:  16%|█▌        | 32/200 [3:25:05<30:11:59, 647.14s/it][I 2024-12-15 22:12:08,305] Trial 32 finished with value: 0.7358518776578724 and parameters: {'n_epochs': 1649, 'lr': 0.0027274255434090997, 'weight_decay': 7.4060342025347405e-06, 'batch_size': 32, 'n_genotype': 7, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 32 with value: 0.7358518776578724.
# Optuna Trials:  16%|█▋        | 33/200 [3:38:17<32:02:14, 690.63s/it][I 2024-12-15 22:25:02,142] Trial 33 finished with value: 0.73691876377084 and parameters: {'n_epochs': 1623, 'lr': 0.00031618003232209053, 'weight_decay': 1.2412655983084617e-05, 'batch_size': 32, 'n_genotype': 7, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  17%|█▋        | 34/200 [3:51:11<32:59:47, 715.59s/it][I 2024-12-15 22:37:35,412] Trial 34 finished with value: 0.7291030493542806 and parameters: {'n_epochs': 1575, 'lr': 0.0001260668762704771, 'weight_decay': 1.0070224029188084e-05, 'batch_size': 32, 'n_genotype': 9, 'n_history': 4, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  18%|█▊        | 35/200 [4:03:44<33:18:57, 726.89s/it][I 2024-12-15 22:48:56,227] Trial 35 finished with value: 0.7225388342419443 and parameters: {'n_epochs': 1391, 'lr': 0.0003727430126929144, 'weight_decay': 2.0786625066122855e-05, 'batch_size': 32, 'n_genotype': 7, 'n_history': 5, 'n_phenotype': 7, 'n_behaviour': 1}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  18%|█▊        | 36/200 [4:15:05<32:29:03, 713.07s/it][I 2024-12-15 22:58:02,680] Trial 36 finished with value: 0.7325206908096549 and parameters: {'n_epochs': 1120, 'lr': 0.001172637028666243, 'weight_decay': 8.387646409199229e-05, 'batch_size': 32, 'n_genotype': 7, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  18%|█▊        | 37/200 [4:24:11<30:01:22, 663.08s/it][I 2024-12-15 23:11:09,310] Trial 37 finished with value: 0.720130996841289 and parameters: {'n_epochs': 1642, 'lr': 0.0002819083619418613, 'weight_decay': 5.877102105134635e-06, 'batch_size': 32, 'n_genotype': 6, 'n_history': 4, 'n_phenotype': 8, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  19%|█▉        | 38/200 [4:37:18<31:30:24, 700.15s/it][I 2024-12-15 23:14:34,961] Trial 38 finished with value: 0.7204290396353448 and parameters: {'n_epochs': 2383, 'lr': 0.0007686758201967136, 'weight_decay': 1.955181322144743e-05, 'batch_size': 512, 'n_genotype': 9, 'n_history': 4, 'n_phenotype': 5, 'n_behaviour': 1}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  20%|█▉        | 39/200 [4:40:44<24:40:39, 551.80s/it][I 2024-12-15 23:20:28,836] Trial 39 finished with value: 0.7246946112243646 and parameters: {'n_epochs': 2033, 'lr': 3.571344592510507e-05, 'weight_decay': 2.309691869223889e-06, 'batch_size': 128, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  20%|██        | 40/200 [4:46:38<21:53:07, 492.42s/it][I 2024-12-15 23:34:42,328] Trial 40 finished with value: 0.701159963714467 and parameters: {'n_epochs': 1786, 'lr': 0.00013349986894309893, 'weight_decay': 0.00042985023921147876, 'batch_size': 32, 'n_genotype': 4, 'n_history': 5, 'n_phenotype': 6, 'n_behaviour': 1}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  20%|██        | 41/200 [5:00:51<26:31:58, 600.74s/it][I 2024-12-15 23:48:18,588] Trial 41 finished with value: 0.6873747590552621 and parameters: {'n_epochs': 1702, 'lr': 1.0381902110866255e-06, 'weight_decay': 1.6113113661695886e-05, 'batch_size': 32, 'n_genotype': 5, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 3}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  21%|██        | 42/200 [5:14:27<29:12:12, 665.40s/it][I 2024-12-15 23:55:22,595] Trial 42 finished with value: 0.7277541474427183 and parameters: {'n_epochs': 1505, 'lr': 0.0022512306323565394, 'weight_decay': 5.7167094259348465e-05, 'batch_size': 64, 'n_genotype': 4, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 3}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  22%|██▏       | 43/200 [5:21:31<25:51:37, 592.98s/it][I 2024-12-16 00:10:10,123] Trial 43 finished with value: 0.7329965558223492 and parameters: {'n_epochs': 1857, 'lr': 0.005306601294468835, 'weight_decay': 6.380237422693146e-06, 'batch_size': 32, 'n_genotype': 4, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  22%|██▏       | 44/200 [5:36:19<29:31:29, 681.35s/it][I 2024-12-16 00:13:25,365] Trial 44 finished with value: 0.7312047833884925 and parameters: {'n_epochs': 2227, 'lr': 0.0015313732590740705, 'weight_decay': 4.4540298834755605e-08, 'batch_size': 512, 'n_genotype': 6, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  22%|██▎       | 45/200 [5:39:34<23:03:24, 535.51s/it][I 2024-12-16 00:16:53,712] Trial 45 finished with value: 0.7331969224543842 and parameters: {'n_epochs': 1195, 'lr': 0.000801462112630377, 'weight_decay': 1.9880959477746124e-06, 'batch_size': 128, 'n_genotype': 7, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 3}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  23%|██▎       | 46/200 [5:43:02<18:42:34, 437.36s/it][I 2024-12-16 00:28:32,451] Trial 46 finished with value: 0.7263809668327479 and parameters: {'n_epochs': 1433, 'lr': 0.0027049012809295327, 'weight_decay': 3.172481394879597e-05, 'batch_size': 32, 'n_genotype': 2, 'n_history': 4, 'n_phenotype': 13, 'n_behaviour': 3}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  24%|██▎       | 47/200 [5:54:41<21:55:13, 515.78s/it][I 2024-12-16 00:35:45,253] Trial 47 finished with value: 0.7323156993844664 and parameters: {'n_epochs': 1582, 'lr': 0.001280594496780428, 'weight_decay': 1.4491403410422938e-07, 'batch_size': 64, 'n_genotype': 11, 'n_history': 5, 'n_phenotype': 10, 'n_behaviour': 1}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  24%|██▍       | 48/200 [6:01:54<20:43:34, 490.88s/it][I 2024-12-16 00:39:04,136] Trial 48 finished with value: 0.7298762385955818 and parameters: {'n_epochs': 1724, 'lr': 0.0003404791863487262, 'weight_decay': 3.913294052122094e-06, 'batch_size': 256, 'n_genotype': 8, 'n_history': 6, 'n_phenotype': 4, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  24%|██▍       | 49/200 [6:05:13<16:54:55, 403.28s/it][I 2024-12-16 00:55:16,567] Trial 49 finished with value: 0.7230569044295453 and parameters: {'n_epochs': 2017, 'lr': 0.005937442434078421, 'weight_decay': 2.4989198643312047e-08, 'batch_size': 32, 'n_genotype': 6, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 3}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  25%|██▌       | 50/200 [6:21:25<23:55:04, 574.03s/it][I 2024-12-16 01:00:02,094] Trial 50 finished with value: 0.7234623914638761 and parameters: {'n_epochs': 2500, 'lr': 0.000624734816332168, 'weight_decay': 7.034278215984993e-07, 'batch_size': 256, 'n_genotype': 2, 'n_history': 4, 'n_phenotype': 9, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  26%|██▌       | 51/200 [6:26:11<20:10:34, 487.48s/it][I 2024-12-16 01:15:30,356] Trial 51 finished with value: 0.7331364673665501 and parameters: {'n_epochs': 1920, 'lr': 0.0027772329465770022, 'weight_decay': 6.470678065049825e-06, 'batch_size': 32, 'n_genotype': 8, 'n_history': 6, 'n_phenotype': 10, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  26%|██▌       | 52/200 [6:41:39<25:28:37, 619.71s/it][I 2024-12-16 01:33:58,271] Trial 52 finished with value: 0.7339834205830675 and parameters: {'n_epochs': 2269, 'lr': 0.0014632877209983272, 'weight_decay': 4.579539669557253e-06, 'batch_size': 32, 'n_genotype': 7, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  26%|██▋       | 53/200 [7:00:07<31:17:07, 766.17s/it][I 2024-12-16 01:52:15,761] Trial 53 finished with value: 0.7276695093459634 and parameters: {'n_epochs': 2278, 'lr': 0.0014535926283841193, 'weight_decay': 1.2313715682176215e-05, 'batch_size': 32, 'n_genotype': 7, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  27%|██▋       | 54/200 [7:18:25<35:06:13, 865.57s/it][I 2024-12-16 02:09:42,340] Trial 54 finished with value: 0.7306490074192084 and parameters: {'n_epochs': 2159, 'lr': 0.00016958475883535623, 'weight_decay': 3.275120780952715e-06, 'batch_size': 32, 'n_genotype': 9, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  28%|██▊       | 55/200 [7:35:51<37:03:01, 919.87s/it][I 2024-12-16 02:13:44,321] Trial 55 finished with value: 0.7284104361264107 and parameters: {'n_epochs': 2093, 'lr': 0.0004880323755061065, 'weight_decay': 1.1115132512273502e-06, 'batch_size': 256, 'n_genotype': 5, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 3}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  28%|██▊       | 56/200 [7:39:53<28:39:36, 716.50s/it][I 2024-12-16 02:22:05,078] Trial 56 finished with value: 0.7345338446979535 and parameters: {'n_epochs': 1789, 'lr': 0.0010124632124273443, 'weight_decay': 6.234058716780138e-08, 'batch_size': 64, 'n_genotype': 7, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  28%|██▊       | 57/200 [7:48:14<25:53:24, 651.78s/it][I 2024-12-16 02:34:25,922] Trial 57 finished with value: 0.7344046077483023 and parameters: {'n_epochs': 2654, 'lr': 0.0009503714232188072, 'weight_decay': 6.87678202571607e-08, 'batch_size': 64, 'n_genotype': 7, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  29%|██▉       | 58/200 [8:00:35<26:45:46, 678.50s/it][I 2024-12-16 02:47:01,274] Trial 58 finished with value: 0.729475214288409 and parameters: {'n_epochs': 2692, 'lr': 0.0006051008722800747, 'weight_decay': 6.907453474725284e-08, 'batch_size': 64, 'n_genotype': 7, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  30%|██▉       | 59/200 [8:13:10<27:28:39, 701.56s/it][I 2024-12-16 02:58:43,313] Trial 59 finished with value: 0.7326488264855908 and parameters: {'n_epochs': 2577, 'lr': 0.0002215583396067209, 'weight_decay': 1.458786937444106e-07, 'batch_size': 64, 'n_genotype': 6, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  30%|███       | 60/200 [8:24:52<27:17:18, 701.70s/it][I 2024-12-16 03:11:53,870] Trial 60 finished with value: 0.73342246585501 and parameters: {'n_epochs': 2738, 'lr': 0.00035985083129456215, 'weight_decay': 4.372886410796083e-07, 'batch_size': 64, 'n_genotype': 7, 'n_history': 4, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  30%|███       | 61/200 [8:38:03<28:07:21, 728.36s/it][I 2024-12-16 03:23:07,180] Trial 61 finished with value: 0.7339792015014159 and parameters: {'n_epochs': 2455, 'lr': 0.0010479536055674223, 'weight_decay': 7.412072874363135e-08, 'batch_size': 64, 'n_genotype': 9, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  31%|███       | 62/200 [8:49:16<27:17:14, 711.84s/it][I 2024-12-16 03:34:28,173] Trial 62 finished with value: 0.7359914562265052 and parameters: {'n_epochs': 2444, 'lr': 0.0017337874935846286, 'weight_decay': 6.228521965813469e-08, 'batch_size': 64, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  32%|███▏      | 63/200 [9:00:37<26:44:14, 702.59s/it][I 2024-12-16 03:46:46,508] Trial 63 finished with value: 0.7336724500200393 and parameters: {'n_epochs': 2681, 'lr': 0.004272425574808948, 'weight_decay': 2.341752345505396e-07, 'batch_size': 64, 'n_genotype': 11, 'n_history': 5, 'n_phenotype': 10, 'n_behaviour': 2}. Best is trial 33 with value: 0.73691876377084.
# Optuna Trials:  32%|███▏      | 64/200 [9:12:55<26:56:50, 713.31s/it][I 2024-12-16 03:57:24,972] Trial 64 finished with value: 0.7378404212633194 and parameters: {'n_epochs': 2349, 'lr': 0.0018939134349252086, 'weight_decay': 5.694843688223696e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 64 with value: 0.7378404212633194.
# Optuna Trials:  32%|███▎      | 65/200 [9:23:34<25:54:25, 690.86s/it][I 2024-12-16 04:10:40,964] Trial 65 finished with value: 0.7412195502338925 and parameters: {'n_epochs': 2869, 'lr': 0.002067135023644032, 'weight_decay': 2.0374453044129235e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  33%|███▎      | 66/200 [9:36:50<26:53:21, 722.40s/it][I 2024-12-16 04:24:12,216] Trial 66 finished with value: 0.7352173383102837 and parameters: {'n_epochs': 2910, 'lr': 0.001824975754791312, 'weight_decay': 1.7963434603047687e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  34%|███▎      | 67/200 [9:50:21<27:40:24, 749.05s/it][I 2024-12-16 04:38:03,314] Trial 67 finished with value: 0.7313906914681735 and parameters: {'n_epochs': 2968, 'lr': 0.009124386007591478, 'weight_decay': 1.9394960624728885e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  34%|███▍      | 68/200 [10:04:12<28:22:04, 773.67s/it][I 2024-12-16 04:51:11,206] Trial 68 finished with value: 0.7365667334748209 and parameters: {'n_epochs': 2845, 'lr': 0.0019801813154439337, 'weight_decay': 1.0224530012952642e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  34%|███▍      | 69/200 [10:17:20<28:18:29, 777.93s/it][I 2024-12-16 05:05:37,736] Trial 69 finished with value: 0.7176702135927674 and parameters: {'n_epochs': 2841, 'lr': 5.116386806997484e-06, 'weight_decay': 3.497388259042904e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  35%|███▌      | 70/200 [10:31:47<29:03:06, 804.51s/it][I 2024-12-16 05:18:53,563] Trial 70 finished with value: 0.7358931690130801 and parameters: {'n_epochs': 2779, 'lr': 0.004550992199888775, 'weight_decay': 1.3154870699088276e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  36%|███▌      | 71/200 [10:45:02<28:44:06, 801.91s/it][I 2024-12-16 05:31:55,311] Trial 71 finished with value: 0.7380224230656125 and parameters: {'n_epochs': 2796, 'lr': 0.004111658044650235, 'weight_decay': 1.4720326775282428e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  36%|███▌      | 72/200 [10:58:04<28:17:50, 795.86s/it][I 2024-12-16 05:44:45,686] Trial 72 finished with value: 0.7362698612622866 and parameters: {'n_epochs': 2788, 'lr': 0.004252466964693495, 'weight_decay': 1.0662039877562459e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  36%|███▋      | 73/200 [11:10:54<27:48:23, 788.21s/it][I 2024-12-16 05:57:43,108] Trial 73 finished with value: 0.7323028089274384 and parameters: {'n_epochs': 2822, 'lr': 0.004036922049032917, 'weight_decay': 1.1857698937821238e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  37%|███▋      | 74/200 [11:23:52<27:28:27, 784.98s/it][I 2024-12-16 06:10:25,417] Trial 74 finished with value: 0.7327956148546588 and parameters: {'n_epochs': 2751, 'lr': 0.007104650149135222, 'weight_decay': 1.0310982208235451e-08, 'batch_size': 64, 'n_genotype': 15, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  38%|███▊      | 75/200 [11:36:34<27:01:12, 778.18s/it][I 2024-12-16 06:23:50,208] Trial 75 finished with value: 0.7351450280600925 and parameters: {'n_epochs': 2928, 'lr': 0.0020480081154363203, 'weight_decay': 1.7332453510296384e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  38%|███▊      | 76/200 [11:49:59<27:04:43, 786.16s/it][I 2024-12-16 06:36:08,906] Trial 76 finished with value: 0.7326184284295656 and parameters: {'n_epochs': 2617, 'lr': 0.004908084420206769, 'weight_decay': 2.6954353950877503e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  38%|███▊      | 77/200 [12:02:18<26:22:26, 771.92s/it][I 2024-12-16 06:47:52,804] Trial 77 finished with value: 0.7343425760196637 and parameters: {'n_epochs': 2519, 'lr': 0.003170514385088833, 'weight_decay': 1.4913191960294815e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  39%|███▉      | 78/200 [12:14:02<25:28:04, 751.51s/it][I 2024-12-16 07:00:51,874] Trial 78 finished with value: 0.7295130939109625 and parameters: {'n_epochs': 2781, 'lr': 0.006136498621429295, 'weight_decay': 2.487109189713775e-08, 'batch_size': 64, 'n_genotype': 15, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  40%|███▉      | 79/200 [12:27:01<25:32:13, 759.78s/it][I 2024-12-16 07:14:06,029] Trial 79 finished with value: 0.7367330411081718 and parameters: {'n_epochs': 2886, 'lr': 0.009478043737124877, 'weight_decay': 4.9751791600772693e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  40%|████      | 80/200 [12:40:15<25:40:11, 770.09s/it][I 2024-12-16 07:27:35,021] Trial 80 finished with value: 0.7339189911521148 and parameters: {'n_epochs': 2916, 'lr': 0.009202464390375854, 'weight_decay': 4.669999009361753e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  40%|████      | 81/200 [12:53:44<25:50:29, 781.76s/it][I 2024-12-16 07:41:00,252] Trial 81 finished with value: 0.7368971303948937 and parameters: {'n_epochs': 2994, 'lr': 0.0037642842920241285, 'weight_decay': 1.0507731590067732e-07, 'batch_size': 64, 'n_genotype': 14, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  41%|████      | 82/200 [13:07:09<25:51:18, 788.80s/it][I 2024-12-16 07:54:21,333] Trial 82 finished with value: 0.7342961538001092 and parameters: {'n_epochs': 2873, 'lr': 0.007544771169332761, 'weight_decay': 1.0805512797283177e-07, 'batch_size': 64, 'n_genotype': 13, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  42%|████▏     | 83/200 [13:20:30<25:45:20, 792.49s/it][I 2024-12-16 08:08:05,487] Trial 83 finished with value: 0.714548466389456 and parameters: {'n_epochs': 2995, 'lr': 0.0017993308227243138, 'weight_decay': 2.318235105570308e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 1, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  42%|████▏     | 84/200 [13:34:14<25:50:30, 801.99s/it][I 2024-12-16 08:20:34,375] Trial 84 finished with value: 0.7349260181746988 and parameters: {'n_epochs': 2729, 'lr': 0.0037446516357633264, 'weight_decay': 4.3499349342017955e-08, 'batch_size': 64, 'n_genotype': 15, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  42%|████▎     | 85/200 [13:46:43<25:06:36, 786.06s/it][I 2024-12-16 08:33:39,960] Trial 85 finished with value: 0.7369547547432533 and parameters: {'n_epochs': 2823, 'lr': 0.0024598394503835904, 'weight_decay': 1.0110004740435067e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  43%|████▎     | 86/200 [13:59:49<24:53:14, 785.92s/it][I 2024-12-16 08:37:44,996] Trial 86 finished with value: 0.7261642330256468 and parameters: {'n_epochs': 2835, 'lr': 0.002433360786860535, 'weight_decay': 3.1714251615141656e-08, 'batch_size': 512, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 65 with value: 0.7412195502338925.
# Optuna Trials:  44%|████▎     | 87/200 [14:03:54<19:34:32, 623.65s/it][I 2024-12-16 08:45:40,095] Trial 87 finished with value: 0.7426839416060658 and parameters: {'n_epochs': 2624, 'lr': 0.0031059218082262457, 'weight_decay': 1.4926415051283617e-08, 'batch_size': 128, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  44%|████▍     | 88/200 [14:11:49<18:00:57, 579.09s/it][I 2024-12-16 08:53:17,426] Trial 88 finished with value: 0.7189747618867964 and parameters: {'n_epochs': 2624, 'lr': 2.3241944209721982e-05, 'weight_decay': 1.0955262369696514e-07, 'batch_size': 128, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 3}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  44%|████▍     | 89/200 [14:19:26<16:43:44, 542.56s/it][I 2024-12-16 09:01:49,548] Trial 89 finished with value: 0.7325396396135574 and parameters: {'n_epochs': 2944, 'lr': 0.0057692290164557585, 'weight_decay': 1.9578977409683663e-08, 'batch_size': 128, 'n_genotype': 15, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  45%|████▌     | 90/200 [14:27:58<16:17:57, 533.43s/it][I 2024-12-16 09:10:11,728] Trial 90 finished with value: 0.7350849597048488 and parameters: {'n_epochs': 2881, 'lr': 0.0031191908332007198, 'weight_decay': 1.5144021518457488e-08, 'batch_size': 128, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  46%|████▌     | 91/200 [14:36:21<15:52:01, 524.05s/it][I 2024-12-16 09:23:05,820] Trial 91 finished with value: 0.7373769228499405 and parameters: {'n_epochs': 2803, 'lr': 0.002498156935857255, 'weight_decay': 1.0164856741473674e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  46%|████▌     | 92/200 [14:49:15<17:58:19, 599.07s/it][I 2024-12-16 09:30:29,650] Trial 92 finished with value: 0.7322139726158985 and parameters: {'n_epochs': 2547, 'lr': 0.0023473628406364745, 'weight_decay': 1.0078746897632817e-08, 'batch_size': 128, 'n_genotype': 14, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  46%|████▋     | 93/200 [14:56:38<16:25:16, 552.49s/it][I 2024-12-16 09:43:06,998] Trial 93 finished with value: 0.7342423676634064 and parameters: {'n_epochs': 2708, 'lr': 0.0031519557757107818, 'weight_decay': 3.180659997290735e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  47%|████▋     | 94/200 [15:09:16<18:04:38, 613.95s/it][I 2024-12-16 09:56:47,535] Trial 94 finished with value: 0.7324962883011731 and parameters: {'n_epochs': 2987, 'lr': 0.005284290851614539, 'weight_decay': 2.1678014888331205e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  48%|████▊     | 95/200 [15:22:56<19:42:52, 675.93s/it][I 2024-12-16 10:10:03,231] Trial 95 finished with value: 0.7389398952608905 and parameters: {'n_epochs': 2881, 'lr': 0.002142106057080936, 'weight_decay': 1.393507177415509e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  48%|████▊     | 96/200 [15:36:12<20:33:53, 711.86s/it][I 2024-12-16 10:23:20,713] Trial 96 finished with value: 0.7373601450944365 and parameters: {'n_epochs': 2895, 'lr': 0.007473971682483372, 'weight_decay': 1.4737509675458334e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  48%|████▊     | 97/200 [15:49:29<21:06:07, 737.54s/it][I 2024-12-16 10:30:56,282] Trial 97 finished with value: 0.7351565874097771 and parameters: {'n_epochs': 2639, 'lr': 0.001418384833074781, 'weight_decay': 1.49554333567352e-08, 'batch_size': 128, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  49%|████▉     | 98/200 [15:57:05<18:30:01, 652.95s/it][I 2024-12-16 10:34:53,737] Trial 98 finished with value: 0.7194832999407825 and parameters: {'n_epochs': 2799, 'lr': 0.0071578469638639885, 'weight_decay': 1.431412434746147e-08, 'batch_size': 512, 'n_genotype': 15, 'n_history': 3, 'n_phenotype': 11, 'n_behaviour': 3}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  50%|████▉     | 99/200 [16:01:03<14:49:18, 528.30s/it][I 2024-12-16 10:47:23,676] Trial 99 finished with value: 0.740510842491344 and parameters: {'n_epochs': 2710, 'lr': 0.0012166723976326154, 'weight_decay': 3.0058875253533665e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  50%|█████     | 100/200 [16:13:32<16:31:19, 594.79s/it][I 2024-12-16 10:58:28,371] Trial 100 finished with value: 0.7355740028392294 and parameters: {'n_epochs': 2374, 'lr': 0.0011904851161190578, 'weight_decay': 2.9232631628851804e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 10, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  50%|█████     | 101/200 [16:24:37<16:56:00, 615.76s/it][I 2024-12-16 11:12:06,698] Trial 101 finished with value: 0.7339322694347595 and parameters: {'n_epochs': 2943, 'lr': 0.0026790444720688204, 'weight_decay': 3.784179245182715e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  51%|█████     | 102/200 [16:38:15<18:25:00, 676.53s/it][I 2024-12-16 11:24:30,835] Trial 102 finished with value: 0.7390577812314231 and parameters: {'n_epochs': 2721, 'lr': 0.0007842243865542433, 'weight_decay': 1.8976942794890846e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  52%|█████▏    | 103/200 [16:50:40<18:46:30, 696.81s/it][I 2024-12-16 11:35:03,093] Trial 103 finished with value: 0.7335452864419789 and parameters: {'n_epochs': 2596, 'lr': 0.0008572197782590862, 'weight_decay': 2.133190420913327e-08, 'batch_size': 64, 'n_genotype': 11, 'n_history': 3, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  52%|█████▏    | 104/200 [17:01:12<18:03:54, 677.45s/it][I 2024-12-16 11:45:37,355] Trial 104 finished with value: 0.7375989984754707 and parameters: {'n_epochs': 2681, 'lr': 0.0016442210091748538, 'weight_decay': 1.7779590255018376e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  52%|█████▎    | 105/200 [17:11:46<17:32:06, 664.49s/it][I 2024-12-16 11:55:53,353] Trial 105 finished with value: 0.738516836735205 and parameters: {'n_epochs': 2681, 'lr': 0.0016541936821045428, 'weight_decay': 1.616152896947008e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  53%|█████▎    | 106/200 [17:22:02<16:58:14, 649.94s/it][I 2024-12-16 12:06:26,443] Trial 106 finished with value: 0.7341961086028741 and parameters: {'n_epochs': 2672, 'lr': 0.0011765175361478967, 'weight_decay': 1.5752281686694793e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  54%|█████▎    | 107/200 [17:32:35<16:39:34, 644.89s/it][I 2024-12-16 12:16:57,880] Trial 107 finished with value: 0.7380343228433172 and parameters: {'n_epochs': 2706, 'lr': 0.0007492186511186153, 'weight_decay': 2.4963155347238996e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  54%|█████▍    | 108/200 [17:43:07<16:22:38, 640.85s/it][I 2024-12-16 12:26:50,246] Trial 108 finished with value: 0.7370486941960175 and parameters: {'n_epochs': 2515, 'lr': 0.0007360938886232219, 'weight_decay': 2.662517962364579e-08, 'batch_size': 64, 'n_genotype': 11, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  55%|█████▍    | 109/200 [17:52:59<15:49:53, 626.31s/it][I 2024-12-16 12:37:13,467] Trial 109 finished with value: 0.7388552430541594 and parameters: {'n_epochs': 2725, 'lr': 0.000594420381725291, 'weight_decay': 3.8973319593371124e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  55%|█████▌    | 110/200 [18:03:22<15:38:04, 625.38s/it][I 2024-12-16 12:47:54,734] Trial 110 finished with value: 0.7349131983669185 and parameters: {'n_epochs': 2746, 'lr': 0.0006158289724487692, 'weight_decay': 5.061182285585113e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  56%|█████▌    | 111/200 [18:14:04<15:34:43, 630.15s/it][I 2024-12-16 12:58:16,038] Trial 111 finished with value: 0.736552536056395 and parameters: {'n_epochs': 2691, 'lr': 0.0016225667961427559, 'weight_decay': 2.0261193772695017e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  56%|█████▌    | 112/200 [18:24:25<15:20:19, 627.49s/it][I 2024-12-16 13:08:24,311] Trial 112 finished with value: 0.7360998183604862 and parameters: {'n_epochs': 2587, 'lr': 0.001365118442006247, 'weight_decay': 3.615008633696358e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  56%|█████▋    | 113/200 [18:34:33<15:01:30, 621.73s/it][I 2024-12-16 13:19:14,734] Trial 113 finished with value: 0.7331603628101788 and parameters: {'n_epochs': 2753, 'lr': 0.0005473464966067526, 'weight_decay': 1.863991957561255e-08, 'batch_size': 64, 'n_genotype': 11, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  57%|█████▋    | 114/200 [18:45:24<15:03:28, 630.34s/it][I 2024-12-16 13:28:50,421] Trial 114 finished with value: 0.7350993004090907 and parameters: {'n_epochs': 2459, 'lr': 0.0007412813636137722, 'weight_decay': 1.27019364661717e-08, 'batch_size': 64, 'n_genotype': 11, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  57%|█████▊    | 115/200 [18:54:59<14:29:45, 613.94s/it][I 2024-12-16 13:38:46,991] Trial 115 finished with value: 0.7270249702979037 and parameters: {'n_epochs': 2555, 'lr': 0.002033911526182154, 'weight_decay': 2.5706715993771888e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 6, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  58%|█████▊    | 116/200 [19:04:56<14:12:13, 608.73s/it][I 2024-12-16 13:49:20,906] Trial 116 finished with value: 0.7299546194146692 and parameters: {'n_epochs': 2678, 'lr': 0.0015637183155325421, 'weight_decay': 5.8032505664331135e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 4, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  58%|█████▊    | 117/200 [19:15:30<14:12:31, 616.29s/it][I 2024-12-16 13:59:50,366] Trial 117 finished with value: 0.731728630468687 and parameters: {'n_epochs': 2632, 'lr': 0.0010409048761670953, 'weight_decay': 3.1945528442381474e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  59%|█████▉    | 118/200 [19:25:59<14:07:39, 620.24s/it][I 2024-12-16 14:06:23,893] Trial 118 finished with value: 0.7337932121403222 and parameters: {'n_epochs': 2717, 'lr': 0.0021669396301235233, 'weight_decay': 3.7692660418059884e-08, 'batch_size': 128, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  60%|█████▉    | 119/200 [19:32:33<12:25:30, 552.22s/it][I 2024-12-16 14:16:14,388] Trial 119 finished with value: 0.7348564109786331 and parameters: {'n_epochs': 2487, 'lr': 0.001237091415578364, 'weight_decay': 1.714794714700826e-08, 'batch_size': 64, 'n_genotype': 11, 'n_history': 4, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  60%|██████    | 120/200 [19:42:23<12:31:36, 563.71s/it][I 2024-12-16 14:27:13,870] Trial 120 finished with value: 0.731743046889844 and parameters: {'n_epochs': 2794, 'lr': 0.0004096741355268803, 'weight_decay': 8.998051202918958e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 3, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  60%|██████    | 121/200 [19:53:23<13:00:02, 592.44s/it][I 2024-12-16 14:30:44,354] Trial 121 finished with value: 0.7382831593306951 and parameters: {'n_epochs': 865, 'lr': 0.002911452833659372, 'weight_decay': 1.3719915290956245e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# Optuna Trials:  61%|██████    | 122/200 [19:56:53<10:21:12, 477.85s/it][I 2024-12-16 14:41:48,958] Trial 122 finished with value: 0.7331758795113907 and parameters: {'n_epochs': 2846, 'lr': 0.003023464530794747, 'weight_decay': 1.3180011127085731e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 87 with value: 0.7426839416060658.
# ...
# Optuna Trials:  81%|████████  | 162/200 [22:41:28<2:45:24, 261.17s/it][I 2024-12-16 17:19:48,849] Trial 162 finished with value: 0.7318121353952308 and parameters: {'n_epochs': 2290, 'lr': 0.0005913972890218673, 'weight_decay': 1.529954154678192e-08, 'batch_size': 128, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  82%|████████▏ | 163/200 [22:45:58<2:42:40, 263.79s/it][I 2024-12-16 17:24:08,475] Trial 163 finished with value: 0.7293047483854173 and parameters: {'n_epochs': 2319, 'lr': 0.00034934040862496276, 'weight_decay': 3.455220178191015e-08, 'batch_size': 128, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  82%|████████▏ | 164/200 [22:50:17<2:37:31, 262.54s/it][I 2024-12-16 17:27:33,587] Trial 164 finished with value: 0.7384861057036117 and parameters: {'n_epochs': 2188, 'lr': 0.0004879477036710159, 'weight_decay': 2.0094172793675896e-08, 'batch_size': 128, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  82%|████████▎ | 165/200 [22:53:42<2:23:05, 245.31s/it][I 2024-12-16 17:30:51,343] Trial 165 finished with value: 0.7354770901561031 and parameters: {'n_epochs': 2137, 'lr': 0.001313692845043831, 'weight_decay': 1.8347938687839613e-08, 'batch_size': 128, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  83%|████████▎ | 166/200 [22:57:00<2:10:55, 231.05s/it][I 2024-12-16 17:37:19,132] Trial 166 finished with value: 0.7349490907682297 and parameters: {'n_epochs': 2650, 'lr': 0.0004326816142458238, 'weight_decay': 1.3016471579220929e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  84%|████████▎ | 167/200 [23:03:28<2:32:56, 278.07s/it][I 2024-12-16 17:43:05,988] Trial 167 finished with value: 0.7411483164159091 and parameters: {'n_epochs': 2417, 'lr': 0.0007187822366029737, 'weight_decay': 2.535837134269636e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  84%|████████▍ | 168/200 [23:09:15<2:39:18, 298.71s/it][I 2024-12-16 17:49:24,312] Trial 168 finished with value: 0.73733067700509 and parameters: {'n_epochs': 2540, 'lr': 0.0007402718337975318, 'weight_decay': 2.2706836500128817e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  84%|████████▍ | 169/200 [23:15:33<2:46:40, 322.59s/it][I 2024-12-16 17:53:07,767] Trial 169 finished with value: 0.7337529269655383 and parameters: {'n_epochs': 2384, 'lr': 0.0010185433803289814, 'weight_decay': 2.7749101701115122e-08, 'batch_size': 128, 'n_genotype': 14, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  85%|████████▌ | 170/200 [23:19:17<2:26:25, 292.85s/it][I 2024-12-16 17:59:03,928] Trial 170 finished with value: 0.7407898528649826 and parameters: {'n_epochs': 2418, 'lr': 0.0008762365818654828, 'weight_decay': 4.172669709885687e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  86%|████████▌ | 171/200 [23:25:13<2:30:43, 311.84s/it][I 2024-12-16 18:05:16,069] Trial 171 finished with value: 0.7405032036283895 and parameters: {'n_epochs': 2480, 'lr': 0.0008153026450247602, 'weight_decay': 4.347934984162952e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  86%|████████▌ | 172/200 [23:31:25<2:33:58, 329.93s/it][I 2024-12-16 18:11:12,016] Trial 172 finished with value: 0.7377185051059592 and parameters: {'n_epochs': 2417, 'lr': 0.0008824277343095178, 'weight_decay': 4.5109210731601055e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  86%|████████▋ | 173/200 [23:37:21<2:31:58, 337.74s/it][I 2024-12-16 18:17:01,866] Trial 173 finished with value: 0.7355799031941155 and parameters: {'n_epochs': 2336, 'lr': 0.0005411069212406857, 'weight_decay': 3.525269471298309e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  87%|████████▋ | 174/200 [23:43:11<2:27:55, 341.37s/it][I 2024-12-16 18:22:53,363] Trial 174 finished with value: 0.7345878122770275 and parameters: {'n_epochs': 2425, 'lr': 0.001173406957405239, 'weight_decay': 7.187066798913255e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  88%|████████▊ | 175/200 [23:49:02<2:23:30, 344.41s/it][I 2024-12-16 18:29:01,284] Trial 175 finished with value: 0.7371353040129138 and parameters: {'n_epochs': 2492, 'lr': 0.0014981873558508887, 'weight_decay': 4.1998281063705166e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  88%|████████▊ | 176/200 [23:55:10<2:20:35, 351.46s/it][I 2024-12-16 18:34:28,595] Trial 176 finished with value: 0.733553368676161 and parameters: {'n_epochs': 2214, 'lr': 4.8259081364765985e-05, 'weight_decay': 1.9074967492391293e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  88%|████████▊ | 177/200 [24:00:37<2:11:56, 344.22s/it][I 2024-12-16 18:40:29,180] Trial 177 finished with value: 0.7372706913223837 and parameters: {'n_epochs': 2479, 'lr': 0.0017469329482356008, 'weight_decay': 3.155537551910735e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  89%|████████▉ | 178/200 [24:06:38<2:08:00, 349.13s/it][I 2024-12-16 18:46:31,552] Trial 178 finished with value: 0.7336333390536369 and parameters: {'n_epochs': 2437, 'lr': 0.0008653682385480991, 'weight_decay': 1.8027898808839138e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 4, 'n_phenotype': 7, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  90%|████████▉ | 179/200 [24:12:40<2:03:35, 353.10s/it][I 2024-12-16 18:52:43,092] Trial 179 finished with value: 0.7372993310965007 and parameters: {'n_epochs': 2558, 'lr': 0.0011845368655529769, 'weight_decay': 5.051948256563933e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  90%|█████████ | 180/200 [24:18:52<1:59:32, 358.63s/it][I 2024-12-16 18:53:58,970] Trial 180 finished with value: 0.7278580504267183 and parameters: {'n_epochs': 809, 'lr': 0.00033680330335691895, 'weight_decay': 2.4532367687570897e-08, 'batch_size': 128, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  90%|█████████ | 181/200 [24:20:08<1:26:42, 273.81s/it][I 2024-12-16 18:59:53,372] Trial 181 finished with value: 0.7426289546308855 and parameters: {'n_epochs': 2390, 'lr': 0.0006926891677558881, 'weight_decay': 2.526144518681637e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  91%|█████████ | 182/200 [24:26:02<1:29:23, 297.98s/it][I 2024-12-16 19:05:43,869] Trial 182 finished with value: 0.7285519509415121 and parameters: {'n_epochs': 2403, 'lr': 0.0004626158066735672, 'weight_decay': 1.2683754624139312e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 5, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  92%|█████████▏| 183/200 [24:31:53<1:28:53, 313.74s/it][I 2024-12-16 19:11:28,803] Trial 183 finished with value: 0.7362465647970893 and parameters: {'n_epochs': 2363, 'lr': 0.0007552890565431249, 'weight_decay': 2.9259305150698473e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  92%|█████████▏| 184/200 [24:37:38<1:26:09, 323.10s/it][I 2024-12-16 19:13:43,092] Trial 184 finished with value: 0.7342406410792621 and parameters: {'n_epochs': 901, 'lr': 0.0005579440034692724, 'weight_decay': 2.1322415158366194e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  92%|█████████▎| 185/200 [24:39:52<1:06:36, 266.45s/it][I 2024-12-16 19:16:25,808] Trial 185 finished with value: 0.7314060485875403 and parameters: {'n_epochs': 2508, 'lr': 0.0006960275965451633, 'weight_decay': 3.805263385287684e-08, 'batch_size': 256, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  93%|█████████▎| 186/200 [24:42:35<54:54, 235.33s/it]  [I 2024-12-16 19:22:27,524] Trial 186 finished with value: 0.7367227465886887 and parameters: {'n_epochs': 2439, 'lr': 0.000989410338252906, 'weight_decay': 1.5520337756412963e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  94%|█████████▎| 187/200 [24:48:36<59:12, 273.25s/it][I 2024-12-16 19:28:48,792] Trial 187 finished with value: 0.7341179114122107 and parameters: {'n_epochs': 2585, 'lr': 0.002059125281555809, 'weight_decay': 1.0161888071453642e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  94%|█████████▍| 188/200 [24:54:58<1:01:07, 305.65s/it][I 2024-12-16 19:34:22,152] Trial 188 finished with value: 0.7376695117903677 and parameters: {'n_epochs': 2266, 'lr': 0.0014151502569450679, 'weight_decay': 2.6512618516883507e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  94%|█████████▍| 189/200 [25:00:31<57:33, 313.97s/it]  [I 2024-12-16 19:36:15,862] Trial 189 finished with value: 0.7347530605691283 and parameters: {'n_epochs': 2348, 'lr': 0.0006271440951558533, 'weight_decay': 0.0009227815335788976, 'batch_size': 512, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  95%|█████████▌| 190/200 [25:02:25<42:18, 253.89s/it][I 2024-12-16 19:42:43,679] Trial 190 finished with value: 0.7033570837224308 and parameters: {'n_epochs': 2634, 'lr': 3.2182601954847738e-06, 'weight_decay': 8.338167228347656e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  96%|█████████▌| 191/200 [25:08:52<44:06, 294.07s/it][I 2024-12-16 19:49:25,031] Trial 191 finished with value: 0.7361665093622911 and parameters: {'n_epochs': 2706, 'lr': 0.0008583815901311743, 'weight_decay': 2.22302262974604e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  96%|█████████▌| 192/200 [25:15:34<43:30, 326.25s/it][I 2024-12-16 19:55:57,294] Trial 192 finished with value: 0.7332555710677853 and parameters: {'n_epochs': 2663, 'lr': 0.000513367413056985, 'weight_decay': 1.77705625506481e-08, 'batch_size': 64, 'n_genotype': 11, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  96%|█████████▋| 193/200 [25:22:06<40:22, 346.06s/it][I 2024-12-16 20:02:42,605] Trial 193 finished with value: 0.732019787246518 and parameters: {'n_epochs': 2776, 'lr': 0.0006832910596773115, 'weight_decay': 2.5481644633452976e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  97%|█████████▋| 194/200 [25:28:51<36:22, 363.83s/it][I 2024-12-16 20:08:11,053] Trial 194 finished with value: 0.7431681292193698 and parameters: {'n_epochs': 2201, 'lr': 0.002586849587758849, 'weight_decay': 4.244834329042942e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  98%|█████████▊| 195/200 [25:34:20<29:26, 353.22s/it][I 2024-12-16 20:13:41,702] Trial 195 finished with value: 0.7368216146959276 and parameters: {'n_epochs': 2203, 'lr': 0.002619261163899841, 'weight_decay': 5.3972008957936617e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  98%|█████████▊| 196/200 [25:39:50<23:05, 346.45s/it][I 2024-12-16 20:18:43,992] Trial 196 finished with value: 0.734371289026545 and parameters: {'n_epochs': 2080, 'lr': 0.001743377416656384, 'weight_decay': 4.1702306765210216e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  98%|█████████▊| 197/200 [25:44:53<16:39, 333.20s/it][I 2024-12-16 20:22:06,071] Trial 197 finished with value: 0.7186336482409772 and parameters: {'n_epochs': 2157, 'lr': 1.1790813856220078e-05, 'weight_decay': 3.307492523066364e-08, 'batch_size': 128, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials:  99%|█████████▉| 198/200 [25:48:15<09:47, 293.86s/it][I 2024-12-16 20:27:43,832] Trial 198 finished with value: 0.7351477549620652 and parameters: {'n_epochs': 2317, 'lr': 0.0031825862824345578, 'weight_decay': 6.33876487347418e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials: 100%|█████████▉| 199/200 [25:53:53<05:07, 307.03s/it][I 2024-12-16 20:33:38,880] Trial 199 finished with value: 0.7393743454064015 and parameters: {'n_epochs': 2404, 'lr': 0.0022606662547180563, 'weight_decay': 1.3776346146049517e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 150 with value: 0.7433285096690063.
# Optuna Trials: 100%|██████████| 200/200 [25:59:48<00:00, 467.94s/it]
# Number of finished trials:  200
# Best trial:
#   Value (Mean AUC):  0.7433285096690063
#   Params:
#     n_epochs: 1175
#     lr: 0.0004464002613441988
#     weight_decay: 1.4153526263149175e-08
#     batch_size: 128
#     n_genotype: 10
#     n_history: 3
#     n_phenotype: 13
#     n_behaviour: 2
#
# Best Trial Metrics:
# Selected Features: ['class1_SNP_risk_score', 'rs9340799', 'rs591058', 'rs1800795', 'rs13946', 'rs4789932', 'rs650108', 'rs11225395', 'rs1800012', 'rs12722', 'tracking_period_injury', 'average_run_hours', 'average_interval_training_frequency', 'Duty_factor_12', 'Impact_peak_12', 'Q_angle', 'Q_angle_asymmetry', 'navicular_drop', 'total_ad_ab_ratio', 'knee_flexion_peak_torque', 'navicular_drop_asymmetry', 'knee_extension_peak_torque', 'BMI', 'hip_abduction_peak_torque', 'VALR_12', 'BMD_spine', 'non_running_past_season', 'fat_intake_avg']
# Average AUC: 0.7433 ± 0.0368
# Average F1 Score: 0.0718 ± 0.0559
# Average Accuracy: 0.9073 ± 0.0049
# Average Precision: 0.3878 ± 0.3015

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score, precision_score
from imblearn.over_sampling import RandomOverSampler, ADASYN, SMOTE
import optuna
from joblib import Parallel, delayed
from tqdm import tqdm
import random
import warnings
from optuna.exceptions import TrialPruned

import os

# Limit each parallel process to one thread per library
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'
os.environ['NUMEXPR_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['VECLIB_MAXIMUM_THREADS'] = '1'
os.environ['TORCH_NUM_THREADS'] = '1'  # For PyTorch

# Additional control for PyTorch if needed
import torch
torch.set_num_threads(1)

# # For reproducibility
# def set_seed(seed=42):
#     random.seed(seed)
#     np.random.seed(seed)
#     torch.manual_seed(seed)

# set_seed()

# Suppress warnings for cleaner output
warnings.filterwarnings("ignore")

# Load the dataset
data = pd.read_excel("class1_dataset.xlsx")

# Define feature groups (as provided)
feature_groups = {
    'Genotype': [
        'rs11225395', 'rs1144393', 'rs650108', 'rs591058', 'rs2252070', 'rs4986938', 'rs1800012', 'rs4789932', 'rs9340799', 'rs970547', 
        'rs1800795', 'rs13946', 'rs12722', 'class1_SNP_risk_score', 'rs7528684', 'rs4919510', 'rs1937810', 'rs6481512', 'rs1249269', 
        'rs12574452', 'rs12429486', 'rs4454832', 'rs2761884', 'rs62051384', 'rs4362400', 'rs2586488', 'rs2277698', 'rs1045485', 
        'rs143383', 'rs17576', 'rs2305948', 'rs1011814', 'rs11154027', 'rs2234693', 'rs1643821', 'rs2010963', 'rs10263021', 'rs149047058', 
        'rs420257', 'rs42517', 'rs42522', 'rs42531', 'rs413826', 'rs2104772', 'rs1330363', 'class12_SNP_risk_score', 'rs3753841', 
        'rs57104447', 'rs1887632', 'rs4654760', 'rs1137101', 'rs2306033', 'rs2277268', 'rs4988321', 'rs11232681', 'rs1718119', 'rs3751143', 
        'rs1544410', 'rs2228570', 'rs4328262', 'rs1021188', 'rs74544784', 'rs78391032', 'rs77569527', 'rs117544024', 'rs912336', 
        'rs3218791', 'rs911263', 'rs2525504', 'rs17756404', 'rs4903399', 'rs10132091', 'rs17583842', 'rs1676303', 'rs11629171', 
        'rs2281518', 'rs2285053', 'rs71404070', 'rs710079', 'rs2858056', 'rs820218', 'rs3018362', 'rs1800470', 'rs1800469', 'rs25487', 
        'rs25489', 'rs2289360', 'rs183364169', 'rs11177', 'rs6617', 'rs3219008', 'rs13107325', 'rs60713544', 'rs145648292', 'rs4244032', 
        'rs12656106', 'rs3045', 'rs187483', 'rs4701616', 'rs144414988', 'rs1800629', 'rs10484958', 'rs4730153', 'rs1800797', 'rs1554606', 
        'rs2237352', 'rs4725069', 'rs12154667', 'rs1548456', 'rs3216902', 'rs35360670', 'rs13317', 'rs1800972', 'rs7035322', 'rs7021589', 
        'rs72758637', 'rs10759753', 'rs3789870', 'rs1138545', 'rs3196378', 'rs1134170', 'rs10992075', 'rs1590', 'rs144371252', 
        'rs761804508', 'class123_SNP_risk_score', 'sex'
    ],
    'History': [
        'Age', 'lower_limb_days_total', 'average_run_hours', 'average_interval_training_frequency', 'EDEQ_total', 'tracking_period_injury',
        'past_stress_injury', 'LEAF-Q', 'Athlete_Score', 'average_run_frequency', 'past_month_injury'
    ],
    'Phenotype': [
        'hip_abduction_peak_torque', 'total_ad_ab_ratio', 'knee_extension_peak_torque', 'knee_flexion_peak_torque', 'navicular_drop', 
        'navicular_drop_asymmetry', 'Q_angle', 'Q_angle_asymmetry', 'VALR_12', 'Impact_peak_12', 'Duty_factor_12', 'BMI', 'BMD_spine',
        'hip_abduction_peak_torque_asymmetry', 'hip_adduction_peak_torque', 'hip_adduction_peak_torque_asymmetry', 
        'knee_extension_peak_torque_asymmetry', 'knee_flexion_peak_torque_asymmetry', 'total_fl_ex_ratio', 'leg_lean_mass', 
        'hip_abduction_peak_angle', 'hip_abduction_peak_angle_asymmetry', 'hip_adduction_peak_angle', 'hip_adduction_peak_angle_asymmetry', 
        'ad_ab_ratio_asymmetry', 'knee_extension_peak_angle', 'knee_extension_peak_angle_asymmetry', 'knee_flexion_peak_angle', 
        'knee_flexion_peak_angle_asymmetry', 'fl_ex_ratio_asymmetry', 'VILR_10', 'VALR_10', 'VILR_asymmetry_10', 'VALR_asymmetry_10', 
        'Impact_peak_10', 'Impact_peak_asymmetry_10', 'Flight_time_10', 'Contact_time_10', 'Duty_factor_10', 'Step_frequency_10', 
        'Cadence_asymmetry_10', 'Duty_factor_asymmetry_10', 'VILR_12', 'VILR_asymmetry_12', 'VALR_asymmetry_12', 
        'Impact_peak_asymmetry_12', 'Flight_time_12', 'Contact_time_12', 'Step_frequency_12', 'Cadence_asymmetry_12', 
        'Duty_factor_asymmetry_12', 'Alt_strike', 'height', 'Mass', 'thigh_lean_mass', 'thigh_ffmi', 'lower_leg_lean_mass', 
        'lower_leg_ffmi', 'leg_ffmi', 'total_lean_mass', 'total_ffmi', 'calf_size', 'BMD_hip', 'BMD_body',
    ],
    'Behaviour': [
        'fat_intake_avg', 'past_month_distance', 'past_month_ratio', 'SC_past_season', 'non_running_past_season', 'fat_intake_BW', 
        'fat_percentage_avg', 'average_energy_availability', 'protein_intake_BW', 'omega3_intake_BW', 'vitaminD_intake_BW', 
        'vitaminC_intake_BW', 'vitaminE_intake_BW', 'calcium_intake_BW', 'copper_intake_BW', 'iron_intake_BW', 'glycine_intake_BW', 
        'arginine_intake_BW', 'past_month_min', 'past_week_ratio', 'past_month_volume_low', 'past_week_ratio_low', 'past_month_ratio_low', 
        'past_month_volume_moderate', 'past_week_ratio_moderate', 'past_month_ratio_moderate', 'past_month_volume_high', 
        'past_week_ratio_high', 'past_month_ratio_high', 'past_month_volume_very_high', 'past_week_ratio_very_high', 
        'past_month_ratio_very_high', 'past_month_calculated_volume', 'past_week_ratio_calculated_volume', 
        'past_month_ratio_calculated_volume', 'resistance_training_past_month', 'resistance_training_past_season', 
        'bodyweight_exercises_past_month', 'bodyweight_exercises_past_season', 'core_stability_past_month', 'core_stability_past_season', 
        'balance_training_past_month', 'balance_training_past_season', 'plyometrics_past_month', 'plyometrics_past_season', 
        'drills_past_month', 'drills_past_season', 'circuit_training_past_month', 'circuit_training_past_season', 'barefoot_past_month', 
        'barefoot_past_season', 'stretching_past_month', 'stretching_past_season', 'SC_past_month', 'non_running_past_month'
    ]
}

# Define predictors and outcome
X = data.drop(columns=['RRI'])  # Predictors
y = data['RRI']  # Outcome

# Ensure that the feature groups exist in the dataset
for group in feature_groups:
    feature_groups[group] = [feature for feature in feature_groups[group] if feature in X.columns]

num_features = len(X.columns)
feature_to_idx = {feature: idx for idx, feature in enumerate(X.columns)}  # Corrected to X.columns

# Initialize adjacency matrix with zeros
adjacency = np.zeros((num_features, num_features), dtype=np.float32)

# Define groups
genotype_features = feature_groups['Genotype']
history_features = feature_groups['History']
phenotype_features = feature_groups['Phenotype']
behaviour_features = feature_groups['Behaviour']

# Get indices for each group
genotype_indices = [feature_to_idx[feat] for feat in genotype_features]
history_indices = [feature_to_idx[feat] for feat in history_features]
phenotype_indices = [feature_to_idx[feat] for feat in phenotype_features]
behaviour_indices = [feature_to_idx[feat] for feat in behaviour_features]

# Genotype nodes: connect to every node except themselves
for i in genotype_indices:
    for j in range(num_features):
        if j != i:
            adjacency[i, j] = 1.0

# History nodes: connect to every node except genotype nodes and themselves
for i in history_indices:
    for j in range(num_features):
        if j not in genotype_indices and j != i:
            adjacency[i, j] = 1.0

# Phenotype nodes: connect to every node except genotype, history nodes, and themselves
for i in phenotype_indices:
    for j in range(num_features):
        if j not in genotype_indices and j not in history_indices and j != i:
            adjacency[i, j] = 1.0

# Behaviour nodes: connect to all other behaviour nodes except themselves
for i in behaviour_indices:
    for j in behaviour_indices:
        if j != i:
            adjacency[i, j] = 1.0

# Convert adjacency to tensor
adjacency_mask = torch.tensor(adjacency, dtype=torch.float32)

class CustomDataset(Dataset):
    def __init__(self, X, y):
        if isinstance(X, pd.DataFrame):
            self.X = X.values.astype(np.float32)
        elif isinstance(X, np.ndarray):
            self.X = X.astype(np.float32)
        else:
            raise TypeError("X should be a pandas DataFrame or a NumPy array.")
        self.y = y.astype(np.float32)
    
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

class CustomNetwork(nn.Module):
    def __init__(self, num_features, adjacency_mask):
        super(CustomNetwork, self).__init__()
        self.num_features = num_features

        # Register the fixed adjacency mask as a buffer (non-trainable)
        self.register_buffer('mask', adjacency_mask.float())  # Shape: (num_features, num_features)

        # Initialize connection weights (W_ij: from node j to node i)
        self.W = nn.Parameter(torch.randn(num_features, num_features) * 0.01)

        # Initialize bias for each node
        self.bias = nn.Parameter(torch.zeros(num_features))

        # Initialize output weights (from each node to the final output)
        self.output_weights = nn.Parameter(torch.randn(num_features) * 0.01)

        # Add Batch Normalization
        self.batch_norm = nn.BatchNorm1d(num_features)

    def forward(self, x, threshold=None):
        """
        x: input tensor of shape (batch_size, num_features)
        threshold: if provided, apply binary thresholding to gating
        """
        # Use the fixed mask directly
        learnable_mask = self.mask

        # Apply the learnable mask to connection weights
        W_masked = self.W * learnable_mask  # Shape: (num_features, num_features)

        # Compute incoming messages: (batch_size, num_features) @ (num_features, num_features) = (batch_size, num_features)
        incoming = torch.matmul(x, W_masked)

        # Element-wise multiplication with own feature value
        node_input = incoming * x  # Shape: (batch_size, num_features)

        node_input = self.batch_norm(node_input)

        # Add bias
        node_input += self.bias  # Broadcasting over batch

        # Apply Leaky ReLU activation
        node_output = F.leaky_relu(node_input)  # Shape: (batch_size, num_features)

        # Aggregate node outputs to final output
        output = torch.matmul(node_output, self.output_weights)  # Shape: (batch_size,)

        return output  # Raw scores (logits)

# Removed ReliefF import since it's no longer used
# from skrebate import ReliefF

def train_evaluate_fold(fold, train_index, val_index, X, y, selected_features, adjacency, feature_to_idx, 
                       n_epochs, lr, weight_decay, batch_size, threshold):
    """
    Function to train and evaluate the model on a single fold.
    This function is intended to be run in parallel.
    """
    # Split data
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]

    # Encode labels for binary classification
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y_train_enc = le.fit_transform(y_train)
    y_val_enc = le.transform(y_val)
    y_train_final = y_train_enc
    y_val_final = y_val_enc

    # Create datasets
    train_dataset = CustomDataset(X_train[selected_features], y_train_final)
    val_dataset = CustomDataset(X_val[selected_features], y_val_final)

    # Create dataloaders with drop_last=True for training and drop_last=False for validation
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

    # Map selected_features to their indices
    selected_feature_indices = [feature_to_idx[feat] for feat in selected_features]

    # Select the corresponding adjacency submatrix using integer indices
    selected_adjacency = adjacency[np.ix_(selected_feature_indices, selected_feature_indices)]
    selected_adjacency_mask = torch.tensor(selected_adjacency, dtype=torch.float32)

    device = torch.device('cpu')

    # Initialize the model with the number of selected features and the selected adjacency mask
    model = CustomNetwork(num_features=len(selected_features), 
                          adjacency_mask=selected_adjacency_mask).to(device)

    # Define loss and optimizer
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    # Training Loop
    for epoch in range(1, n_epochs + 1):
        model.train()
        epoch_loss = 0.0

        for batch_X, batch_y in train_loader:
            batch_X = batch_X.to(device).float()  # Ensure float type
            batch_y = batch_y.to(device).float()  # BCEWithLogitsLoss expects float targets

            optimizer.zero_grad()
            outputs = model(batch_X)  # Forward pass
            loss = criterion(outputs, batch_y)

            # Total loss
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item() * batch_X.size(0)

        epoch_loss /= len(train_loader.dataset)

    # Validation
    model.eval()
    all_outputs = []
    all_labels = []
    all_preds = []  # Initialize a list to accumulate predictions

    with torch.no_grad():
        for batch_X, batch_y in val_loader:
            batch_X = batch_X.to(device).float()

            outputs = model(batch_X)  # Forward pass
            probs = torch.sigmoid(outputs).cpu().numpy()
            preds = (probs >= threshold).astype(int).flatten()

            all_outputs.extend(probs)
            all_labels.extend(batch_y.numpy())
            all_preds.extend(preds)  # Accumulate predictions

    # Compute metrics
    roc_auc = roc_auc_score(all_labels, all_outputs)
    f1 = f1_score(all_labels, all_preds, average='binary')
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='binary')

    return {
        'roc_auc': roc_auc,
        'f1': f1,
        'accuracy': accuracy,
        'precision': precision
    }

def global_feature_ranking(X, y):
    """
    Perform global feature ranking using Logistic Regression with L1 regularization (Lasso).
    """
    from sklearn.linear_model import LogisticRegression
    from sklearn.preprocessing import LabelEncoder

    # Encode labels
    le = LabelEncoder()
    y_encoded = le.fit_transform(y)

    # Initialize Logistic Regression with L1 penalty and C=25
    clf = LogisticRegression(penalty='l1', C=25, solver='saga', max_iter=10000, random_state=42)
    clf.fit(X, y_encoded)

    # Get absolute coefficients as feature scores
    feature_scores = np.abs(clf.coef_[0])

    # Create a DataFrame
    feature_score_df = pd.DataFrame({
        'feature': X.columns,
        'score': feature_scores
    })

    # Sort features by score in descending order
    feature_score_df = feature_score_df.sort_values(by='score', ascending=False)

    return feature_score_df

def objective(trial, X, y, feature_groups, feature_to_idx, global_feature_score_df, adjacency, threshold=0.5):
    # ====================
    # Hyperparameters to Tune
    # ====================

    # 1. Number of Epochs
    n_epochs = trial.suggest_int('n_epochs', 500, 3000)

    # 2. Learning Rate
    lr = trial.suggest_loguniform('lr', 1e-6, 1e-2)

    # 3. Weight Decay
    weight_decay = trial.suggest_loguniform('weight_decay', 1e-8, 1e-3)

    # 4. Batch Size
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128, 256, 512])

    # 5. Number of Features per Group
    n_genotype = trial.suggest_int('n_genotype', 1, len(feature_groups['Genotype']))
    n_history = trial.suggest_int('n_history', 1, len(feature_groups['History']))
    n_phenotype = trial.suggest_int('n_phenotype', 1, len(feature_groups['Phenotype']))
    n_behaviour = trial.suggest_int('n_behaviour', 1, len(feature_groups['Behaviour']))

    # ====================
    # Feature Selection Using Global Rankings
    # ====================

    # Initialize selected features list
    selected_features = []

    # For each group, select the top N features based on global Logistic Lasso scores
    for group, n_select in zip(['Genotype', 'History', 'Phenotype', 'Behaviour'],
                               [n_genotype, n_history, n_phenotype, n_behaviour]):
        group_features = feature_groups[group]
        # Filter the features present in the group
        group_feature_scores = global_feature_score_df[global_feature_score_df['feature'].isin(group_features)]
        # Select top N features
        top_features = group_feature_scores.head(n_select)['feature'].tolist()
        selected_features.extend(top_features)

    # Ensure that selected_features are unique
    selected_features = list(dict.fromkeys(selected_features))

    # ====================
    # Data Preparation
    # ====================

    X_selected = X[selected_features].copy()
    y_selected = y.copy()

    # Initialize Stratified K-Fold
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

    # Get all fold indices
    fold_indices = list(skf.split(X_selected, y_selected))

    # ====================
    # Parallel Training and Evaluation
    # ====================

    # Define a wrapper for joblib's Parallel
    results = Parallel(n_jobs=10)(
        delayed(train_evaluate_fold)(
            fold=fold,
            train_index=train_idx,
            val_index=val_idx,
            X=X_selected,
            y=y_selected,
            selected_features=selected_features,
            adjacency=adjacency,  # Pass the numpy adjacency matrix
            feature_to_idx=feature_to_idx,  # Pass the feature_to_idx mapping
            n_epochs=n_epochs,
            lr=lr,
            weight_decay=weight_decay,
            batch_size=batch_size,
            threshold=threshold
        )
        for fold, (train_idx, val_idx) in enumerate(fold_indices)
    )

    # ====================
    # Collect Metrics
    # ====================

    aucs = []
    f1s = []
    accuracies = []
    precisions = []

    for res in results:
        aucs.append(res['roc_auc'])
        f1s.append(res['f1'])
        accuracies.append(res['accuracy'])
        precisions.append(res['precision'])

    # ====================
    # Final Metrics Calculation
    # ====================

    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_f1 = np.mean(f1s)
    std_f1 = np.std(f1s)
    mean_accuracy = np.mean(accuracies)
    std_accuracy = np.std(accuracies)
    mean_precision = np.mean(precisions)
    std_precision = np.std(precisions)

    # ====================
    # Objective Metric
    # ====================

    # Since it's binary classification, we aim to maximize the mean AUC
    trial.set_user_attr("mean_auc", mean_auc)
    trial.set_user_attr("std_auc", std_auc)
    trial.set_user_attr("mean_f1", mean_f1)
    trial.set_user_attr("std_f1", std_f1)
    trial.set_user_attr("mean_accuracy", mean_accuracy)
    trial.set_user_attr("std_accuracy", std_accuracy)
    trial.set_user_attr("mean_precision", mean_precision)
    trial.set_user_attr("std_precision", std_precision)
    trial.set_user_attr("selected_features", selected_features)

    return mean_auc

def run_hyperparameter_tuning(X, y, feature_groups, feature_to_idx, adjacency, threshold=0.5):
    # Generate the global feature ranking before the study starts using Logistic Lasso
    global_feature_score_df = global_feature_ranking(X, y)

    def objective_wrapper(trial):
        return objective(trial, X, y, feature_groups, feature_to_idx, global_feature_score_df, adjacency, threshold)

    study = optuna.create_study(
        direction='maximize',
        study_name='CustomNetwork_Hyperparameter_Tuning',
        sampler=optuna.samplers.TPESampler(seed=42)
    )

    # Integrate a progress bar for the Optuna study
    with tqdm(total=200, desc="Optuna Trials") as pbar:
        def callback(study, trial):
            pbar.update(1)

        # Set n_jobs=1 to ensure serial execution of hyperparameter trials
        study.optimize(objective_wrapper, n_trials=200, timeout=None, callbacks=[callback], n_jobs=1)

    print("Number of finished trials: ", len(study.trials))
    print("Best trial:")
    trial = study.best_trial

    print("  Value (Mean AUC): ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

    # Extract additional metrics from the best trial
    best_trial_metrics = trial.user_attrs
    mean_auc = best_trial_metrics.get("mean_auc", None)
    std_auc = best_trial_metrics.get("std_auc", None)
    mean_f1 = best_trial_metrics.get("mean_f1", None)
    std_f1 = best_trial_metrics.get("std_f1", None)
    mean_accuracy = best_trial_metrics.get("mean_accuracy", None)
    std_accuracy = best_trial_metrics.get("std_accuracy", None)
    mean_precision = best_trial_metrics.get("mean_precision", None)
    std_precision = best_trial_metrics.get("std_precision", None)
    selected_features = best_trial_metrics.get("selected_features", None)

    print(f"\nBest Trial Metrics:")
    print(f"Selected Features: {selected_features}")
    print(f"Average AUC: {mean_auc:.4f} ± {std_auc:.4f}")
    print(f"Average F1 Score: {mean_f1:.4f} ± {std_f1:.4f}")
    print(f"Average Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}")
    print(f"Average Precision: {mean_precision:.4f} ± {std_precision:.4f}")

    return study

if __name__ == "__main__":
    # Run hyperparameter tuning
    study = run_hyperparameter_tuning(X, y, feature_groups, feature_to_idx, adjacency)
# Out:
# [I 2024-12-15 18:32:51,627] A new study created in memory with name: CustomNetwork_Hyperparameter_Tuning
# Optuna Trials:   0%|          | 0/200 [00:00<?, ?it/s][I 2024-12-15 18:34:11,655] Trial 0 finished with value: 0.7132250685581889 and parameters: {'n_epochs': 1436, 'lr': 0.006351221010640704, 'weight_decay': 4.570563099801451e-05, 'batch_size': 512, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 1, 'n_behaviour': 5}. Best is trial 0 with value: 0.7132250685581889.
# Optuna Trials:   0%|          | 1/200 [01:20<4:25:20, 80.00s/it][I 2024-12-15 18:40:47,568] Trial 1 finished with value: 0.6922091489515714 and parameters: {'n_epochs': 2581, 'lr': 7.068974950624607e-06, 'weight_decay': 8.111941985431907e-08, 'batch_size': 128, 'n_genotype': 10, 'n_history': 1, 'n_phenotype': 4, 'n_behaviour': 2}. Best is trial 0 with value: 0.7132250685581889.
# Optuna Trials:   1%|          | 2/200 [07:55<14:37:15, 265.83s/it][I 2024-12-15 18:43:57,153] Trial 2 finished with value: 0.7226383346649177 and parameters: {'n_epochs': 1640, 'lr': 0.0013826232179369874, 'weight_decay': 9.9625132220551e-08, 'batch_size': 256, 'n_genotype': 1, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 2 with value: 0.7226383346649177.
# Optuna Trials:   2%|▏         | 3/200 [11:05<12:38:30, 231.02s/it][I 2024-12-15 18:45:39,980] Trial 3 finished with value: 0.5402473266602923 and parameters: {'n_epochs': 1261, 'lr': 2.4586032763280077e-06, 'weight_decay': 2.6373339933815247e-05, 'batch_size': 512, 'n_genotype': 4, 'n_history': 4, 'n_phenotype': 5, 'n_behaviour': 3}. Best is trial 2 with value: 0.7226383346649177.
# Optuna Trials:   2%|▏         | 4/200 [12:48<9:49:20, 180.41s/it] [I 2024-12-15 18:54:07,320] Trial 4 finished with value: 0.6495874681128446 and parameters: {'n_epochs': 1867, 'lr': 5.4880470007660465e-06, 'weight_decay': 0.00070456836384545, 'batch_size': 64, 'n_genotype': 2, 'n_history': 2, 'n_phenotype': 1, 'n_behaviour': 2}. Best is trial 2 with value: 0.7226383346649177.
# Optuna Trials:   2%|▎         | 5/200 [21:15<16:09:28, 298.30s/it][I 2024-12-15 18:56:12,627] Trial 5 finished with value: 0.6693389512064936 and parameters: {'n_epochs': 1472, 'lr': 1.2172958098369984e-05, 'weight_decay': 0.00013921548533046482, 'batch_size': 512, 'n_genotype': 2, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 2 with value: 0.7226383346649177.
# Optuna Trials:   3%|▎         | 6/200 [23:20<12:54:19, 239.48s/it][I 2024-12-15 18:58:37,901] Trial 6 finished with value: 0.7180315574171344 and parameters: {'n_epochs': 513, 'lr': 0.0018274508859816032, 'weight_decay': 3.422052903270691e-05, 'batch_size': 64, 'n_genotype': 13, 'n_history': 4, 'n_phenotype': 5, 'n_behaviour': 1}. Best is trial 2 with value: 0.7226383346649177.
# Optuna Trials:   4%|▎         | 7/200 [25:46<11:11:16, 208.68s/it][I 2024-12-15 19:04:35,838] Trial 7 finished with value: 0.7192566416532955 and parameters: {'n_epochs': 1277, 'lr': 1.99863407785289e-05, 'weight_decay': 4.446628955475447e-05, 'batch_size': 64, 'n_genotype': 12, 'n_history': 4, 'n_phenotype': 11, 'n_behaviour': 3}. Best is trial 2 with value: 0.7226383346649177.
# Optuna Trials:   4%|▍         | 8/200 [31:44<13:39:50, 256.20s/it][I 2024-12-15 19:09:42,569] Trial 8 finished with value: 0.7249437053678595 and parameters: {'n_epochs': 1807, 'lr': 5.1305517605898387e-05, 'weight_decay': 1.3399717231179682e-08, 'batch_size': 128, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 6, 'n_behaviour': 4}. Best is trial 8 with value: 0.7249437053678595.
# Optuna Trials:   4%|▍         | 9/200 [36:50<14:25:51, 272.00s/it][I 2024-12-15 19:14:29,479] Trial 9 finished with value: 0.6855870547660567 and parameters: {'n_epochs': 1072, 'lr': 2.031980983842497e-06, 'weight_decay': 2.810329644763601e-07, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 3}. Best is trial 8 with value: 0.7249437053678595.
# Optuna Trials:   5%|▌         | 10/200 [41:37<14:35:54, 276.60s/it][I 2024-12-15 19:21:29,341] Trial 10 finished with value: 0.7171928719014949 and parameters: {'n_epochs': 2443, 'lr': 0.00014696843472823023, 'weight_decay': 1.090778569000606e-08, 'batch_size': 128, 'n_genotype': 15, 'n_history': 2, 'n_phenotype': 8, 'n_behaviour': 4}. Best is trial 8 with value: 0.7249437053678595.
# Optuna Trials:   6%|▌         | 11/200 [48:37<16:49:24, 320.45s/it][I 2024-12-15 19:25:33,340] Trial 11 finished with value: 0.7220880771868646 and parameters: {'n_epochs': 2064, 'lr': 0.00037570843587531505, 'weight_decay': 1.1086851817494573e-08, 'batch_size': 256, 'n_genotype': 6, 'n_history': 6, 'n_phenotype': 8, 'n_behaviour': 5}. Best is trial 8 with value: 0.7249437053678595.
# Optuna Trials:   6%|▌         | 12/200 [52:41<15:31:11, 297.19s/it][I 2024-12-15 19:42:52,255] Trial 12 finished with value: 0.7288414887486094 and parameters: {'n_epochs': 2172, 'lr': 0.0005667807784606256, 'weight_decay': 5.337212695483277e-07, 'batch_size': 32, 'n_genotype': 7, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:   6%|▋         | 13/200 [1:10:00<27:06:32, 521.88s/it][I 2024-12-15 20:06:11,477] Trial 13 finished with value: 0.7200455610340419 and parameters: {'n_epochs': 2918, 'lr': 4.9146810539426464e-05, 'weight_decay': 1.5914962367275416e-06, 'batch_size': 32, 'n_genotype': 7, 'n_history': 3, 'n_phenotype': 9, 'n_behaviour': 4}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:   7%|▋         | 14/200 [1:33:19<40:39:20, 786.88s/it][I 2024-12-15 20:23:26,482] Trial 14 finished with value: 0.7173368728546775 and parameters: {'n_epochs': 2173, 'lr': 0.00025795971447953623, 'weight_decay': 2.08675767166627e-06, 'batch_size': 32, 'n_genotype': 9, 'n_history': 3, 'n_phenotype': 6, 'n_behaviour': 4}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:   8%|▊         | 15/200 [1:50:34<44:16:49, 861.67s/it][I 2024-12-15 20:30:04,913] Trial 15 finished with value: 0.6865979546790422 and parameters: {'n_epochs': 2305, 'lr': 5.2671171546177014e-05, 'weight_decay': 5.54558751796182e-07, 'batch_size': 128, 'n_genotype': 5, 'n_history': 1, 'n_phenotype': 3, 'n_behaviour': 4}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:   8%|▊         | 16/200 [1:57:13<36:54:51, 722.24s/it][I 2024-12-15 20:45:05,530] Trial 16 finished with value: 0.7212022985819163 and parameters: {'n_epochs': 1887, 'lr': 0.0007075332957625989, 'weight_decay': 4.495354287852515e-08, 'batch_size': 32, 'n_genotype': 15, 'n_history': 3, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:   8%|▊         | 17/200 [2:12:13<39:26:25, 775.88s/it][I 2024-12-15 20:53:01,741] Trial 17 finished with value: 0.7182039545486105 and parameters: {'n_epochs': 2737, 'lr': 0.008290600699824688, 'weight_decay': 6.494777614419829e-06, 'batch_size': 128, 'n_genotype': 8, 'n_history': 2, 'n_phenotype': 7, 'n_behaviour': 2}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:   9%|▉         | 18/200 [2:20:10<34:40:21, 685.83s/it][I 2024-12-15 20:59:17,374] Trial 18 finished with value: 0.7196297460932417 and parameters: {'n_epochs': 759, 'lr': 6.08947943725685e-05, 'weight_decay': 4.34478610465339e-07, 'batch_size': 32, 'n_genotype': 11, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 3}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:  10%|▉         | 19/200 [2:26:25<29:47:52, 592.66s/it][I 2024-12-15 21:05:07,608] Trial 19 finished with value: 0.6962263043218389 and parameters: {'n_epochs': 2042, 'lr': 0.0022233529392929547, 'weight_decay': 6.687591818789232e-06, 'batch_size': 128, 'n_genotype': 4, 'n_history': 5, 'n_phenotype': 3, 'n_behaviour': 5}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:  10%|█         | 20/200 [2:32:15<25:59:37, 519.88s/it][I 2024-12-15 21:18:32,282] Trial 20 finished with value: 0.7150891929759695 and parameters: {'n_epochs': 1678, 'lr': 0.00013869594397031393, 'weight_decay': 3.0488917127269565e-08, 'batch_size': 32, 'n_genotype': 8, 'n_history': 3, 'n_phenotype': 7, 'n_behaviour': 4}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:  10%|█         | 21/200 [2:45:40<30:06:00, 605.36s/it][I 2024-12-15 21:21:49,015] Trial 21 finished with value: 0.7261551415306938 and parameters: {'n_epochs': 1663, 'lr': 0.0009068245759615308, 'weight_decay': 1.0391805593295124e-07, 'batch_size': 256, 'n_genotype': 3, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:  11%|█         | 22/200 [2:48:57<23:52:05, 482.73s/it][I 2024-12-15 21:25:33,625] Trial 22 finished with value: 0.7169166947514815 and parameters: {'n_epochs': 1928, 'lr': 0.0007429191568819916, 'weight_decay': 2.2912662918994099e-07, 'batch_size': 256, 'n_genotype': 6, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:  12%|█▏        | 23/200 [2:52:41<19:55:32, 405.27s/it][I 2024-12-15 21:30:01,811] Trial 23 finished with value: 0.718382880475432 and parameters: {'n_epochs': 2297, 'lr': 0.0003525488154571104, 'weight_decay': 2.642140992433917e-08, 'batch_size': 256, 'n_genotype': 3, 'n_history': 4, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:  12%|█▏        | 24/200 [2:57:10<17:48:08, 364.14s/it][I 2024-12-15 21:33:13,152] Trial 24 finished with value: 0.701257960630034 and parameters: {'n_epochs': 1656, 'lr': 2.775091100391172e-05, 'weight_decay': 1.003349499498293e-06, 'batch_size': 256, 'n_genotype': 6, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:  12%|█▎        | 25/200 [3:00:21<15:10:50, 312.29s/it][I 2024-12-15 21:36:05,065] Trial 25 finished with value: 0.704028630755656 and parameters: {'n_epochs': 1484, 'lr': 0.0037759506080265676, 'weight_decay': 1.5181242377806317e-07, 'batch_size': 256, 'n_genotype': 1, 'n_history': 5, 'n_phenotype': 9, 'n_behaviour': 4}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:  13%|█▎        | 26/200 [3:03:13<13:03:30, 270.17s/it][I 2024-12-15 21:43:23,973] Trial 26 finished with value: 0.716154824195339 and parameters: {'n_epochs': 901, 'lr': 0.0008654895934904404, 'weight_decay': 5.314358622424755e-08, 'batch_size': 32, 'n_genotype': 4, 'n_history': 3, 'n_phenotype': 11, 'n_behaviour': 5}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:  14%|█▎        | 27/200 [3:10:32<15:24:57, 320.80s/it][I 2024-12-15 21:50:01,912] Trial 27 finished with value: 0.7208018312213441 and parameters: {'n_epochs': 2213, 'lr': 0.00020470202874024604, 'weight_decay': 2.512419389483111e-08, 'batch_size': 128, 'n_genotype': 14, 'n_history': 4, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:  14%|█▍        | 28/200 [3:17:10<16:25:57, 343.94s/it][I 2024-12-15 22:10:15,528] Trial 28 finished with value: 0.7143153632212362 and parameters: {'n_epochs': 2546, 'lr': 8.283175550838339e-05, 'weight_decay': 8.661357981093641e-07, 'batch_size': 32, 'n_genotype': 7, 'n_history': 2, 'n_phenotype': 6, 'n_behaviour': 5}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:  14%|█▍        | 29/200 [3:37:23<28:43:49, 604.85s/it][I 2024-12-15 22:12:06,814] Trial 29 finished with value: 0.716060767192561 and parameters: {'n_epochs': 1311, 'lr': 0.0037427414918311816, 'weight_decay': 1.356152878777976e-07, 'batch_size': 512, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 9, 'n_behaviour': 5}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:  15%|█▌        | 30/200 [3:39:15<21:34:12, 456.78s/it][I 2024-12-15 22:15:29,506] Trial 30 finished with value: 0.7072923650608114 and parameters: {'n_epochs': 1795, 'lr': 0.000499667187340538, 'weight_decay': 4.556747268291321e-06, 'batch_size': 256, 'n_genotype': 11, 'n_history': 3, 'n_phenotype': 1, 'n_behaviour': 3}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:  16%|█▌        | 31/200 [3:42:37<17:51:53, 380.55s/it][I 2024-12-15 22:18:36,702] Trial 31 finished with value: 0.7181004948364721 and parameters: {'n_epochs': 1608, 'lr': 0.00128753449861007, 'weight_decay': 9.139306396460183e-08, 'batch_size': 256, 'n_genotype': 1, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:  16%|█▌        | 32/200 [3:45:45<15:03:07, 322.54s/it][I 2024-12-15 22:21:41,417] Trial 32 finished with value: 0.7269033585980608 and parameters: {'n_epochs': 1582, 'lr': 0.004051357572382927, 'weight_decay': 9.805112642515535e-08, 'batch_size': 256, 'n_genotype': 2, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:  16%|█▋        | 33/200 [3:48:49<13:02:39, 281.20s/it][I 2024-12-15 22:25:44,649] Trial 33 finished with value: 0.7242386434643329 and parameters: {'n_epochs': 2040, 'lr': 0.004524237680984895, 'weight_decay': 1.820783388618705e-08, 'batch_size': 256, 'n_genotype': 3, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 12 with value: 0.7288414887486094.
# Optuna Trials:  17%|█▋        | 34/200 [3:52:52<12:26:27, 269.81s/it][I 2024-12-15 22:30:06,988] Trial 34 finished with value: 0.7301895971230529 and parameters: {'n_epochs': 1487, 'lr': 0.0020640043908277572, 'weight_decay': 5.998082557008712e-08, 'batch_size': 128, 'n_genotype': 2, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 34 with value: 0.7301895971230529.
# Optuna Trials:  18%|█▊        | 35/200 [3:57:15<12:15:48, 267.57s/it][I 2024-12-15 22:32:24,597] Trial 35 finished with value: 0.731419509504949 and parameters: {'n_epochs': 1147, 'lr': 0.002397899688421492, 'weight_decay': 6.85183171619398e-08, 'batch_size': 256, 'n_genotype': 2, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 35 with value: 0.731419509504949.
# Optuna Trials:  18%|█▊        | 36/200 [3:59:32<10:24:46, 228.58s/it][I 2024-12-15 22:33:59,484] Trial 36 finished with value: 0.7276653128204008 and parameters: {'n_epochs': 1092, 'lr': 0.002626516754409799, 'weight_decay': 2.516435393059995e-07, 'batch_size': 512, 'n_genotype': 2, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 5}. Best is trial 35 with value: 0.731419509504949.
# Optuna Trials:  18%|█▊        | 37/200 [4:01:07<8:32:00, 188.47s/it] [I 2024-12-15 22:35:35,488] Trial 37 finished with value: 0.7266834263971726 and parameters: {'n_epochs': 1113, 'lr': 0.0023533938891136864, 'weight_decay': 3.0214865615196897e-07, 'batch_size': 512, 'n_genotype': 2, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 5}. Best is trial 35 with value: 0.731419509504949.
# Optuna Trials:  19%|█▉        | 38/200 [4:02:43<7:13:58, 160.73s/it][I 2024-12-15 22:37:12,055] Trial 38 finished with value: 0.7201170746667672 and parameters: {'n_epochs': 1088, 'lr': 0.008636494962328546, 'weight_decay': 5.262285769131019e-08, 'batch_size': 512, 'n_genotype': 5, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 35 with value: 0.731419509504949.
# Optuna Trials:  20%|█▉        | 39/200 [4:04:20<6:19:38, 141.48s/it][I 2024-12-15 22:38:25,485] Trial 39 finished with value: 0.7173671549505451 and parameters: {'n_epochs': 837, 'lr': 0.0012615555752084633, 'weight_decay': 4.3415554546245977e-07, 'batch_size': 512, 'n_genotype': 3, 'n_history': 5, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 35 with value: 0.731419509504949.
# Optuna Trials:  20%|██        | 40/200 [4:05:33<5:22:50, 121.07s/it][I 2024-12-15 22:39:11,897] Trial 40 finished with value: 0.7193125488572835 and parameters: {'n_epochs': 510, 'lr': 0.0020662007199915215, 'weight_decay': 0.000984474933724538, 'batch_size': 512, 'n_genotype': 1, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 35 with value: 0.731419509504949.
# Optuna Trials:  20%|██        | 41/200 [4:06:20<4:21:28, 98.67s/it] [I 2024-12-15 22:45:28,002] Trial 41 finished with value: 0.7238979454666188 and parameters: {'n_epochs': 1330, 'lr': 0.005528325540239552, 'weight_decay': 1.959801283911164e-07, 'batch_size': 64, 'n_genotype': 2, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 35 with value: 0.731419509504949.
# Optuna Trials:  21%|██        | 42/200 [4:12:36<7:59:00, 181.90s/it][I 2024-12-15 22:49:38,538] Trial 42 finished with value: 0.7319898429951536 and parameters: {'n_epochs': 1444, 'lr': 0.0029493662823725695, 'weight_decay': 6.886782393465355e-08, 'batch_size': 128, 'n_genotype': 2, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  22%|██▏       | 43/200 [4:16:46<8:49:51, 202.49s/it][I 2024-12-15 22:53:11,845] Trial 43 finished with value: 0.7223459856934539 and parameters: {'n_epochs': 1207, 'lr': 0.002847705661901322, 'weight_decay': 6.452764845174978e-08, 'batch_size': 128, 'n_genotype': 4, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  22%|██▏       | 44/200 [4:20:20<8:54:54, 205.74s/it][I 2024-12-15 22:57:26,863] Trial 44 finished with value: 0.7264884057569403 and parameters: {'n_epochs': 1432, 'lr': 0.0015959137106251956, 'weight_decay': 3.859043212840444e-08, 'batch_size': 128, 'n_genotype': 2, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  22%|██▎       | 45/200 [4:24:35<9:29:40, 220.52s/it][I 2024-12-15 23:00:30,280] Trial 45 finished with value: 0.7140665503829734 and parameters: {'n_epochs': 1022, 'lr': 0.0060135080792222476, 'weight_decay': 8.600015751245228e-07, 'batch_size': 128, 'n_genotype': 1, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  23%|██▎       | 46/200 [4:27:38<8:57:25, 209.39s/it][I 2024-12-15 23:02:41,916] Trial 46 finished with value: 0.7207898069380033 and parameters: {'n_epochs': 741, 'lr': 0.001318110298595343, 'weight_decay': 1.3224927329716865e-05, 'batch_size': 128, 'n_genotype': 5, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  24%|██▎       | 47/200 [4:29:50<7:54:27, 186.06s/it][I 2024-12-15 23:04:24,570] Trial 47 finished with value: 0.7132181477141704 and parameters: {'n_epochs': 1198, 'lr': 0.0004908163716888555, 'weight_decay': 2.4780180327930214e-07, 'batch_size': 512, 'n_genotype': 3, 'n_history': 4, 'n_phenotype': 10, 'n_behaviour': 3}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  24%|██▍       | 48/200 [4:31:32<6:47:58, 161.04s/it][I 2024-12-15 23:08:34,604] Trial 48 finished with value: 0.7259118815643089 and parameters: {'n_epochs': 1429, 'lr': 0.002898523305728186, 'weight_decay': 0.0003549769780940641, 'batch_size': 128, 'n_genotype': 4, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  24%|██▍       | 49/200 [4:35:42<7:52:28, 187.74s/it][I 2024-12-15 23:12:57,926] Trial 49 finished with value: 0.7171628219246742 and parameters: {'n_epochs': 959, 'lr': 0.007906328228313, 'weight_decay': 2.188246417850854e-06, 'batch_size': 64, 'n_genotype': 2, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  25%|██▌       | 50/200 [4:40:06<8:46:02, 210.41s/it][I 2024-12-15 23:24:47,427] Trial 50 finished with value: 0.7214478930538201 and parameters: {'n_epochs': 1491, 'lr': 0.0005642303453284849, 'weight_decay': 5.82060421524349e-07, 'batch_size': 32, 'n_genotype': 1, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  26%|██▌       | 51/200 [4:51:55<14:54:20, 360.14s/it][I 2024-12-15 23:27:54,211] Trial 51 finished with value: 0.7238080910507312 and parameters: {'n_epochs': 1563, 'lr': 0.0048029552059367, 'weight_decay': 8.146663446643679e-08, 'batch_size': 256, 'n_genotype': 2, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  26%|██▌       | 52/200 [4:55:02<12:40:03, 308.13s/it][I 2024-12-15 23:31:57,237] Trial 52 finished with value: 0.6820254016259685 and parameters: {'n_epochs': 1374, 'lr': 3.568558360430446e-06, 'weight_decay': 1.4324396172430354e-07, 'batch_size': 128, 'n_genotype': 3, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  26%|██▋       | 53/200 [4:59:05<11:47:04, 288.60s/it][I 2024-12-15 23:34:20,750] Trial 53 finished with value: 0.7301896575375995 and parameters: {'n_epochs': 1203, 'lr': 0.0032763863338181633, 'weight_decay': 1.8136668102321387e-08, 'batch_size': 256, 'n_genotype': 2, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  27%|██▋       | 54/200 [5:01:29<9:56:20, 245.07s/it] [I 2024-12-15 23:36:04,683] Trial 54 finished with value: 0.7234094606699633 and parameters: {'n_epochs': 1192, 'lr': 0.0011094556006452452, 'weight_decay': 1.903038021071762e-08, 'batch_size': 512, 'n_genotype': 4, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  28%|██▊       | 55/200 [5:03:13<8:09:56, 202.73s/it][I 2024-12-15 23:41:21,755] Trial 55 finished with value: 0.7201993001563035 and parameters: {'n_epochs': 661, 'lr': 0.0018136409619418366, 'weight_decay': 1.496868824537085e-08, 'batch_size': 32, 'n_genotype': 1, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  28%|██▊       | 56/200 [5:08:30<9:28:52, 237.03s/it][I 2024-12-15 23:44:20,495] Trial 56 finished with value: 0.7243210477133578 and parameters: {'n_epochs': 995, 'lr': 0.0029218091121693767, 'weight_decay': 3.673641152032743e-08, 'batch_size': 128, 'n_genotype': 5, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  28%|██▊       | 57/200 [5:11:28<8:43:15, 219.55s/it][I 2024-12-15 23:49:38,979] Trial 57 finished with value: 0.7307980151285657 and parameters: {'n_epochs': 1130, 'lr': 0.0017464827796727605, 'weight_decay': 6.533966390422154e-08, 'batch_size': 64, 'n_genotype': 9, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  29%|██▉       | 58/200 [5:16:47<9:49:50, 249.23s/it][I 2024-12-15 23:55:30,776] Trial 58 finished with value: 0.7112000695435026 and parameters: {'n_epochs': 1259, 'lr': 0.0017695317231007904, 'weight_decay': 2.3124219681230767e-08, 'batch_size': 64, 'n_genotype': 9, 'n_history': 4, 'n_phenotype': 2, 'n_behaviour': 4}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  30%|██▉       | 59/200 [5:22:39<10:57:59, 280.00s/it][I 2024-12-16 00:08:30,847] Trial 59 finished with value: 0.7250455413396948 and parameters: {'n_epochs': 2796, 'lr': 0.00027561256069997435, 'weight_decay': 1.0906136413352062e-08, 'batch_size': 64, 'n_genotype': 9, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 3}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  30%|███       | 60/200 [5:35:39<16:43:22, 430.02s/it][I 2024-12-16 00:16:22,950] Trial 60 finished with value: 0.7175884785739572 and parameters: {'n_epochs': 1757, 'lr': 0.009716494974434726, 'weight_decay': 7.800301093479749e-05, 'batch_size': 64, 'n_genotype': 10, 'n_history': 3, 'n_phenotype': 5, 'n_behaviour': 4}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  30%|███       | 61/200 [5:43:31<17:05:27, 442.64s/it][I 2024-12-16 00:21:28,820] Trial 61 finished with value: 0.718444413485964 and parameters: {'n_epochs': 1115, 'lr': 0.0028754620371306047, 'weight_decay': 6.427803581545436e-08, 'batch_size': 64, 'n_genotype': 2, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  31%|███       | 62/200 [5:48:37<15:23:42, 401.61s/it][I 2024-12-16 00:23:10,631] Trial 62 finished with value: 0.7307282366254635 and parameters: {'n_epochs': 878, 'lr': 0.000949177949998403, 'weight_decay': 3.4244413238068e-07, 'batch_size': 256, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  32%|███▏      | 63/200 [5:50:18<11:51:39, 311.67s/it][I 2024-12-16 00:24:26,403] Trial 63 finished with value: 0.7201099347206517 and parameters: {'n_epochs': 638, 'lr': 0.0010191893819813242, 'weight_decay': 3.9638287684780295e-08, 'batch_size': 256, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  32%|███▏      | 64/200 [5:51:34<9:06:02, 240.90s/it] [I 2024-12-16 00:26:13,152] Trial 64 finished with value: 0.7210422999959347 and parameters: {'n_epochs': 863, 'lr': 0.0006609304930998948, 'weight_decay': 3.580545269688332e-07, 'batch_size': 256, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  32%|███▎      | 65/200 [5:53:21<7:31:28, 200.66s/it][I 2024-12-16 00:28:43,229] Trial 65 finished with value: 0.7190243675952336 and parameters: {'n_epochs': 1264, 'lr': 0.0008611176824224407, 'weight_decay': 1.3718259910416683e-07, 'batch_size': 256, 'n_genotype': 9, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 3}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  33%|███▎      | 66/200 [5:55:51<6:54:14, 185.48s/it][I 2024-12-16 00:31:29,627] Trial 66 finished with value: 0.7223987037446955 and parameters: {'n_epochs': 1383, 'lr': 0.000374897227428299, 'weight_decay': 7.408427006059334e-08, 'batch_size': 256, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 10, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  34%|███▎      | 67/200 [5:58:37<6:38:27, 179.76s/it][I 2024-12-16 00:39:05,574] Trial 67 finished with value: 0.7113630553704565 and parameters: {'n_epochs': 930, 'lr': 1.0045885649397894e-05, 'weight_decay': 1.4743727309323567e-06, 'batch_size': 32, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  34%|███▍      | 68/200 [6:06:13<9:37:45, 262.61s/it][I 2024-12-16 00:43:54,852] Trial 68 finished with value: 0.6256974038629284 and parameters: {'n_epochs': 2463, 'lr': 1.256701112083561e-06, 'weight_decay': 1.9717518694423731e-07, 'batch_size': 256, 'n_genotype': 7, 'n_history': 4, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  34%|███▍      | 69/200 [6:11:03<9:50:50, 270.61s/it][I 2024-12-16 00:45:26,449] Trial 69 finished with value: 0.7217762269363692 and parameters: {'n_epochs': 766, 'lr': 0.006859346304128054, 'weight_decay': 6.300341046290106e-07, 'batch_size': 256, 'n_genotype': 11, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 2}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  35%|███▌      | 70/200 [6:12:34<7:49:58, 216.91s/it][I 2024-12-16 00:49:59,806] Trial 70 finished with value: 0.71675374340454 and parameters: {'n_epochs': 1532, 'lr': 0.0014934283021821595, 'weight_decay': 2.5239432717660067e-08, 'batch_size': 128, 'n_genotype': 8, 'n_history': 6, 'n_phenotype': 8, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  36%|███▌      | 71/200 [6:17:08<8:22:45, 233.84s/it][I 2024-12-16 00:58:59,506] Trial 71 finished with value: 0.7285235314618848 and parameters: {'n_epochs': 1043, 'lr': 0.0025550283614254976, 'weight_decay': 1.1377661921987172e-07, 'batch_size': 32, 'n_genotype': 3, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  36%|███▌      | 72/200 [6:26:07<11:34:36, 325.60s/it][I 2024-12-16 01:07:44,506] Trial 72 finished with value: 0.7292432322671104 and parameters: {'n_epochs': 1013, 'lr': 0.003611685744644105, 'weight_decay': 4.8038943689589927e-08, 'batch_size': 32, 'n_genotype': 10, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  36%|███▋      | 73/200 [6:34:52<13:35:48, 385.42s/it][I 2024-12-16 01:16:54,812] Trial 73 finished with value: 0.7285265960096288 and parameters: {'n_epochs': 1135, 'lr': 0.004505704553429024, 'weight_decay': 3.1433754057094914e-08, 'batch_size': 32, 'n_genotype': 10, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 42 with value: 0.7319898429951536.
# Optuna Trials:  37%|███▋      | 74/200 [6:44:03<15:13:15, 434.89s/it][I 2024-12-16 01:26:42,275] Trial 74 finished with value: 0.7327863306889727 and parameters: {'n_epochs': 1185, 'lr': 0.0035707924608779627, 'weight_decay': 5.3037801470463216e-08, 'batch_size': 32, 'n_genotype': 10, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 74 with value: 0.7327863306889727.
# Optuna Trials:  38%|███▊      | 75/200 [6:53:50<16:41:22, 480.66s/it][I 2024-12-16 01:37:07,189] Trial 75 finished with value: 0.7299402545644819 and parameters: {'n_epochs': 1198, 'lr': 0.0033943681059534167, 'weight_decay': 5.432182830314167e-08, 'batch_size': 32, 'n_genotype': 10, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 74 with value: 0.7327863306889727.
# Optuna Trials:  38%|███▊      | 76/200 [7:04:15<18:02:47, 523.94s/it][I 2024-12-16 01:48:10,122] Trial 76 finished with value: 0.7372982943113392 and parameters: {'n_epochs': 1334, 'lr': 0.005899696911035607, 'weight_decay': 1.9275297219197642e-08, 'batch_size': 32, 'n_genotype': 8, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  38%|███▊      | 77/200 [7:15:18<19:19:33, 565.63s/it][I 2024-12-16 01:50:54,032] Trial 77 finished with value: 0.7121171780591091 and parameters: {'n_epochs': 1336, 'lr': 0.006703758032474118, 'weight_decay': 1.7137030186055733e-08, 'batch_size': 256, 'n_genotype': 8, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  39%|███▉      | 78/200 [7:18:02<15:05:04, 445.12s/it][I 2024-12-16 01:56:46,108] Trial 78 finished with value: 0.7246464161160955 and parameters: {'n_epochs': 1249, 'lr': 0.0021298062362993505, 'weight_decay': 1.0446094616799206e-08, 'batch_size': 64, 'n_genotype': 11, 'n_history': 5, 'n_phenotype': 10, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  40%|███▉      | 79/200 [7:23:54<14:01:21, 417.20s/it][I 2024-12-16 02:00:52,698] Trial 79 finished with value: 0.7230792042534576 and parameters: {'n_epochs': 1399, 'lr': 0.005255118644720283, 'weight_decay': 1.394467288753777e-08, 'batch_size': 128, 'n_genotype': 9, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  40%|████      | 80/200 [7:28:01<12:12:02, 366.02s/it][I 2024-12-16 02:04:19,348] Trial 80 finished with value: 0.7121842322437554 and parameters: {'n_epochs': 1717, 'lr': 0.0017674669124457256, 'weight_decay': 2.1236496605678312e-08, 'batch_size': 256, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  40%|████      | 81/200 [7:31:27<10:31:06, 318.21s/it][I 2024-12-16 02:14:56,642] Trial 81 finished with value: 0.729748779801045 and parameters: {'n_epochs': 1310, 'lr': 0.003519368156040996, 'weight_decay': 6.16226952901241e-08, 'batch_size': 32, 'n_genotype': 10, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  41%|████      | 82/200 [7:42:04<13:34:04, 413.93s/it][I 2024-12-16 02:24:17,869] Trial 82 finished with value: 0.727994093750721 and parameters: {'n_epochs': 1149, 'lr': 0.003474113249046948, 'weight_decay': 3.229552360745149e-08, 'batch_size': 32, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  42%|████▏     | 83/200 [7:51:26<14:53:20, 458.12s/it][I 2024-12-16 02:34:02,702] Trial 83 finished with value: 0.7273322661063949 and parameters: {'n_epochs': 1197, 'lr': 0.0022259307019892437, 'weight_decay': 4.878635960809366e-08, 'batch_size': 32, 'n_genotype': 10, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  42%|████▏     | 84/200 [8:01:11<15:59:11, 496.14s/it][I 2024-12-16 02:46:19,716] Trial 84 finished with value: 0.7306904394767153 and parameters: {'n_epochs': 1487, 'lr': 0.00577621936107593, 'weight_decay': 8.24641678520924e-08, 'batch_size': 32, 'n_genotype': 9, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  42%|████▎     | 85/200 [8:13:28<18:09:25, 568.40s/it][I 2024-12-16 02:58:33,557] Trial 85 finished with value: 0.722636029869842 and parameters: {'n_epochs': 1500, 'lr': 0.0069220493880272176, 'weight_decay': 1.1112977434256833e-07, 'batch_size': 32, 'n_genotype': 8, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  43%|████▎     | 86/200 [8:25:41<19:34:15, 618.03s/it][I 2024-12-16 03:03:16,716] Trial 86 finished with value: 0.7219752763723049 and parameters: {'n_epochs': 1607, 'lr': 0.004053692517880865, 'weight_decay': 8.25685821903092e-08, 'batch_size': 128, 'n_genotype': 9, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  44%|████▎     | 87/200 [8:30:25<16:14:45, 517.57s/it][I 2024-12-16 03:15:10,767] Trial 87 finished with value: 0.730153408014775 and parameters: {'n_epochs': 1449, 'lr': 0.0054913628689963415, 'weight_decay': 2.013420210233936e-07, 'batch_size': 32, 'n_genotype': 6, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  44%|████▍     | 88/200 [8:42:19<17:56:09, 576.51s/it][I 2024-12-16 03:17:55,662] Trial 88 finished with value: 0.7029090362299517 and parameters: {'n_epochs': 1341, 'lr': 2.3241944209721982e-05, 'weight_decay': 2.819427776293924e-08, 'batch_size': 256, 'n_genotype': 7, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  44%|████▍     | 89/200 [8:45:04<13:58:06, 453.03s/it][I 2024-12-16 03:20:28,753] Trial 89 finished with value: 0.7229054286667245 and parameters: {'n_epochs': 835, 'lr': 0.0011950489294770496, 'weight_decay': 4.0420435399558355e-08, 'batch_size': 128, 'n_genotype': 9, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  45%|████▌     | 90/200 [8:47:37<11:05:35, 363.05s/it][I 2024-12-16 03:29:21,634] Trial 90 finished with value: 0.7196718602985474 and parameters: {'n_epochs': 1891, 'lr': 0.009656270617781442, 'weight_decay': 8.684825506999365e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  46%|████▌     | 91/200 [8:56:29<12:32:05, 414.00s/it][I 2024-12-16 03:41:00,473] Trial 91 finished with value: 0.7288048291421776 and parameters: {'n_epochs': 1419, 'lr': 0.005235310896172729, 'weight_decay': 1.7611954269009119e-07, 'batch_size': 32, 'n_genotype': 6, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  46%|████▌     | 92/200 [9:08:08<14:59:00, 499.45s/it][I 2024-12-16 03:52:53,332] Trial 92 finished with value: 0.7325600964957035 and parameters: {'n_epochs': 1458, 'lr': 0.005886560075131311, 'weight_decay': 1.1736129517603093e-07, 'batch_size': 32, 'n_genotype': 8, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  46%|████▋     | 93/200 [9:20:01<16:44:51, 563.47s/it][I 2024-12-16 04:05:27,073] Trial 93 finished with value: 0.7187579247390239 and parameters: {'n_epochs': 1544, 'lr': 0.007567016606376518, 'weight_decay': 1.1381068503999243e-07, 'batch_size': 32, 'n_genotype': 8, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  47%|████▋     | 94/200 [9:32:35<18:16:18, 620.55s/it][I 2024-12-16 04:19:14,209] Trial 94 finished with value: 0.7266839747982946 and parameters: {'n_epochs': 1671, 'lr': 0.0020684886896133476, 'weight_decay': 7.183213509468918e-08, 'batch_size': 32, 'n_genotype': 8, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  48%|████▊     | 95/200 [9:46:22<19:54:25, 682.53s/it][I 2024-12-16 04:29:41,642] Trial 95 finished with value: 0.7170457174679711 and parameters: {'n_epochs': 1280, 'lr': 0.003068435214167116, 'weight_decay': 1.5816036203743078e-07, 'batch_size': 32, 'n_genotype': 2, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  48%|████▊     | 96/200 [9:56:49<19:14:23, 666.00s/it][I 2024-12-16 04:32:39,437] Trial 96 finished with value: 0.716310488633806 and parameters: {'n_epochs': 1476, 'lr': 0.004248757706176207, 'weight_decay': 4.211779796941348e-08, 'batch_size': 256, 'n_genotype': 1, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  48%|████▊     | 97/200 [9:59:47<14:51:52, 519.54s/it][I 2024-12-16 04:36:06,294] Trial 97 finished with value: 0.7207144325375323 and parameters: {'n_epochs': 1163, 'lr': 0.001400044754419303, 'weight_decay': 2.9584992772733755e-07, 'batch_size': 128, 'n_genotype': 7, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  49%|████▉     | 98/200 [10:03:14<12:03:44, 425.73s/it][I 2024-12-16 04:44:03,596] Trial 98 finished with value: 0.7245313365403601 and parameters: {'n_epochs': 976, 'lr': 0.00239889562384097, 'weight_decay': 1.714646373282742e-08, 'batch_size': 32, 'n_genotype': 9, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  50%|████▉     | 99/200 [10:11:11<12:22:41, 441.20s/it][I 2024-12-16 04:46:07,860] Trial 99 finished with value: 0.7246463488452927 and parameters: {'n_epochs': 1041, 'lr': 0.004747273341104392, 'weight_decay': 5.9078888896587326e-08, 'batch_size': 256, 'n_genotype': 3, 'n_history': 5, 'n_phenotype': 9, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  50%|█████     | 100/200 [10:13:16<9:36:52, 346.12s/it][I 2024-12-16 04:52:28,472] Trial 100 finished with value: 0.7272451463430303 and parameters: {'n_epochs': 1374, 'lr': 0.006075609625813638, 'weight_decay': 2.1999159562534064e-08, 'batch_size': 64, 'n_genotype': 9, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  50%|█████     | 101/200 [10:19:36<9:48:10, 356.47s/it][I 2024-12-16 05:04:20,432] Trial 101 finished with value: 0.7295369138364081 and parameters: {'n_epochs': 1458, 'lr': 0.006056986463609329, 'weight_decay': 9.841610597908722e-08, 'batch_size': 32, 'n_genotype': 6, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  51%|█████     | 102/200 [10:31:28<12:36:25, 463.12s/it][I 2024-12-16 05:17:10,998] Trial 102 finished with value: 0.7284547032954974 and parameters: {'n_epochs': 1621, 'lr': 0.0053164422887955805, 'weight_decay': 3.659646848001048e-07, 'batch_size': 32, 'n_genotype': 8, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  52%|█████▏    | 103/200 [10:44:19<14:57:49, 555.35s/it][I 2024-12-16 05:27:08,330] Trial 103 finished with value: 0.7148112617174212 and parameters: {'n_epochs': 1253, 'lr': 0.00780424548388826, 'weight_decay': 2.1607029706374063e-07, 'batch_size': 32, 'n_genotype': 3, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  52%|█████▏    | 104/200 [10:54:16<15:08:42, 567.95s/it][I 2024-12-16 05:38:08,402] Trial 104 finished with value: 0.7310798754193226 and parameters: {'n_epochs': 1341, 'lr': 0.001652008088534531, 'weight_decay': 1.2254697119733458e-07, 'batch_size': 32, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  52%|█████▎    | 105/200 [11:05:16<15:43:00, 595.58s/it][I 2024-12-16 05:47:09,691] Trial 105 finished with value: 0.7285327519339451 and parameters: {'n_epochs': 1103, 'lr': 0.0015902663978945404, 'weight_decay': 1.242064966118154e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  53%|█████▎    | 106/200 [11:14:18<15:07:33, 579.30s/it][I 2024-12-16 05:51:42,201] Trial 106 finished with value: 0.7142839045322023 and parameters: {'n_epochs': 1532, 'lr': 0.000940399435386441, 'weight_decay': 3.422228738081274e-08, 'batch_size': 128, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  54%|█████▎    | 107/200 [11:18:50<12:35:15, 487.26s/it][I 2024-12-16 05:54:25,644] Trial 107 finished with value: 0.7247115874138311 and parameters: {'n_epochs': 1380, 'lr': 0.0024603551354774548, 'weight_decay': 7.158551683272089e-08, 'batch_size': 256, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  54%|█████▍    | 108/200 [11:21:33<9:58:10, 390.11s/it] [I 2024-12-16 06:04:56,352] Trial 108 finished with value: 0.7238907259283128 and parameters: {'n_epochs': 1286, 'lr': 0.0029857404907215755, 'weight_decay': 1.3810424400657394e-08, 'batch_size': 32, 'n_genotype': 10, 'n_history': 6, 'n_phenotype': 5, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  55%|█████▍    | 109/200 [11:32:04<11:41:08, 462.29s/it][I 2024-12-16 06:07:03,198] Trial 109 finished with value: 0.7073128447971447 and parameters: {'n_epochs': 1063, 'lr': 0.00013413210186050283, 'weight_decay': 1.5250510225894904e-07, 'batch_size': 256, 'n_genotype': 2, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  55%|█████▌    | 110/200 [11:34:11<9:02:29, 361.66s/it] [I 2024-12-16 06:12:41,515] Trial 110 finished with value: 0.7157163930491856 and parameters: {'n_epochs': 1232, 'lr': 0.0018811003001763078, 'weight_decay': 4.7252818837772814e-08, 'batch_size': 64, 'n_genotype': 1, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  56%|█████▌    | 111/200 [11:39:49<8:46:04, 354.66s/it][I 2024-12-16 06:24:29,077] Trial 111 finished with value: 0.73671744580843 and parameters: {'n_epochs': 1447, 'lr': 0.004091850677322757, 'weight_decay': 9.372704976628235e-08, 'batch_size': 32, 'n_genotype': 9, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  56%|█████▌    | 112/200 [11:51:37<11:15:26, 460.53s/it][I 2024-12-16 06:35:46,293] Trial 112 finished with value: 0.718579520583228 and parameters: {'n_epochs': 1349, 'lr': 0.004209472536759226, 'weight_decay': 1.674558590916895e-05, 'batch_size': 32, 'n_genotype': 9, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  56%|█████▋    | 113/200 [12:02:54<12:42:01, 525.53s/it][I 2024-12-16 06:47:58,137] Trial 113 finished with value: 0.722180123319285 and parameters: {'n_epochs': 1506, 'lr': 3.618434281954673e-05, 'weight_decay': 8.290458107695183e-08, 'batch_size': 32, 'n_genotype': 10, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  57%|█████▋    | 114/200 [12:15:06<14:01:58, 587.43s/it][I 2024-12-16 07:01:07,166] Trial 114 finished with value: 0.7291762736725854 and parameters: {'n_epochs': 1578, 'lr': 0.00343297038872195, 'weight_decay': 1.0206810781056213e-07, 'batch_size': 32, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  57%|█████▊    | 115/200 [12:28:15<15:17:52, 647.91s/it][I 2024-12-16 07:11:45,976] Trial 115 finished with value: 0.7306629595029053 and parameters: {'n_epochs': 1309, 'lr': 0.002625249513327984, 'weight_decay': 6.029279787908276e-08, 'batch_size': 32, 'n_genotype': 14, 'n_history': 6, 'n_phenotype': 7, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  58%|█████▊    | 116/200 [12:38:54<15:03:14, 645.18s/it][I 2024-12-16 07:21:00,242] Trial 116 finished with value: 0.7225496507808684 and parameters: {'n_epochs': 1144, 'lr': 0.002756875472525719, 'weight_decay': 2.959846104371385e-08, 'batch_size': 32, 'n_genotype': 14, 'n_history': 6, 'n_phenotype': 7, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  58%|█████▊    | 117/200 [12:48:08<14:14:46, 617.90s/it][I 2024-12-16 07:31:44,263] Trial 117 finished with value: 0.722219160307678 and parameters: {'n_epochs': 1309, 'lr': 0.008695054345922592, 'weight_decay': 5.5324179019380485e-08, 'batch_size': 32, 'n_genotype': 15, 'n_history': 6, 'n_phenotype': 4, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  59%|█████▉    | 118/200 [12:58:52<14:15:10, 625.74s/it][I 2024-12-16 07:39:17,505] Trial 118 finished with value: 0.721974329612767 and parameters: {'n_epochs': 914, 'lr': 0.00159457873480731, 'weight_decay': 1.368115629780537e-07, 'batch_size': 32, 'n_genotype': 9, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  60%|█████▉    | 119/200 [13:06:25<12:54:53, 573.99s/it][I 2024-12-16 07:49:11,410] Trial 119 finished with value: 0.7269921839793373 and parameters: {'n_epochs': 1219, 'lr': 0.0039691810350457185, 'weight_decay': 3.8965055644855096e-08, 'batch_size': 32, 'n_genotype': 14, 'n_history': 6, 'n_phenotype': 6, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  60%|██████    | 120/200 [13:16:19<12:53:17, 579.96s/it][I 2024-12-16 08:00:57,272] Trial 120 finished with value: 0.7246335580523934 and parameters: {'n_epochs': 1452, 'lr': 0.0024153209841181545, 'weight_decay': 7.621352447899508e-08, 'batch_size': 32, 'n_genotype': 8, 'n_history': 6, 'n_phenotype': 7, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  60%|██████    | 121/200 [13:28:05<13:33:20, 617.73s/it][I 2024-12-16 08:04:57,763] Trial 121 finished with value: 0.7125143989327356 and parameters: {'n_epochs': 1389, 'lr': 0.0020345547507636514, 'weight_decay': 6.52343602354306e-08, 'batch_size': 128, 'n_genotype': 9, 'n_history': 6, 'n_phenotype': 8, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  61%|██████    | 122/200 [13:32:06<10:55:55, 504.56s/it][I 2024-12-16 08:18:49,664] Trial 122 finished with value: 0.72399130700655 and parameters: {'n_epochs': 1722, 'lr': 0.003280166825511224, 'weight_decay': 1.0206161064230659e-07, 'batch_size': 32, 'n_genotype': 10, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# ...
# Optuna Trials:  81%|████████  | 162/200 [18:03:01<4:22:46, 414.90s/it][I 2024-12-16 12:43:57,430] Trial 162 finished with value: 0.7288636459822682 and parameters: {'n_epochs': 1175, 'lr': 0.0016967066552031724, 'weight_decay': 1.1188204530636447e-07, 'batch_size': 32, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  82%|████████▏ | 163/200 [18:11:05<4:28:40, 435.68s/it][I 2024-12-16 12:52:39,421] Trial 163 finished with value: 0.7313409594655119 and parameters: {'n_epochs': 1265, 'lr': 0.0027720995490617675, 'weight_decay': 1.732145802274943e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  82%|████████▏ | 164/200 [18:19:47<4:36:56, 461.57s/it][I 2024-12-16 13:01:30,509] Trial 164 finished with value: 0.7311771392620005 and parameters: {'n_epochs': 1284, 'lr': 0.002715847045320015, 'weight_decay': 1.617794068463868e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  82%|████████▎ | 165/200 [18:28:38<4:41:24, 482.43s/it][I 2024-12-16 13:08:39,018] Trial 165 finished with value: 0.7313081513857849 and parameters: {'n_epochs': 1029, 'lr': 0.0011614934789999996, 'weight_decay': 2.6681527401517826e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  83%|████████▎ | 166/200 [18:35:47<4:24:12, 466.25s/it][I 2024-12-16 13:15:54,730] Trial 166 finished with value: 0.7226980075433602 and parameters: {'n_epochs': 1011, 'lr': 0.0011159390491604726, 'weight_decay': 2.2771993207506016e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  84%|████████▎ | 167/200 [18:43:03<4:11:23, 457.09s/it][I 2024-12-16 13:21:30,172] Trial 167 finished with value: 0.7266944838490375 and parameters: {'n_epochs': 811, 'lr': 0.001571616339770489, 'weight_decay': 1.7046410463484433e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  84%|████████▍ | 168/200 [18:48:38<3:44:19, 420.60s/it][I 2024-12-16 13:26:27,932] Trial 168 finished with value: 0.725636892533921 and parameters: {'n_epochs': 711, 'lr': 0.0006552499677390501, 'weight_decay': 3.143189858695374e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  84%|████████▍ | 169/200 [18:53:36<3:18:16, 383.75s/it][I 2024-12-16 13:33:01,892] Trial 169 finished with value: 0.7179383465657884 and parameters: {'n_epochs': 951, 'lr': 7.796104958722431e-05, 'weight_decay': 2.6167709038589776e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  85%|████████▌ | 170/200 [19:00:10<3:13:24, 386.81s/it][I 2024-12-16 13:40:35,860] Trial 170 finished with value: 0.7244548047243666 and parameters: {'n_epochs': 1092, 'lr': 0.0008087104115056954, 'weight_decay': 1.4175033537806408e-07, 'batch_size': 32, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  86%|████████▌ | 171/200 [19:07:44<3:16:41, 406.96s/it][I 2024-12-16 13:49:32,091] Trial 171 finished with value: 0.7330483152894955 and parameters: {'n_epochs': 1267, 'lr': 0.0019240773145826763, 'weight_decay': 4.032315553524419e-07, 'batch_size': 32, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  86%|████████▌ | 172/200 [19:16:40<3:28:00, 445.74s/it][I 2024-12-16 13:58:04,660] Trial 172 finished with value: 0.7284103861452973 and parameters: {'n_epochs': 1275, 'lr': 0.0012384174974842581, 'weight_decay': 6.51759098701402e-07, 'batch_size': 32, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  86%|████████▋ | 173/200 [19:25:13<3:29:36, 465.79s/it][I 2024-12-16 14:06:16,259] Trial 173 finished with value: 0.7277606281945881 and parameters: {'n_epochs': 1216, 'lr': 0.001855951864895793, 'weight_decay': 1.941121918858711e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 3}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  87%|████████▋ | 174/200 [19:33:24<3:25:11, 473.53s/it][I 2024-12-16 14:14:07,048] Trial 174 finished with value: 0.7345807137665465 and parameters: {'n_epochs': 1132, 'lr': 0.0021688735257349135, 'weight_decay': 4.0411720561244486e-07, 'batch_size': 32, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  88%|████████▊ | 175/200 [19:41:15<3:16:57, 472.71s/it][I 2024-12-16 14:21:12,486] Trial 175 finished with value: 0.7269811648827603 and parameters: {'n_epochs': 1038, 'lr': 0.0023073697753528805, 'weight_decay': 4.039506076821476e-07, 'batch_size': 32, 'n_genotype': 13, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  88%|████████▊ | 176/200 [19:48:20<3:03:24, 458.53s/it][I 2024-12-16 14:28:59,325] Trial 176 finished with value: 0.7274181964583752 and parameters: {'n_epochs': 1119, 'lr': 0.0029113719535642352, 'weight_decay': 1.222865030677402e-06, 'batch_size': 32, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  88%|████████▊ | 177/200 [19:56:07<2:56:43, 461.02s/it][I 2024-12-16 14:36:53,202] Trial 177 finished with value: 0.7272147243397916 and parameters: {'n_epochs': 1144, 'lr': 0.001965080595292768, 'weight_decay': 5.152546960739387e-07, 'batch_size': 32, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  89%|████████▉ | 178/200 [20:04:01<2:50:27, 464.88s/it][I 2024-12-16 14:45:47,172] Trial 178 finished with value: 0.7253907922889226 and parameters: {'n_epochs': 1265, 'lr': 0.001513827203358528, 'weight_decay': 1.6219772315223952e-07, 'batch_size': 32, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  90%|████████▉ | 179/200 [20:12:55<2:49:57, 485.61s/it][I 2024-12-16 14:55:31,993] Trial 179 finished with value: 0.7193423743165585 and parameters: {'n_epochs': 1352, 'lr': 0.0026697260055985553, 'weight_decay': 7.37759090068773e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 3}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  90%|█████████ | 180/200 [20:22:40<2:51:47, 515.37s/it][I 2024-12-16 15:03:48,079] Trial 180 finished with value: 0.7222733454486757 and parameters: {'n_epochs': 1201, 'lr': 0.002177405986429215, 'weight_decay': 3.190000656676691e-07, 'batch_size': 32, 'n_genotype': 10, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  90%|█████████ | 181/200 [20:30:56<2:41:22, 509.58s/it][I 2024-12-16 15:07:46,627] Trial 181 finished with value: 0.7199272095336571 and parameters: {'n_epochs': 994, 'lr': 0.0013573463356409206, 'weight_decay': 2.883809072623742e-07, 'batch_size': 64, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  91%|█████████ | 182/200 [20:34:54<2:08:28, 428.27s/it][I 2024-12-16 15:15:21,156] Trial 182 finished with value: 0.7309202873144127 and parameters: {'n_epochs': 1093, 'lr': 0.0009525474898387153, 'weight_decay': 2.390932753173901e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  92%|█████████▏| 183/200 [20:42:29<2:03:34, 436.15s/it][I 2024-12-16 15:22:42,303] Trial 183 finished with value: 0.7357051467223701 and parameters: {'n_epochs': 1058, 'lr': 0.0016833186380555002, 'weight_decay': 2.2533330984877252e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  92%|█████████▏| 184/200 [20:49:50<1:56:42, 437.65s/it][I 2024-12-16 15:30:32,939] Trial 184 finished with value: 0.7277353462967369 and parameters: {'n_epochs': 1163, 'lr': 0.001750649503072842, 'weight_decay': 2.5089724359475213e-07, 'batch_size': 32, 'n_genotype': 13, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  92%|█████████▎| 185/200 [20:57:41<1:51:53, 447.55s/it][I 2024-12-16 15:38:05,162] Trial 185 finished with value: 0.7272005793866299 and parameters: {'n_epochs': 1072, 'lr': 0.0034293869045254706, 'weight_decay': 2.0895858386307904e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  93%|█████████▎| 186/200 [21:05:13<1:44:45, 448.95s/it][I 2024-12-16 15:46:41,258] Trial 186 finished with value: 0.7207954534126817 and parameters: {'n_epochs': 1240, 'lr': 0.001176118375791904, 'weight_decay': 4.09259881124095e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  94%|█████████▎| 187/200 [21:13:49<1:41:38, 469.09s/it][I 2024-12-16 15:55:55,998] Trial 187 finished with value: 0.7312699016247681 and parameters: {'n_epochs': 1309, 'lr': 0.0022057434792557016, 'weight_decay': 1.6931694234446718e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  94%|█████████▍| 188/200 [21:23:04<1:38:57, 494.79s/it][I 2024-12-16 16:04:57,505] Trial 188 finished with value: 0.7291513671795973 and parameters: {'n_epochs': 1318, 'lr': 0.0027103931549191367, 'weight_decay': 1.2819841851383954e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  94%|█████████▍| 189/200 [21:32:05<1:33:16, 508.80s/it][I 2024-12-16 16:14:22,293] Trial 189 finished with value: 0.7220222141028252 and parameters: {'n_epochs': 1371, 'lr': 0.002145566879480732, 'weight_decay': 1.7296445969790328e-07, 'batch_size': 32, 'n_genotype': 13, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  95%|█████████▌| 190/200 [21:41:30<1:27:35, 525.60s/it][I 2024-12-16 16:23:15,342] Trial 190 finished with value: 0.727757968662784 and parameters: {'n_epochs': 1293, 'lr': 0.004020477914358751, 'weight_decay': 1.0895104986652867e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  96%|█████████▌| 191/200 [21:50:23<1:19:10, 527.83s/it][I 2024-12-16 16:30:43,253] Trial 191 finished with value: 0.7253871607586089 and parameters: {'n_epochs': 1095, 'lr': 0.001789636706415288, 'weight_decay': 2.404751697916587e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  96%|█████████▌| 192/200 [21:57:51<1:07:10, 503.86s/it][I 2024-12-16 16:37:25,854] Trial 192 finished with value: 0.7255440924120617 and parameters: {'n_epochs': 1205, 'lr': 0.0014948139115926293, 'weight_decay': 1.90845139478665e-07, 'batch_size': 32, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7372982943113392.
# Optuna Trials:  96%|█████████▋| 193/200 [22:04:34<55:14, 473.48s/it]  [I 2024-12-16 16:43:15,364] Trial 193 finished with value: 0.7377684524348088 and parameters: {'n_epochs': 1042, 'lr': 0.002295940611801856, 'weight_decay': 1.3988230833611534e-07, 'batch_size': 32, 'n_genotype': 13, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 193 with value: 0.7377684524348088.
# Optuna Trials:  97%|█████████▋| 194/200 [22:10:23<43:37, 436.29s/it][I 2024-12-16 16:49:03,870] Trial 194 finished with value: 0.7308221488519353 and parameters: {'n_epochs': 1044, 'lr': 0.0030580881464024093, 'weight_decay': 1.3861153366912847e-07, 'batch_size': 32, 'n_genotype': 13, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 5}. Best is trial 193 with value: 0.7377684524348088.
# Optuna Trials:  98%|█████████▊| 195/200 [22:16:12<34:09, 409.95s/it][I 2024-12-16 16:54:21,626] Trial 195 finished with value: 0.7270162654361749 and parameters: {'n_epochs': 956, 'lr': 0.002301917549252038, 'weight_decay': 1.5837110078567732e-07, 'batch_size': 32, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 193 with value: 0.7377684524348088.
# Optuna Trials:  98%|█████████▊| 196/200 [22:21:29<25:29, 382.29s/it][I 2024-12-16 17:01:20,758] Trial 196 finished with value: 0.71145126955128 and parameters: {'n_epochs': 1268, 'lr': 5.597468388672673e-06, 'weight_decay': 9.318398164287939e-08, 'batch_size': 32, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 193 with value: 0.7377684524348088.
# Optuna Trials:  98%|█████████▊| 197/200 [22:28:29<19:40, 393.35s/it][I 2024-12-16 17:07:47,060] Trial 197 finished with value: 0.7213160874922825 and parameters: {'n_epochs': 1156, 'lr': 0.002654292769980516, 'weight_decay': 1.2054253891603965e-07, 'batch_size': 32, 'n_genotype': 10, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 193 with value: 0.7377684524348088.
# Optuna Trials:  99%|█████████▉| 198/200 [22:34:55<13:02, 391.23s/it][I 2024-12-16 17:15:31,257] Trial 198 finished with value: 0.7288114177061904 and parameters: {'n_epochs': 1393, 'lr': 0.002023564218198097, 'weight_decay': 1.812314282202657e-07, 'batch_size': 32, 'n_genotype': 13, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 193 with value: 0.7377684524348088.
# Optuna Trials: 100%|█████████▉| 199/200 [22:42:39<06:53, 413.12s/it][I 2024-12-16 17:23:05,462] Trial 199 finished with value: 0.7210337180499857 and parameters: {'n_epochs': 1332, 'lr': 0.0033216100952207926, 'weight_decay': 9.7648239418499e-08, 'batch_size': 32, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 5}. Best is trial 193 with value: 0.7377684524348088.
# Optuna Trials: 100%|██████████| 200/200 [22:50:13<00:00, 411.07s/it]
# Number of finished trials:  200
# Best trial:
#   Value (Mean AUC):  0.7377684524348088
#   Params:
#     n_epochs: 1042
#     lr: 0.002295940611801856
#     weight_decay: 1.3988230833611534e-07
#     batch_size: 32
#     n_genotype: 13
#     n_history: 6
#     n_phenotype: 12
#     n_behaviour: 5
#
# Best Trial Metrics:
# Selected Features: ['rs591058', 'rs2252070', 'class1_SNP_risk_score', 'rs1144393', 'rs1800012', 'rs9340799', 'rs1800795', 'rs970547', 'rs13946', 'rs4789932', 'rs4986938', 'sex', 'rs650108', 'tracking_period_injury', 'average_run_hours', 'lower_limb_days_total', 'EDEQ_total', 'Age', 'average_interval_training_frequency', 'Duty_factor_12', 'Impact_peak_12', 'Q_angle', 'navicular_drop', 'Q_angle_asymmetry', 'knee_flexion_peak_torque', 'BMD_spine', 'hip_abduction_peak_torque', 'navicular_drop_asymmetry', 'knee_extension_peak_torque', 'VALR_12', 'BMI', 'past_month_distance', 'past_month_ratio', 'SC_past_season', 'non_running_past_season', 'fat_intake_avg']
# Average AUC: 0.7378 ± 0.0317
# Average F1 Score: 0.1673 ± 0.0557
# Average Accuracy: 0.9073 ± 0.0062
# Average Precision: 0.4841 ± 0.1696

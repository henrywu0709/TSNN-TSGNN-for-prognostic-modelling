# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score, precision_score
from imblearn.over_sampling import RandomOverSampler, ADASYN, SMOTE
import optuna
from joblib import Parallel, delayed
from tqdm import tqdm
import random
import warnings
from optuna.exceptions import TrialPruned

import os

# Limit each parallel process to one thread per library
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'
os.environ['NUMEXPR_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['VECLIB_MAXIMUM_THREADS'] = '1'
os.environ['TORCH_NUM_THREADS'] = '1'  # For PyTorch

# Additional control for PyTorch if needed
import torch
torch.set_num_threads(1)

# # For reproducibility
# def set_seed(seed=42):
#     random.seed(seed)
#     np.random.seed(seed)
#     torch.manual_seed(seed)

# set_seed()

# Suppress warnings for cleaner output
warnings.filterwarnings("ignore")

# Load the dataset
data = pd.read_excel("class1_dataset.xlsx")

# Define feature groups (as provided)
feature_groups = {
    'Genotype': [
        'rs11225395', 'rs1144393', 'rs650108', 'rs591058', 'rs2252070', 'rs4986938', 'rs1800012', 'rs4789932', 'rs9340799', 'rs970547', 
        'rs1800795', 'rs13946', 'rs12722', 'class1_SNP_risk_score', 'rs7528684', 'rs4919510', 'rs1937810', 'rs6481512', 'rs1249269', 
        'rs12574452', 'rs12429486', 'rs4454832', 'rs2761884', 'rs62051384', 'rs4362400', 'rs2586488', 'rs2277698', 'rs1045485', 
        'rs143383', 'rs17576', 'rs2305948', 'rs1011814', 'rs11154027', 'rs2234693', 'rs1643821', 'rs2010963', 'rs10263021', 'rs149047058', 
        'rs420257', 'rs42517', 'rs42522', 'rs42531', 'rs413826', 'rs2104772', 'rs1330363', 'class12_SNP_risk_score', 'rs3753841', 
        'rs57104447', 'rs1887632', 'rs4654760', 'rs1137101', 'rs2306033', 'rs2277268', 'rs4988321', 'rs11232681', 'rs1718119', 'rs3751143', 
        'rs1544410', 'rs2228570', 'rs4328262', 'rs1021188', 'rs74544784', 'rs78391032', 'rs77569527', 'rs117544024', 'rs912336', 
        'rs3218791', 'rs911263', 'rs2525504', 'rs17756404', 'rs4903399', 'rs10132091', 'rs17583842', 'rs1676303', 'rs11629171', 
        'rs2281518', 'rs2285053', 'rs71404070', 'rs710079', 'rs2858056', 'rs820218', 'rs3018362', 'rs1800470', 'rs1800469', 'rs25487', 
        'rs25489', 'rs2289360', 'rs183364169', 'rs11177', 'rs6617', 'rs3219008', 'rs13107325', 'rs60713544', 'rs145648292', 'rs4244032', 
        'rs12656106', 'rs3045', 'rs187483', 'rs4701616', 'rs144414988', 'rs1800629', 'rs10484958', 'rs4730153', 'rs1800797', 'rs1554606', 
        'rs2237352', 'rs4725069', 'rs12154667', 'rs1548456', 'rs3216902', 'rs35360670', 'rs13317', 'rs1800972', 'rs7035322', 'rs7021589', 
        'rs72758637', 'rs10759753', 'rs3789870', 'rs1138545', 'rs3196378', 'rs1134170', 'rs10992075', 'rs1590', 'rs144371252', 
        'rs761804508', 'class123_SNP_risk_score', 'sex'
    ],
    'History': [
        'Age', 'lower_limb_days_total', 'average_run_hours', 'average_interval_training_frequency', 'EDEQ_total', 'tracking_period_injury',
        'past_stress_injury', 'LEAF-Q', 'Athlete_Score', 'average_run_frequency', 'past_month_injury'
    ],
    'Phenotype': [
        'hip_abduction_peak_torque', 'total_ad_ab_ratio', 'knee_extension_peak_torque', 'knee_flexion_peak_torque', 'navicular_drop', 
        'navicular_drop_asymmetry', 'Q_angle', 'Q_angle_asymmetry', 'VALR_12', 'Impact_peak_12', 'Duty_factor_12', 'BMI', 'BMD_spine',
        'hip_abduction_peak_torque_asymmetry', 'hip_adduction_peak_torque', 'hip_adduction_peak_torque_asymmetry', 
        'knee_extension_peak_torque_asymmetry', 'knee_flexion_peak_torque_asymmetry', 'total_fl_ex_ratio', 'leg_lean_mass', 
        'hip_abduction_peak_angle', 'hip_abduction_peak_angle_asymmetry', 'hip_adduction_peak_angle', 'hip_adduction_peak_angle_asymmetry', 
        'ad_ab_ratio_asymmetry', 'knee_extension_peak_angle', 'knee_extension_peak_angle_asymmetry', 'knee_flexion_peak_angle', 
        'knee_flexion_peak_angle_asymmetry', 'fl_ex_ratio_asymmetry', 'VILR_10', 'VALR_10', 'VILR_asymmetry_10', 'VALR_asymmetry_10', 
        'Impact_peak_10', 'Impact_peak_asymmetry_10', 'Flight_time_10', 'Contact_time_10', 'Duty_factor_10', 'Step_frequency_10', 
        'Cadence_asymmetry_10', 'Duty_factor_asymmetry_10', 'VILR_12', 'VILR_asymmetry_12', 'VALR_asymmetry_12', 
        'Impact_peak_asymmetry_12', 'Flight_time_12', 'Contact_time_12', 'Step_frequency_12', 'Cadence_asymmetry_12', 
        'Duty_factor_asymmetry_12', 'Alt_strike', 'height', 'Mass', 'thigh_lean_mass', 'thigh_ffmi', 'lower_leg_lean_mass', 
        'lower_leg_ffmi', 'leg_ffmi', 'total_lean_mass', 'total_ffmi', 'calf_size', 'BMD_hip', 'BMD_body',
    ],
    'Behaviour': [
        'fat_intake_avg', 'past_month_distance', 'past_month_ratio', 'SC_past_season', 'non_running_past_season', 'fat_intake_BW', 
        'fat_percentage_avg', 'average_energy_availability', 'protein_intake_BW', 'omega3_intake_BW', 'vitaminD_intake_BW', 
        'vitaminC_intake_BW', 'vitaminE_intake_BW', 'calcium_intake_BW', 'copper_intake_BW', 'iron_intake_BW', 'glycine_intake_BW', 
        'arginine_intake_BW', 'past_month_min', 'past_week_ratio', 'past_month_volume_low', 'past_week_ratio_low', 'past_month_ratio_low', 
        'past_month_volume_moderate', 'past_week_ratio_moderate', 'past_month_ratio_moderate', 'past_month_volume_high', 
        'past_week_ratio_high', 'past_month_ratio_high', 'past_month_volume_very_high', 'past_week_ratio_very_high', 
        'past_month_ratio_very_high', 'past_month_calculated_volume', 'past_week_ratio_calculated_volume', 
        'past_month_ratio_calculated_volume', 'resistance_training_past_month', 'resistance_training_past_season', 
        'bodyweight_exercises_past_month', 'bodyweight_exercises_past_season', 'core_stability_past_month', 'core_stability_past_season', 
        'balance_training_past_month', 'balance_training_past_season', 'plyometrics_past_month', 'plyometrics_past_season', 
        'drills_past_month', 'drills_past_season', 'circuit_training_past_month', 'circuit_training_past_season', 'barefoot_past_month', 
        'barefoot_past_season', 'stretching_past_month', 'stretching_past_season', 'SC_past_month', 'non_running_past_month'
    ]
}

# Define predictors and outcome
X = data.drop(columns=['RRI'])  # Predictors
y = data['RRI']  # Outcome

# Ensure that the feature groups exist in the dataset
for group in feature_groups:
    feature_groups[group] = [feature for feature in feature_groups[group] if feature in X.columns]

num_features = len(X.columns)
feature_to_idx = {feature: idx for idx, feature in enumerate(X)}

# Initialize adjacency matrix with zeros
adjacency = np.zeros((num_features, num_features), dtype=np.float32)

# Define groups
genotype_features = feature_groups['Genotype']
history_features = feature_groups['History']
phenotype_features = feature_groups['Phenotype']
behaviour_features = feature_groups['Behaviour']

# Get indices for each group
genotype_indices = [feature_to_idx[feat] for feat in genotype_features]
history_indices = [feature_to_idx[feat] for feat in history_features]
phenotype_indices = [feature_to_idx[feat] for feat in phenotype_features]
behaviour_indices = [feature_to_idx[feat] for feat in behaviour_features]

# Genotype nodes: connect to every node except themselves
for i in genotype_indices:
    for j in range(num_features):
        if j != i:
            adjacency[i, j] = 1.0

# History nodes: connect to every node except genotype nodes and themselves
for i in history_indices:
    for j in range(num_features):
        if j not in genotype_indices and j != i:
            adjacency[i, j] = 1.0

# Phenotype nodes: connect to every node except genotype, history nodes, and themselves
for i in phenotype_indices:
    for j in range(num_features):
        if j not in genotype_indices and j not in history_indices and j != i:
            adjacency[i, j] = 1.0

# Behaviour nodes: connect to all other behaviour nodes except themselves
for i in behaviour_indices:
    for j in behaviour_indices:
        if j != i:
            adjacency[i, j] = 1.0

# Convert adjacency to tensor
adjacency_mask = torch.tensor(adjacency, dtype=torch.float32)

class CustomDataset(Dataset):
    def __init__(self, X, y):
        if isinstance(X, pd.DataFrame):
            self.X = X.values.astype(np.float32)
        elif isinstance(X, np.ndarray):
            self.X = X.astype(np.float32)
        else:
            raise TypeError("X should be a pandas DataFrame or a NumPy array.")
        self.y = y.astype(np.float32)
    
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

class CustomNetwork(nn.Module):
    def __init__(self, num_features, adjacency_mask):
        super(CustomNetwork, self).__init__()
        self.num_features = num_features

        # Register the fixed adjacency mask as a buffer (non-trainable)
        self.register_buffer('mask', adjacency_mask.float())  # Shape: (num_features, num_features)

        # Initialize connection weights (W_ij: from node j to node i)
        self.W = nn.Parameter(torch.randn(num_features, num_features) * 0.01)

        # Initialize bias for each node
        self.bias = nn.Parameter(torch.zeros(num_features))

        # Initialize output weights (from each node to the final output)
        self.output_weights = nn.Parameter(torch.randn(num_features) * 0.01)

        # Add Batch Normalization
        self.batch_norm = nn.BatchNorm1d(num_features)

    def forward(self, x, threshold=None):
        """
        x: input tensor of shape (batch_size, num_features)
        threshold: if provided, apply binary thresholding to gating
        """
        # Use the fixed mask directly
        learnable_mask = self.mask

        # Apply the learnable mask to connection weights
        W_masked = self.W * learnable_mask  # Shape: (num_features, num_features)

        # Compute incoming messages: (batch_size, num_features) @ (num_features, num_features) = (batch_size, num_features)
        incoming = torch.matmul(x, W_masked)

        # Element-wise multiplication with own feature value
        node_input = incoming * x  # Shape: (batch_size, num_features)

        node_input = self.batch_norm(node_input)

        # Add bias
        node_input += self.bias  # Broadcasting over batch

        # Apply Leaky ReLU activation
        node_output = F.leaky_relu(node_input)  # Shape: (batch_size, num_features)

        # Aggregate node outputs to final output
        output = torch.matmul(node_output, self.output_weights) # Shape: (batch_size,)

        return output  # Raw scores (logits)

# Import ReliefF for feature selection
from skrebate import ReliefF

def train_evaluate_fold(fold, train_index, val_index, X, y, selected_features, adjacency, feature_to_idx, 
                       n_epochs, lr, weight_decay, batch_size, threshold):
    """
    Function to train and evaluate the model on a single fold.
    This function is intended to be run in parallel.
    """
    # Split data
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]

    # Encode labels for binary classification
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y_train_enc = le.fit_transform(y_train)
    y_val_enc = le.transform(y_val)
    y_train_final = y_train_enc
    y_val_final = y_val_enc

    # Create datasets
    train_dataset = CustomDataset(X_train[selected_features], y_train_final)
    val_dataset = CustomDataset(X_val[selected_features], y_val_final)

    # Create dataloaders with drop_last=True for training and drop_last=False for validation
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

    # Map selected_features to their indices
    selected_feature_indices = [feature_to_idx[feat] for feat in selected_features]

    # Select the corresponding adjacency submatrix using integer indices
    selected_adjacency = adjacency[np.ix_(selected_feature_indices, selected_feature_indices)]
    selected_adjacency_mask = torch.tensor(selected_adjacency, dtype=torch.float32)

    device = torch.device('cpu')

    # Initialize the model with the number of selected features and the selected adjacency mask
    model = CustomNetwork(num_features=len(selected_features), 
                          adjacency_mask=selected_adjacency_mask).to(device)

    # Define loss and optimizer
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    # Training Loop
    for epoch in range(1, n_epochs + 1):
        model.train()
        epoch_loss = 0.0

        for batch_X, batch_y in train_loader:
            batch_X = batch_X.to(device).float()  # Ensure float type
            batch_y = batch_y.to(device).float()  # BCEWithLogitsLoss expects float targets

            optimizer.zero_grad()
            outputs = model(batch_X)  # Forward pass
            loss = criterion(outputs, batch_y)

            # Total loss
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item() * batch_X.size(0)

        epoch_loss /= len(train_loader.dataset)

    # Validation
    model.eval()
    all_outputs = []
    all_labels = []
    all_preds = []  # Initialize a list to accumulate predictions

    with torch.no_grad():
        for batch_X, batch_y in val_loader:
            batch_X = batch_X.to(device).float()

            outputs = model(batch_X)  # Forward pass
            probs = torch.sigmoid(outputs).cpu().numpy()
            preds = (probs >= threshold).astype(int).flatten()

            all_outputs.extend(probs)
            all_labels.extend(batch_y.numpy())
            all_preds.extend(preds)  # Accumulate predictions

    # Compute metrics
    roc_auc = roc_auc_score(all_labels, all_outputs)
    f1 = f1_score(all_labels, all_preds, average='binary')
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='binary')

    return {
        'roc_auc': roc_auc,
        'f1': f1,
        'accuracy': accuracy,
        'precision': precision
    }

def global_feature_ranking(X, y):
    """
    Perform global feature ranking using ReliefF.
    """
    # Initialize ReliefF without random_state
    relief = ReliefF(n_features_to_select='all')

    # Convert X and y to NumPy arrays to avoid KeyError
    X_array = X.values
    y_array = y.values
    
    # Fit ReliefF on the entire dataset
    relief.fit(X_array, y_array)
    
    # Get feature scores
    feature_scores = relief.feature_importances_
    
    # Create a DataFrame for easy handling
    feature_score_df = pd.DataFrame({
        'feature': X.columns,
        'score': feature_scores
    })
    
    # Sort features by score in descending order
    feature_score_df = feature_score_df.sort_values(by='score', ascending=False)
    
    return feature_score_df

def objective(trial, X, y, feature_groups, feature_to_idx, global_feature_score_df, adjacency, threshold=0.5):
    # ====================
    # Hyperparameters to Tune
    # ====================

    # 1. Number of Epochs
    n_epochs = trial.suggest_int('n_epochs', 500, 3000)

    # 2. Learning Rate
    lr = trial.suggest_loguniform('lr', 1e-6, 1e-2)

    # 3. Weight Decay
    weight_decay = trial.suggest_loguniform('weight_decay', 1e-8, 1e-3)

    # 4. Batch Size
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128, 256, 512])

    # 5. Number of Features per Group
    n_genotype = trial.suggest_int('n_genotype', 1, len(feature_groups['Genotype']))
    n_history = trial.suggest_int('n_history', 1, len(feature_groups['History']))
    n_phenotype = trial.suggest_int('n_phenotype', 1, len(feature_groups['Phenotype']))
    n_behaviour = trial.suggest_int('n_behaviour', 1, len(feature_groups['Behaviour']))

    # ====================
    # Feature Selection Using Global Rankings
    # ====================

    # Initialize selected features list
    selected_features = []

    # For each group, select the top N features based on global ReliefF scores
    for group, n_select in zip(['Genotype', 'History', 'Phenotype', 'Behaviour'],
                               [n_genotype, n_history, n_phenotype, n_behaviour]):
        group_features = feature_groups[group]
        # Filter the features present in the group
        group_feature_scores = global_feature_score_df[global_feature_score_df['feature'].isin(group_features)]
        # Select top N features
        top_features = group_feature_scores.head(n_select)['feature'].tolist()
        selected_features.extend(top_features)

    # Ensure that selected_features are unique
    selected_features = list(dict.fromkeys(selected_features))

    # ====================
    # Data Preparation
    # ====================

    X_selected = X[selected_features].copy()
    y_selected = y.copy()

    # Initialize Stratified K-Fold
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

    # Get all fold indices
    fold_indices = list(skf.split(X_selected, y_selected))

    # ====================
    # Parallel Training and Evaluation
    # ====================

    # Define a wrapper for joblib's Parallel
    results = Parallel(n_jobs=10)(
        delayed(train_evaluate_fold)(
            fold=fold,
            train_index=train_idx,
            val_index=val_idx,
            X=X_selected,
            y=y_selected,
            selected_features=selected_features,
            adjacency=adjacency,  # Pass the numpy adjacency matrix
            feature_to_idx=feature_to_idx,  # Pass the feature_to_idx mapping
            n_epochs=n_epochs,
            lr=lr,
            weight_decay=weight_decay,
            batch_size=batch_size,
            threshold=threshold
        )
        for fold, (train_idx, val_idx) in enumerate(fold_indices)
    )

    # ====================
    # Collect Metrics
    # ====================

    aucs = []
    f1s = []
    accuracies = []
    precisions = []

    for res in results:
        aucs.append(res['roc_auc'])
        f1s.append(res['f1'])
        accuracies.append(res['accuracy'])
        precisions.append(res['precision'])

    # ====================
    # Final Metrics Calculation
    # ====================

    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_f1 = np.mean(f1s)
    std_f1 = np.std(f1s)
    mean_accuracy = np.mean(accuracies)
    std_accuracy = np.std(accuracies)
    mean_precision = np.mean(precisions)
    std_precision = np.std(precisions)

    # ====================
    # Objective Metric
    # ====================

    # Since it's binary classification, we aim to maximize the mean AUC
    trial.set_user_attr("mean_auc", mean_auc)
    trial.set_user_attr("std_auc", std_auc)
    trial.set_user_attr("mean_f1", mean_f1)
    trial.set_user_attr("std_f1", std_f1)
    trial.set_user_attr("mean_accuracy", mean_accuracy)
    trial.set_user_attr("std_accuracy", std_accuracy)
    trial.set_user_attr("mean_precision", mean_precision)
    trial.set_user_attr("std_precision", std_precision)
    trial.set_user_attr("selected_features", selected_features)

    return mean_auc

def run_hyperparameter_tuning(X, y, feature_groups, feature_to_idx, adjacency, threshold=0.5):
    # Generate the global feature ranking before the study starts
    global_feature_score_df = global_feature_ranking(X, y)

    def objective_wrapper(trial):
        return objective(trial, X, y, feature_groups, feature_to_idx, global_feature_score_df, adjacency, threshold)

    study = optuna.create_study(
        direction='maximize',
        study_name='CustomNetwork_Hyperparameter_Tuning',
        sampler=optuna.samplers.TPESampler(seed=42)
    )

    # Integrate a progress bar for the Optuna study
    with tqdm(total=200, desc="Optuna Trials") as pbar:
        def callback(study, trial):
            pbar.update(1)

        # Set n_jobs=1 to ensure serial execution of hyperparameter trials
        study.optimize(objective_wrapper, n_trials=200, timeout=None, callbacks=[callback], n_jobs=1)

    print("Number of finished trials: ", len(study.trials))
    print("Best trial:")
    trial = study.best_trial

    print("  Value (Mean AUC): ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

    # Extract additional metrics from the best trial
    best_trial_metrics = trial.user_attrs
    mean_auc = best_trial_metrics.get("mean_auc", None)
    std_auc = best_trial_metrics.get("std_auc", None)
    mean_f1 = best_trial_metrics.get("mean_f1", None)
    std_f1 = best_trial_metrics.get("std_f1", None)
    mean_accuracy = best_trial_metrics.get("mean_accuracy", None)
    std_accuracy = best_trial_metrics.get("std_accuracy", None)
    mean_precision = best_trial_metrics.get("mean_precision", None)
    std_precision = best_trial_metrics.get("std_precision", None)
    selected_features = best_trial_metrics.get("selected_features", None)

    print(f"\nBest Trial Metrics:")
    print(f"Selected Features: {selected_features}")
    print(f"Average AUC: {mean_auc:.4f} ± {std_auc:.4f}")
    print(f"Average F1 Score: {mean_f1:.4f} ± {std_f1:.4f}")
    print(f"Average Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}")
    print(f"Average Precision: {mean_precision:.4f} ± {std_precision:.4f}")

    return study

if __name__ == "__main__":
    # Run hyperparameter tuning
    study = run_hyperparameter_tuning(X, y, feature_groups, feature_to_idx, adjacency)
# Out:
# [I 2024-12-15 18:34:11,893] A new study created in memory with name: CustomNetwork_Hyperparameter_Tuning
# Optuna Trials:   0%|          | 0/200 [00:00<?, ?it/s][I 2024-12-15 18:36:05,834] Trial 0 finished with value: 0.7217848524046396 and parameters: {'n_epochs': 1436, 'lr': 0.006351221010640704, 'weight_decay': 4.570563099801451e-05, 'batch_size': 512, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 1, 'n_behaviour': 5}. Best is trial 0 with value: 0.7217848524046396.
# Optuna Trials:   0%|          | 1/200 [01:53<6:17:53, 113.94s/it][I 2024-12-15 18:43:01,868] Trial 1 finished with value: 0.6958413735356846 and parameters: {'n_epochs': 2581, 'lr': 7.068974950624607e-06, 'weight_decay': 8.111941985431907e-08, 'batch_size': 128, 'n_genotype': 10, 'n_history': 1, 'n_phenotype': 4, 'n_behaviour': 2}. Best is trial 0 with value: 0.7217848524046396.
# Optuna Trials:   1%|          | 2/200 [08:49<16:02:25, 291.64s/it][I 2024-12-15 18:46:12,743] Trial 2 finished with value: 0.7229343062237523 and parameters: {'n_epochs': 1640, 'lr': 0.0013826232179369874, 'weight_decay': 9.9625132220551e-08, 'batch_size': 256, 'n_genotype': 1, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 2 with value: 0.7229343062237523.
# Optuna Trials:   2%|▏         | 3/200 [12:00<13:26:28, 245.63s/it][I 2024-12-15 18:47:52,974] Trial 3 finished with value: 0.552336741552405 and parameters: {'n_epochs': 1261, 'lr': 2.4586032763280077e-06, 'weight_decay': 2.6373339933815247e-05, 'batch_size': 512, 'n_genotype': 4, 'n_history': 4, 'n_phenotype': 5, 'n_behaviour': 3}. Best is trial 2 with value: 0.7229343062237523.
# Optuna Trials:   2%|▏         | 4/200 [13:41<10:14:52, 188.23s/it][I 2024-12-15 18:56:07,310] Trial 4 finished with value: 0.6572199713431549 and parameters: {'n_epochs': 1867, 'lr': 5.4880470007660465e-06, 'weight_decay': 0.00070456836384545, 'batch_size': 64, 'n_genotype': 2, 'n_history': 2, 'n_phenotype': 1, 'n_behaviour': 2}. Best is trial 2 with value: 0.7229343062237523.
# Optuna Trials:   2%|▎         | 5/200 [21:55<16:10:29, 298.61s/it][I 2024-12-15 18:58:13,962] Trial 5 finished with value: 0.6687210884597898 and parameters: {'n_epochs': 1472, 'lr': 1.2172958098369984e-05, 'weight_decay': 0.00013921548533046482, 'batch_size': 512, 'n_genotype': 2, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 2 with value: 0.7229343062237523.
# Optuna Trials:   3%|▎         | 6/200 [24:02<12:56:28, 240.15s/it][I 2024-12-15 19:00:41,307] Trial 6 finished with value: 0.7252890547888233 and parameters: {'n_epochs': 513, 'lr': 0.0018274508859816032, 'weight_decay': 3.422052903270691e-05, 'batch_size': 64, 'n_genotype': 13, 'n_history': 4, 'n_phenotype': 5, 'n_behaviour': 1}. Best is trial 6 with value: 0.7252890547888233.
# Optuna Trials:   4%|▎         | 7/200 [26:29<11:14:52, 209.81s/it][I 2024-12-15 19:06:37,814] Trial 7 finished with value: 0.7152263461191659 and parameters: {'n_epochs': 1277, 'lr': 1.99863407785289e-05, 'weight_decay': 4.446628955475447e-05, 'batch_size': 64, 'n_genotype': 12, 'n_history': 4, 'n_phenotype': 11, 'n_behaviour': 3}. Best is trial 6 with value: 0.7252890547888233.
# Optuna Trials:   4%|▍         | 8/200 [32:25<13:40:49, 256.51s/it][I 2024-12-15 19:11:59,320] Trial 8 finished with value: 0.7201254642400815 and parameters: {'n_epochs': 1807, 'lr': 5.1305517605898387e-05, 'weight_decay': 1.3399717231179682e-08, 'batch_size': 128, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 6, 'n_behaviour': 4}. Best is trial 6 with value: 0.7252890547888233.
# Optuna Trials:   4%|▍         | 9/200 [37:47<14:41:14, 276.83s/it][I 2024-12-15 19:17:03,412] Trial 9 finished with value: 0.6840692673682163 and parameters: {'n_epochs': 1072, 'lr': 2.031980983842497e-06, 'weight_decay': 2.810329644763601e-07, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 3}. Best is trial 6 with value: 0.7252890547888233.
# Optuna Trials:   5%|▌         | 10/200 [42:51<15:03:16, 285.25s/it][I 2024-12-15 19:21:31,967] Trial 10 finished with value: 0.720234526705845 and parameters: {'n_epochs': 551, 'lr': 0.0005800693677313923, 'weight_decay': 3.0675727454645503e-06, 'batch_size': 32, 'n_genotype': 6, 'n_history': 3, 'n_phenotype': 8, 'n_behaviour': 1}. Best is trial 6 with value: 0.7252890547888233.
# Optuna Trials:   6%|▌         | 11/200 [47:20<14:42:25, 280.14s/it][I 2024-12-15 19:26:18,117] Trial 11 finished with value: 0.7140667673983838 and parameters: {'n_epochs': 2459, 'lr': 0.0008987153901963661, 'weight_decay': 1.4169288344911355e-06, 'batch_size': 256, 'n_genotype': 7, 'n_history': 6, 'n_phenotype': 8, 'n_behaviour': 5}. Best is trial 6 with value: 0.7252890547888233.
# Optuna Trials:   6%|▌         | 12/200 [52:06<14:43:29, 281.97s/it][I 2024-12-15 19:27:23,537] Trial 12 finished with value: 0.7317587527839778 and parameters: {'n_epochs': 560, 'lr': 0.009819932255387066, 'weight_decay': 5.337212695483277e-07, 'batch_size': 256, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 12 with value: 0.7317587527839778.
# Optuna Trials:   6%|▋         | 13/200 [53:11<11:14:20, 216.37s/it][I 2024-12-15 19:28:33,887] Trial 13 finished with value: 0.7233174013218606 and parameters: {'n_epochs': 568, 'lr': 0.009545384837341344, 'weight_decay': 6.88388301225202e-06, 'batch_size': 256, 'n_genotype': 15, 'n_history': 5, 'n_phenotype': 9, 'n_behaviour': 4}. Best is trial 12 with value: 0.7317587527839778.
# Optuna Trials:   7%|▋         | 14/200 [54:21<8:54:00, 172.26s/it] [I 2024-12-15 19:35:33,135] Trial 14 finished with value: 0.7209558400230123 and parameters: {'n_epochs': 853, 'lr': 0.002559789615492311, 'weight_decay': 9.190300196188759e-07, 'batch_size': 32, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 3, 'n_behaviour': 4}. Best is trial 12 with value: 0.7317587527839778.
# Optuna Trials:   8%|▊         | 15/200 [1:01:21<12:40:41, 246.71s/it][I 2024-12-15 19:41:28,574] Trial 15 finished with value: 0.726342563352482 and parameters: {'n_epochs': 2981, 'lr': 0.00015768669030309665, 'weight_decay': 1.1856641191773123e-05, 'batch_size': 256, 'n_genotype': 12, 'n_history': 4, 'n_phenotype': 10, 'n_behaviour': 2}. Best is trial 12 with value: 0.7317587527839778.
# Optuna Trials:   8%|▊         | 16/200 [1:07:16<14:16:56, 279.44s/it][I 2024-12-15 19:46:56,864] Trial 16 finished with value: 0.7205039584922494 and parameters: {'n_epochs': 2844, 'lr': 0.00023033313114540635, 'weight_decay': 9.072611374743732e-06, 'batch_size': 256, 'n_genotype': 11, 'n_history': 3, 'n_phenotype': 10, 'n_behaviour': 2}. Best is trial 12 with value: 0.7317587527839778.
# Optuna Trials:   8%|▊         | 17/200 [1:12:44<14:57:05, 294.13s/it][I 2024-12-15 19:50:56,737] Trial 17 finished with value: 0.7267315617864576 and parameters: {'n_epochs': 2008, 'lr': 0.00012926536335314802, 'weight_decay': 4.3644207042296024e-07, 'batch_size': 256, 'n_genotype': 8, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 12 with value: 0.7317587527839778.
# Optuna Trials:   9%|▉         | 18/200 [1:16:44<14:02:44, 277.83s/it][I 2024-12-15 19:55:17,172] Trial 18 finished with value: 0.7219707654526222 and parameters: {'n_epochs': 2174, 'lr': 5.269972289469775e-05, 'weight_decay': 3.4995391447991276e-07, 'batch_size': 256, 'n_genotype': 8, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 12 with value: 0.7317587527839778.
# Optuna Trials:  10%|▉         | 19/200 [1:21:05<13:42:20, 272.60s/it][I 2024-12-15 19:59:14,721] Trial 19 finished with value: 0.7310798163959006 and parameters: {'n_epochs': 2007, 'lr': 0.00046899671234917423, 'weight_decay': 4.2154994302757204e-08, 'batch_size': 256, 'n_genotype': 8, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 3}. Best is trial 12 with value: 0.7317587527839778.
# Optuna Trials:  10%|█         | 20/200 [1:25:02<13:06:14, 262.08s/it][I 2024-12-15 20:03:38,584] Trial 20 finished with value: 0.7307149744401158 and parameters: {'n_epochs': 2232, 'lr': 0.00044897745813162506, 'weight_decay': 1.1515414867394104e-08, 'batch_size': 256, 'n_genotype': 5, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 3}. Best is trial 12 with value: 0.7317587527839778.
# Optuna Trials:  10%|█         | 21/200 [1:29:26<13:03:27, 262.61s/it][I 2024-12-15 20:08:00,197] Trial 21 finished with value: 0.7324375443957487 and parameters: {'n_epochs': 2293, 'lr': 0.00048101490566733603, 'weight_decay': 1.1977595564136082e-08, 'batch_size': 256, 'n_genotype': 6, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 3}. Best is trial 21 with value: 0.7324375443957487.
# Optuna Trials:  11%|█         | 22/200 [1:33:48<12:58:11, 262.31s/it][I 2024-12-15 20:12:45,850] Trial 22 finished with value: 0.7200832107236012 and parameters: {'n_epochs': 2416, 'lr': 0.0031086348689002286, 'weight_decay': 4.322342827260143e-08, 'batch_size': 256, 'n_genotype': 9, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 3}. Best is trial 21 with value: 0.7324375443957487.
# Optuna Trials:  12%|█▏        | 23/200 [1:38:33<13:14:29, 269.32s/it][I 2024-12-15 20:16:50,601] Trial 23 finished with value: 0.7316658646238156 and parameters: {'n_epochs': 2100, 'lr': 0.0003903924399980575, 'weight_decay': 3.348925035075075e-08, 'batch_size': 256, 'n_genotype': 6, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 21 with value: 0.7324375443957487.
# Optuna Trials:  12%|█▏        | 24/200 [1:42:38<12:48:22, 261.95s/it][I 2024-12-15 20:21:52,312] Trial 24 finished with value: 0.7334666448864278 and parameters: {'n_epochs': 2648, 'lr': 0.004653355598556837, 'weight_decay': 3.438711321608629e-08, 'batch_size': 256, 'n_genotype': 4, 'n_history': 6, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 24 with value: 0.7334666448864278.
# Optuna Trials:  12%|█▎        | 25/200 [1:47:40<13:18:48, 273.88s/it][I 2024-12-15 20:43:11,928] Trial 25 finished with value: 0.7280064732179375 and parameters: {'n_epochs': 2672, 'lr': 0.005089489265015528, 'weight_decay': 1.3603080262974131e-07, 'batch_size': 32, 'n_genotype': 3, 'n_history': 6, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 24 with value: 0.7334666448864278.
# Optuna Trials:  13%|█▎        | 26/200 [2:09:00<27:49:19, 575.63s/it][I 2024-12-15 20:49:58,235] Trial 26 finished with value: 0.7314433873607904 and parameters: {'n_epochs': 2383, 'lr': 0.004158677303979756, 'weight_decay': 2.205988351355012e-08, 'batch_size': 128, 'n_genotype': 4, 'n_history': 6, 'n_phenotype': 9, 'n_behaviour': 5}. Best is trial 24 with value: 0.7334666448864278.
# Optuna Trials:  14%|█▎        | 27/200 [2:15:46<25:13:15, 524.83s/it][I 2024-12-15 20:55:21,020] Trial 27 finished with value: 0.72950187419437 and parameters: {'n_epochs': 2743, 'lr': 0.0011786067168792144, 'weight_decay': 1.5235118291607371e-07, 'batch_size': 256, 'n_genotype': 5, 'n_history': 6, 'n_phenotype': 7, 'n_behaviour': 4}. Best is trial 24 with value: 0.7334666448864278.
# Optuna Trials:  14%|█▍        | 28/200 [2:21:09<22:10:44, 464.21s/it][I 2024-12-15 20:59:50,203] Trial 28 finished with value: 0.7335818081283606 and parameters: {'n_epochs': 2278, 'lr': 0.008466119249739478, 'weight_decay': 8.661357981093641e-07, 'batch_size': 256, 'n_genotype': 6, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 28 with value: 0.7335818081283606.
# Optuna Trials:  14%|█▍        | 29/200 [2:25:38<19:16:14, 405.70s/it][I 2024-12-15 21:03:10,226] Trial 29 finished with value: 0.7201954652237256 and parameters: {'n_epochs': 2327, 'lr': 0.0045600441305964495, 'weight_decay': 2.034583964642124e-06, 'batch_size': 512, 'n_genotype': 6, 'n_history': 5, 'n_phenotype': 9, 'n_behaviour': 5}. Best is trial 28 with value: 0.7335818081283606.
# Optuna Trials:  15%|█▌        | 30/200 [2:28:58<16:14:39, 344.00s/it][I 2024-12-15 21:08:02,536] Trial 30 finished with value: 0.720718541223524 and parameters: {'n_epochs': 2548, 'lr': 0.0021444534834873176, 'weight_decay': 1.1243209966355093e-08, 'batch_size': 256, 'n_genotype': 4, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 3}. Best is trial 28 with value: 0.7335818081283606.
# Optuna Trials:  16%|█▌        | 31/200 [2:33:50<15:25:14, 328.49s/it][I 2024-12-15 21:11:16,023] Trial 31 finished with value: 0.7227479392717431 and parameters: {'n_epochs': 1608, 'lr': 0.009269108361172437, 'weight_decay': 8.16892229791613e-07, 'batch_size': 256, 'n_genotype': 7, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 28 with value: 0.7335818081283606.
# Optuna Trials:  16%|█▌        | 32/200 [2:37:04<13:26:22, 287.99s/it][I 2024-12-15 21:17:01,382] Trial 32 finished with value: 0.7268103051921899 and parameters: {'n_epochs': 2921, 'lr': 0.007902918911853221, 'weight_decay': 5.17171688820736e-08, 'batch_size': 256, 'n_genotype': 9, 'n_history': 4, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 28 with value: 0.7335818081283606.
# Optuna Trials:  16%|█▋        | 33/200 [2:42:49<14:09:28, 305.20s/it][I 2024-12-15 21:24:39,128] Trial 33 finished with value: 0.7194698018604787 and parameters: {'n_epochs': 2635, 'lr': 0.005335673895523355, 'weight_decay': 9.553468471444392e-08, 'batch_size': 128, 'n_genotype': 5, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 28 with value: 0.7335818081283606.
# Optuna Trials:  17%|█▋        | 34/200 [2:50:27<16:11:00, 350.96s/it][I 2024-12-15 21:30:01,960] Trial 34 finished with value: 0.7246475540558757 and parameters: {'n_epochs': 2773, 'lr': 0.0015161967382645966, 'weight_decay': 2.1422597308086797e-07, 'batch_size': 256, 'n_genotype': 3, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 28 with value: 0.7335818081283606.
# Optuna Trials:  18%|█▊        | 35/200 [2:55:50<15:41:56, 342.52s/it][I 2024-12-15 21:32:48,703] Trial 35 finished with value: 0.7241420648498009 and parameters: {'n_epochs': 1927, 'lr': 0.0009730449275215584, 'weight_decay': 6.160580250912573e-07, 'batch_size': 512, 'n_genotype': 7, 'n_history': 1, 'n_phenotype': 10, 'n_behaviour': 5}. Best is trial 28 with value: 0.7335818081283606.
# Optuna Trials:  18%|█▊        | 36/200 [2:58:36<13:12:05, 289.79s/it][I 2024-12-15 21:37:50,536] Trial 36 finished with value: 0.7300606558867083 and parameters: {'n_epochs': 2546, 'lr': 0.0033593290618623337, 'weight_decay': 2.4521101725097205e-08, 'batch_size': 256, 'n_genotype': 9, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 3}. Best is trial 28 with value: 0.7335818081283606.
# Optuna Trials:  18%|█▊        | 37/200 [3:03:38<13:17:04, 293.40s/it][I 2024-12-15 21:41:09,583] Trial 37 finished with value: 0.7300042154846013 and parameters: {'n_epochs': 1708, 'lr': 0.006249496290229636, 'weight_decay': 7.435655301305398e-08, 'batch_size': 256, 'n_genotype': 2, 'n_history': 4, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 28 with value: 0.7335818081283606.
# Optuna Trials:  19%|█▉        | 38/200 [3:06:57<11:55:45, 265.10s/it][I 2024-12-15 21:58:54,190] Trial 38 finished with value: 0.6740124623325239 and parameters: {'n_epochs': 2224, 'lr': 0.0022928019720595758, 'weight_decay': 3.677261294877532e-06, 'batch_size': 32, 'n_genotype': 1, 'n_history': 5, 'n_phenotype': 1, 'n_behaviour': 3}. Best is trial 28 with value: 0.7335818081283606.
# Optuna Trials:  20%|█▉        | 39/200 [3:24:42<22:34:56, 504.95s/it][I 2024-12-15 22:05:46,891] Trial 39 finished with value: 0.7261931045213468 and parameters: {'n_epochs': 1505, 'lr': 5.889290659728171e-05, 'weight_decay': 0.0002773938216133653, 'batch_size': 64, 'n_genotype': 10, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 5}. Best is trial 28 with value: 0.7335818081283606.
# Optuna Trials:  20%|██        | 40/200 [3:31:34<21:12:43, 477.27s/it][I 2024-12-15 22:06:52,866] Trial 40 finished with value: 0.6354540014652753 and parameters: {'n_epochs': 770, 'lr': 2.677183369962713e-05, 'weight_decay': 2.1867653260548505e-08, 'batch_size': 512, 'n_genotype': 3, 'n_history': 3, 'n_phenotype': 3, 'n_behaviour': 3}. Best is trial 28 with value: 0.7335818081283606.
# Optuna Trials:  20%|██        | 41/200 [3:32:40<15:37:47, 353.88s/it][I 2024-12-15 22:11:00,258] Trial 41 finished with value: 0.613792889280216 and parameters: {'n_epochs': 2156, 'lr': 1.0381902110866255e-06, 'weight_decay': 2.7130192942561323e-08, 'batch_size': 256, 'n_genotype': 5, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 28 with value: 0.7335818081283606.
# Optuna Trials:  21%|██        | 42/200 [3:36:48<14:07:46, 321.94s/it][I 2024-12-15 22:14:58,491] Trial 42 finished with value: 0.7345181386050875 and parameters: {'n_epochs': 2036, 'lr': 0.0003713306549504629, 'weight_decay': 4.745268623857331e-08, 'batch_size': 256, 'n_genotype': 6, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 42 with value: 0.7345181386050875.
# Optuna Trials:  22%|██▏       | 43/200 [3:40:46<12:56:41, 296.83s/it][I 2024-12-15 22:19:28,738] Trial 43 finished with value: 0.7302729983114611 and parameters: {'n_epochs': 2280, 'lr': 0.0007213956227245922, 'weight_decay': 7.098217701487635e-08, 'batch_size': 256, 'n_genotype': 6, 'n_history': 4, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 42 with value: 0.7345181386050875.
# Optuna Trials:  22%|██▏       | 44/200 [3:45:16<12:31:00, 288.85s/it][I 2024-12-15 22:23:24,726] Trial 44 finished with value: 0.7242049735830242 and parameters: {'n_epochs': 1339, 'lr': 0.00027319532600649047, 'weight_decay': 2.2685547447839945e-07, 'batch_size': 128, 'n_genotype': 7, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 42 with value: 0.7345181386050875.
# Optuna Trials:  22%|██▎       | 45/200 [3:49:12<11:45:13, 272.99s/it][I 2024-12-15 22:26:56,826] Trial 45 finished with value: 0.7287305396200265 and parameters: {'n_epochs': 1822, 'lr': 0.0014698244394670058, 'weight_decay': 1.4428453321242516e-06, 'batch_size': 256, 'n_genotype': 4, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 3}. Best is trial 42 with value: 0.7345181386050875.
# Optuna Trials:  23%|██▎       | 46/200 [3:52:44<10:53:47, 254.72s/it][I 2024-12-15 22:31:50,660] Trial 46 finished with value: 0.7334522339304024 and parameters: {'n_epochs': 2459, 'lr': 0.0003086066527503889, 'weight_decay': 1.713016280124351e-08, 'batch_size': 256, 'n_genotype': 11, 'n_history': 4, 'n_phenotype': 8, 'n_behaviour': 4}. Best is trial 42 with value: 0.7345181386050875.
# Optuna Trials:  24%|██▎       | 47/200 [3:57:38<11:19:28, 266.46s/it][I 2024-12-15 22:43:46,241] Trial 47 finished with value: 0.7187101449807619 and parameters: {'n_epochs': 2577, 'lr': 9.046502576874191e-05, 'weight_decay': 1.6579517092803334e-08, 'batch_size': 64, 'n_genotype': 6, 'n_history': 4, 'n_phenotype': 8, 'n_behaviour': 5}. Best is trial 42 with value: 0.7345181386050875.
# Optuna Trials:  24%|██▍       | 48/200 [4:09:34<16:56:21, 401.19s/it][I 2024-12-15 22:47:50,266] Trial 48 finished with value: 0.7213123260905673 and parameters: {'n_epochs': 2084, 'lr': 0.0002807432544138387, 'weight_decay': 1.0424632865026676e-08, 'batch_size': 256, 'n_genotype': 11, 'n_history': 3, 'n_phenotype': 7, 'n_behaviour': 3}. Best is trial 42 with value: 0.7345181386050875.
# Optuna Trials:  24%|██▍       | 49/200 [4:13:38<14:51:00, 354.04s/it][I 2024-12-15 22:52:33,190] Trial 49 finished with value: 0.7162058062226634 and parameters: {'n_epochs': 2457, 'lr': 0.00017178440855994284, 'weight_decay': 2.075337179687065e-05, 'batch_size': 256, 'n_genotype': 5, 'n_history': 4, 'n_phenotype': 6, 'n_behaviour': 4}. Best is trial 42 with value: 0.7345181386050875.
# Optuna Trials:  25%|██▌       | 50/200 [4:18:21<13:51:46, 332.71s/it][I 2024-12-15 23:08:18,470] Trial 50 finished with value: 0.7254646991524905 and parameters: {'n_epochs': 1969, 'lr': 8.26481481867136e-05, 'weight_decay': 5.4026099677181796e-08, 'batch_size': 32, 'n_genotype': 15, 'n_history': 6, 'n_phenotype': 10, 'n_behaviour': 2}. Best is trial 42 with value: 0.7345181386050875.
# Optuna Trials:  26%|██▌       | 51/200 [4:34:06<21:22:35, 516.48s/it][I 2024-12-15 23:10:30,489] Trial 51 finished with value: 0.7366845700604363 and parameters: {'n_epochs': 1103, 'lr': 0.00736369619954111, 'weight_decay': 1.4300131930679657e-07, 'batch_size': 256, 'n_genotype': 11, 'n_history': 5, 'n_phenotype': 9, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  26%|██▌       | 52/200 [4:36:18<16:29:28, 401.14s/it][I 2024-12-15 23:15:13,422] Trial 52 finished with value: 0.7265371470802786 and parameters: {'n_epochs': 2407, 'lr': 0.0007436206159875295, 'weight_decay': 1.3021238377162577e-07, 'batch_size': 256, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 9, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  26%|██▋       | 53/200 [4:41:01<14:55:54, 365.68s/it][I 2024-12-15 23:19:47,357] Trial 53 finished with value: 0.698089881431524 and parameters: {'n_epochs': 2315, 'lr': 5.655910657509181e-06, 'weight_decay': 1.8848397987079736e-08, 'batch_size': 256, 'n_genotype': 13, 'n_history': 4, 'n_phenotype': 8, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  27%|██▋       | 54/200 [4:45:35<13:42:50, 338.16s/it][I 2024-12-15 23:22:01,263] Trial 54 finished with value: 0.7254062966687467 and parameters: {'n_epochs': 1137, 'lr': 0.0003659049969869007, 'weight_decay': 3.476835042610194e-08, 'batch_size': 256, 'n_genotype': 11, 'n_history': 5, 'n_phenotype': 9, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  28%|██▊       | 55/200 [4:47:49<11:09:07, 276.88s/it][I 2024-12-15 23:27:01,275] Trial 55 finished with value: 0.7252679734905422 and parameters: {'n_epochs': 2506, 'lr': 0.006966462803437314, 'weight_decay': 5.917081500156423e-08, 'batch_size': 256, 'n_genotype': 14, 'n_history': 5, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  28%|██▊       | 56/200 [4:52:49<11:21:10, 283.82s/it][I 2024-12-15 23:36:31,707] Trial 56 finished with value: 0.7216563835544038 and parameters: {'n_epochs': 2091, 'lr': 0.003028886815506061, 'weight_decay': 1.0222505679107975e-07, 'batch_size': 64, 'n_genotype': 9, 'n_history': 3, 'n_phenotype': 6, 'n_behaviour': 3}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  28%|██▊       | 57/200 [5:02:19<14:41:21, 369.80s/it][I 2024-12-15 23:41:41,575] Trial 57 finished with value: 0.725115450707859 and parameters: {'n_epochs': 2654, 'lr': 0.0001821679488682935, 'weight_decay': 1.535008413096798e-08, 'batch_size': 256, 'n_genotype': 7, 'n_history': 4, 'n_phenotype': 8, 'n_behaviour': 3}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  29%|██▉       | 58/200 [5:07:29<13:52:38, 351.82s/it][I 2024-12-15 23:45:28,090] Trial 58 finished with value: 0.717648815118117 and parameters: {'n_epochs': 1914, 'lr': 2.4804817011910567e-05, 'weight_decay': 3.3802887208846345e-08, 'batch_size': 256, 'n_genotype': 8, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  30%|██▉       | 59/200 [5:11:16<12:18:26, 314.23s/it][I 2024-12-15 23:48:02,960] Trial 59 finished with value: 0.7216752345821322 and parameters: {'n_epochs': 865, 'lr': 0.0005604416062522269, 'weight_decay': 2.7777063449355837e-07, 'batch_size': 128, 'n_genotype': 4, 'n_history': 5, 'n_phenotype': 9, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  30%|███       | 60/200 [5:13:51<10:21:39, 266.42s/it][I 2024-12-15 23:50:35,902] Trial 60 finished with value: 0.7254861281325121 and parameters: {'n_epochs': 1744, 'lr': 0.0039049889950809177, 'weight_decay': 7.800301093479749e-05, 'batch_size': 512, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 7, 'n_behaviour': 1}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  30%|███       | 61/200 [5:16:24<8:58:20, 232.38s/it] [I 2024-12-15 23:52:01,461] Trial 61 finished with value: 0.7335658244068057 and parameters: {'n_epochs': 709, 'lr': 0.008416418091965278, 'weight_decay': 4.880294928724501e-07, 'batch_size': 256, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  31%|███       | 62/200 [5:17:49<7:13:09, 188.33s/it][I 2024-12-15 23:53:28,667] Trial 62 finished with value: 0.7340218834842195 and parameters: {'n_epochs': 720, 'lr': 0.006800731788071845, 'weight_decay': 1.7979890348731137e-07, 'batch_size': 256, 'n_genotype': 11, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  32%|███▏      | 63/200 [5:19:16<6:00:45, 157.99s/it][I 2024-12-15 23:54:57,737] Trial 63 finished with value: 0.733295800696958 and parameters: {'n_epochs': 718, 'lr': 0.005792134070838265, 'weight_decay': 4.6958377485789596e-07, 'batch_size': 256, 'n_genotype': 11, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  32%|███▏      | 64/200 [5:20:45<5:11:15, 137.32s/it][I 2024-12-15 23:56:11,758] Trial 64 finished with value: 0.721503898183031 and parameters: {'n_epochs': 654, 'lr': 0.009903915155364049, 'weight_decay': 1.0652945046990637e-06, 'batch_size': 256, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 5}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  32%|███▎      | 65/200 [5:21:59<4:26:14, 118.33s/it][I 2024-12-15 23:58:08,871] Trial 65 finished with value: 0.7235842745323481 and parameters: {'n_epochs': 954, 'lr': 0.0070263357663083986, 'weight_decay': 1.5268796718086293e-07, 'batch_size': 256, 'n_genotype': 10, 'n_history': 4, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  33%|███▎      | 66/200 [5:23:56<4:23:27, 117.96s/it][I 2024-12-16 00:00:32,559] Trial 66 finished with value: 0.7324543067495178 and parameters: {'n_epochs': 1197, 'lr': 0.001936565553608041, 'weight_decay': 4.007673377626137e-07, 'batch_size': 256, 'n_genotype': 11, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  34%|███▎      | 67/200 [5:26:20<4:38:35, 125.68s/it][I 2024-12-16 00:02:33,791] Trial 67 finished with value: 0.7018723484472881 and parameters: {'n_epochs': 1011, 'lr': 1.0357042935994936e-05, 'weight_decay': 2.0081172148202928e-07, 'batch_size': 256, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  34%|███▍      | 68/200 [5:28:21<4:33:33, 124.35s/it][I 2024-12-16 00:03:47,939] Trial 68 finished with value: 0.7112162847879082 and parameters: {'n_epochs': 593, 'lr': 0.004213578262467451, 'weight_decay': 2.7714527635121372e-06, 'batch_size': 256, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 9, 'n_behaviour': 5}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  34%|███▍      | 69/200 [5:29:36<3:58:36, 109.29s/it][I 2024-12-16 00:11:48,231] Trial 69 finished with value: 0.7273788724512037 and parameters: {'n_epochs': 938, 'lr': 0.002786834767292373, 'weight_decay': 1.0481350633253665e-07, 'batch_size': 32, 'n_genotype': 11, 'n_history': 5, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  35%|███▌      | 70/200 [5:37:36<7:57:56, 220.59s/it][I 2024-12-16 00:13:25,565] Trial 70 finished with value: 0.7234976753476169 and parameters: {'n_epochs': 788, 'lr': 0.007596891356640008, 'weight_decay': 6.193841902401637e-07, 'batch_size': 256, 'n_genotype': 9, 'n_history': 4, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  36%|███▌      | 71/200 [5:39:13<6:34:45, 183.61s/it][I 2024-12-16 00:14:54,618] Trial 71 finished with value: 0.7338725440910527 and parameters: {'n_epochs': 717, 'lr': 0.006020650132171145, 'weight_decay': 3.110699126640794e-07, 'batch_size': 256, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  36%|███▌      | 72/200 [5:40:42<5:31:11, 155.24s/it][I 2024-12-16 00:16:16,085] Trial 72 finished with value: 0.7305653944817893 and parameters: {'n_epochs': 678, 'lr': 0.0051692130789358515, 'weight_decay': 2.6210570774097383e-07, 'batch_size': 256, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  36%|███▋      | 73/200 [5:42:04<4:41:45, 133.11s/it][I 2024-12-16 00:17:17,545] Trial 73 finished with value: 0.7326575705969016 and parameters: {'n_epochs': 518, 'lr': 0.0037584409827410518, 'weight_decay': 3.4875748113328844e-07, 'batch_size': 256, 'n_genotype': 13, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 51 with value: 0.7366845700604363.
# Optuna Trials:  37%|███▋      | 74/200 [5:43:05<3:54:23, 111.62s/it][I 2024-12-16 00:19:00,101] Trial 74 finished with value: 0.7369167325304462 and parameters: {'n_epochs': 847, 'lr': 0.00968506967057429, 'weight_decay': 7.560230760704664e-07, 'batch_size': 256, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 74 with value: 0.7369167325304462.
# Optuna Trials:  38%|███▊      | 75/200 [5:44:48<3:46:52, 108.90s/it][I 2024-12-16 00:20:37,462] Trial 75 finished with value: 0.7337057644690572 and parameters: {'n_epochs': 829, 'lr': 0.009533495433225889, 'weight_decay': 9.145821023409744e-07, 'batch_size': 256, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 74 with value: 0.7369167325304462.
# Optuna Trials:  38%|███▊      | 76/200 [5:46:25<3:37:54, 105.44s/it][I 2024-12-16 00:22:14,242] Trial 76 finished with value: 0.7379359679616254 and parameters: {'n_epochs': 856, 'lr': 0.008772166026667255, 'weight_decay': 8.139056021297103e-07, 'batch_size': 256, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  38%|███▊      | 77/200 [5:48:02<3:30:49, 102.84s/it][I 2024-12-16 00:23:58,107] Trial 77 finished with value: 0.7242710235745669 and parameters: {'n_epochs': 848, 'lr': 0.009931774395937168, 'weight_decay': 4.653856128609183e-06, 'batch_size': 256, 'n_genotype': 8, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  39%|███▉      | 78/200 [5:49:46<3:29:43, 103.15s/it][I 2024-12-16 00:29:00,496] Trial 78 finished with value: 0.72680730712032 and parameters: {'n_epochs': 1050, 'lr': 0.0061621069558637186, 'weight_decay': 1.597799917501099e-06, 'batch_size': 64, 'n_genotype': 9, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  40%|███▉      | 79/200 [5:54:48<5:28:33, 162.92s/it][I 2024-12-16 00:29:57,492] Trial 79 finished with value: 0.7276139487306896 and parameters: {'n_epochs': 609, 'lr': 0.0026315062129668144, 'weight_decay': 9.480442008240986e-07, 'batch_size': 512, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  40%|████      | 80/200 [5:55:45<4:22:17, 131.14s/it][I 2024-12-16 00:32:23,454] Trial 80 finished with value: 0.7320856954427353 and parameters: {'n_epochs': 807, 'lr': 0.007519152555721591, 'weight_decay': 8.509830506886534e-07, 'batch_size': 128, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  40%|████      | 81/200 [5:58:11<4:28:55, 135.59s/it][I 2024-12-16 00:34:12,390] Trial 81 finished with value: 0.7295574277546557 and parameters: {'n_epochs': 947, 'lr': 0.005244682132027622, 'weight_decay': 2.1113718846881705e-06, 'batch_size': 256, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  41%|████      | 82/200 [6:00:00<4:10:55, 127.59s/it][I 2024-12-16 00:35:50,385] Trial 82 finished with value: 0.7296128957607892 and parameters: {'n_epochs': 883, 'lr': 0.007868045064901574, 'weight_decay': 6.2528702971296e-07, 'batch_size': 256, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  42%|████▏     | 83/200 [6:01:38<3:51:29, 118.71s/it][I 2024-12-16 00:37:13,540] Trial 83 finished with value: 0.7349170207793766 and parameters: {'n_epochs': 683, 'lr': 0.00808849901693192, 'weight_decay': 3.681330149992282e-07, 'batch_size': 256, 'n_genotype': 11, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  42%|████▏     | 84/200 [6:03:01<3:28:53, 108.05s/it][I 2024-12-16 00:38:40,462] Trial 84 finished with value: 0.7322128293103526 and parameters: {'n_epochs': 721, 'lr': 0.0035273486718061563, 'weight_decay': 1.1358905681237279e-06, 'batch_size': 256, 'n_genotype': 11, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  42%|████▎     | 85/200 [6:04:28<3:14:56, 101.71s/it][I 2024-12-16 00:39:52,581] Trial 85 finished with value: 0.7377394017821559 and parameters: {'n_epochs': 632, 'lr': 0.005953706747848083, 'weight_decay': 1.7339981463507703e-07, 'batch_size': 256, 'n_genotype': 11, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  43%|████▎     | 86/200 [6:05:40<2:56:22, 92.83s/it] [I 2024-12-16 00:41:08,130] Trial 86 finished with value: 0.7313734459967643 and parameters: {'n_epochs': 626, 'lr': 0.005920439215276807, 'weight_decay': 1.7775529257520937e-07, 'batch_size': 256, 'n_genotype': 11, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  44%|████▎     | 87/200 [6:06:56<2:45:04, 87.65s/it][I 2024-12-16 00:42:42,620] Trial 87 finished with value: 0.7268560002511337 and parameters: {'n_epochs': 771, 'lr': 0.0046829991977027155, 'weight_decay': 3.3054439989010724e-07, 'batch_size': 256, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  44%|████▍     | 88/200 [6:08:30<2:47:26, 89.70s/it][I 2024-12-16 00:43:50,261] Trial 88 finished with value: 0.7296413929446525 and parameters: {'n_epochs': 552, 'lr': 0.0019074121934108822, 'weight_decay': 6.996835307310395e-07, 'batch_size': 256, 'n_genotype': 13, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  44%|████▍     | 89/200 [6:09:38<2:33:42, 83.08s/it][I 2024-12-16 00:52:40,475] Trial 89 finished with value: 0.7311592967994806 and parameters: {'n_epochs': 1093, 'lr': 0.006364618953658459, 'weight_decay': 1.317164075101288e-07, 'batch_size': 32, 'n_genotype': 11, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  45%|████▌     | 90/200 [6:18:28<6:38:14, 217.22s/it][I 2024-12-16 00:53:41,412] Trial 90 finished with value: 0.7282516998864794 and parameters: {'n_epochs': 503, 'lr': 0.009939428615485604, 'weight_decay': 8.295124406996873e-08, 'batch_size': 256, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  46%|████▌     | 91/200 [6:19:29<5:09:26, 170.34s/it][I 2024-12-16 00:55:13,882] Trial 91 finished with value: 0.7362209021286096 and parameters: {'n_epochs': 818, 'lr': 0.008092157965453036, 'weight_decay': 3.0006403844670594e-07, 'batch_size': 256, 'n_genotype': 11, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  46%|████▌     | 92/200 [6:21:01<4:24:33, 146.98s/it][I 2024-12-16 00:57:13,169] Trial 92 finished with value: 0.7190391107318985 and parameters: {'n_epochs': 991, 'lr': 0.004218691537060621, 'weight_decay': 2.678261709197767e-07, 'batch_size': 256, 'n_genotype': 11, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  46%|████▋     | 93/200 [6:23:01<4:07:17, 138.67s/it][I 2024-12-16 00:59:00,958] Trial 93 finished with value: 0.7361385921779474 and parameters: {'n_epochs': 908, 'lr': 0.006825324465775075, 'weight_decay': 3.935064738385805e-07, 'batch_size': 256, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  47%|████▋     | 94/200 [6:24:49<3:48:36, 129.41s/it][I 2024-12-16 01:00:48,151] Trial 94 finished with value: 0.7265974498399881 and parameters: {'n_epochs': 911, 'lr': 0.006986283919279939, 'weight_decay': 1.7922452150510939e-07, 'batch_size': 256, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  48%|████▊     | 95/200 [6:26:36<3:34:47, 122.74s/it][I 2024-12-16 01:02:17,632] Trial 95 finished with value: 0.7373465267812358 and parameters: {'n_epochs': 737, 'lr': 0.003391517116562365, 'weight_decay': 3.7480260843966874e-07, 'batch_size': 256, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  48%|████▊     | 96/200 [6:28:05<3:15:27, 112.76s/it][I 2024-12-16 01:03:45,917] Trial 96 finished with value: 0.7287036314977217 and parameters: {'n_epochs': 757, 'lr': 0.0032175386993445374, 'weight_decay': 4.2647837771103554e-07, 'batch_size': 256, 'n_genotype': 13, 'n_history': 4, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  48%|████▊     | 97/200 [6:29:34<3:00:58, 105.42s/it][I 2024-12-16 01:05:03,851] Trial 97 finished with value: 0.7311201948753869 and parameters: {'n_epochs': 640, 'lr': 0.0012241750845873077, 'weight_decay': 2.2957058114866334e-07, 'batch_size': 256, 'n_genotype': 14, 'n_history': 5, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  49%|████▉     | 98/200 [6:30:51<2:45:11, 97.17s/it] [I 2024-12-16 01:07:02,773] Trial 98 finished with value: 0.7276624734360817 and parameters: {'n_epochs': 1004, 'lr': 0.004435496435857066, 'weight_decay': 4.984314258592481e-07, 'batch_size': 256, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 3}. Best is trial 76 with value: 0.7379359679616254.
# Optuna Trials:  50%|████▉     | 99/200 [6:32:50<2:54:33, 103.70s/it][I 2024-12-16 01:12:23,417] Trial 99 finished with value: 0.7455567712393181 and parameters: {'n_epochs': 1175, 'lr': 0.002652887105202934, 'weight_decay': 1.1942523033711955e-07, 'batch_size': 64, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  50%|█████     | 100/200 [6:38:11<4:41:18, 168.78s/it][I 2024-12-16 01:16:23,632] Trial 100 finished with value: 0.7342134726179573 and parameters: {'n_epochs': 859, 'lr': 0.0022953942173663195, 'weight_decay': 1.111431390524616e-07, 'batch_size': 64, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  50%|█████     | 101/200 [6:42:11<5:13:50, 190.21s/it][I 2024-12-16 01:21:59,066] Trial 101 finished with value: 0.735327628542719 and parameters: {'n_epochs': 1184, 'lr': 0.0025146871107028855, 'weight_decay': 6.107658007754649e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  51%|█████     | 102/200 [6:47:47<6:21:50, 233.78s/it][I 2024-12-16 01:28:16,928] Trial 102 finished with value: 0.7343720201617968 and parameters: {'n_epochs': 1327, 'lr': 0.0033802533591690796, 'weight_decay': 6.325598745618549e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  52%|█████▏    | 103/200 [6:54:05<7:27:49, 277.00s/it][I 2024-12-16 01:33:51,421] Trial 103 finished with value: 0.7443904673262313 and parameters: {'n_epochs': 1194, 'lr': 0.0025335332730082173, 'weight_decay': 8.436212312707041e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  52%|█████▏    | 104/200 [6:59:39<7:50:48, 294.25s/it][I 2024-12-16 01:39:19,164] Trial 104 finished with value: 0.73345226503197 and parameters: {'n_epochs': 1206, 'lr': 0.001652008088534531, 'weight_decay': 8.608214638895361e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  52%|█████▎    | 105/200 [7:05:07<8:01:48, 304.30s/it][I 2024-12-16 01:45:53,059] Trial 105 finished with value: 0.7343451724540383 and parameters: {'n_epochs': 1395, 'lr': 0.0023354967595469577, 'weight_decay': 1.4625240499811868e-07, 'batch_size': 64, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  53%|█████▎    | 106/200 [7:11:41<8:38:50, 331.18s/it][I 2024-12-16 01:51:22,142] Trial 106 finished with value: 0.7343713465594767 and parameters: {'n_epochs': 1149, 'lr': 0.005064996609379933, 'weight_decay': 0.0009897711738314173, 'batch_size': 64, 'n_genotype': 14, 'n_history': 5, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  54%|█████▎    | 107/200 [7:17:10<8:32:21, 330.55s/it][I 2024-12-16 01:57:06,779] Trial 107 finished with value: 0.7367540741145624 and parameters: {'n_epochs': 1259, 'lr': 0.002816423176012273, 'weight_decay': 2.3341266652788018e-07, 'batch_size': 64, 'n_genotype': 13, 'n_history': 5, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  54%|█████▍    | 108/200 [7:22:54<8:33:19, 334.78s/it][I 2024-12-16 02:02:50,232] Trial 108 finished with value: 0.7303934717734255 and parameters: {'n_epochs': 1220, 'lr': 0.0009927578740972702, 'weight_decay': 4.119362625956522e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 4, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  55%|█████▍    | 109/200 [7:28:38<8:31:41, 337.38s/it][I 2024-12-16 02:09:56,523] Trial 109 finished with value: 0.7349628894307757 and parameters: {'n_epochs': 1512, 'lr': 0.002922720304585022, 'weight_decay': 1.216826299818747e-07, 'batch_size': 64, 'n_genotype': 14, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  55%|█████▌    | 110/200 [7:35:44<9:06:04, 364.05s/it][I 2024-12-16 02:15:56,951] Trial 110 finished with value: 0.7344204554377616 and parameters: {'n_epochs': 1285, 'lr': 0.0017803717087247887, 'weight_decay': 7.403272115398165e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 5, 'n_phenotype': 10, 'n_behaviour': 3}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  56%|█████▌    | 111/200 [7:41:45<8:58:23, 362.97s/it][I 2024-12-16 02:23:01,980] Trial 111 finished with value: 0.7380586362204699 and parameters: {'n_epochs': 1536, 'lr': 0.0026982220550310155, 'weight_decay': 1.2408031424617592e-07, 'batch_size': 64, 'n_genotype': 15, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  56%|█████▌    | 112/200 [7:48:50<9:19:39, 381.58s/it][I 2024-12-16 02:28:17,712] Trial 112 finished with value: 0.7323776839142406 and parameters: {'n_epochs': 1108, 'lr': 0.0026102162144291913, 'weight_decay': 2.2372791623282637e-07, 'batch_size': 64, 'n_genotype': 15, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  56%|█████▋    | 113/200 [7:54:05<8:44:39, 361.83s/it][I 2024-12-16 02:35:50,568] Trial 113 finished with value: 0.7369674831342856 and parameters: {'n_epochs': 1614, 'lr': 0.001431713720173453, 'weight_decay': 9.664201984522395e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  57%|█████▋    | 114/200 [8:01:38<9:17:45, 389.14s/it][I 2024-12-16 02:43:44,503] Trial 114 finished with value: 0.7362443867930686 and parameters: {'n_epochs': 1632, 'lr': 0.001312598434917941, 'weight_decay': 1.0581773266270353e-07, 'batch_size': 64, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  57%|█████▊    | 115/200 [8:09:32<9:47:18, 414.58s/it][I 2024-12-16 02:50:55,234] Trial 115 finished with value: 0.7340679230451908 and parameters: {'n_epochs': 1575, 'lr': 0.0015826332471374327, 'weight_decay': 9.84908594928444e-08, 'batch_size': 64, 'n_genotype': 15, 'n_history': 6, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  58%|█████▊    | 116/200 [8:16:43<9:47:11, 419.42s/it][I 2024-12-16 02:58:33,981] Trial 116 finished with value: 0.7298566792867885 and parameters: {'n_epochs': 1638, 'lr': 0.0007659224078506348, 'weight_decay': 1.6741203847024955e-07, 'batch_size': 64, 'n_genotype': 14, 'n_history': 6, 'n_phenotype': 9, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  58%|█████▊    | 117/200 [8:24:22<9:56:31, 431.22s/it][I 2024-12-16 03:05:28,789] Trial 117 finished with value: 0.7339053642934353 and parameters: {'n_epochs': 1452, 'lr': 0.0013525854232245569, 'weight_decay': 1.2718170016351783e-07, 'batch_size': 64, 'n_genotype': 13, 'n_history': 6, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  59%|█████▉    | 118/200 [8:31:16<9:42:36, 426.30s/it][I 2024-12-16 03:13:17,737] Trial 118 finished with value: 0.7303534569736106 and parameters: {'n_epochs': 1690, 'lr': 0.0011080908422468172, 'weight_decay': 2.7777841916192017e-07, 'batch_size': 64, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  60%|█████▉    | 119/200 [8:39:05<9:52:46, 439.09s/it][I 2024-12-16 03:20:40,438] Trial 119 finished with value: 0.7311646279857447 and parameters: {'n_epochs': 1544, 'lr': 0.003802624931000261, 'weight_decay': 8.838222362609455e-08, 'batch_size': 64, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 9, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  60%|██████    | 120/200 [8:46:28<9:46:53, 440.17s/it][I 2024-12-16 03:27:10,800] Trial 120 finished with value: 0.7258730163300996 and parameters: {'n_epochs': 1403, 'lr': 0.002072600752168642, 'weight_decay': 2.075961998291462e-07, 'batch_size': 64, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 10, 'n_behaviour': 5}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  60%|██████    | 121/200 [8:52:58<9:19:53, 425.23s/it][I 2024-12-16 03:35:53,768] Trial 121 finished with value: 0.7328042850376428 and parameters: {'n_epochs': 1830, 'lr': 0.004916083577356102, 'weight_decay': 5.672932075327691e-07, 'batch_size': 64, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  61%|██████    | 122/200 [9:01:41<9:50:55, 454.55s/it][I 2024-12-16 03:41:51,233] Trial 122 finished with value: 0.7332618720665062 and parameters: {'n_epochs': 1273, 'lr': 0.003161134244819599, 'weight_decay': 1.5072393363414878e-07, 'batch_size': 64, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# ...
# Optuna Trials:  81%|████████  | 162/200 [12:56:58<4:42:54, 446.69s/it][I 2024-12-16 07:38:42,245] Trial 162 finished with value: 0.7296984089741738 and parameters: {'n_epochs': 1584, 'lr': 0.006316800208538893, 'weight_decay': 7.542690954844022e-08, 'batch_size': 64, 'n_genotype': 11, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  82%|████████▏ | 163/200 [13:04:30<4:36:26, 448.29s/it][I 2024-12-16 07:44:43,700] Trial 163 finished with value: 0.7381306127001647 and parameters: {'n_epochs': 1325, 'lr': 0.003878455584492755, 'weight_decay': 1.3518426261820316e-07, 'batch_size': 64, 'n_genotype': 11, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  82%|████████▏ | 164/200 [13:10:31<4:13:20, 422.24s/it][I 2024-12-16 07:50:47,892] Trial 164 finished with value: 0.7384128845650197 and parameters: {'n_epochs': 1306, 'lr': 0.003803622832988134, 'weight_decay': 1.371677831193517e-07, 'batch_size': 64, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  82%|████████▎ | 165/200 [13:16:35<3:56:08, 404.83s/it][I 2024-12-16 07:56:49,330] Trial 165 finished with value: 0.7322648651144293 and parameters: {'n_epochs': 1305, 'lr': 0.004050707727106987, 'weight_decay': 1.3587812903146707e-07, 'batch_size': 64, 'n_genotype': 11, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  83%|████████▎ | 166/200 [13:22:37<3:42:01, 391.81s/it][I 2024-12-16 08:03:13,603] Trial 166 finished with value: 0.7369242706362458 and parameters: {'n_epochs': 1393, 'lr': 0.0032671307759390366, 'weight_decay': 3.537788316160107e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  84%|████████▎ | 167/200 [13:29:01<3:34:15, 389.55s/it][I 2024-12-16 08:09:34,782] Trial 167 finished with value: 0.7355523517761297 and parameters: {'n_epochs': 1382, 'lr': 0.0029306194895897192, 'weight_decay': 6.164938813387306e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  84%|████████▍ | 168/200 [13:35:22<3:26:25, 387.04s/it][I 2024-12-16 08:16:09,157] Trial 168 finished with value: 0.7372901663687832 and parameters: {'n_epochs': 1431, 'lr': 0.0034724151076377706, 'weight_decay': 3.599564077479397e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  84%|████████▍ | 169/200 [13:41:57<3:21:06, 389.24s/it][I 2024-12-16 08:22:21,209] Trial 169 finished with value: 0.7378655004544684 and parameters: {'n_epochs': 1353, 'lr': 0.0038218673416006987, 'weight_decay': 3.3135921268584696e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  85%|████████▌ | 170/200 [13:48:09<3:12:02, 384.08s/it][I 2024-12-16 08:29:18,172] Trial 170 finished with value: 0.7365839276733583 and parameters: {'n_epochs': 1453, 'lr': 0.0036961140592160035, 'weight_decay': 1.9046811189168733e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  86%|████████▌ | 171/200 [13:55:06<3:10:24, 393.95s/it][I 2024-12-16 08:35:42,463] Trial 171 finished with value: 0.725392231009677 and parameters: {'n_epochs': 1396, 'lr': 0.0032046712219128523, 'weight_decay': 3.1207919237559914e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  86%|████████▌ | 172/200 [14:01:30<3:02:29, 391.05s/it][I 2024-12-16 08:42:53,894] Trial 172 finished with value: 0.7338108588517621 and parameters: {'n_epochs': 1493, 'lr': 0.0043920812087259705, 'weight_decay': 4.1670224776300376e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  86%|████████▋ | 173/200 [14:08:41<3:01:25, 403.16s/it][I 2024-12-16 08:49:10,443] Trial 173 finished with value: 0.733901700965992 and parameters: {'n_epochs': 1347, 'lr': 0.0023054294868356307, 'weight_decay': 2.2049175597109752e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  87%|████████▋ | 174/200 [14:14:58<2:51:14, 395.18s/it][I 2024-12-16 08:55:46,959] Trial 174 finished with value: 0.7325805997817858 and parameters: {'n_epochs': 1426, 'lr': 0.004876058421043826, 'weight_decay': 3.4317160244096056e-08, 'batch_size': 64, 'n_genotype': 11, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  88%|████████▊ | 175/200 [14:21:35<2:44:49, 395.58s/it][I 2024-12-16 09:01:50,120] Trial 175 finished with value: 0.7283123079980004 and parameters: {'n_epochs': 1309, 'lr': 0.0034924915320146536, 'weight_decay': 5.4645557005587525e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  88%|████████▊ | 176/200 [14:27:38<2:34:20, 385.85s/it][I 2024-12-16 09:08:39,529] Trial 176 finished with value: 0.7370377289558288 and parameters: {'n_epochs': 1519, 'lr': 0.0027333059276046425, 'weight_decay': 3.7197909004217444e-08, 'batch_size': 64, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  88%|████████▊ | 177/200 [14:34:27<2:30:37, 392.92s/it][I 2024-12-16 09:15:20,092] Trial 177 finished with value: 0.7384774082943354 and parameters: {'n_epochs': 1463, 'lr': 0.002482960864412485, 'weight_decay': 3.799182428253816e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  89%|████████▉ | 178/200 [14:41:08<2:24:54, 395.21s/it][I 2024-12-16 09:22:30,410] Trial 178 finished with value: 0.7381190512637936 and parameters: {'n_epochs': 1541, 'lr': 0.002414687014094768, 'weight_decay': 2.59303924853301e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  90%|████████▉ | 179/200 [14:48:18<2:22:00, 405.74s/it][I 2024-12-16 09:29:29,845] Trial 179 finished with value: 0.7354369676435111 and parameters: {'n_epochs': 1534, 'lr': 0.0024623990285238886, 'weight_decay': 2.733430034770409e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  90%|█████████ | 180/200 [14:55:17<2:16:37, 409.85s/it][I 2024-12-16 09:36:14,395] Trial 180 finished with value: 0.7377837297632533 and parameters: {'n_epochs': 1472, 'lr': 0.0019364726443812945, 'weight_decay': 1.987074323802044e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  90%|█████████ | 181/200 [15:02:02<2:09:16, 408.26s/it][I 2024-12-16 09:42:59,998] Trial 181 finished with value: 0.7403079784928666 and parameters: {'n_epochs': 1468, 'lr': 0.0020418633378125025, 'weight_decay': 2.2013676293957865e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  91%|█████████ | 182/200 [15:08:48<2:02:14, 407.46s/it][I 2024-12-16 09:49:48,376] Trial 182 finished with value: 0.7343396397534647 and parameters: {'n_epochs': 1449, 'lr': 0.001998092330947837, 'weight_decay': 1.510206554687572e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  92%|█████████▏| 183/200 [15:15:36<1:55:31, 407.74s/it][I 2024-12-16 09:56:34,263] Trial 183 finished with value: 0.7344345944289615 and parameters: {'n_epochs': 1477, 'lr': 0.001693735896542792, 'weight_decay': 2.0021032695336918e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  92%|█████████▏| 184/200 [15:22:22<1:48:34, 407.18s/it][I 2024-12-16 10:03:08,260] Trial 184 finished with value: 0.735057222472386 and parameters: {'n_epochs': 1431, 'lr': 0.0020902260042647705, 'weight_decay': 1.3514559649919044e-08, 'batch_size': 64, 'n_genotype': 15, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  92%|█████████▎| 185/200 [15:28:56<1:40:48, 403.23s/it][I 2024-12-16 10:09:26,302] Trial 185 finished with value: 0.7389513199696038 and parameters: {'n_epochs': 1348, 'lr': 0.002672114679128062, 'weight_decay': 2.4302039480290697e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  93%|█████████▎| 186/200 [15:35:14<1:32:19, 395.67s/it][I 2024-12-16 10:15:34,703] Trial 186 finished with value: 0.7361496323401229 and parameters: {'n_epochs': 1336, 'lr': 0.0023920422881086516, 'weight_decay': 1.050282280636703e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  94%|█████████▎| 187/200 [15:41:22<1:23:57, 387.49s/it][I 2024-12-16 10:21:34,341] Trial 187 finished with value: 0.7349440992150578 and parameters: {'n_epochs': 1284, 'lr': 0.002770977305195548, 'weight_decay': 2.3673676013925675e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  94%|█████████▍| 188/200 [15:47:22<1:15:49, 379.13s/it][I 2024-12-16 10:28:40,124] Trial 188 finished with value: 0.7330967152905196 and parameters: {'n_epochs': 1567, 'lr': 0.0017798303056437697, 'weight_decay': 2.6366798134795906e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  94%|█████████▍| 189/200 [15:54:28<1:12:04, 393.13s/it][I 2024-12-16 10:34:26,089] Trial 189 finished with value: 0.7302185140290287 and parameters: {'n_epochs': 1253, 'lr': 0.004356699732123656, 'weight_decay': 1.9514790161414187e-08, 'batch_size': 64, 'n_genotype': 15, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  95%|█████████▌| 190/200 [16:00:14<1:03:09, 378.98s/it][I 2024-12-16 10:38:51,083] Trial 190 finished with value: 0.7305852907407919 and parameters: {'n_epochs': 1478, 'lr': 0.002312363552237806, 'weight_decay': 1.6962313293808952e-08, 'batch_size': 128, 'n_genotype': 15, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  96%|█████████▌| 191/200 [16:04:39<51:43, 344.78s/it]  [I 2024-12-16 10:45:10,625] Trial 191 finished with value: 0.743238361924597 and parameters: {'n_epochs': 1352, 'lr': 0.0038170112740579733, 'weight_decay': 2.8400877305535396e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  96%|█████████▌| 192/200 [16:10:58<47:21, 355.21s/it][I 2024-12-16 10:51:31,580] Trial 192 finished with value: 0.7331226622452122 and parameters: {'n_epochs': 1363, 'lr': 0.0029790986698400765, 'weight_decay': 2.59845004438113e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  96%|█████████▋| 193/200 [16:17:19<42:20, 362.93s/it][I 2024-12-16 10:57:04,193] Trial 193 finished with value: 0.7323533204566086 and parameters: {'n_epochs': 1199, 'lr': 0.0038538607748233845, 'weight_decay': 5.031935176867977e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  97%|█████████▋| 194/200 [16:22:52<35:23, 353.84s/it][I 2024-12-16 11:03:11,731] Trial 194 finished with value: 0.7347103907089805 and parameters: {'n_epochs': 1327, 'lr': 0.004982362895709501, 'weight_decay': 1.3952253057697485e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  98%|█████████▊| 195/200 [16:28:59<29:49, 357.95s/it][I 2024-12-16 11:05:13,781] Trial 195 finished with value: 0.7339741393983624 and parameters: {'n_epochs': 1373, 'lr': 0.0021207106604079393, 'weight_decay': 2.9473353253432703e-08, 'batch_size': 512, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  98%|█████████▊| 196/200 [16:31:01<19:08, 287.18s/it][I 2024-12-16 11:12:26,865] Trial 196 finished with value: 0.733940836773902 and parameters: {'n_epochs': 1539, 'lr': 0.002954874174077929, 'weight_decay': 4.2279013216353846e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  98%|█████████▊| 197/200 [16:38:14<16:32, 330.95s/it][I 2024-12-16 11:18:10,382] Trial 197 finished with value: 0.7327663038630062 and parameters: {'n_epochs': 1225, 'lr': 0.005705805696057096, 'weight_decay': 2.1368598489451674e-08, 'batch_size': 64, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials:  99%|█████████▉| 198/200 [16:43:58<11:09, 334.72s/it][I 2024-12-16 11:24:34,877] Trial 198 finished with value: 0.7347226118364275 and parameters: {'n_epochs': 1414, 'lr': 0.004065127470947865, 'weight_decay': 5.396147838315295e-08, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials: 100%|█████████▉| 199/200 [16:50:22<05:49, 349.65s/it][I 2024-12-16 11:27:18,878] Trial 199 finished with value: 0.732473835751672 and parameters: {'n_epochs': 578, 'lr': 0.0017789609370299417, 'weight_decay': 1.1700354925816845e-05, 'batch_size': 64, 'n_genotype': 15, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 99 with value: 0.7455567712393181.
# Optuna Trials: 100%|██████████| 200/200 [16:53:06<00:00, 303.93s/it]
# Number of finished trials:  200
# Best trial:
#   Value (Mean AUC):  0.7455567712393181
#   Params:
#     n_epochs: 1175
#     lr: 0.002652887105202934
#     weight_decay: 1.1942523033711955e-07
#     batch_size: 64
#     n_genotype: 12
#     n_history: 5
#     n_phenotype: 11
#     n_behaviour: 4
#
# Best Trial Metrics:
# Selected Features: ['rs12722', 'rs4986938', 'rs11225395', 'rs1144393', 'rs2252070', 'rs591058', 'rs4789932', 'class1_SNP_risk_score', 'rs13946', 'rs9340799', 'rs970547', 'rs1800012', 'tracking_period_injury', 'average_run_hours', 'average_interval_training_frequency', 'Age', 'EDEQ_total', 'navicular_drop', 'total_ad_ab_ratio', 'Q_angle_asymmetry', 'Q_angle', 'VALR_12', 'BMI', 'Impact_peak_12', 'hip_abduction_peak_torque', 'Duty_factor_12', 'knee_extension_peak_torque', 'navicular_drop_asymmetry', 'fat_intake_avg', 'past_month_distance', 'SC_past_season', 'non_running_past_season']
# Average AUC: 0.7456 ± 0.0312
# Average F1 Score: 0.1408 ± 0.0673
# Average Accuracy: 0.9058 ± 0.0083
# Average Precision: 0.4434 ± 0.2184

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score, precision_score
from imblearn.over_sampling import RandomOverSampler, ADASYN, SMOTE
import optuna
from joblib import Parallel, delayed
from tqdm import tqdm
import random
import warnings
from optuna.exceptions import TrialPruned

import os

# Limit each parallel process to one thread per library
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'
os.environ['NUMEXPR_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['VECLIB_MAXIMUM_THREADS'] = '1'
os.environ['TORCH_NUM_THREADS'] = '1'  # For PyTorch

# Additional control for PyTorch if needed
import torch
torch.set_num_threads(1)

# # For reproducibility
# def set_seed(seed=42):
#     random.seed(seed)
#     np.random.seed(seed)
#     torch.manual_seed(seed)

# set_seed()

# Suppress warnings for cleaner output
warnings.filterwarnings("ignore")

# Load the dataset
data = pd.read_excel("class1_dataset.xlsx")

# Define feature groups (as provided)
feature_groups = {
    'Genotype': [
        'rs11225395', 'rs1144393', 'rs650108', 'rs591058', 'rs2252070', 'rs4986938', 'rs1800012', 'rs4789932', 'rs9340799', 'rs970547', 
        'rs1800795', 'rs13946', 'rs12722', 'class1_SNP_risk_score', 'rs7528684', 'rs4919510', 'rs1937810', 'rs6481512', 'rs1249269', 
        'rs12574452', 'rs12429486', 'rs4454832', 'rs2761884', 'rs62051384', 'rs4362400', 'rs2586488', 'rs2277698', 'rs1045485', 
        'rs143383', 'rs17576', 'rs2305948', 'rs1011814', 'rs11154027', 'rs2234693', 'rs1643821', 'rs2010963', 'rs10263021', 'rs149047058', 
        'rs420257', 'rs42517', 'rs42522', 'rs42531', 'rs413826', 'rs2104772', 'rs1330363', 'class12_SNP_risk_score', 'rs3753841', 
        'rs57104447', 'rs1887632', 'rs4654760', 'rs1137101', 'rs2306033', 'rs2277268', 'rs4988321', 'rs11232681', 'rs1718119', 'rs3751143', 
        'rs1544410', 'rs2228570', 'rs4328262', 'rs1021188', 'rs74544784', 'rs78391032', 'rs77569527', 'rs117544024', 'rs912336', 
        'rs3218791', 'rs911263', 'rs2525504', 'rs17756404', 'rs4903399', 'rs10132091', 'rs17583842', 'rs1676303', 'rs11629171', 
        'rs2281518', 'rs2285053', 'rs71404070', 'rs710079', 'rs2858056', 'rs820218', 'rs3018362', 'rs1800470', 'rs1800469', 'rs25487', 
        'rs25489', 'rs2289360', 'rs183364169', 'rs11177', 'rs6617', 'rs3219008', 'rs13107325', 'rs60713544', 'rs145648292', 'rs4244032', 
        'rs12656106', 'rs3045', 'rs187483', 'rs4701616', 'rs144414988', 'rs1800629', 'rs10484958', 'rs4730153', 'rs1800797', 'rs1554606', 
        'rs2237352', 'rs4725069', 'rs12154667', 'rs1548456', 'rs3216902', 'rs35360670', 'rs13317', 'rs1800972', 'rs7035322', 'rs7021589', 
        'rs72758637', 'rs10759753', 'rs3789870', 'rs1138545', 'rs3196378', 'rs1134170', 'rs10992075', 'rs1590', 'rs144371252', 
        'rs761804508', 'class123_SNP_risk_score', 'sex'
    ],
    'History': [
        'Age', 'lower_limb_days_total', 'average_run_hours', 'average_interval_training_frequency', 'EDEQ_total', 'tracking_period_injury',
        'past_stress_injury', 'LEAF-Q', 'Athlete_Score', 'average_run_frequency', 'past_month_injury'
    ],
    'Phenotype': [
        'hip_abduction_peak_torque', 'total_ad_ab_ratio', 'knee_extension_peak_torque', 'knee_flexion_peak_torque', 'navicular_drop', 
        'navicular_drop_asymmetry', 'Q_angle', 'Q_angle_asymmetry', 'VALR_12', 'Impact_peak_12', 'Duty_factor_12', 'BMI', 'BMD_spine',
        'hip_abduction_peak_torque_asymmetry', 'hip_adduction_peak_torque', 'hip_adduction_peak_torque_asymmetry', 
        'knee_extension_peak_torque_asymmetry', 'knee_flexion_peak_torque_asymmetry', 'total_fl_ex_ratio', 'leg_lean_mass', 
        'hip_abduction_peak_angle', 'hip_abduction_peak_angle_asymmetry', 'hip_adduction_peak_angle', 'hip_adduction_peak_angle_asymmetry', 
        'ad_ab_ratio_asymmetry', 'knee_extension_peak_angle', 'knee_extension_peak_angle_asymmetry', 'knee_flexion_peak_angle', 
        'knee_flexion_peak_angle_asymmetry', 'fl_ex_ratio_asymmetry', 'VILR_10', 'VALR_10', 'VILR_asymmetry_10', 'VALR_asymmetry_10', 
        'Impact_peak_10', 'Impact_peak_asymmetry_10', 'Flight_time_10', 'Contact_time_10', 'Duty_factor_10', 'Step_frequency_10', 
        'Cadence_asymmetry_10', 'Duty_factor_asymmetry_10', 'VILR_12', 'VILR_asymmetry_12', 'VALR_asymmetry_12', 
        'Impact_peak_asymmetry_12', 'Flight_time_12', 'Contact_time_12', 'Step_frequency_12', 'Cadence_asymmetry_12', 
        'Duty_factor_asymmetry_12', 'Alt_strike', 'height', 'Mass', 'thigh_lean_mass', 'thigh_ffmi', 'lower_leg_lean_mass', 
        'lower_leg_ffmi', 'leg_ffmi', 'total_lean_mass', 'total_ffmi', 'calf_size', 'BMD_hip', 'BMD_body',
    ],
    'Behaviour': [
        'fat_intake_avg', 'past_month_distance', 'past_month_ratio', 'SC_past_season', 'non_running_past_season', 'fat_intake_BW', 
        'fat_percentage_avg', 'average_energy_availability', 'protein_intake_BW', 'omega3_intake_BW', 'vitaminD_intake_BW', 
        'vitaminC_intake_BW', 'vitaminE_intake_BW', 'calcium_intake_BW', 'copper_intake_BW', 'iron_intake_BW', 'glycine_intake_BW', 
        'arginine_intake_BW', 'past_month_min', 'past_week_ratio', 'past_month_volume_low', 'past_week_ratio_low', 'past_month_ratio_low', 
        'past_month_volume_moderate', 'past_week_ratio_moderate', 'past_month_ratio_moderate', 'past_month_volume_high', 
        'past_week_ratio_high', 'past_month_ratio_high', 'past_month_volume_very_high', 'past_week_ratio_very_high', 
        'past_month_ratio_very_high', 'past_month_calculated_volume', 'past_week_ratio_calculated_volume', 
        'past_month_ratio_calculated_volume', 'resistance_training_past_month', 'resistance_training_past_season', 
        'bodyweight_exercises_past_month', 'bodyweight_exercises_past_season', 'core_stability_past_month', 'core_stability_past_season', 
        'balance_training_past_month', 'balance_training_past_season', 'plyometrics_past_month', 'plyometrics_past_season', 
        'drills_past_month', 'drills_past_season', 'circuit_training_past_month', 'circuit_training_past_season', 'barefoot_past_month', 
        'barefoot_past_season', 'stretching_past_month', 'stretching_past_season', 'SC_past_month', 'non_running_past_month'
    ]
}

# Define predictors and outcome
X = data.drop(columns=['RRI'])  # Predictors
y = data['RRI']  # Outcome

# Ensure that the feature groups exist in the dataset
for group in feature_groups:
    feature_groups[group] = [feature for feature in feature_groups[group] if feature in X.columns]

num_features = len(X.columns)
feature_to_idx = {feature: idx for idx, feature in enumerate(X)}

# Initialize adjacency matrix with zeros
adjacency = np.zeros((num_features, num_features), dtype=np.float32)

# Define groups
genotype_features = feature_groups['Genotype']
history_features = feature_groups['History']
phenotype_features = feature_groups['Phenotype']
behaviour_features = feature_groups['Behaviour']

# Get indices for each group
genotype_indices = [feature_to_idx[feat] for feat in genotype_features]
history_indices = [feature_to_idx[feat] for feat in history_features]
phenotype_indices = [feature_to_idx[feat] for feat in phenotype_features]
behaviour_indices = [feature_to_idx[feat] for feat in behaviour_features]

# Genotype nodes: connect to every node except themselves
for i in genotype_indices:
    for j in range(num_features):
        if j != i:
            adjacency[i, j] = 1.0

# History nodes: connect to every node except genotype nodes and themselves
for i in history_indices:
    for j in range(num_features):
        if j not in genotype_indices and j != i:
            adjacency[i, j] = 1.0

# Phenotype nodes: connect to every node except genotype, history nodes, and themselves
for i in phenotype_indices:
    for j in range(num_features):
        if j not in genotype_indices and j not in history_indices and j != i:
            adjacency[i, j] = 1.0

# Behaviour nodes: connect to all other behaviour nodes except themselves
for i in behaviour_indices:
    for j in behaviour_indices:
        if j != i:
            adjacency[i, j] = 1.0

# Convert adjacency to tensor
adjacency_mask = torch.tensor(adjacency, dtype=torch.float32)

class CustomDataset(Dataset):
    def __init__(self, X, y):
        if isinstance(X, pd.DataFrame):
            self.X = X.values.astype(np.float32)
        elif isinstance(X, np.ndarray):
            self.X = X.astype(np.float32)
        else:
            raise TypeError("X should be a pandas DataFrame or a NumPy array.")
        self.y = y.astype(np.float32)
    
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

class CustomNetwork(nn.Module):
    def __init__(self, num_features, adjacency_mask):
        super(CustomNetwork, self).__init__()
        self.num_features = num_features

        # Register the fixed adjacency mask as a buffer (non-trainable)
        self.register_buffer('mask', adjacency_mask.float())  # Shape: (num_features, num_features)

        # Initialize connection weights (W_ij: from node j to node i)
        self.W = nn.Parameter(torch.randn(num_features, num_features) * 0.01)

        # Initialize bias for each node
        self.bias = nn.Parameter(torch.zeros(num_features))

        # Initialize output weights (from each node to the final output)
        self.output_weights = nn.Parameter(torch.randn(num_features) * 0.01)

        # Add Batch Normalization
        self.batch_norm = nn.BatchNorm1d(num_features)

    def forward(self, x, threshold=None):
        """
        x: input tensor of shape (batch_size, num_features)
        threshold: if provided, apply binary thresholding to gating
        """
        # Use the fixed mask directly
        learnable_mask = self.mask

        # Apply the learnable mask to connection weights
        W_masked = self.W * learnable_mask  # Shape: (num_features, num_features)

        # Compute incoming messages: (batch_size, num_features) @ (num_features, num_features) = (batch_size, num_features)
        incoming = torch.matmul(x, W_masked)  # Sum over j for each i: sum_j (x_j * W_ij)

        # Element-wise multiplication with own feature value
        node_input = incoming * x  # Shape: (batch_size, num_features)

        node_input = self.batch_norm(node_input)

        # Add bias
        node_input += self.bias  # Broadcasting over batch

        # Apply Leaky ReLU activation
        node_output = F.leaky_relu(node_input)  # Shape: (batch_size, num_features)

        # Aggregate node outputs to final output
        output = torch.matmul(node_output, self.output_weights)  # Shape: (batch_size,)

        return output  # Raw scores (logits)

# Import ReliefF for feature selection
from skrebate import ReliefF

def train_evaluate_fold(fold, train_index, val_index, X, y, selected_features, adjacency, feature_to_idx, 
                       n_epochs, lr, weight_decay, batch_size, threshold):
    """
    Function to train and evaluate the model on a single fold.
    This function is intended to be run in parallel.
    """
    # Split data
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]

    # Encode labels for binary classification
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y_train_enc = le.fit_transform(y_train)
    y_val_enc = le.transform(y_val)
    y_train_final = y_train_enc
    y_val_final = y_val_enc

    # Create datasets
    train_dataset = CustomDataset(X_train[selected_features], y_train_final)
    val_dataset = CustomDataset(X_val[selected_features], y_val_final)

    # Create dataloaders with drop_last=True for training and drop_last=False for validation
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

    # Map selected_features to their indices
    selected_feature_indices = [feature_to_idx[feat] for feat in selected_features]

    # Select the corresponding adjacency submatrix using integer indices
    selected_adjacency = adjacency[np.ix_(selected_feature_indices, selected_feature_indices)]
    selected_adjacency_mask = torch.tensor(selected_adjacency, dtype=torch.float32)

    device = torch.device('cpu')

    # Initialize the model with the number of selected features and the selected adjacency mask
    model = CustomNetwork(num_features=len(selected_features), 
                          adjacency_mask=selected_adjacency_mask).to(device)

    # Define loss and optimizer
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    # Training Loop
    for epoch in range(1, n_epochs + 1):
        model.train()
        epoch_loss = 0.0

        for batch_X, batch_y in train_loader:
            batch_X = batch_X.to(device).float()  # Ensure float type
            batch_y = batch_y.to(device).float()  # BCEWithLogitsLoss expects float targets

            optimizer.zero_grad()
            outputs = model(batch_X)  # Forward pass
            loss = criterion(outputs, batch_y)

            # Total loss
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item() * batch_X.size(0)

        epoch_loss /= len(train_loader.dataset)

    # Validation
    model.eval()
    all_outputs = []
    all_labels = []
    all_preds = []  # Initialize a list to accumulate predictions

    with torch.no_grad():
        for batch_X, batch_y in val_loader:
            batch_X = batch_X.to(device).float()

            outputs = model(batch_X)  # Forward pass
            probs = torch.sigmoid(outputs).cpu().numpy()
            preds = (probs >= threshold).astype(int).flatten()

            all_outputs.extend(probs)
            all_labels.extend(batch_y.numpy())
            all_preds.extend(preds)  # Accumulate predictions

    # Compute metrics
    roc_auc = roc_auc_score(all_labels, all_outputs)
    f1 = f1_score(all_labels, all_preds, average='binary')
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='binary')

    return {
        'roc_auc': roc_auc,
        'f1': f1,
        'accuracy': accuracy,
        'precision': precision
    }

def group_feature_ranking(X, y, feature_groups):
    """
    Perform group-wise feature ranking using ReliefF.
    Returns a dictionary with group names as keys and DataFrames with feature and score sorted descendingly.
    """
    group_rankings = {}
    for group, features in feature_groups.items():
        # Ensure features are in X
        valid_features = [feat for feat in features if feat in X.columns]
        if not valid_features:
            continue
        relief = ReliefF(n_features_to_select='all')
        X_group = X[valid_features].values
        y_group = y.values
        relief.fit(X_group, y_group)
        feature_scores = relief.feature_importances_
        group_score_df = pd.DataFrame({
            'feature': valid_features,
            'score': feature_scores
        }).sort_values(by='score', ascending=False)
        group_rankings[group] = group_score_df
        
    return group_rankings

def objective(trial, X, y, feature_groups, feature_to_idx, group_feature_rankings, adjacency, threshold=0.5):
    # ====================
    # Hyperparameters to Tune
    # ====================

    # 1. Number of Epochs
    n_epochs = trial.suggest_int('n_epochs', 500, 3000)

    # 2. Learning Rate
    lr = trial.suggest_loguniform('lr', 1e-6, 1e-2)

    # 3. Weight Decay
    weight_decay = trial.suggest_loguniform('weight_decay', 1e-8, 1e-3)

    # 4. Batch Size
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128, 256, 512])

    # 5. Number of Features per Group
    n_genotype = trial.suggest_int('n_genotype', 1, len(feature_groups['Genotype']))
    n_history = trial.suggest_int('n_history', 1, len(feature_groups['History']))
    n_phenotype = trial.suggest_int('n_phenotype', 1, len(feature_groups['Phenotype']))
    n_behaviour = trial.suggest_int('n_behaviour', 1, len(feature_groups['Behaviour']))

    # ====================
    # Feature Selection Using Global Rankings
    # ====================

    # Initialize selected features list
    selected_features = []
    
    # For each group, select the top N features based on group-specific ReliefF scores
    for group, n_select in zip(['Genotype', 'History', 'Phenotype', 'Behaviour'],
                               [n_genotype, n_history, n_phenotype, n_behaviour]):
        if group not in group_feature_rankings:
            continue  # Skip if the group has no features
        group_feature_scores = group_feature_rankings[group]
        # Select top N features
        top_features = group_feature_scores.head(n_select)['feature'].tolist()
        selected_features.extend(top_features)
    
    # Ensure that selected_features are unique
    selected_features = list(dict.fromkeys(selected_features))

    # ====================
    # Data Preparation
    # ====================

    X_selected = X[selected_features].copy()
    y_selected = y.copy()

    # Initialize Stratified K-Fold
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

    # Get all fold indices
    fold_indices = list(skf.split(X_selected, y_selected))

    # ====================
    # Parallel Training and Evaluation
    # ====================

    # Define a wrapper for joblib's Parallel
    results = Parallel(n_jobs=10)(
        delayed(train_evaluate_fold)(
            fold=fold,
            train_index=train_idx,
            val_index=val_idx,
            X=X_selected,
            y=y_selected,
            selected_features=selected_features,
            adjacency=adjacency,  # Pass the numpy adjacency matrix
            feature_to_idx=feature_to_idx,  # Pass the feature_to_idx mapping
            n_epochs=n_epochs,
            lr=lr,
            weight_decay=weight_decay,
            batch_size=batch_size,
            threshold=threshold
        )
        for fold, (train_idx, val_idx) in enumerate(fold_indices)
    )

    # ====================
    # Collect Metrics
    # ====================

    aucs = []
    f1s = []
    accuracies = []
    precisions = []

    for res in results:
        aucs.append(res['roc_auc'])
        f1s.append(res['f1'])
        accuracies.append(res['accuracy'])
        precisions.append(res['precision'])

    # ====================
    # Final Metrics Calculation
    # ====================

    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_f1 = np.mean(f1s)
    std_f1 = np.std(f1s)
    mean_accuracy = np.mean(accuracies)
    std_accuracy = np.std(accuracies)
    mean_precision = np.mean(precisions)
    std_precision = np.std(precisions)

    # ====================
    # Objective Metric
    # ====================

    # Since it's binary classification, we aim to maximize the mean AUC
    trial.set_user_attr("mean_auc", mean_auc)
    trial.set_user_attr("std_auc", std_auc)
    trial.set_user_attr("mean_f1", mean_f1)
    trial.set_user_attr("std_f1", std_f1)
    trial.set_user_attr("mean_accuracy", mean_accuracy)
    trial.set_user_attr("std_accuracy", std_accuracy)
    trial.set_user_attr("mean_precision", mean_precision)
    trial.set_user_attr("std_precision", std_precision)
    trial.set_user_attr("selected_features", selected_features)

    return mean_auc

def run_hyperparameter_tuning(X, y, feature_groups, feature_to_idx, adjacency, threshold=0.5):
    # Generate the group-wise feature ranking before the study starts
    group_feature_rankings = group_feature_ranking(X, y, feature_groups)

    def objective_wrapper(trial):
        return objective(trial, X, y, feature_groups, feature_to_idx, group_feature_rankings, adjacency, threshold)

    study = optuna.create_study(
        direction='maximize',
        study_name='CustomNetwork_Hyperparameter_Tuning',
        sampler=optuna.samplers.TPESampler(seed=42)
    )

    # Integrate a progress bar for the Optuna study
    with tqdm(total=200, desc="Optuna Trials") as pbar:
        def callback(study, trial):
            pbar.update(1)

        # Set n_jobs=1 to ensure serial execution of hyperparameter trials
        study.optimize(objective_wrapper, n_trials=200, timeout=None, callbacks=[callback], n_jobs=1)

    print("Number of finished trials: ", len(study.trials))
    print("Best trial:")
    trial = study.best_trial

    print("  Value (Mean AUC): ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

    # Extract additional metrics from the best trial
    best_trial_metrics = trial.user_attrs
    mean_auc = best_trial_metrics.get("mean_auc", None)
    std_auc = best_trial_metrics.get("std_auc", None)
    mean_f1 = best_trial_metrics.get("mean_f1", None)
    std_f1 = best_trial_metrics.get("std_f1", None)
    mean_accuracy = best_trial_metrics.get("mean_accuracy", None)
    std_accuracy = best_trial_metrics.get("std_accuracy", None)
    mean_precision = best_trial_metrics.get("mean_precision", None)
    std_precision = best_trial_metrics.get("std_precision", None)
    selected_features = best_trial_metrics.get("selected_features", None)

    print(f"\nBest Trial Metrics:")
    print(f"Selected Features: {selected_features}")
    print(f"Average AUC: {mean_auc:.4f} ± {std_auc:.4f}")
    print(f"Average F1 Score: {mean_f1:.4f} ± {std_f1:.4f}")
    print(f"Average Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}")
    print(f"Average Precision: {mean_precision:.4f} ± {std_precision:.4f}")

    return study

if __name__ == "__main__":
    # Run hyperparameter tuning
    study = run_hyperparameter_tuning(X, y, feature_groups, feature_to_idx, adjacency)
# Out:
# [I 2024-12-15 18:38:27,000] A new study created in memory with name: CustomNetwork_Hyperparameter_Tuning
# Optuna Trials:   0%|          | 0/200 [00:00<?, ?it/s][I 2024-12-15 18:40:38,295] Trial 0 finished with value: 0.7197738777127543 and parameters: {'n_epochs': 1436, 'lr': 0.006351221010640704, 'weight_decay': 4.570563099801451e-05, 'batch_size': 512, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 1, 'n_behaviour': 5}. Best is trial 0 with value: 0.7197738777127543.
# Optuna Trials:   0%|          | 1/200 [02:11<7:15:23, 131.27s/it][I 2024-12-15 18:47:49,906] Trial 1 finished with value: 0.693765958085119 and parameters: {'n_epochs': 2581, 'lr': 7.068974950624607e-06, 'weight_decay': 8.111941985431907e-08, 'batch_size': 128, 'n_genotype': 10, 'n_history': 1, 'n_phenotype': 4, 'n_behaviour': 2}. Best is trial 0 with value: 0.7197738777127543.
# Optuna Trials:   1%|          | 2/200 [09:22<16:56:12, 307.94s/it][I 2024-12-15 18:51:04,710] Trial 2 finished with value: 0.7198482810090101 and parameters: {'n_epochs': 1640, 'lr': 0.0013826232179369874, 'weight_decay': 9.9625132220551e-08, 'batch_size': 256, 'n_genotype': 1, 'n_history': 6, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 2 with value: 0.7198482810090101.
# Optuna Trials:   2%|▏         | 3/200 [12:37<14:01:27, 256.28s/it][I 2024-12-15 18:52:50,063] Trial 3 finished with value: 0.5327636054790843 and parameters: {'n_epochs': 1261, 'lr': 2.4586032763280077e-06, 'weight_decay': 2.6373339933815247e-05, 'batch_size': 512, 'n_genotype': 4, 'n_history': 4, 'n_phenotype': 5, 'n_behaviour': 3}. Best is trial 2 with value: 0.7198482810090101.
# Optuna Trials:   2%|▏         | 4/200 [14:23<10:42:32, 196.70s/it][I 2024-12-15 19:01:19,336] Trial 4 finished with value: 0.5745853268742552 and parameters: {'n_epochs': 1867, 'lr': 5.4880470007660465e-06, 'weight_decay': 0.00070456836384545, 'batch_size': 64, 'n_genotype': 2, 'n_history': 2, 'n_phenotype': 1, 'n_behaviour': 2}. Best is trial 2 with value: 0.7198482810090101.
# Optuna Trials:   2%|▎         | 5/200 [22:52<16:45:35, 309.41s/it][I 2024-12-15 19:03:28,322] Trial 5 finished with value: 0.6799396783408715 and parameters: {'n_epochs': 1472, 'lr': 1.2172958098369984e-05, 'weight_decay': 0.00013921548533046482, 'batch_size': 512, 'n_genotype': 2, 'n_history': 6, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 2 with value: 0.7198482810090101.
# Optuna Trials:   3%|▎         | 6/200 [25:01<13:22:05, 248.07s/it][I 2024-12-15 19:05:48,767] Trial 6 finished with value: 0.7251294794027652 and parameters: {'n_epochs': 513, 'lr': 0.0018274508859816032, 'weight_decay': 3.422052903270691e-05, 'batch_size': 64, 'n_genotype': 13, 'n_history': 4, 'n_phenotype': 5, 'n_behaviour': 1}. Best is trial 6 with value: 0.7251294794027652.
# Optuna Trials:   4%|▎         | 7/200 [27:21<11:24:46, 212.88s/it][I 2024-12-15 19:11:52,500] Trial 7 finished with value: 0.7230867309321635 and parameters: {'n_epochs': 1277, 'lr': 1.99863407785289e-05, 'weight_decay': 4.446628955475447e-05, 'batch_size': 64, 'n_genotype': 12, 'n_history': 4, 'n_phenotype': 11, 'n_behaviour': 3}. Best is trial 6 with value: 0.7251294794027652.
# Optuna Trials:   4%|▍         | 8/200 [33:25<13:54:54, 260.91s/it][I 2024-12-15 19:17:09,088] Trial 8 finished with value: 0.7199238847462793 and parameters: {'n_epochs': 1807, 'lr': 5.1305517605898387e-05, 'weight_decay': 1.3399717231179682e-08, 'batch_size': 128, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 6, 'n_behaviour': 4}. Best is trial 6 with value: 0.7251294794027652.
# Optuna Trials:   4%|▍         | 9/200 [38:42<14:45:57, 278.31s/it][I 2024-12-15 19:22:06,454] Trial 9 finished with value: 0.6806522319959445 and parameters: {'n_epochs': 1072, 'lr': 2.031980983842497e-06, 'weight_decay': 2.810329644763601e-07, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 3}. Best is trial 6 with value: 0.7251294794027652.
# Optuna Trials:   5%|▌         | 10/200 [43:39<14:59:57, 284.20s/it][I 2024-12-15 19:26:35,271] Trial 10 finished with value: 0.7242832852433543 and parameters: {'n_epochs': 551, 'lr': 0.0005800693677313923, 'weight_decay': 3.0675727454645503e-06, 'batch_size': 32, 'n_genotype': 6, 'n_history': 3, 'n_phenotype': 8, 'n_behaviour': 1}. Best is trial 6 with value: 0.7251294794027652.
# Optuna Trials:   6%|▌         | 11/200 [48:08<14:40:23, 279.49s/it][I 2024-12-15 19:30:59,981] Trial 11 finished with value: 0.7143506848640687 and parameters: {'n_epochs': 545, 'lr': 0.0004818634574871949, 'weight_decay': 2.4823927253702935e-06, 'batch_size': 32, 'n_genotype': 6, 'n_history': 3, 'n_phenotype': 8, 'n_behaviour': 1}. Best is trial 6 with value: 0.7251294794027652.
# Optuna Trials:   6%|▌         | 12/200 [52:32<14:21:38, 274.99s/it][I 2024-12-15 19:35:14,384] Trial 12 finished with value: 0.721096663349908 and parameters: {'n_epochs': 514, 'lr': 0.0003351292823298157, 'weight_decay': 2.513591364117141e-06, 'batch_size': 32, 'n_genotype': 7, 'n_history': 3, 'n_phenotype': 8, 'n_behaviour': 1}. Best is trial 6 with value: 0.7251294794027652.
# Optuna Trials:   6%|▋         | 13/200 [56:47<13:57:37, 268.76s/it][I 2024-12-15 19:41:32,756] Trial 13 finished with value: 0.7208261121058048 and parameters: {'n_epochs': 783, 'lr': 0.008446324327601356, 'weight_decay': 6.88388301225202e-06, 'batch_size': 32, 'n_genotype': 9, 'n_history': 5, 'n_phenotype': 9, 'n_behaviour': 2}. Best is trial 6 with value: 0.7251294794027652.
# Optuna Trials:   7%|▋         | 14/200 [1:03:05<15:35:46, 301.86s/it][I 2024-12-15 19:43:16,630] Trial 14 finished with value: 0.7283058302271115 and parameters: {'n_epochs': 915, 'lr': 0.0014299624361462236, 'weight_decay': 9.190300196188759e-07, 'batch_size': 256, 'n_genotype': 15, 'n_history': 4, 'n_phenotype': 3, 'n_behaviour': 1}. Best is trial 14 with value: 0.7283058302271115.
# Optuna Trials:   8%|▊         | 15/200 [1:04:49<12:26:44, 242.18s/it][I 2024-12-15 19:45:10,173] Trial 15 finished with value: 0.7308459905385414 and parameters: {'n_epochs': 944, 'lr': 0.002747201835920014, 'weight_decay': 5.324668177665499e-07, 'batch_size': 256, 'n_genotype': 15, 'n_history': 5, 'n_phenotype': 3, 'n_behaviour': 2}. Best is trial 15 with value: 0.7308459905385414.
# Optuna Trials:   8%|▊         | 16/200 [1:06:43<10:23:57, 203.46s/it][I 2024-12-15 19:49:21,365] Trial 16 finished with value: 0.7271096871919206 and parameters: {'n_epochs': 2156, 'lr': 0.00018183007951234691, 'weight_decay': 5.21720125185256e-07, 'batch_size': 256, 'n_genotype': 15, 'n_history': 5, 'n_phenotype': 3, 'n_behaviour': 2}. Best is trial 15 with value: 0.7308459905385414.
# Optuna Trials:   8%|▊         | 17/200 [1:10:54<11:04:20, 217.82s/it][I 2024-12-15 19:51:14,536] Trial 17 finished with value: 0.7266265736260392 and parameters: {'n_epochs': 947, 'lr': 0.0022094860255768393, 'weight_decay': 7.037894397809954e-07, 'batch_size': 256, 'n_genotype': 15, 'n_history': 5, 'n_phenotype': 3, 'n_behaviour': 2}. Best is trial 15 with value: 0.7308459905385414.
# Optuna Trials:   9%|▉         | 18/200 [1:12:47<9:25:19, 186.37s/it] [I 2024-12-15 19:55:30,755] Trial 18 finished with value: 0.7077287815606982 and parameters: {'n_epochs': 2232, 'lr': 6.08947943725685e-05, 'weight_decay': 4.180642255398568e-08, 'batch_size': 256, 'n_genotype': 11, 'n_history': 6, 'n_phenotype': 3, 'n_behaviour': 4}. Best is trial 15 with value: 0.7308459905385414.
# Optuna Trials:  10%|▉         | 19/200 [1:17:03<10:25:30, 207.35s/it][I 2024-12-15 20:01:14,274] Trial 19 finished with value: 0.72557293240873 and parameters: {'n_epochs': 2912, 'lr': 0.0040982721467932495, 'weight_decay': 8.087977803792987e-07, 'batch_size': 256, 'n_genotype': 15, 'n_history': 4, 'n_phenotype': 2, 'n_behaviour': 2}. Best is trial 15 with value: 0.7308459905385414.
# Optuna Trials:  10%|█         | 20/200 [1:22:47<12:24:41, 248.23s/it][I 2024-12-15 20:03:02,825] Trial 20 finished with value: 0.720288592657289 and parameters: {'n_epochs': 911, 'lr': 0.0008409774723770019, 'weight_decay': 7.288922695657402e-06, 'batch_size': 256, 'n_genotype': 12, 'n_history': 5, 'n_phenotype': 6, 'n_behaviour': 3}. Best is trial 15 with value: 0.7308459905385414.
# Optuna Trials:  10%|█         | 21/200 [1:24:35<10:15:28, 206.30s/it][I 2024-12-15 20:07:03,393] Trial 21 finished with value: 0.725242995652744 and parameters: {'n_epochs': 2107, 'lr': 0.0001638003496997183, 'weight_decay': 6.057777159139789e-07, 'batch_size': 256, 'n_genotype': 15, 'n_history': 5, 'n_phenotype': 3, 'n_behaviour': 2}. Best is trial 15 with value: 0.7308459905385414.
# Optuna Trials:  11%|█         | 22/200 [1:28:36<10:42:32, 216.59s/it][I 2024-12-15 20:11:42,436] Trial 22 finished with value: 0.7274959467006337 and parameters: {'n_epochs': 2336, 'lr': 0.00019127818606188998, 'weight_decay': 2.937160207647785e-07, 'batch_size': 256, 'n_genotype': 13, 'n_history': 5, 'n_phenotype': 4, 'n_behaviour': 1}. Best is trial 15 with value: 0.7308459905385414.
# Optuna Trials:  12%|█▏        | 23/200 [1:33:15<11:34:13, 235.33s/it][I 2024-12-15 20:16:37,029] Trial 23 finished with value: 0.7282712084192313 and parameters: {'n_epochs': 2526, 'lr': 0.002469642695517747, 'weight_decay': 1.7226594618901244e-07, 'batch_size': 256, 'n_genotype': 13, 'n_history': 4, 'n_phenotype': 5, 'n_behaviour': 1}. Best is trial 15 with value: 0.7308459905385414.
# Optuna Trials:  12%|█▏        | 24/200 [1:38:10<12:22:27, 253.11s/it][I 2024-12-15 20:22:03,990] Trial 24 finished with value: 0.7309440270514717 and parameters: {'n_epochs': 2888, 'lr': 0.0031093374705943714, 'weight_decay': 1.5978602964253042e-07, 'batch_size': 256, 'n_genotype': 14, 'n_history': 4, 'n_phenotype': 5, 'n_behaviour': 1}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  12%|█▎        | 25/200 [1:43:36<13:22:52, 275.27s/it][I 2024-12-15 20:27:51,138] Trial 25 finished with value: 0.7244432357361772 and parameters: {'n_epochs': 2999, 'lr': 0.003951696130111766, 'weight_decay': 4.310894326778183e-08, 'batch_size': 256, 'n_genotype': 14, 'n_history': 3, 'n_phenotype': 2, 'n_behaviour': 1}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  13%|█▎        | 26/200 [1:49:24<14:20:49, 296.84s/it][I 2024-12-15 20:30:02,848] Trial 26 finished with value: 0.7275762099098013 and parameters: {'n_epochs': 1109, 'lr': 0.0010348274942686053, 'weight_decay': 1.3005413729948783e-06, 'batch_size': 256, 'n_genotype': 11, 'n_history': 4, 'n_phenotype': 6, 'n_behaviour': 2}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  14%|█▎        | 27/200 [1:51:35<11:53:01, 247.29s/it][I 2024-12-15 20:32:23,780] Trial 27 finished with value: 0.7219269119443199 and parameters: {'n_epochs': 781, 'lr': 0.0048383695775082594, 'weight_decay': 2.9660179674420573e-08, 'batch_size': 128, 'n_genotype': 14, 'n_history': 6, 'n_phenotype': 4, 'n_behaviour': 1}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  14%|█▍        | 28/200 [1:53:56<10:17:26, 215.38s/it][I 2024-12-15 20:35:38,104] Trial 28 finished with value: 0.7255095124869634 and parameters: {'n_epochs': 1644, 'lr': 0.0026077088152438497, 'weight_decay': 1.5480732773107534e-07, 'batch_size': 256, 'n_genotype': 12, 'n_history': 4, 'n_phenotype': 2, 'n_behaviour': 1}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  14%|█▍        | 29/200 [1:57:11<9:55:50, 209.07s/it] [I 2024-12-15 20:37:40,946] Trial 29 finished with value: 0.7279390775619277 and parameters: {'n_epochs': 1394, 'lr': 0.00918581143428159, 'weight_decay': 1.0265950040210153e-05, 'batch_size': 512, 'n_genotype': 9, 'n_history': 5, 'n_phenotype': 7, 'n_behaviour': 2}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  15%|█▌        | 30/200 [1:59:13<8:39:03, 183.20s/it][I 2024-12-15 20:42:58,546] Trial 30 finished with value: 0.7200269486835186 and parameters: {'n_epochs': 2743, 'lr': 0.0008420889894584394, 'weight_decay': 1.436250482116321e-06, 'batch_size': 256, 'n_genotype': 11, 'n_history': 3, 'n_phenotype': 1, 'n_behaviour': 4}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  16%|█▌        | 31/200 [2:04:31<10:29:34, 223.52s/it][I 2024-12-15 20:47:45,471] Trial 31 finished with value: 0.7300381636901612 and parameters: {'n_epochs': 2514, 'lr': 0.002843983730575024, 'weight_decay': 2.0158676134763868e-07, 'batch_size': 256, 'n_genotype': 14, 'n_history': 4, 'n_phenotype': 5, 'n_behaviour': 1}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  16%|█▌        | 32/200 [2:09:18<11:19:06, 242.54s/it][I 2024-12-15 20:53:12,851] Trial 32 finished with value: 0.7304518120540344 and parameters: {'n_epochs': 2776, 'lr': 0.005704326065788205, 'weight_decay': 2.9470436001331933e-07, 'batch_size': 256, 'n_genotype': 14, 'n_history': 4, 'n_phenotype': 4, 'n_behaviour': 1}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  16%|█▋        | 33/200 [2:14:45<12:25:54, 267.99s/it][I 2024-12-15 20:58:38,620] Trial 33 finished with value: 0.7173075511314937 and parameters: {'n_epochs': 2715, 'lr': 0.005689986079683202, 'weight_decay': 8.583716285149221e-08, 'batch_size': 256, 'n_genotype': 14, 'n_history': 4, 'n_phenotype': 5, 'n_behaviour': 2}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  17%|█▋        | 34/200 [2:20:11<13:09:24, 285.33s/it][I 2024-12-15 21:05:28,092] Trial 34 finished with value: 0.7227290847662033 and parameters: {'n_epochs': 2457, 'lr': 0.004091874480803176, 'weight_decay': 2.3034870406483244e-07, 'batch_size': 128, 'n_genotype': 10, 'n_history': 1, 'n_phenotype': 4, 'n_behaviour': 1}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  18%|█▊        | 35/200 [2:27:01<14:47:04, 322.57s/it][I 2024-12-15 21:10:59,872] Trial 35 finished with value: 0.730191067144107 and parameters: {'n_epochs': 2743, 'lr': 0.008294212336460863, 'weight_decay': 1.1198190006768329e-08, 'batch_size': 256, 'n_genotype': 14, 'n_history': 5, 'n_phenotype': 7, 'n_behaviour': 2}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  18%|█▊        | 36/200 [2:32:32<14:49:14, 325.33s/it][I 2024-12-15 21:15:00,854] Trial 36 finished with value: 0.7160504848950995 and parameters: {'n_epochs': 2735, 'lr': 0.009450740152502067, 'weight_decay': 1.4592978148331372e-08, 'batch_size': 512, 'n_genotype': 12, 'n_history': 6, 'n_phenotype': 6, 'n_behaviour': 5}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  18%|█▊        | 37/200 [2:36:33<13:35:04, 300.03s/it][I 2024-12-15 21:18:46,184] Trial 37 finished with value: 0.7171042106729006 and parameters: {'n_epochs': 1968, 'lr': 0.006249496290229636, 'weight_decay': 2.2689832598410125e-08, 'batch_size': 256, 'n_genotype': 4, 'n_history': 5, 'n_phenotype': 7, 'n_behaviour': 3}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  19%|█▉        | 38/200 [2:40:19<12:29:34, 277.62s/it][I 2024-12-15 21:24:24,581] Trial 38 finished with value: 0.7271272568946869 and parameters: {'n_epochs': 2858, 'lr': 0.0014605582581066004, 'weight_decay': 7.584109902253589e-08, 'batch_size': 256, 'n_genotype': 13, 'n_history': 6, 'n_phenotype': 7, 'n_behaviour': 2}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  20%|█▉        | 39/200 [2:45:57<13:13:52, 295.85s/it][I 2024-12-15 21:35:17,863] Trial 39 finished with value: 0.7267562008854578 and parameters: {'n_epochs': 2378, 'lr': 0.003274914353462419, 'weight_decay': 7.387441748516834e-08, 'batch_size': 64, 'n_genotype': 10, 'n_history': 5, 'n_phenotype': 9, 'n_behaviour': 2}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  20%|██        | 40/200 [2:56:50<17:54:52, 403.08s/it][I 2024-12-15 21:39:06,750] Trial 40 finished with value: 0.7236128832048975 and parameters: {'n_epochs': 2635, 'lr': 0.0003353844094402381, 'weight_decay': 0.000984474933724538, 'batch_size': 512, 'n_genotype': 14, 'n_history': 5, 'n_phenotype': 4, 'n_behaviour': 3}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  20%|██        | 41/200 [3:00:39<15:29:40, 350.82s/it][I 2024-12-15 21:44:36,169] Trial 41 finished with value: 0.6009473741167135 and parameters: {'n_epochs': 2883, 'lr': 1.0381902110866255e-06, 'weight_decay': 3.797162380239696e-07, 'batch_size': 256, 'n_genotype': 14, 'n_history': 4, 'n_phenotype': 5, 'n_behaviour': 1}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  21%|██        | 42/200 [3:06:09<15:06:55, 344.40s/it][I 2024-12-15 21:49:41,810] Trial 42 finished with value: 0.7262766961944352 and parameters: {'n_epochs': 2537, 'lr': 0.0020834148363342206, 'weight_decay': 1.296851498096697e-07, 'batch_size': 256, 'n_genotype': 15, 'n_history': 4, 'n_phenotype': 5, 'n_behaviour': 1}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  22%|██▏       | 43/200 [3:11:14<14:30:45, 332.77s/it][I 2024-12-15 21:54:46,707] Trial 43 finished with value: 0.7287417056789627 and parameters: {'n_epochs': 2625, 'lr': 0.006458743303536015, 'weight_decay': 1.0248620185913818e-08, 'batch_size': 256, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 4, 'n_behaviour': 1}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  22%|██▏       | 44/200 [3:16:19<14:03:28, 324.41s/it][I 2024-12-15 22:03:30,648] Trial 44 finished with value: 0.7270003781990357 and parameters: {'n_epochs': 2994, 'lr': 0.0010937766462546068, 'weight_decay': 3.8967893830453147e-07, 'batch_size': 128, 'n_genotype': 14, 'n_history': 4, 'n_phenotype': 6, 'n_behaviour': 2}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  22%|██▎       | 45/200 [3:25:03<16:32:41, 384.27s/it][I 2024-12-15 22:08:55,126] Trial 45 finished with value: 0.7275061116468133 and parameters: {'n_epochs': 2823, 'lr': 0.00306951167719513, 'weight_decay': 5.827134408462824e-08, 'batch_size': 256, 'n_genotype': 12, 'n_history': 4, 'n_phenotype': 7, 'n_behaviour': 1}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  23%|██▎       | 46/200 [3:30:28<15:40:15, 366.33s/it][I 2024-12-15 22:12:40,188] Trial 46 finished with value: 0.7303159148974624 and parameters: {'n_epochs': 1952, 'lr': 0.0016215593519367734, 'weight_decay': 8.324235042191647e-05, 'batch_size': 256, 'n_genotype': 13, 'n_history': 3, 'n_phenotype': 9, 'n_behaviour': 1}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  24%|██▎       | 47/200 [3:34:13<13:46:04, 323.95s/it][I 2024-12-15 22:21:38,413] Trial 47 finished with value: 0.7254694687219505 and parameters: {'n_epochs': 1946, 'lr': 2.4487197894453884e-05, 'weight_decay': 1.3756203691631658e-05, 'batch_size': 64, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 10, 'n_behaviour': 3}. Best is trial 24 with value: 0.7309440270514717.
# Optuna Trials:  24%|██▍       | 48/200 [3:43:11<16:23:31, 388.23s/it][I 2024-12-15 22:35:39,763] Trial 48 finished with value: 0.7311939598442634 and parameters: {'n_epochs': 1733, 'lr': 0.0005626228199577038, 'weight_decay': 0.0003549769780940641, 'batch_size': 32, 'n_genotype': 15, 'n_history': 3, 'n_phenotype': 10, 'n_behaviour': 1}. Best is trial 48 with value: 0.7311939598442634.
# Optuna Trials:  24%|██▍       | 49/200 [3:57:12<21:59:09, 524.17s/it][I 2024-12-15 22:48:58,395] Trial 49 finished with value: 0.7321995820299093 and parameters: {'n_epochs': 1674, 'lr': 0.0005746660101410839, 'weight_decay': 0.0002753522087889451, 'batch_size': 32, 'n_genotype': 15, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 49 with value: 0.7321995820299093.
# Optuna Trials:  25%|██▌       | 50/200 [4:10:31<25:16:16, 606.51s/it][I 2024-12-15 23:02:40,517] Trial 50 finished with value: 0.7329973139851614 and parameters: {'n_epochs': 1670, 'lr': 0.0004364678681794829, 'weight_decay': 0.00036299921424002874, 'batch_size': 32, 'n_genotype': 15, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 50 with value: 0.7329973139851614.
# Optuna Trials:  26%|██▌       | 51/200 [4:24:13<27:46:47, 671.19s/it][I 2024-12-15 23:15:44,588] Trial 51 finished with value: 0.7326338045278444 and parameters: {'n_epochs': 1641, 'lr': 0.0004928495013524584, 'weight_decay': 0.0002546599057038073, 'batch_size': 32, 'n_genotype': 15, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 50 with value: 0.7329973139851614.
# Optuna Trials:  26%|██▌       | 52/200 [4:37:17<28:59:08, 705.06s/it][I 2024-12-15 23:29:26,747] Trial 52 finished with value: 0.7332304397094703 and parameters: {'n_epochs': 1693, 'lr': 0.0005142695192911599, 'weight_decay': 0.00033694064806910715, 'batch_size': 32, 'n_genotype': 15, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 52 with value: 0.7332304397094703.
# Optuna Trials:  26%|██▋       | 53/200 [4:50:59<30:13:27, 740.19s/it][I 2024-12-15 23:42:46,149] Trial 53 finished with value: 0.7318452969199281 and parameters: {'n_epochs': 1663, 'lr': 0.0005106718647668923, 'weight_decay': 0.0003492433289936653, 'batch_size': 32, 'n_genotype': 15, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 52 with value: 0.7332304397094703.
# Optuna Trials:  27%|██▋       | 54/200 [5:04:19<30:44:20, 757.95s/it][I 2024-12-15 23:56:01,625] Trial 54 finished with value: 0.734347225952423 and parameters: {'n_epochs': 1656, 'lr': 0.0005166587057389762, 'weight_decay': 0.0004153123007159873, 'batch_size': 32, 'n_genotype': 15, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 54 with value: 0.734347225952423.
# Optuna Trials:  28%|██▊       | 55/200 [5:17:34<30:58:55, 769.21s/it][I 2024-12-16 00:09:41,397] Trial 55 finished with value: 0.7299051743811035 and parameters: {'n_epochs': 1513, 'lr': 0.000340640285899653, 'weight_decay': 0.00037420557367568406, 'batch_size': 32, 'n_genotype': 15, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 54 with value: 0.734347225952423.
# Optuna Trials:  28%|██▊       | 56/200 [5:31:14<31:22:30, 784.38s/it][I 2024-12-16 00:22:20,554] Trial 56 finished with value: 0.731703686017875 and parameters: {'n_epochs': 1568, 'lr': 0.0001307931702939117, 'weight_decay': 0.00019769342437110443, 'batch_size': 32, 'n_genotype': 15, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 54 with value: 0.734347225952423.
# Optuna Trials:  28%|██▊       | 57/200 [5:43:53<30:51:24, 776.81s/it][I 2024-12-16 00:35:00,611] Trial 57 finished with value: 0.7347859686110818 and parameters: {'n_epochs': 1395, 'lr': 0.00044579262988091753, 'weight_decay': 9.463544526868078e-05, 'batch_size': 32, 'n_genotype': 15, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 57 with value: 0.7347859686110818.
# Optuna Trials:  29%|██▉       | 58/200 [5:56:33<30:26:33, 771.79s/it][I 2024-12-16 00:46:00,517] Trial 58 finished with value: 0.730541232141003 and parameters: {'n_epochs': 1371, 'lr': 0.000266627298201818, 'weight_decay': 0.0001242212818880652, 'batch_size': 32, 'n_genotype': 3, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 57 with value: 0.7347859686110818.
# Optuna Trials:  30%|██▉       | 59/200 [6:07:33<28:54:49, 738.22s/it][I 2024-12-16 01:00:37,254] Trial 59 finished with value: 0.7281770249234965 and parameters: {'n_epochs': 1807, 'lr': 8.157616343286027e-05, 'weight_decay': 0.000584373250671289, 'batch_size': 32, 'n_genotype': 7, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 57 with value: 0.7347859686110818.
# Optuna Trials:  30%|███       | 60/200 [6:22:10<30:19:28, 779.78s/it][I 2024-12-16 01:11:28,238] Trial 60 finished with value: 0.7320587680434204 and parameters: {'n_epochs': 1331, 'lr': 0.000696390601074958, 'weight_decay': 7.800301093479749e-05, 'batch_size': 32, 'n_genotype': 15, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 57 with value: 0.7347859686110818.
# Optuna Trials:  30%|███       | 61/200 [6:33:01<28:36:58, 741.14s/it][I 2024-12-16 01:21:26,492] Trial 61 finished with value: 0.7280151794211075 and parameters: {'n_epochs': 1240, 'lr': 0.0007514861817003407, 'weight_decay': 6.417764057092654e-05, 'batch_size': 32, 'n_genotype': 15, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 57 with value: 0.7347859686110818.
# Optuna Trials:  31%|███       | 62/200 [6:42:59<26:46:01, 698.27s/it][I 2024-12-16 01:31:48,582] Trial 62 finished with value: 0.7319931760299119 and parameters: {'n_epochs': 1292, 'lr': 0.00043944080282435564, 'weight_decay': 0.000199785322414011, 'batch_size': 32, 'n_genotype': 15, 'n_history': 2, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 57 with value: 0.7347859686110818.
# Optuna Trials:  32%|███▏      | 63/200 [6:53:21<25:42:12, 675.42s/it][I 2024-12-16 01:44:17,970] Trial 63 finished with value: 0.7239918619658299 and parameters: {'n_epochs': 1543, 'lr': 0.00023126232828237615, 'weight_decay': 3.1371718050863074e-05, 'batch_size': 32, 'n_genotype': 1, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 57 with value: 0.7347859686110818.
# Optuna Trials:  32%|███▏      | 64/200 [7:05:50<26:21:14, 697.61s/it][I 2024-12-16 01:58:27,744] Trial 64 finished with value: 0.7298242603244366 and parameters: {'n_epochs': 1744, 'lr': 0.0007020647595511116, 'weight_decay': 0.00021072312008317152, 'batch_size': 32, 'n_genotype': 15, 'n_history': 1, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 57 with value: 0.7347859686110818.
# Optuna Trials:  32%|███▎      | 65/200 [7:20:00<27:52:19, 743.26s/it][I 2024-12-16 02:10:05,612] Trial 65 finished with value: 0.7372532329095715 and parameters: {'n_epochs': 1437, 'lr': 0.00040665305827834546, 'weight_decay': 0.0005205230789327563, 'batch_size': 32, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  33%|███▎      | 66/200 [7:31:38<27:09:31, 729.64s/it][I 2024-12-16 02:19:36,428] Trial 66 finished with value: 0.7244893817181672 and parameters: {'n_epochs': 1151, 'lr': 0.00012535003185539745, 'weight_decay': 0.0005346593488763881, 'batch_size': 32, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  34%|███▎      | 67/200 [7:41:09<25:11:45, 681.99s/it][I 2024-12-16 02:30:58,696] Trial 67 finished with value: 0.7254865192372079 and parameters: {'n_epochs': 1417, 'lr': 0.001105008095731167, 'weight_decay': 0.0008932925851978367, 'batch_size': 32, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  34%|███▍      | 68/200 [7:52:31<25:00:34, 682.08s/it][I 2024-12-16 02:46:03,684] Trial 68 finished with value: 0.7347879020753016 and parameters: {'n_epochs': 1857, 'lr': 0.0003815736024517105, 'weight_decay': 0.0001374492063439107, 'batch_size': 32, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  34%|███▍      | 69/200 [8:07:36<27:15:12, 748.95s/it][I 2024-12-16 03:00:46,037] Trial 69 finished with value: 0.7252825013010193 and parameters: {'n_epochs': 1863, 'lr': 0.00040936325420393854, 'weight_decay': 0.00012456206405300586, 'batch_size': 32, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  35%|███▌      | 70/200 [8:22:19<28:29:26, 788.97s/it][I 2024-12-16 03:12:54,654] Trial 70 finished with value: 0.7300445388159406 and parameters: {'n_epochs': 1469, 'lr': 0.00022170194068100231, 'weight_decay': 0.0005233647845819447, 'batch_size': 32, 'n_genotype': 14, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  36%|███▌      | 71/200 [8:34:27<27:37:21, 770.86s/it][I 2024-12-16 03:26:34,205] Trial 71 finished with value: 0.7322364285438445 and parameters: {'n_epochs': 1623, 'lr': 0.00026814369732406073, 'weight_decay': 0.0002662348553235798, 'batch_size': 32, 'n_genotype': 15, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  36%|███▌      | 72/200 [8:48:07<27:55:40, 785.47s/it][I 2024-12-16 03:39:16,176] Trial 72 finished with value: 0.7320104557826014 and parameters: {'n_epochs': 1586, 'lr': 0.0002796611374541416, 'weight_decay': 0.00014590308393149453, 'batch_size': 32, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  36%|███▋      | 73/200 [9:00:49<27:27:39, 778.42s/it][I 2024-12-16 03:56:05,953] Trial 73 finished with value: 0.7308939781705391 and parameters: {'n_epochs': 2066, 'lr': 0.00014584361469404558, 'weight_decay': 4.5475968912939614e-05, 'batch_size': 32, 'n_genotype': 14, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  37%|███▋      | 74/200 [9:17:38<29:40:26, 847.83s/it][I 2024-12-16 04:10:48,358] Trial 74 finished with value: 0.7330470146875234 and parameters: {'n_epochs': 1811, 'lr': 0.0003833550532992121, 'weight_decay': 0.00026883733634847665, 'batch_size': 32, 'n_genotype': 15, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  38%|███▊      | 75/200 [9:32:21<29:47:55, 858.20s/it][I 2024-12-16 04:26:03,242] Trial 75 finished with value: 0.7294505630667529 and parameters: {'n_epochs': 1852, 'lr': 9.31176380905851e-05, 'weight_decay': 0.0006782664986884354, 'batch_size': 32, 'n_genotype': 13, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  38%|███▊      | 76/200 [9:47:36<30:08:45, 875.21s/it][I 2024-12-16 04:40:31,077] Trial 76 finished with value: 0.7280361579749133 and parameters: {'n_epochs': 1786, 'lr': 0.00039223062467915696, 'weight_decay': 0.00010388468159062144, 'batch_size': 32, 'n_genotype': 14, 'n_history': 1, 'n_phenotype': 10, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  38%|███▊      | 77/200 [10:02:04<29:49:38, 872.99s/it][I 2024-12-16 04:54:30,366] Trial 77 finished with value: 0.723310107358398 and parameters: {'n_epochs': 1706, 'lr': 0.0009767219762332657, 'weight_decay': 0.00048364723171731577, 'batch_size': 32, 'n_genotype': 15, 'n_history': 1, 'n_phenotype': 11, 'n_behaviour': 5}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  39%|███▉      | 78/200 [10:16:03<29:14:31, 862.88s/it][I 2024-12-16 05:04:20,603] Trial 78 finished with value: 0.7306309587721755 and parameters: {'n_epochs': 1217, 'lr': 0.0002052438260117667, 'weight_decay': 2.2181230776528285e-05, 'batch_size': 32, 'n_genotype': 13, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  40%|███▉      | 79/200 [10:25:53<26:15:11, 781.09s/it][I 2024-12-16 05:16:05,469] Trial 79 finished with value: 0.7310362511484527 and parameters: {'n_epochs': 1456, 'lr': 0.0004667442465164265, 'weight_decay': 0.00026117533521739593, 'batch_size': 32, 'n_genotype': 15, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  40%|████      | 80/200 [10:37:38<25:16:26, 758.22s/it][I 2024-12-16 05:24:37,402] Trial 80 finished with value: 0.7332736641314337 and parameters: {'n_epochs': 1899, 'lr': 0.0003279592567368676, 'weight_decay': 0.00016691075157478847, 'batch_size': 64, 'n_genotype': 5, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  40%|████      | 81/200 [10:46:10<22:37:15, 684.34s/it][I 2024-12-16 05:33:51,248] Trial 81 finished with value: 0.7293598361177522 and parameters: {'n_epochs': 2023, 'lr': 0.0003704818868942077, 'weight_decay': 0.00015710152815751359, 'batch_size': 64, 'n_genotype': 4, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  41%|████      | 82/200 [10:55:24<21:08:52, 645.19s/it][I 2024-12-16 05:42:31,485] Trial 82 finished with value: 0.7335849631985585 and parameters: {'n_epochs': 1900, 'lr': 0.0005696861543961121, 'weight_decay': 0.00038841919670315006, 'batch_size': 64, 'n_genotype': 5, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  42%|████▏     | 83/200 [11:04:04<19:45:01, 607.70s/it][I 2024-12-16 05:51:19,426] Trial 83 finished with value: 0.7338736990224243 and parameters: {'n_epochs': 1911, 'lr': 0.0006350521735317229, 'weight_decay': 0.00040984534907744034, 'batch_size': 64, 'n_genotype': 5, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  42%|████▏     | 84/200 [11:12:52<18:48:37, 583.77s/it][I 2024-12-16 06:01:18,503] Trial 84 finished with value: 0.7302947447659499 and parameters: {'n_epochs': 2179, 'lr': 0.0012298199856339116, 'weight_decay': 5.914094534823098e-05, 'batch_size': 64, 'n_genotype': 5, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  42%|████▎     | 85/200 [11:22:51<18:47:42, 588.37s/it][I 2024-12-16 06:10:01,624] Trial 85 finished with value: 0.7317545277403645 and parameters: {'n_epochs': 1923, 'lr': 0.0008655451153932758, 'weight_decay': 0.000747366322737017, 'batch_size': 64, 'n_genotype': 6, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  43%|████▎     | 86/200 [11:31:34<18:00:42, 568.79s/it][I 2024-12-16 06:19:07,816] Trial 86 finished with value: 0.7269966067613512 and parameters: {'n_epochs': 2015, 'lr': 0.0006846578039280293, 'weight_decay': 0.000450021526310934, 'batch_size': 64, 'n_genotype': 5, 'n_history': 2, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  44%|████▎     | 87/200 [11:40:40<17:38:27, 562.01s/it][I 2024-12-16 06:27:38,343] Trial 87 finished with value: 0.7321060260306568 and parameters: {'n_epochs': 1811, 'lr': 0.00030126587081603863, 'weight_decay': 0.0001687109682715396, 'batch_size': 64, 'n_genotype': 5, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  44%|████▍     | 88/200 [11:49:11<17:00:15, 546.57s/it][I 2024-12-16 06:36:13,861] Trial 88 finished with value: 0.7275002389156835 and parameters: {'n_epochs': 1879, 'lr': 0.00016770532028137071, 'weight_decay': 9.145978225682921e-05, 'batch_size': 64, 'n_genotype': 3, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  44%|████▍     | 89/200 [11:57:46<16:33:54, 537.25s/it][I 2024-12-16 06:46:27,254] Trial 89 finished with value: 0.7286811756691417 and parameters: {'n_epochs': 2191, 'lr': 0.0018103793820182523, 'weight_decay': 0.0007786867794714336, 'batch_size': 64, 'n_genotype': 6, 'n_history': 1, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  45%|████▌     | 90/200 [12:08:00<17:06:50, 560.09s/it][I 2024-12-16 06:56:48,642] Trial 90 finished with value: 0.7337650483294909 and parameters: {'n_epochs': 2287, 'lr': 0.0006321444592378283, 'weight_decay': 0.0003096973026267396, 'batch_size': 64, 'n_genotype': 8, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  46%|████▌     | 91/200 [12:18:21<17:30:54, 578.48s/it][I 2024-12-16 07:07:22,153] Trial 91 finished with value: 0.737002480843859 and parameters: {'n_epochs': 2298, 'lr': 0.000618396798314276, 'weight_decay': 0.0004328087805261287, 'batch_size': 64, 'n_genotype': 9, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  46%|████▌     | 92/200 [12:28:55<17:50:59, 594.99s/it][I 2024-12-16 07:18:07,713] Trial 92 finished with value: 0.7330214788100987 and parameters: {'n_epochs': 2347, 'lr': 0.0006255189345236038, 'weight_decay': 0.00044360197046629094, 'batch_size': 64, 'n_genotype': 9, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  46%|████▋     | 93/200 [12:39:40<18:08:07, 610.16s/it][I 2024-12-16 07:28:29,861] Trial 93 finished with value: 0.733561871824848 and parameters: {'n_epochs': 2259, 'lr': 0.0008826509696446555, 'weight_decay': 0.0006652875205874565, 'batch_size': 64, 'n_genotype': 7, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  47%|████▋     | 94/200 [12:50:02<18:04:18, 613.76s/it][I 2024-12-16 07:39:42,528] Trial 94 finished with value: 0.733036291999815 and parameters: {'n_epochs': 2416, 'lr': 0.0013829228493624926, 'weight_decay': 0.0006074780840031036, 'batch_size': 64, 'n_genotype': 9, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  48%|████▊     | 95/200 [13:01:15<18:25:00, 631.43s/it][I 2024-12-16 07:49:25,691] Trial 95 finished with value: 0.7329291548502571 and parameters: {'n_epochs': 2097, 'lr': 0.000881441150782066, 'weight_decay': 0.0008833693440271336, 'batch_size': 64, 'n_genotype': 7, 'n_history': 3, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  48%|████▊     | 96/200 [13:10:58<17:49:22, 616.95s/it][I 2024-12-16 07:59:59,505] Trial 96 finished with value: 0.7348347531586434 and parameters: {'n_epochs': 2289, 'lr': 0.000563330102894358, 'weight_decay': 0.0001867712845842946, 'batch_size': 64, 'n_genotype': 8, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  48%|████▊     | 97/200 [13:21:32<17:47:46, 622.01s/it][I 2024-12-16 08:10:22,994] Trial 97 finished with value: 0.7331488737122779 and parameters: {'n_epochs': 2293, 'lr': 0.0006090117096380772, 'weight_decay': 0.0003921398100032388, 'batch_size': 64, 'n_genotype': 8, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  49%|████▉     | 98/200 [13:31:55<17:38:10, 622.45s/it][I 2024-12-16 08:20:46,059] Trial 98 finished with value: 0.7264356300734011 and parameters: {'n_epochs': 2286, 'lr': 0.0008414429553013001, 'weight_decay': 0.00011221033927401421, 'batch_size': 64, 'n_genotype': 8, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 2}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  50%|████▉     | 99/200 [13:42:19<17:28:06, 622.64s/it][I 2024-12-16 08:31:12,459] Trial 99 finished with value: 0.7263348724217278 and parameters: {'n_epochs': 2226, 'lr': 0.001161724484755121, 'weight_decay': 0.00021882729202465933, 'batch_size': 64, 'n_genotype': 8, 'n_history': 3, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  50%|█████     | 100/200 [13:52:45<17:19:36, 623.77s/it][I 2024-12-16 08:34:05,758] Trial 100 finished with value: 0.7281592809327129 and parameters: {'n_epochs': 2134, 'lr': 0.0018495793002407622, 'weight_decay': 0.000312219082699257, 'batch_size': 512, 'n_genotype': 8, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  50%|█████     | 101/200 [13:55:38<13:26:13, 488.63s/it][I 2024-12-16 08:45:08,497] Trial 101 finished with value: 0.7181792485762715 and parameters: {'n_epochs': 2439, 'lr': 6.61109565378136e-06, 'weight_decay': 0.0001745092853007882, 'batch_size': 64, 'n_genotype': 7, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  51%|█████     | 102/200 [14:06:41<14:43:24, 540.86s/it][I 2024-12-16 08:54:19,814] Trial 102 finished with value: 0.7349314984100083 and parameters: {'n_epochs': 2023, 'lr': 0.0005610649831018652, 'weight_decay': 0.0005862790916948156, 'batch_size': 64, 'n_genotype': 6, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  52%|█████▏    | 103/200 [14:15:52<14:39:27, 544.00s/it][I 2024-12-16 09:04:44,427] Trial 103 finished with value: 0.7333981605265057 and parameters: {'n_epochs': 2287, 'lr': 0.0005524507186022437, 'weight_decay': 0.0006710144031111846, 'batch_size': 64, 'n_genotype': 6, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  52%|█████▏    | 104/200 [14:26:17<15:09:05, 568.18s/it][I 2024-12-16 09:10:41,649] Trial 104 finished with value: 0.7356440492331495 and parameters: {'n_epochs': 2045, 'lr': 0.0007506735102261956, 'weight_decay': 0.00043789330844735513, 'batch_size': 128, 'n_genotype': 7, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  52%|█████▎    | 105/200 [14:32:14<13:19:24, 504.89s/it][I 2024-12-16 09:16:23,825] Trial 105 finished with value: 0.7346981458330523 and parameters: {'n_epochs': 2000, 'lr': 0.0007072531095204028, 'weight_decay': 0.000463490907713307, 'batch_size': 128, 'n_genotype': 9, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  53%|█████▎    | 106/200 [14:37:56<11:54:31, 456.08s/it][I 2024-12-16 09:22:14,193] Trial 106 finished with value: 0.7335647378392632 and parameters: {'n_epochs': 2038, 'lr': 0.000733695896376838, 'weight_decay': 0.0009897711738314173, 'batch_size': 128, 'n_genotype': 9, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  54%|█████▎    | 107/200 [14:43:47<10:57:45, 424.37s/it][I 2024-12-16 09:27:55,412] Trial 107 finished with value: 0.7173023770429238 and parameters: {'n_epochs': 1984, 'lr': 0.0013537011516508545, 'weight_decay': 0.00046793686676501936, 'batch_size': 128, 'n_genotype': 10, 'n_history': 2, 'n_phenotype': 10, 'n_behaviour': 4}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  54%|█████▍    | 108/200 [14:49:28<10:12:26, 399.42s/it][I 2024-12-16 09:35:05,967] Trial 108 finished with value: 0.7318824197707938 and parameters: {'n_epochs': 2492, 'lr': 0.00025102980412635946, 'weight_decay': 5.49741831280933e-06, 'batch_size': 128, 'n_genotype': 8, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  55%|█████▍    | 109/200 [14:56:38<10:19:57, 408.76s/it][I 2024-12-16 09:41:18,365] Trial 109 finished with value: 0.7289887300280439 and parameters: {'n_epochs': 2135, 'lr': 0.0009916444950026004, 'weight_decay': 0.00030234979908007646, 'batch_size': 128, 'n_genotype': 8, 'n_history': 2, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  55%|█████▌    | 110/200 [15:02:51<9:56:46, 397.85s/it] [I 2024-12-16 09:48:11,222] Trial 110 finished with value: 0.7334685921625258 and parameters: {'n_epochs': 2379, 'lr': 0.0004510384547990349, 'weight_decay': 0.00023965753942986796, 'batch_size': 128, 'n_genotype': 7, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  56%|█████▌    | 111/200 [15:09:44<9:56:49, 402.35s/it][I 2024-12-16 09:54:09,908] Trial 111 finished with value: 0.7338326676087521 and parameters: {'n_epochs': 2086, 'lr': 0.000541043171627168, 'weight_decay': 0.0003985867276356488, 'batch_size': 128, 'n_genotype': 6, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 65 with value: 0.7372532329095715.
# Optuna Trials:  56%|█████▌    | 112/200 [15:15:42<9:30:54, 389.25s/it][I 2024-12-16 10:00:09,928] Trial 112 finished with value: 0.7394404100047507 and parameters: {'n_epochs': 2080, 'lr': 0.0003314586104440468, 'weight_decay': 0.0005417687953694567, 'batch_size': 128, 'n_genotype': 6, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  56%|█████▋    | 113/200 [15:21:42<9:11:42, 380.48s/it][I 2024-12-16 10:06:12,226] Trial 113 finished with value: 0.7263401838838347 and parameters: {'n_epochs': 2092, 'lr': 3.618434281954673e-05, 'weight_decay': 0.0005457332608513935, 'batch_size': 128, 'n_genotype': 6, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  57%|█████▋    | 114/200 [15:27:45<8:57:32, 375.03s/it][I 2024-12-16 10:11:52,621] Trial 114 finished with value: 0.7342069875933482 and parameters: {'n_epochs': 1980, 'lr': 0.00031731522400229185, 'weight_decay': 0.0007807481546684034, 'batch_size': 128, 'n_genotype': 6, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  57%|█████▊    | 115/200 [15:33:25<8:36:34, 364.64s/it][I 2024-12-16 10:18:15,369] Trial 115 finished with value: 0.7264974334589018 and parameters: {'n_epochs': 2203, 'lr': 0.00030830017069316486, 'weight_decay': 0.0007787718040249204, 'batch_size': 128, 'n_genotype': 7, 'n_history': 2, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  58%|█████▊    | 116/200 [15:39:48<8:38:05, 370.07s/it][I 2024-12-16 10:23:51,607] Trial 116 finished with value: 0.7321890717867741 and parameters: {'n_epochs': 1951, 'lr': 0.0002021189327185664, 'weight_decay': 0.0005696102879047044, 'batch_size': 128, 'n_genotype': 10, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  58%|█████▊    | 117/200 [15:45:24<8:17:53, 359.92s/it][I 2024-12-16 10:29:37,240] Trial 117 finished with value: 0.7362444019960711 and parameters: {'n_epochs': 1998, 'lr': 0.00037910595123408556, 'weight_decay': 0.0002151969259423075, 'batch_size': 128, 'n_genotype': 6, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  59%|█████▉    | 118/200 [15:51:10<8:06:02, 355.63s/it][I 2024-12-16 10:35:25,467] Trial 118 finished with value: 0.7300346504054237 and parameters: {'n_epochs': 2025, 'lr': 0.00042062472620226887, 'weight_decay': 6.568312173490405e-05, 'batch_size': 128, 'n_genotype': 6, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  60%|█████▉    | 119/200 [15:56:58<7:57:06, 353.41s/it][I 2024-12-16 10:39:49,927] Trial 119 finished with value: 0.7348871083251419 and parameters: {'n_epochs': 1511, 'lr': 0.0003591262281570556, 'weight_decay': 0.0002181915486697557, 'batch_size': 128, 'n_genotype': 7, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  60%|██████    | 120/200 [16:01:22<7:15:38, 326.73s/it]/home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
# Optuna Trials:  81%|████████  | 162/200 [18:51:39<2:56:40, 278.97s/it][I 2024-12-16 13:34:30,452] Trial 162 finished with value: 0.7350550616586886 and parameters: {'n_epochs': 1766, 'lr': 0.0010729067150399467, 'weight_decay': 4.6765373986002984e-05, 'batch_size': 128, 'n_genotype': 11, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  82%|████████▏ | 163/200 [18:56:03<2:49:19, 274.59s/it][I 2024-12-16 13:38:59,603] Trial 163 finished with value: 0.7354631291294635 and parameters: {'n_epochs': 1771, 'lr': 0.001036913695017296, 'weight_decay': 4.301384798420141e-05, 'batch_size': 128, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  82%|████████▏ | 164/200 [19:00:32<2:43:46, 272.96s/it][I 2024-12-16 13:43:41,171] Trial 164 finished with value: 0.7296858434440654 and parameters: {'n_epochs': 1895, 'lr': 0.002077621500869414, 'weight_decay': 8.425787791896519e-05, 'batch_size': 128, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  82%|████████▎ | 165/200 [19:05:14<2:40:43, 275.54s/it][I 2024-12-16 13:48:26,907] Trial 165 finished with value: 0.7229592089408314 and parameters: {'n_epochs': 1770, 'lr': 0.0015846967124412508, 'weight_decay': 5.815717956217788e-05, 'batch_size': 128, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 4}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  83%|████████▎ | 166/200 [19:09:59<2:37:52, 278.60s/it][I 2024-12-16 13:53:14,567] Trial 166 finished with value: 0.7335172984096554 and parameters: {'n_epochs': 1987, 'lr': 0.0009802978021873385, 'weight_decay': 0.00011703659163435332, 'batch_size': 128, 'n_genotype': 10, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  84%|████████▎ | 167/200 [19:14:47<2:34:43, 281.32s/it][I 2024-12-16 13:58:40,179] Trial 167 finished with value: 0.7179904822327259 and parameters: {'n_epochs': 2159, 'lr': 0.0012571058246195839, 'weight_decay': 3.9299410949781804e-05, 'batch_size': 128, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  84%|████████▍ | 168/200 [19:20:13<2:37:07, 294.61s/it][I 2024-12-16 14:02:49,872] Trial 168 finished with value: 0.723721520980247 and parameters: {'n_epochs': 1710, 'lr': 0.0009260899583355156, 'weight_decay': 0.00015139376429861256, 'batch_size': 128, 'n_genotype': 11, 'n_history': 2, 'n_phenotype': 11, 'n_behaviour': 3}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  84%|████████▍ | 169/200 [19:24:22<2:25:15, 281.13s/it][I 2024-12-16 14:07:30,503] Trial 169 finished with value: 0.733954753185194 and parameters: {'n_epochs': 1932, 'lr': 0.0025915699941678415, 'weight_decay': 7.592453071928552e-05, 'batch_size': 128, 'n_genotype': 11, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  85%|████████▌ | 170/200 [19:29:03<2:20:29, 280.98s/it][I 2024-12-16 14:11:56,073] Trial 170 finished with value: 0.7309373284892631 and parameters: {'n_epochs': 1789, 'lr': 0.00085426557188683, 'weight_decay': 0.00010029792676104617, 'batch_size': 128, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 10, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  86%|████████▌ | 171/200 [19:33:29<2:13:34, 276.36s/it][I 2024-12-16 14:16:12,125] Trial 171 finished with value: 0.7351746598052913 and parameters: {'n_epochs': 1755, 'lr': 0.0010754302023009753, 'weight_decay': 5.015275302923973e-05, 'batch_size': 128, 'n_genotype': 11, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  86%|████████▌ | 172/200 [19:37:45<2:06:07, 270.27s/it][I 2024-12-16 14:20:44,028] Trial 172 finished with value: 0.7344328507538598 and parameters: {'n_epochs': 1837, 'lr': 0.001099621560516011, 'weight_decay': 7.891408492568433e-05, 'batch_size': 128, 'n_genotype': 10, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  86%|████████▋ | 173/200 [19:42:17<2:01:50, 270.76s/it][I 2024-12-16 14:25:45,913] Trial 173 finished with value: 0.7352610589662031 and parameters: {'n_epochs': 2064, 'lr': 0.001459462343936105, 'weight_decay': 2.5207573885641554e-05, 'batch_size': 128, 'n_genotype': 11, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  87%|████████▋ | 174/200 [19:47:18<2:01:22, 280.10s/it][I 2024-12-16 14:30:50,290] Trial 174 finished with value: 0.7307376868317863 and parameters: {'n_epochs': 2047, 'lr': 0.0014990395836141158, 'weight_decay': 4.127754084312425e-05, 'batch_size': 128, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  88%|████████▊ | 175/200 [19:52:23<1:59:44, 287.38s/it][I 2024-12-16 14:35:38,911] Trial 175 finished with value: 0.7371604363648891 and parameters: {'n_epochs': 1882, 'lr': 0.0012812725949683248, 'weight_decay': 5.467539346497585e-05, 'batch_size': 128, 'n_genotype': 11, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  88%|████████▊ | 176/200 [19:57:11<1:55:06, 287.75s/it][I 2024-12-16 14:40:55,557] Trial 176 finished with value: 0.7355563421171791 and parameters: {'n_epochs': 2107, 'lr': 0.0013000861468858065, 'weight_decay': 3.230356093299055e-05, 'batch_size': 128, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  88%|████████▊ | 177/200 [20:02:28<1:53:37, 296.42s/it][I 2024-12-16 14:45:51,595] Trial 177 finished with value: 0.7298189524891898 and parameters: {'n_epochs': 1972, 'lr': 0.0018231287938075946, 'weight_decay': 3.180966092270085e-05, 'batch_size': 128, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  89%|████████▉ | 178/200 [20:07:24<1:48:38, 296.31s/it][I 2024-12-16 14:50:47,272] Trial 178 finished with value: 0.7365638286082878 and parameters: {'n_epochs': 1891, 'lr': 0.0007911954702437637, 'weight_decay': 1.5476530999655374e-05, 'batch_size': 128, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  90%|████████▉ | 179/200 [20:12:20<1:43:38, 296.12s/it][I 2024-12-16 14:55:34,079] Trial 179 finished with value: 0.737511417653725 and parameters: {'n_epochs': 1897, 'lr': 0.0007943173074557625, 'weight_decay': 2.2962570230139818e-05, 'batch_size': 128, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  90%|█████████ | 180/200 [20:17:07<1:37:46, 293.32s/it][I 2024-12-16 15:00:20,076] Trial 180 finished with value: 0.7288522163052533 and parameters: {'n_epochs': 1900, 'lr': 0.000765311591373238, 'weight_decay': 2.0992020763302307e-05, 'batch_size': 128, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  90%|█████████ | 181/200 [20:21:53<1:32:11, 291.13s/it][I 2024-12-16 15:04:57,644] Trial 181 finished with value: 0.7338663129466513 and parameters: {'n_epochs': 1872, 'lr': 0.0007954137854569526, 'weight_decay': 1.1856558636955957e-05, 'batch_size': 128, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  91%|█████████ | 182/200 [20:26:30<1:26:07, 287.06s/it][I 2024-12-16 15:09:48,528] Trial 182 finished with value: 0.7381180825443632 and parameters: {'n_epochs': 1945, 'lr': 0.001195629352626672, 'weight_decay': 1.72451084230516e-05, 'batch_size': 128, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  92%|█████████▏| 183/200 [20:31:21<1:21:39, 288.21s/it][I 2024-12-16 15:14:40,275] Trial 183 finished with value: 0.7368074037637212 and parameters: {'n_epochs': 1932, 'lr': 0.0012709282164986805, 'weight_decay': 2.6833859943113292e-05, 'batch_size': 128, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  92%|█████████▏| 184/200 [20:36:13<1:17:08, 289.27s/it][I 2024-12-16 15:19:31,731] Trial 184 finished with value: 0.7301512083489595 and parameters: {'n_epochs': 1928, 'lr': 0.0008307713906488582, 'weight_decay': 1.849535203276527e-05, 'batch_size': 128, 'n_genotype': 11, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  92%|█████████▎| 185/200 [20:41:04<1:12:28, 289.92s/it][I 2024-12-16 15:24:25,804] Trial 185 finished with value: 0.7385128234406024 and parameters: {'n_epochs': 1981, 'lr': 0.0006765004849513738, 'weight_decay': 5.732587954427943e-06, 'batch_size': 128, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  93%|█████████▎| 186/200 [20:45:58<1:07:56, 291.17s/it][I 2024-12-16 15:29:00,858] Trial 186 finished with value: 0.7335091538729722 and parameters: {'n_epochs': 1820, 'lr': 0.0006615518226195567, 'weight_decay': 5.5448483479393875e-06, 'batch_size': 128, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  94%|█████████▎| 187/200 [20:50:33<1:02:02, 286.33s/it][I 2024-12-16 15:34:02,934] Trial 187 finished with value: 0.7350783461005962 and parameters: {'n_epochs': 1978, 'lr': 0.0006873532980524522, 'weight_decay': 7.3900113328593425e-06, 'batch_size': 128, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  94%|█████████▍| 188/200 [20:55:35<58:12, 291.06s/it]  [I 2024-12-16 15:38:54,106] Trial 188 finished with value: 0.7393539799410033 and parameters: {'n_epochs': 2005, 'lr': 0.0012229551370139542, 'weight_decay': 3.1173003023431926e-06, 'batch_size': 128, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  94%|█████████▍| 189/200 [21:00:27<53:22, 291.09s/it][I 2024-12-16 15:43:36,255] Trial 189 finished with value: 0.7389753008680187 and parameters: {'n_epochs': 1883, 'lr': 0.0012119447302833728, 'weight_decay': 1.4885611633896327e-05, 'batch_size': 128, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  95%|█████████▌| 190/200 [21:05:09<48:04, 288.41s/it][I 2024-12-16 15:48:29,813] Trial 190 finished with value: 0.7356889044504042 and parameters: {'n_epochs': 2003, 'lr': 0.002126017258550976, 'weight_decay': 2.43704488670298e-06, 'batch_size': 128, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  96%|█████████▌| 191/200 [21:10:02<43:29, 289.95s/it][I 2024-12-16 15:53:11,297] Trial 191 finished with value: 0.736780961568733 and parameters: {'n_epochs': 1881, 'lr': 0.001211258066937769, 'weight_decay': 1.6129591645110715e-05, 'batch_size': 128, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  96%|█████████▌| 192/200 [21:14:44<38:19, 287.41s/it][I 2024-12-16 15:57:50,867] Trial 192 finished with value: 0.7353396701157491 and parameters: {'n_epochs': 1902, 'lr': 0.0013371370910401712, 'weight_decay': 1.4655069121594608e-05, 'batch_size': 128, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  96%|█████████▋| 193/200 [21:19:23<33:15, 285.06s/it][I 2024-12-16 16:02:35,978] Trial 193 finished with value: 0.7269167595977529 and parameters: {'n_epochs': 1924, 'lr': 0.0011091485019932366, 'weight_decay': 1.585617986996917e-05, 'batch_size': 128, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 11, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  97%|█████████▋| 194/200 [21:24:08<28:30, 285.08s/it][I 2024-12-16 16:07:07,488] Trial 194 finished with value: 0.7340745790787382 and parameters: {'n_epochs': 1833, 'lr': 0.0012368766986022278, 'weight_decay': 1.018755253818859e-05, 'batch_size': 128, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  98%|█████████▊| 195/200 [21:28:40<23:25, 281.01s/it][I 2024-12-16 16:11:49,510] Trial 195 finished with value: 0.7360820913612937 and parameters: {'n_epochs': 1882, 'lr': 0.0009057714051489503, 'weight_decay': 2.9603951757308353e-06, 'batch_size': 128, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  98%|█████████▊| 196/200 [21:33:22<18:45, 281.31s/it][I 2024-12-16 16:16:32,432] Trial 196 finished with value: 0.7363019490376591 and parameters: {'n_epochs': 1893, 'lr': 0.0016526966536085424, 'weight_decay': 2.6609866025382004e-06, 'batch_size': 128, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  98%|█████████▊| 197/200 [21:38:05<14:05, 281.79s/it][I 2024-12-16 16:21:03,997] Trial 197 finished with value: 0.7358393948996673 and parameters: {'n_epochs': 1808, 'lr': 0.0015011843094151285, 'weight_decay': 2.0292950377601387e-06, 'batch_size': 128, 'n_genotype': 13, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials:  99%|█████████▉| 198/200 [21:42:36<09:17, 278.73s/it][I 2024-12-16 16:25:54,838] Trial 198 finished with value: 0.7383062988969306 and parameters: {'n_epochs': 1997, 'lr': 0.0030205873062462514, 'weight_decay': 4.095456609587552e-06, 'batch_size': 128, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials: 100%|█████████▉| 199/200 [21:47:27<04:42, 282.36s/it][I 2024-12-16 16:30:27,568] Trial 199 finished with value: 0.7355148677297433 and parameters: {'n_epochs': 1868, 'lr': 0.0032464911561678124, 'weight_decay': 4.1648633746459245e-06, 'batch_size': 128, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 112 with value: 0.7394404100047507.
# Optuna Trials: 100%|██████████| 200/200 [21:52:00<00:00, 393.60s/it]
# Number of finished trials:  200
# Best trial:
#   Value (Mean AUC):  0.7394404100047507
#   Params:
#     n_epochs: 2080
#     lr: 0.0003314586104440468
#     weight_decay: 0.0005417687953694567
#     batch_size: 128
#     n_genotype: 6
#     n_history: 2
#     n_phenotype: 13
#     n_behaviour: 1
#
# Best Trial Metrics:
# Selected Features: ['rs2252070', 'rs4986938', 'rs12722', 'rs1144393', 'rs591058', 'rs4789932', 'average_run_hours', 'Age', 'BMD_spine', 'Q_angle_asymmetry', 'Q_angle', 'Impact_peak_12', 'navicular_drop', 'Duty_factor_12', 'VALR_12', 'knee_flexion_peak_torque', 'navicular_drop_asymmetry', 'total_ad_ab_ratio', 'hip_abduction_peak_torque', 'BMI', 'knee_extension_peak_torque', 'fat_intake_avg']
# Average AUC: 0.7394 ± 0.0405
# Average F1 Score: 0.0334 ± 0.0297
# Average Accuracy: 0.9079 ± 0.0031
# Average Precision: 0.4571 ± 0.4554

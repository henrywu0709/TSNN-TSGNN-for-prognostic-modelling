# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score, precision_score
from imblearn.over_sampling import RandomOverSampler, ADASYN, SMOTE
import optuna
from joblib import Parallel, delayed
from tqdm import tqdm
import random
import warnings
from optuna.exceptions import TrialPruned

import os

# Limit each parallel process to one thread per library
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'
os.environ['NUMEXPR_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['VECLIB_MAXIMUM_THREADS'] = '1'
os.environ['TORCH_NUM_THREADS'] = '1'  # For PyTorch

# Additional control for PyTorch if needed
import torch
torch.set_num_threads(1)

# # For reproducibility
# def set_seed(seed=42):
#     random.seed(seed)
#     np.random.seed(seed)
#     torch.manual_seed(seed)

# set_seed()

# Suppress warnings for cleaner output
warnings.filterwarnings("ignore")

# Load the dataset
data = pd.read_excel("class123_dataset.xlsx")

# Define feature groups (as provided)
feature_groups = {
    'Genotype': [
        'rs11225395', 'rs1144393', 'rs650108', 'rs591058', 'rs2252070', 'rs4986938', 'rs1800012', 'rs4789932', 'rs9340799', 'rs970547', 
        'rs1800795', 'rs13946', 'rs12722', 'class1_SNP_risk_score', 'rs7528684', 'rs4919510', 'rs1937810', 'rs6481512', 'rs1249269', 
        'rs12574452', 'rs12429486', 'rs4454832', 'rs2761884', 'rs62051384', 'rs4362400', 'rs2586488', 'rs2277698', 'rs1045485', 
        'rs143383', 'rs17576', 'rs2305948', 'rs1011814', 'rs11154027', 'rs2234693', 'rs1643821', 'rs2010963', 'rs10263021', 'rs149047058', 
        'rs420257', 'rs42517', 'rs42522', 'rs42531', 'rs413826', 'rs2104772', 'rs1330363', 'class12_SNP_risk_score', 'rs3753841', 
        'rs57104447', 'rs1887632', 'rs4654760', 'rs1137101', 'rs2306033', 'rs2277268', 'rs4988321', 'rs11232681', 'rs1718119', 'rs3751143', 
        'rs1544410', 'rs2228570', 'rs4328262', 'rs1021188', 'rs74544784', 'rs78391032', 'rs77569527', 'rs117544024', 'rs912336', 
        'rs3218791', 'rs911263', 'rs2525504', 'rs17756404', 'rs4903399', 'rs10132091', 'rs17583842', 'rs1676303', 'rs11629171', 
        'rs2281518', 'rs2285053', 'rs71404070', 'rs710079', 'rs2858056', 'rs820218', 'rs3018362', 'rs1800470', 'rs1800469', 'rs25487', 
        'rs25489', 'rs2289360', 'rs183364169', 'rs11177', 'rs6617', 'rs3219008', 'rs13107325', 'rs60713544', 'rs145648292', 'rs4244032', 
        'rs12656106', 'rs3045', 'rs187483', 'rs4701616', 'rs144414988', 'rs1800629', 'rs10484958', 'rs4730153', 'rs1800797', 'rs1554606', 
        'rs2237352', 'rs4725069', 'rs12154667', 'rs1548456', 'rs3216902', 'rs35360670', 'rs13317', 'rs1800972', 'rs7035322', 'rs7021589', 
        'rs72758637', 'rs10759753', 'rs3789870', 'rs1138545', 'rs3196378', 'rs1134170', 'rs10992075', 'rs1590', 'rs144371252', 
        'rs761804508', 'class123_SNP_risk_score', 'sex'
    ],
    'History': [
        'Age', 'lower_limb_days_total', 'average_run_hours', 'average_interval_training_frequency', 'EDEQ_total', 'tracking_period_injury',
        'past_stress_injury', 'LEAF-Q', 'Athlete_Score', 'average_run_frequency', 'past_month_injury'
    ],
    'Phenotype': [
        'hip_abduction_peak_torque', 'total_ad_ab_ratio', 'knee_extension_peak_torque', 'knee_flexion_peak_torque', 'navicular_drop', 
        'navicular_drop_asymmetry', 'Q_angle', 'Q_angle_asymmetry', 'VALR_12', 'Impact_peak_12', 'Duty_factor_12', 'BMI', 'BMD_spine',
        'hip_abduction_peak_torque_asymmetry', 'hip_adduction_peak_torque', 'hip_adduction_peak_torque_asymmetry', 
        'knee_extension_peak_torque_asymmetry', 'knee_flexion_peak_torque_asymmetry', 'total_fl_ex_ratio', 'leg_lean_mass', 
        'hip_abduction_peak_angle', 'hip_abduction_peak_angle_asymmetry', 'hip_adduction_peak_angle', 'hip_adduction_peak_angle_asymmetry', 
        'ad_ab_ratio_asymmetry', 'knee_extension_peak_angle', 'knee_extension_peak_angle_asymmetry', 'knee_flexion_peak_angle', 
        'knee_flexion_peak_angle_asymmetry', 'fl_ex_ratio_asymmetry', 'VILR_10', 'VALR_10', 'VILR_asymmetry_10', 'VALR_asymmetry_10', 
        'Impact_peak_10', 'Impact_peak_asymmetry_10', 'Flight_time_10', 'Contact_time_10', 'Duty_factor_10', 'Step_frequency_10', 
        'Cadence_asymmetry_10', 'Duty_factor_asymmetry_10', 'VILR_12', 'VILR_asymmetry_12', 'VALR_asymmetry_12', 
        'Impact_peak_asymmetry_12', 'Flight_time_12', 'Contact_time_12', 'Step_frequency_12', 'Cadence_asymmetry_12', 
        'Duty_factor_asymmetry_12', 'Alt_strike', 'height', 'Mass', 'thigh_lean_mass', 'thigh_ffmi', 'lower_leg_lean_mass', 
        'lower_leg_ffmi', 'leg_ffmi', 'total_lean_mass', 'total_ffmi', 'calf_size', 'BMD_hip', 'BMD_body',
    ],
    'Behaviour': [
        'fat_intake_avg', 'past_month_distance', 'past_month_ratio', 'SC_past_season', 'non_running_past_season', 'fat_intake_BW', 
        'fat_percentage_avg', 'average_energy_availability', 'protein_intake_BW', 'omega3_intake_BW', 'vitaminD_intake_BW', 
        'vitaminC_intake_BW', 'vitaminE_intake_BW', 'calcium_intake_BW', 'copper_intake_BW', 'iron_intake_BW', 'glycine_intake_BW', 
        'arginine_intake_BW', 'past_month_min', 'past_week_ratio', 'past_month_volume_low', 'past_week_ratio_low', 'past_month_ratio_low', 
        'past_month_volume_moderate', 'past_week_ratio_moderate', 'past_month_ratio_moderate', 'past_month_volume_high', 
        'past_week_ratio_high', 'past_month_ratio_high', 'past_month_volume_very_high', 'past_week_ratio_very_high', 
        'past_month_ratio_very_high', 'past_month_calculated_volume', 'past_week_ratio_calculated_volume', 
        'past_month_ratio_calculated_volume', 'resistance_training_past_month', 'resistance_training_past_season', 
        'bodyweight_exercises_past_month', 'bodyweight_exercises_past_season', 'core_stability_past_month', 'core_stability_past_season', 
        'balance_training_past_month', 'balance_training_past_season', 'plyometrics_past_month', 'plyometrics_past_season', 
        'drills_past_month', 'drills_past_season', 'circuit_training_past_month', 'circuit_training_past_season', 'barefoot_past_month', 
        'barefoot_past_season', 'stretching_past_month', 'stretching_past_season', 'SC_past_month', 'non_running_past_month'
    ]
}

# Define predictors and outcome
X = data.drop(columns=['RRI'])  # Predictors
y = data['RRI']  # Outcome

# Ensure that the feature groups exist in the dataset
for group in feature_groups:
    feature_groups[group] = [feature for feature in feature_groups[group] if feature in X.columns]

num_features = len(X)
feature_to_idx = {feature: idx for idx, feature in enumerate(X)}

# Initialize adjacency matrix with zeros
adjacency = np.zeros((num_features, num_features), dtype=np.float32)

# Define groups
genotype_features = feature_groups['Genotype']
history_features = feature_groups['History']
phenotype_features = feature_groups['Phenotype']
behaviour_features = feature_groups['Behaviour']

# Get indices for each group
genotype_indices = [feature_to_idx[feat] for feat in genotype_features]
history_indices = [feature_to_idx[feat] for feat in history_features]
phenotype_indices = [feature_to_idx[feat] for feat in phenotype_features]
behaviour_indices = [feature_to_idx[feat] for feat in behaviour_features]

# Genotype nodes: connect to every node except themselves
for i in genotype_indices:
    for j in range(num_features):
        if j != i:
            adjacency[i, j] = 1.0

# History nodes: connect to every node except genotype nodes and themselves
for i in history_indices:
    for j in range(num_features):
        if j not in genotype_indices and j != i:
            adjacency[i, j] = 1.0

# Phenotype nodes: connect to every node except genotype, history nodes, and themselves
for i in phenotype_indices:
    for j in range(num_features):
        if j not in genotype_indices and j not in history_indices and j != i:
            adjacency[i, j] = 1.0

# Behaviour nodes: connect to all other behaviour nodes except themselves
for i in behaviour_indices:
    for j in behaviour_indices:
        if j != i:
            adjacency[i, j] = 1.0

# Convert adjacency to tensor
adjacency_mask = torch.tensor(adjacency, dtype=torch.float32)

class CustomDataset(Dataset):
    def __init__(self, X, y):
        if isinstance(X, pd.DataFrame):
            self.X = X.values.astype(np.float32)
        elif isinstance(X, np.ndarray):
            self.X = X.astype(np.float32)
        else:
            raise TypeError("X should be a pandas DataFrame or a NumPy array.")
        self.y = y.astype(np.float32)
    
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

class CustomNetwork(nn.Module):
    def __init__(self, num_features, adjacency_mask):
        super(CustomNetwork, self).__init__()
        self.num_features = num_features

        # Register the fixed adjacency mask as a buffer (non-trainable)
        self.register_buffer('mask', adjacency_mask.float())  # Shape: (num_features, num_features)

        # Initialize connection weights (W_ij: from node j to node i)
        self.W = nn.Parameter(torch.randn(num_features, num_features) * 0.01)

        # Initialize bias for each node
        self.bias = nn.Parameter(torch.zeros(num_features))

        # Initialize output weights (from each node to the final output)
        self.output_weights = nn.Parameter(torch.randn(num_features) * 0.01)

        # Add Batch Normalization
        self.batch_norm = nn.BatchNorm1d(num_features)

    def forward(self, x, threshold=None):
        """
        x: input tensor of shape (batch_size, num_features)
        threshold: if provided, apply binary thresholding to gating
        """
        # Use the fixed mask directly
        learnable_mask = self.mask

        # Apply the learnable mask to connection weights
        W_masked = self.W * learnable_mask  # Shape: (num_features, num_features)

        # Compute incoming messages: (batch_size, num_features) @ (num_features, num_features) = (batch_size, num_features)
        incoming = torch.matmul(x, W_masked) 

        # Element-wise multiplication with own feature value
        node_input = incoming * x  # Shape: (batch_size, num_features)

        node_input = self.batch_norm(node_input)

        # Add bias
        node_input += self.bias  # Broadcasting over batch

        # Apply Leaky ReLU activation
        node_output = F.leaky_relu(node_input)  # Shape: (batch_size, num_features)

        # Aggregate node outputs to final output
        output = torch.matmul(node_output, self.output_weights)  # Shape: (batch_size,)

        return output  # Raw scores (logits)

# Remove the import for ReliefF as it's no longer needed
# from skrebate import ReliefF

from sklearn.linear_model import LogisticRegression

def train_evaluate_fold(fold, train_index, val_index, X, y, selected_features, adjacency, feature_to_idx, 
                       n_epochs, lr, weight_decay, batch_size, threshold):
    """
    Function to train and evaluate the model on a single fold.
    This function is intended to be run in parallel.
    """
    # Split data
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]

    # Encode labels for binary classification
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y_train_enc = le.fit_transform(y_train)
    y_val_enc = le.transform(y_val)
    y_train_final = y_train_enc
    y_val_final = y_val_enc

    # Create datasets
    train_dataset = CustomDataset(X_train[selected_features], y_train_final)
    val_dataset = CustomDataset(X_val[selected_features], y_val_final)

    # Create dataloaders with drop_last=True for training and drop_last=False for validation
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

    # Map selected_features to their indices
    selected_feature_indices = [feature_to_idx[feat] for feat in selected_features]

    # Select the corresponding adjacency submatrix using integer indices
    selected_adjacency = adjacency[np.ix_(selected_feature_indices, selected_feature_indices)]
    selected_adjacency_mask = torch.tensor(selected_adjacency, dtype=torch.float32)

    device = torch.device('cpu')

    # Initialize the model with the number of selected features and the selected adjacency mask
    model = CustomNetwork(num_features=len(selected_features), 
                          adjacency_mask=selected_adjacency_mask).to(device)

    # Define loss and optimizer
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    # Training Loop
    for epoch in range(1, n_epochs + 1):
        model.train()
        epoch_loss = 0.0

        for batch_X, batch_y in train_loader:
            batch_X = batch_X.to(device).float()  # Ensure float type
            batch_y = batch_y.to(device).float()  # BCEWithLogitsLoss expects float targets

            optimizer.zero_grad()
            outputs = model(batch_X)  # Forward pass
            loss = criterion(outputs, batch_y)

            # Total loss
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item() * batch_X.size(0)

        epoch_loss /= len(train_loader.dataset)

    # Validation
    model.eval()
    all_outputs = []
    all_labels = []
    all_preds = []  # Initialize a list to accumulate predictions

    with torch.no_grad():
        for batch_X, batch_y in val_loader:
            batch_X = batch_X.to(device).float()

            outputs = model(batch_X)  # Forward pass
            probs = torch.sigmoid(outputs).cpu().numpy()
            preds = (probs >= threshold).astype(int).flatten()

            all_outputs.extend(probs)
            all_labels.extend(batch_y.numpy())
            all_preds.extend(preds)  # Accumulate predictions

    # Compute metrics
    roc_auc = roc_auc_score(all_labels, all_outputs)
    f1 = f1_score(all_labels, all_preds, average='binary')
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='binary')

    return {
        'roc_auc': roc_auc,
        'f1': f1,
        'accuracy': accuracy,
        'precision': precision
    }

def group_feature_ranking_logistic_lasso(X, y, feature_groups, C=25):
    """
    Perform group-wise feature ranking using Logistic Lasso (Logistic Regression with L1 penalty).
    Returns a dictionary with group names as keys and DataFrames with feature and score sorted descendingly.
    """
    from sklearn.preprocessing import StandardScaler
    from sklearn.preprocessing import LabelEncoder
    
    group_rankings = {}
    
    # Encode labels if they are not binary
    if y.nunique() > 2:
        raise ValueError("Logistic Lasso is only applicable for binary classification.")
    
    y_encoded = y.copy()
    if y.dtype != int and y.dtype != float:
        le = LabelEncoder()
        y_encoded = le.fit_transform(y)
    
    for group, features in feature_groups.items():
        # Ensure features are in X
        valid_features = [feat for feat in features if feat in X.columns]
        if not valid_features:
            continue
        X_group = X[valid_features].values
        
        # Initialize Logistic Regression with L1 penalty
        clf = LogisticRegression(penalty='l1', C=C, solver='liblinear', max_iter=1000)
        
        # Fit the model
        clf.fit(X_group, y_encoded)
        
        # Get absolute coefficients as feature scores
        feature_scores = np.abs(clf.coef_[0])
        
        # Create a DataFrame for feature scores
        group_score_df = pd.DataFrame({
            'feature': valid_features,
            'score': feature_scores
        }).sort_values(by='score', ascending=False)
        
        group_rankings[group] = group_score_df
    
    return group_rankings

def objective(trial, X, y, feature_groups, feature_to_idx, group_feature_rankings, adjacency, threshold=0.5):
    # ====================
    # Hyperparameters to Tune
    # ====================

    # 1. Number of Epochs
    n_epochs = trial.suggest_int('n_epochs', 500, 3000)

    # 2. Learning Rate
    lr = trial.suggest_loguniform('lr', 1e-6, 1e-2)

    # 3. Weight Decay
    weight_decay = trial.suggest_loguniform('weight_decay', 1e-8, 1e-3)

    # 4. Batch Size
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128, 256, 512])

    # 5. Number of Features per Group
    n_genotype = trial.suggest_int('n_genotype', 1, len(feature_groups['Genotype']))
    n_history = trial.suggest_int('n_history', 1, len(feature_groups['History']))
    n_phenotype = trial.suggest_int('n_phenotype', 1, len(feature_groups['Phenotype']))
    n_behaviour = trial.suggest_int('n_behaviour', 1, len(feature_groups['Behaviour']))

    # ====================
    # Feature Selection Using Group-wise Logistic Lasso Rankings
    # ====================

    # Initialize selected features list
    selected_features = []
    
    # For each group, select the top N features based on group-specific Logistic Lasso scores
    for group, n_select in zip(['Genotype', 'History', 'Phenotype', 'Behaviour'],
                               [n_genotype, n_history, n_phenotype, n_behaviour]):
        if group not in group_feature_rankings:
            continue  # Skip if the group has no features
        group_feature_scores = group_feature_rankings[group]
        # Select top N features
        top_features = group_feature_scores.head(n_select)['feature'].tolist()
        selected_features.extend(top_features)
    
    # Ensure that selected_features are unique
    selected_features = list(dict.fromkeys(selected_features))

    # ====================
    # Data Preparation
    # ====================

    X_selected = X[selected_features].copy()
    y_selected = y.copy()

    # Initialize Stratified K-Fold
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

    # Get all fold indices
    fold_indices = list(skf.split(X_selected, y_selected))

    # ====================
    # Parallel Training and Evaluation
    # ====================

    # Define a wrapper for joblib's Parallel
    results = Parallel(n_jobs=10)(
        delayed(train_evaluate_fold)(
            fold=fold,
            train_index=train_idx,
            val_index=val_idx,
            X=X_selected,
            y=y_selected,
            selected_features=selected_features,
            adjacency=adjacency,  # Pass the numpy adjacency matrix
            feature_to_idx=feature_to_idx,  # Pass the feature_to_idx mapping
            n_epochs=n_epochs,
            lr=lr,
            weight_decay=weight_decay,
            batch_size=batch_size,
            threshold=threshold
        )
        for fold, (train_idx, val_idx) in enumerate(fold_indices)
    )

    # ====================
    # Collect Metrics
    # ====================

    aucs = []
    f1s = []
    accuracies = []
    precisions = []

    for res in results:
        aucs.append(res['roc_auc'])
        f1s.append(res['f1'])
        accuracies.append(res['accuracy'])
        precisions.append(res['precision'])

    # ====================
    # Final Metrics Calculation
    # ====================

    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_f1 = np.mean(f1s)
    std_f1 = np.std(f1s)
    mean_accuracy = np.mean(accuracies)
    std_accuracy = np.std(accuracies)
    mean_precision = np.mean(precisions)
    std_precision = np.std(precisions)

    # ====================
    # Objective Metric
    # ====================

    # Since it's binary classification, we aim to maximize the mean AUC
    trial.set_user_attr("mean_auc", mean_auc)
    trial.set_user_attr("std_auc", std_auc)
    trial.set_user_attr("mean_f1", mean_f1)
    trial.set_user_attr("std_f1", std_f1)
    trial.set_user_attr("mean_accuracy", mean_accuracy)
    trial.set_user_attr("std_accuracy", std_accuracy)
    trial.set_user_attr("mean_precision", mean_precision)
    trial.set_user_attr("std_precision", std_precision)
    trial.set_user_attr("selected_features", selected_features)

    return mean_auc

def run_hyperparameter_tuning(X, y, feature_groups, feature_to_idx, adjacency, threshold=0.5):
    # Generate the group-wise feature ranking before the study starts using Logistic Lasso
    group_feature_rankings = group_feature_ranking_logistic_lasso(X, y, feature_groups, C=25)

    def objective_wrapper(trial):
        return objective(trial, X, y, feature_groups, feature_to_idx, group_feature_rankings, adjacency, threshold)

    study = optuna.create_study(
        direction='maximize',
        study_name='CustomNetwork_Hyperparameter_Tuning',
        sampler=optuna.samplers.TPESampler(seed=42)
    )

    # Integrate a progress bar for the Optuna study
    with tqdm(total=500, desc="Optuna Trials") as pbar:
        def callback(study, trial):
            pbar.update(1)

        # Set n_jobs=1 to ensure serial execution of hyperparameter trials
        study.optimize(objective_wrapper, n_trials=500, timeout=None, callbacks=[callback], n_jobs=1)

    print("Number of finished trials: ", len(study.trials))
    print("Best trial:")
    trial = study.best_trial

    print("  Value (Mean AUC): ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

    # Extract additional metrics from the best trial
    best_trial_metrics = trial.user_attrs
    mean_auc = best_trial_metrics.get("mean_auc", None)
    std_auc = best_trial_metrics.get("std_auc", None)
    mean_f1 = best_trial_metrics.get("mean_f1", None)
    std_f1 = best_trial_metrics.get("std_f1", None)
    mean_accuracy = best_trial_metrics.get("mean_accuracy", None)
    std_accuracy = best_trial_metrics.get("std_accuracy", None)
    mean_precision = best_trial_metrics.get("mean_precision", None)
    std_precision = best_trial_metrics.get("std_precision", None)
    selected_features = best_trial_metrics.get("selected_features", None)

    print(f"\nBest Trial Metrics:")
    print(f"Selected Features: {selected_features}")
    print(f"Average AUC: {mean_auc:.4f} ± {std_auc:.4f}")
    print(f"Average F1 Score: {mean_f1:.4f} ± {std_f1:.4f}")
    print(f"Average Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}")
    print(f"Average Precision: {mean_precision:.4f} ± {std_precision:.4f}")

    return study

if __name__ == "__main__":
    # Run hyperparameter tuning
    study = run_hyperparameter_tuning(X, y, feature_groups, feature_to_idx, adjacency)
# Out:
# [I 2024-12-17 00:09:18,140] A new study created in memory with name: CustomNetwork_Hyperparameter_Tuning
# Optuna Trials:   0%|          | 0/500 [00:00<?, ?it/s][I 2024-12-17 00:11:23,855] Trial 0 finished with value: 0.658478657891724 and parameters: {'n_epochs': 1436, 'lr': 0.006351221010640704, 'weight_decay': 4.570563099801451e-05, 'batch_size': 512, 'n_genotype': 77, 'n_history': 8, 'n_phenotype': 2, 'n_behaviour': 54}. Best is trial 0 with value: 0.658478657891724.
# Optuna Trials:   0%|          | 1/500 [02:05<17:25:24, 125.70s/it][I 2024-12-17 00:17:52,981] Trial 1 finished with value: 0.7197574836094938 and parameters: {'n_epochs': 2581, 'lr': 7.068974950624607e-06, 'weight_decay': 8.111941985431907e-08, 'batch_size': 128, 'n_genotype': 78, 'n_history': 2, 'n_phenotype': 19, 'n_behaviour': 21}. Best is trial 1 with value: 0.7197574836094938.
# Optuna Trials:   0%|          | 2/500 [08:34<38:49:27, 280.66s/it][I 2024-12-17 00:20:58,223] Trial 2 finished with value: 0.661952956466518 and parameters: {'n_epochs': 1640, 'lr': 0.0013826232179369874, 'weight_decay': 9.9625132220551e-08, 'batch_size': 256, 'n_genotype': 9, 'n_history': 11, 'n_phenotype': 62, 'n_behaviour': 45}. Best is trial 1 with value: 0.7197574836094938.
# Optuna Trials:   1%|          | 3/500 [11:40<32:43:52, 237.09s/it][I 2024-12-17 00:22:36,301] Trial 3 finished with value: 0.6881871954937935 and parameters: {'n_epochs': 1261, 'lr': 2.4586032763280077e-06, 'weight_decay': 2.6373339933815247e-05, 'batch_size': 512, 'n_genotype': 33, 'n_history': 8, 'n_phenotype': 20, 'n_behaviour': 29}. Best is trial 1 with value: 0.7197574836094938.
# Optuna Trials:   1%|          | 4/500 [13:18<25:06:15, 182.21s/it][I 2024-12-17 00:30:26,204] Trial 4 finished with value: 0.692451952927243 and parameters: {'n_epochs': 1867, 'lr': 5.4880470007660465e-06, 'weight_decay': 0.00070456836384545, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 3, 'n_behaviour': 18}. Best is trial 1 with value: 0.7197574836094938.
# Optuna Trials:   1%|          | 5/500 [21:08<39:19:06, 285.95s/it][I 2024-12-17 00:32:54,737] Trial 5 finished with value: 0.7278356890952332 and parameters: {'n_epochs': 1472, 'lr': 1.2172958098369984e-05, 'weight_decay': 0.00013921548533046482, 'batch_size': 512, 'n_genotype': 10, 'n_history': 11, 'n_phenotype': 50, 'n_behaviour': 11}. Best is trial 5 with value: 0.7278356890952332.
# Optuna Trials:   1%|          | 6/500 [23:36<32:49:39, 239.23s/it][I 2024-12-17 00:35:54,330] Trial 6 finished with value: 0.7115891964577552 and parameters: {'n_epochs': 513, 'lr': 0.0018274508859816032, 'weight_decay': 3.422052903270691e-05, 'batch_size': 64, 'n_genotype': 110, 'n_history': 7, 'n_phenotype': 22, 'n_behaviour': 4}. Best is trial 5 with value: 0.7278356890952332.
# Optuna Trials:   1%|▏         | 7/500 [26:36<30:05:28, 219.73s/it][I 2024-12-17 00:44:03,326] Trial 7 finished with value: 0.6984089346261984 and parameters: {'n_epochs': 1277, 'lr': 1.99863407785289e-05, 'weight_decay': 4.446628955475447e-05, 'batch_size': 64, 'n_genotype': 97, 'n_history': 7, 'n_phenotype': 50, 'n_behaviour': 28}. Best is trial 5 with value: 0.7278356890952332.
# Optuna Trials:   2%|▏         | 8/500 [34:45<41:44:43, 305.45s/it][I 2024-12-17 00:51:36,657] Trial 8 finished with value: 0.6725748216868636 and parameters: {'n_epochs': 1807, 'lr': 5.1305517605898387e-05, 'weight_decay': 1.3399717231179682e-08, 'batch_size': 128, 'n_genotype': 116, 'n_history': 3, 'n_phenotype': 27, 'n_behaviour': 42}. Best is trial 5 with value: 0.7278356890952332.
# Optuna Trials:   2%|▏         | 9/500 [42:18<47:57:56, 351.68s/it][I 2024-12-17 00:58:33,932] Trial 9 finished with value: 0.7345133851329244 and parameters: {'n_epochs': 1072, 'lr': 2.031980983842497e-06, 'weight_decay': 2.810329644763601e-07, 'batch_size': 64, 'n_genotype': 103, 'n_history': 3, 'n_phenotype': 58, 'n_behaviour': 30}. Best is trial 9 with value: 0.7345133851329244.
# Optuna Trials:   2%|▏         | 10/500 [49:15<50:37:26, 371.93s/it][I 2024-12-17 01:03:57,765] Trial 10 finished with value: 0.7259333006077273 and parameters: {'n_epochs': 565, 'lr': 1.0567900894501666e-06, 'weight_decay': 1.412166785354856e-06, 'batch_size': 32, 'n_genotype': 51, 'n_history': 5, 'n_phenotype': 42, 'n_behaviour': 36}. Best is trial 9 with value: 0.7345133851329244.
# Optuna Trials:   2%|▏         | 11/500 [54:39<48:31:16, 357.21s/it][I 2024-12-17 01:05:52,239] Trial 11 finished with value: 0.7144849573860432 and parameters: {'n_epochs': 946, 'lr': 0.0001610128003061733, 'weight_decay': 1.5307411270667852e-06, 'batch_size': 512, 'n_genotype': 51, 'n_history': 11, 'n_phenotype': 64, 'n_behaviour': 5}. Best is trial 9 with value: 0.7345133851329244.
# Optuna Trials:   2%|▏         | 12/500 [56:34<38:24:43, 283.37s/it][I 2024-12-17 01:28:01,842] Trial 12 finished with value: 0.7043038738649836 and parameters: {'n_epochs': 2225, 'lr': 2.097566760983977e-05, 'weight_decay': 0.00035896504727266873, 'batch_size': 32, 'n_genotype': 90, 'n_history': 1, 'n_phenotype': 50, 'n_behaviour': 16}. Best is trial 9 with value: 0.7345133851329244.
# Optuna Trials:   3%|▎         | 13/500 [1:18:43<81:12:30, 600.31s/it][I 2024-12-17 01:30:19,569] Trial 13 finished with value: 0.6951853350556565 and parameters: {'n_epochs': 783, 'lr': 0.0001856531255195951, 'weight_decay': 3.911083974855452e-07, 'batch_size': 256, 'n_genotype': 125, 'n_history': 5, 'n_phenotype': 52, 'n_behaviour': 10}. Best is trial 9 with value: 0.7345133851329244.
# Optuna Trials:   3%|▎         | 14/500 [1:21:01<62:10:45, 460.59s/it][I 2024-12-17 01:36:16,659] Trial 14 finished with value: 0.7250342741261396 and parameters: {'n_epochs': 1061, 'lr': 1.6201218707376455e-06, 'weight_decay': 7.2046708343444e-06, 'batch_size': 64, 'n_genotype': 36, 'n_history': 10, 'n_phenotype': 38, 'n_behaviour': 27}. Best is trial 9 with value: 0.7345133851329244.
# Optuna Trials:   3%|▎         | 15/500 [1:26:58<57:50:54, 429.39s/it][I 2024-12-17 01:40:31,270] Trial 15 finished with value: 0.7319992820724809 and parameters: {'n_epochs': 2078, 'lr': 1.0174540238072545e-05, 'weight_decay': 0.00018379860145758132, 'batch_size': 512, 'n_genotype': 63, 'n_history': 5, 'n_phenotype': 56, 'n_behaviour': 10}. Best is trial 9 with value: 0.7345133851329244.
# Optuna Trials:   3%|▎         | 16/500 [1:31:13<50:39:22, 376.78s/it][I 2024-12-17 01:47:09,136] Trial 16 finished with value: 0.7364998951131929 and parameters: {'n_epochs': 2844, 'lr': 3.854257358917615e-06, 'weight_decay': 5.755156565849602e-06, 'batch_size': 512, 'n_genotype': 78, 'n_history': 4, 'n_phenotype': 57, 'n_behaviour': 36}. Best is trial 16 with value: 0.7364998951131929.
# Optuna Trials:   3%|▎         | 17/500 [1:37:50<51:24:07, 383.12s/it][I 2024-12-17 02:05:20,295] Trial 17 finished with value: 0.6658003096491936 and parameters: {'n_epochs': 2962, 'lr': 5.519180548370286e-05, 'weight_decay': 5.257876035878743e-06, 'batch_size': 64, 'n_genotype': 101, 'n_history': 3, 'n_phenotype': 41, 'n_behaviour': 37}. Best is trial 16 with value: 0.7364998951131929.
# Optuna Trials:   4%|▎         | 18/500 [1:56:02<79:46:53, 595.88s/it][I 2024-12-17 02:16:03,552] Trial 18 finished with value: 0.7227403223686812 and parameters: {'n_epochs': 2573, 'lr': 3.815383411244106e-06, 'weight_decay': 3.524723079252153e-07, 'batch_size': 128, 'n_genotype': 82, 'n_history': 4, 'n_phenotype': 59, 'n_behaviour': 51}. Best is trial 16 with value: 0.7364998951131929.
# Optuna Trials:   4%|▍         | 19/500 [2:06:45<81:31:02, 610.11s/it][I 2024-12-17 02:46:32,080] Trial 19 finished with value: 0.6851664516743486 and parameters: {'n_epochs': 2996, 'lr': 0.00046899671234917423, 'weight_decay': 3.9130602954111617e-07, 'batch_size': 32, 'n_genotype': 105, 'n_history': 1, 'n_phenotype': 35, 'n_behaviour': 34}. Best is trial 16 with value: 0.7364998951131929.
# Optuna Trials:   4%|▍         | 20/500 [2:37:13<130:07:24, 975.93s/it][I 2024-12-17 02:54:50,545] Trial 20 finished with value: 0.7345231059129481 and parameters: {'n_epochs': 2514, 'lr': 1.03763916031285e-06, 'weight_decay': 1.1515414867394104e-08, 'batch_size': 256, 'n_genotype': 126, 'n_history': 4, 'n_phenotype': 46, 'n_behaviour': 45}. Best is trial 16 with value: 0.7364998951131929.
# Optuna Trials:   4%|▍         | 21/500 [2:45:32<110:46:59, 832.61s/it][I 2024-12-17 03:03:51,847] Trial 21 finished with value: 0.7342825264445996 and parameters: {'n_epochs': 2692, 'lr': 1.207148855103205e-06, 'weight_decay': 1.2801439955260601e-08, 'batch_size': 256, 'n_genotype': 127, 'n_history': 4, 'n_phenotype': 45, 'n_behaviour': 46}. Best is trial 16 with value: 0.7364998951131929.
# Optuna Trials:   4%|▍         | 22/500 [2:54:33<98:56:37, 745.18s/it] [I 2024-12-17 03:11:24,493] Trial 22 finished with value: 0.7356129646572199 and parameters: {'n_epochs': 2336, 'lr': 3.0905092323358705e-06, 'weight_decay': 4.9659203206371415e-08, 'batch_size': 256, 'n_genotype': 114, 'n_history': 4, 'n_phenotype': 56, 'n_behaviour': 39}. Best is trial 16 with value: 0.7364998951131929.
# Optuna Trials:   5%|▍         | 23/500 [3:02:06<87:06:18, 657.40s/it][I 2024-12-17 03:18:47,852] Trial 23 finished with value: 0.7356675766250015 and parameters: {'n_epochs': 2339, 'lr': 3.663026723408546e-06, 'weight_decay': 3.375632855633949e-08, 'batch_size': 256, 'n_genotype': 119, 'n_history': 6, 'n_phenotype': 46, 'n_behaviour': 41}. Best is trial 16 with value: 0.7364998951131929.
# Optuna Trials:   5%|▍         | 24/500 [3:09:29<78:25:50, 593.17s/it][I 2024-12-17 03:26:15,763] Trial 24 finished with value: 0.7344396147982823 and parameters: {'n_epochs': 2268, 'lr': 3.705074622547148e-06, 'weight_decay': 3.900775416018804e-08, 'batch_size': 256, 'n_genotype': 115, 'n_history': 6, 'n_phenotype': 56, 'n_behaviour': 40}. Best is trial 16 with value: 0.7364998951131929.
# Optuna Trials:   5%|▌         | 25/500 [3:16:57<72:30:54, 549.59s/it][I 2024-12-17 03:34:00,508] Trial 25 finished with value: 0.6974748810226923 and parameters: {'n_epochs': 2776, 'lr': 2.6860231093377636e-05, 'weight_decay': 1.2172808745006135e-06, 'batch_size': 256, 'n_genotype': 90, 'n_history': 6, 'n_phenotype': 30, 'n_behaviour': 50}. Best is trial 16 with value: 0.7364998951131929.
# Optuna Trials:   5%|▌         | 26/500 [3:24:42<69:00:39, 524.13s/it][I 2024-12-17 03:40:51,851] Trial 26 finished with value: 0.7379483719225685 and parameters: {'n_epochs': 2386, 'lr': 3.832698399220228e-06, 'weight_decay': 5.737613577545757e-08, 'batch_size': 256, 'n_genotype': 69, 'n_history': 7, 'n_phenotype': 53, 'n_behaviour': 40}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   5%|▌         | 27/500 [3:31:33<64:25:09, 490.29s/it][I 2024-12-17 03:46:18,215] Trial 27 finished with value: 0.7272112155265257 and parameters: {'n_epochs': 2016, 'lr': 9.297063635841899e-06, 'weight_decay': 1.055944702304374e-05, 'batch_size': 256, 'n_genotype': 65, 'n_history': 9, 'n_phenotype': 44, 'n_behaviour': 33}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   6%|▌         | 28/500 [3:37:00<57:50:05, 441.11s/it][I 2024-12-17 03:51:21,220] Trial 28 finished with value: 0.7022554207905756 and parameters: {'n_epochs': 2411, 'lr': 4.497666750631757e-05, 'weight_decay': 1.6156371391067987e-07, 'batch_size': 512, 'n_genotype': 66, 'n_history': 7, 'n_phenotype': 52, 'n_behaviour': 24}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   6%|▌         | 29/500 [3:42:03<52:17:28, 399.68s/it][I 2024-12-17 03:57:24,979] Trial 29 finished with value: 0.6536615840663884 and parameters: {'n_epochs': 2846, 'lr': 0.007864923248113765, 'weight_decay': 3.274506509294784e-08, 'batch_size': 512, 'n_genotype': 52, 'n_history': 8, 'n_phenotype': 38, 'n_behaviour': 53}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   6%|▌         | 30/500 [3:48:06<50:46:24, 388.90s/it][I 2024-12-17 04:02:49,760] Trial 30 finished with value: 0.7321478333936604 and parameters: {'n_epochs': 2063, 'lr': 5.042114621152935e-06, 'weight_decay': 2.8165738084084047e-06, 'batch_size': 256, 'n_genotype': 73, 'n_history': 9, 'n_phenotype': 8, 'n_behaviour': 48}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   6%|▌         | 31/500 [3:53:31<48:09:33, 369.67s/it][I 2024-12-17 04:09:59,022] Trial 31 finished with value: 0.7355612078729565 and parameters: {'n_epochs': 2341, 'lr': 2.7382683167750796e-06, 'weight_decay': 3.5914435250063895e-08, 'batch_size': 256, 'n_genotype': 89, 'n_history': 6, 'n_phenotype': 61, 'n_behaviour': 40}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   6%|▋         | 32/500 [4:00:40<50:22:50, 387.54s/it][I 2024-12-17 04:18:39,180] Trial 32 finished with value: 0.7261040039955319 and parameters: {'n_epochs': 2640, 'lr': 6.081541968110053e-06, 'weight_decay': 6.755250193477644e-08, 'batch_size': 256, 'n_genotype': 117, 'n_history': 5, 'n_phenotype': 55, 'n_behaviour': 41}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   7%|▋         | 33/500 [4:09:21<55:26:02, 427.33s/it][I 2024-12-17 04:25:41,923] Trial 33 finished with value: 0.7212947722863657 and parameters: {'n_epochs': 2481, 'lr': 1.2760560582413195e-05, 'weight_decay': 1.607857911404967e-07, 'batch_size': 256, 'n_genotype': 79, 'n_history': 2, 'n_phenotype': 47, 'n_behaviour': 37}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   7%|▋         | 34/500 [4:16:23<55:08:14, 425.95s/it][I 2024-12-17 04:31:26,352] Trial 34 finished with value: 0.7324782708550737 and parameters: {'n_epochs': 2177, 'lr': 2.546531278493965e-06, 'weight_decay': 8.547170667209926e-07, 'batch_size': 256, 'n_genotype': 42, 'n_history': 7, 'n_phenotype': 64, 'n_behaviour': 32}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   7%|▋         | 35/500 [4:22:08<51:51:35, 401.50s/it][I 2024-12-17 04:37:10,297] Trial 35 finished with value: 0.7236442053650056 and parameters: {'n_epochs': 1601, 'lr': 6.575807321650849e-06, 'weight_decay': 7.197325735393911e-08, 'batch_size': 128, 'n_genotype': 22, 'n_history': 4, 'n_phenotype': 54, 'n_behaviour': 44}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   7%|▋         | 36/500 [4:27:52<49:31:22, 384.23s/it][I 2024-12-17 04:43:56,666] Trial 36 finished with value: 0.7347173818047825 and parameters: {'n_epochs': 2814, 'lr': 3.5355159201003937e-06, 'weight_decay': 1.722199556140554e-05, 'batch_size': 512, 'n_genotype': 96, 'n_history': 2, 'n_phenotype': 61, 'n_behaviour': 38}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   7%|▋         | 37/500 [4:34:38<50:16:13, 390.87s/it][I 2024-12-17 04:49:03,497] Trial 37 finished with value: 0.6633024944697239 and parameters: {'n_epochs': 1913, 'lr': 0.003869150543480355, 'weight_decay': 2.58477664288681e-08, 'batch_size': 256, 'n_genotype': 61, 'n_history': 8, 'n_phenotype': 48, 'n_behaviour': 43}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   8%|▊         | 38/500 [4:39:45<46:55:34, 365.66s/it][I 2024-12-17 04:55:09,920] Trial 38 finished with value: 0.7329394348622998 and parameters: {'n_epochs': 2337, 'lr': 1.6525342843260811e-06, 'weight_decay': 1.2772892022813545e-07, 'batch_size': 256, 'n_genotype': 72, 'n_history': 6, 'n_phenotype': 58, 'n_behaviour': 24}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   8%|▊         | 39/500 [4:45:51<46:51:14, 365.89s/it][I 2024-12-17 05:01:40,179] Trial 39 finished with value: 0.7143483651640885 and parameters: {'n_epochs': 2684, 'lr': 1.4225272697253457e-05, 'weight_decay': 9.681136496466928e-05, 'batch_size': 512, 'n_genotype': 83, 'n_history': 5, 'n_phenotype': 54, 'n_behaviour': 55}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   8%|▊         | 40/500 [4:52:22<47:41:11, 373.20s/it][I 2024-12-17 05:07:55,985] Trial 40 finished with value: 0.6924807747399276 and parameters: {'n_epochs': 1609, 'lr': 3.2582518935977835e-05, 'weight_decay': 1.994930575788006e-08, 'batch_size': 128, 'n_genotype': 111, 'n_history': 6, 'n_phenotype': 15, 'n_behaviour': 34}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   8%|▊         | 41/500 [4:58:37<47:40:57, 373.98s/it][I 2024-12-17 05:15:12,629] Trial 41 finished with value: 0.7348778002122427 and parameters: {'n_epochs': 2382, 'lr': 2.668426846875732e-06, 'weight_decay': 5.500569014882257e-08, 'batch_size': 256, 'n_genotype': 92, 'n_history': 6, 'n_phenotype': 59, 'n_behaviour': 39}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   8%|▊         | 42/500 [5:05:54<49:58:13, 392.78s/it][I 2024-12-17 05:21:48,246] Trial 42 finished with value: 0.7244268279700876 and parameters: {'n_epochs': 2161, 'lr': 7.4902063675201636e-06, 'weight_decay': 2.2039194754287517e-08, 'batch_size': 256, 'n_genotype': 87, 'n_history': 7, 'n_phenotype': 61, 'n_behaviour': 47}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   9%|▊         | 43/500 [5:12:30<49:58:09, 393.63s/it][I 2024-12-17 05:27:11,816] Trial 43 finished with value: 0.7349250779733191 and parameters: {'n_epochs': 1943, 'lr': 3.903348552604095e-06, 'weight_decay': 4.414450271588353e-08, 'batch_size': 256, 'n_genotype': 72, 'n_history': 4, 'n_phenotype': 51, 'n_behaviour': 41}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   9%|▉         | 44/500 [5:17:53<47:11:51, 372.61s/it][I 2024-12-17 05:42:38,119] Trial 44 finished with value: 0.7280271883027136 and parameters: {'n_epochs': 1713, 'lr': 2.1094602370097404e-06, 'weight_decay': 2.236772661429447e-07, 'batch_size': 32, 'n_genotype': 1, 'n_history': 8, 'n_phenotype': 61, 'n_behaviour': 30}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   9%|▉         | 45/500 [5:33:19<68:05:17, 538.72s/it][I 2024-12-17 05:50:25,155] Trial 45 finished with value: 0.7322436176761452 and parameters: {'n_epochs': 2464, 'lr': 5.035052985657722e-06, 'weight_decay': 1.0103261415372207e-07, 'batch_size': 256, 'n_genotype': 107, 'n_history': 9, 'n_phenotype': 48, 'n_behaviour': 35}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   9%|▉         | 46/500 [5:41:07<65:13:35, 517.21s/it][I 2024-12-17 05:58:16,859] Trial 46 finished with value: 0.7014150229498168 and parameters: {'n_epochs': 2346, 'lr': 1.637226823683961e-05, 'weight_decay': 6.600260630542958e-07, 'batch_size': 256, 'n_genotype': 119, 'n_history': 5, 'n_phenotype': 58, 'n_behaviour': 43}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:   9%|▉         | 47/500 [5:48:58<63:21:53, 503.56s/it][I 2024-12-17 06:04:28,312] Trial 47 finished with value: 0.7322556992936856 and parameters: {'n_epochs': 2564, 'lr': 1.673781112791022e-06, 'weight_decay': 2.720367102899062e-06, 'batch_size': 512, 'n_genotype': 94, 'n_history': 2, 'n_phenotype': 63, 'n_behaviour': 39}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:  10%|▉         | 48/500 [5:55:10<58:14:55, 463.93s/it][I 2024-12-17 06:10:28,336] Trial 48 finished with value: 0.675368488291637 and parameters: {'n_epochs': 2263, 'lr': 9.872183096566115e-05, 'weight_decay': 1.8770043196643495e-08, 'batch_size': 256, 'n_genotype': 58, 'n_history': 3, 'n_phenotype': 53, 'n_behaviour': 31}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:  10%|▉         | 49/500 [6:01:10<54:12:53, 432.76s/it][I 2024-12-17 06:27:59,480] Trial 49 finished with value: 0.6771337280577349 and parameters: {'n_epochs': 2875, 'lr': 0.00077759402250981, 'weight_decay': 2.075337179687065e-05, 'batch_size': 64, 'n_genotype': 100, 'n_history': 6, 'n_phenotype': 42, 'n_behaviour': 36}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:  10%|█         | 50/500 [6:18:41<77:17:03, 618.27s/it][I 2024-12-17 06:47:48,098] Trial 50 finished with value: 0.7006953812673793 and parameters: {'n_epochs': 1780, 'lr': 8.481767747531759e-06, 'weight_decay': 8.443371400464638e-08, 'batch_size': 32, 'n_genotype': 121, 'n_history': 7, 'n_phenotype': 50, 'n_behaviour': 49}. Best is trial 26 with value: 0.7379483719225685.
# Optuna Trials:  10%|█         | 51/500 [6:38:29<98:27:10, 789.38s/it][I 2024-12-17 06:53:14,086] Trial 51 finished with value: 0.7392800990119694 and parameters: {'n_epochs': 1935, 'lr': 2.7217959211184964e-06, 'weight_decay': 3.932962245954206e-08, 'batch_size': 256, 'n_genotype': 72, 'n_history': 4, 'n_phenotype': 50, 'n_behaviour': 40}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  10%|█         | 52/500 [6:43:55<80:56:01, 650.36s/it][I 2024-12-17 06:59:35,955] Trial 52 finished with value: 0.7370628549483782 and parameters: {'n_epochs': 2106, 'lr': 2.9317983831604295e-06, 'weight_decay': 3.8037162680263704e-08, 'batch_size': 256, 'n_genotype': 78, 'n_history': 3, 'n_phenotype': 56, 'n_behaviour': 43}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  11%|█         | 53/500 [6:50:17<70:45:06, 569.81s/it][I 2024-12-17 07:05:44,687] Trial 53 finished with value: 0.7349937907757449 and parameters: {'n_epochs': 2118, 'lr': 1.5362389317093307e-06, 'weight_decay': 1.0965635497928025e-08, 'batch_size': 256, 'n_genotype': 75, 'n_history': 3, 'n_phenotype': 56, 'n_behaviour': 45}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  11%|█         | 54/500 [6:56:26<63:07:11, 509.49s/it][I 2024-12-17 07:09:47,028] Trial 54 finished with value: 0.7370710687431845 and parameters: {'n_epochs': 1457, 'lr': 4.927029354670182e-06, 'weight_decay': 4.532609223476401e-06, 'batch_size': 256, 'n_genotype': 68, 'n_history': 4, 'n_phenotype': 40, 'n_behaviour': 43}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  11%|█         | 55/500 [7:00:28<53:04:18, 429.34s/it][I 2024-12-17 07:13:02,826] Trial 55 finished with value: 0.7329763971376604 and parameters: {'n_epochs': 1474, 'lr': 5.290565668102636e-06, 'weight_decay': 4.425570797270876e-06, 'batch_size': 512, 'n_genotype': 68, 'n_history': 4, 'n_phenotype': 39, 'n_behaviour': 52}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  11%|█         | 56/500 [7:03:44<44:18:40, 359.28s/it][I 2024-12-17 07:18:12,056] Trial 56 finished with value: 0.7160147185892809 and parameters: {'n_epochs': 1999, 'lr': 1.2315379534292715e-06, 'weight_decay': 1.065912697233209e-05, 'batch_size': 256, 'n_genotype': 45, 'n_history': 3, 'n_phenotype': 33, 'n_behaviour': 42}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  11%|█▏        | 57/500 [7:08:53<42:21:49, 344.27s/it][I 2024-12-17 07:23:21,200] Trial 57 finished with value: 0.7340465053928965 and parameters: {'n_epochs': 1336, 'lr': 2.1926182666959887e-06, 'weight_decay': 1.738334605495412e-06, 'batch_size': 128, 'n_genotype': 59, 'n_history': 3, 'n_phenotype': 44, 'n_behaviour': 47}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  12%|█▏        | 58/500 [7:14:03<40:58:28, 333.73s/it][I 2024-12-17 07:28:42,257] Trial 58 finished with value: 0.737579069226946 and parameters: {'n_epochs': 1840, 'lr': 4.152261128916698e-06, 'weight_decay': 6.057776197316757e-07, 'batch_size': 256, 'n_genotype': 80, 'n_history': 5, 'n_phenotype': 49, 'n_behaviour': 44}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  12%|█▏        | 59/500 [7:19:24<40:24:57, 329.93s/it][I 2024-12-17 07:37:26,759] Trial 59 finished with value: 0.7252104161148871 and parameters: {'n_epochs': 1473, 'lr': 4.5664609298004346e-06, 'weight_decay': 5.3240499420313554e-05, 'batch_size': 64, 'n_genotype': 81, 'n_history': 5, 'n_phenotype': 25, 'n_behaviour': 46}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  12%|█▏        | 60/500 [7:28:08<47:27:31, 388.30s/it][I 2024-12-17 07:42:52,544] Trial 60 finished with value: 0.7225668606792384 and parameters: {'n_epochs': 1862, 'lr': 9.127110897634482e-06, 'weight_decay': 6.571765240281103e-07, 'batch_size': 256, 'n_genotype': 69, 'n_history': 4, 'n_phenotype': 48, 'n_behaviour': 44}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  12%|█▏        | 61/500 [7:33:34<45:03:50, 369.55s/it][I 2024-12-17 07:47:49,717] Trial 61 finished with value: 0.7329273360544363 and parameters: {'n_epochs': 1714, 'lr': 3.171502636512052e-06, 'weight_decay': 5.142259648544545e-06, 'batch_size': 256, 'n_genotype': 78, 'n_history': 5, 'n_phenotype': 40, 'n_behaviour': 42}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  12%|█▏        | 62/500 [7:38:31<42:19:11, 347.83s/it][I 2024-12-17 07:52:56,944] Trial 62 finished with value: 0.7247817776897634 and parameters: {'n_epochs': 1815, 'lr': 7.021306024127293e-06, 'weight_decay': 9.488530786699893e-06, 'batch_size': 256, 'n_genotype': 85, 'n_history': 4, 'n_phenotype': 35, 'n_behaviour': 49}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  13%|█▎        | 63/500 [7:43:38<40:44:39, 335.65s/it][I 2024-12-17 07:56:37,090] Trial 63 finished with value: 0.7309708520044091 and parameters: {'n_epochs': 1371, 'lr': 2.135799252122757e-06, 'weight_decay': 2.233187224990294e-06, 'batch_size': 256, 'n_genotype': 57, 'n_history': 5, 'n_phenotype': 50, 'n_behaviour': 36}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  13%|█▎        | 64/500 [7:47:18<36:27:15, 301.00s/it][I 2024-12-17 08:01:00,441] Trial 64 finished with value: 0.7177540399684197 and parameters: {'n_epochs': 1561, 'lr': 1.8758299569274717e-05, 'weight_decay': 3.7498933899458926e-06, 'batch_size': 256, 'n_genotype': 75, 'n_history': 5, 'n_phenotype': 44, 'n_behaviour': 38}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  13%|█▎        | 65/500 [7:51:42<35:00:21, 289.71s/it][I 2024-12-17 08:03:56,392] Trial 65 finished with value: 0.7356592341511857 and parameters: {'n_epochs': 1079, 'lr': 4.072615788629311e-06, 'weight_decay': 2.9212270548420344e-07, 'batch_size': 256, 'n_genotype': 55, 'n_history': 4, 'n_phenotype': 42, 'n_behaviour': 41}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  13%|█▎        | 66/500 [7:54:38<30:48:41, 255.58s/it][I 2024-12-17 08:06:35,188] Trial 66 finished with value: 0.6898113839376386 and parameters: {'n_epochs': 1185, 'lr': 1.2850292285035102e-06, 'weight_decay': 1.5452551066474208e-08, 'batch_size': 512, 'n_genotype': 64, 'n_history': 2, 'n_phenotype': 53, 'n_behaviour': 44}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  13%|█▎        | 67/500 [7:57:17<27:14:53, 226.54s/it][I 2024-12-17 08:25:58,193] Trial 67 finished with value: 0.7019723062024166 and parameters: {'n_epochs': 1986, 'lr': 1.0357042935994936e-05, 'weight_decay': 0.0007867031562304094, 'batch_size': 32, 'n_genotype': 70, 'n_history': 3, 'n_phenotype': 46, 'n_behaviour': 27}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  14%|█▎        | 68/500 [8:16:40<60:53:52, 507.48s/it][I 2024-12-17 08:31:17,919] Trial 68 finished with value: 0.7381988356280605 and parameters: {'n_epochs': 2086, 'lr': 2.941591671273267e-06, 'weight_decay': 2.8493487438769127e-08, 'batch_size': 256, 'n_genotype': 77, 'n_history': 7, 'n_phenotype': 50, 'n_behaviour': 2}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  14%|█▍        | 69/500 [8:21:59<54:00:48, 451.16s/it][I 2024-12-17 08:36:49,832] Trial 69 finished with value: 0.7294534681320183 and parameters: {'n_epochs': 2093, 'lr': 1.005494551742363e-06, 'weight_decay': 2.9847070199877804e-08, 'batch_size': 256, 'n_genotype': 80, 'n_history': 7, 'n_phenotype': 57, 'n_behaviour': 16}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  14%|█▍        | 70/500 [8:27:31<49:36:54, 415.38s/it][I 2024-12-17 08:41:43,458] Trial 70 finished with value: 0.7322854975763511 and parameters: {'n_epochs': 1875, 'lr': 2.846783038196966e-06, 'weight_decay': 6.852834062291698e-06, 'batch_size': 256, 'n_genotype': 77, 'n_history': 2, 'n_phenotype': 36, 'n_behaviour': 19}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  14%|█▍        | 71/500 [8:32:25<45:08:48, 378.86s/it][I 2024-12-17 08:46:44,019] Trial 71 finished with value: 0.735637249715054 and parameters: {'n_epochs': 2043, 'lr': 5.699937092413126e-06, 'weight_decay': 6.300297645642013e-08, 'batch_size': 256, 'n_genotype': 63, 'n_history': 7, 'n_phenotype': 52, 'n_behaviour': 6}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  14%|█▍        | 72/500 [8:37:25<42:14:57, 355.37s/it][I 2024-12-17 08:52:26,130] Trial 72 finished with value: 0.734857246746315 and parameters: {'n_epochs': 2256, 'lr': 1.7643400738929222e-06, 'weight_decay': 1.1039860518181932e-07, 'batch_size': 256, 'n_genotype': 67, 'n_history': 6, 'n_phenotype': 49, 'n_behaviour': 2}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  15%|█▍        | 73/500 [8:43:07<41:40:43, 351.39s/it][I 2024-12-17 08:58:40,677] Trial 73 finished with value: 0.7368865892489229 and parameters: {'n_epochs': 2157, 'lr': 3.464805822776113e-06, 'weight_decay': 3.967411055953852e-08, 'batch_size': 256, 'n_genotype': 85, 'n_history': 3, 'n_phenotype': 46, 'n_behaviour': 40}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  15%|█▍        | 74/500 [8:49:22<42:24:11, 358.34s/it][I 2024-12-17 09:04:40,673] Trial 74 finished with value: 0.7338684774368918 and parameters: {'n_epochs': 2195, 'lr': 3.196257630137259e-06, 'weight_decay': 4.121355489084498e-08, 'batch_size': 256, 'n_genotype': 86, 'n_history': 3, 'n_phenotype': 51, 'n_behaviour': 13}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  15%|█▌        | 75/500 [8:55:22<42:21:44, 358.83s/it][I 2024-12-17 09:09:14,936] Trial 75 finished with value: 0.7350688427334473 and parameters: {'n_epochs': 1958, 'lr': 4.458464640008863e-06, 'weight_decay': 1.8202436055368746e-07, 'batch_size': 512, 'n_genotype': 84, 'n_history': 3, 'n_phenotype': 54, 'n_behaviour': 33}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  15%|█▌        | 76/500 [8:59:56<39:16:28, 333.46s/it][I 2024-12-17 09:15:45,489] Trial 76 finished with value: 0.7365261890540638 and parameters: {'n_epochs': 1688, 'lr': 2.485950992062333e-06, 'weight_decay': 1.6724598868592345e-08, 'batch_size': 128, 'n_genotype': 75, 'n_history': 4, 'n_phenotype': 46, 'n_behaviour': 37}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  15%|█▌        | 77/500 [9:06:27<41:11:39, 350.59s/it][I 2024-12-17 09:22:11,849] Trial 77 finished with value: 0.663664504990472 and parameters: {'n_epochs': 1697, 'lr': 0.00028630467498685474, 'weight_decay': 1.6341279171733323e-08, 'batch_size': 128, 'n_genotype': 76, 'n_history': 4, 'n_phenotype': 44, 'n_behaviour': 38}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  16%|█▌        | 78/500 [9:12:53<42:21:17, 361.32s/it]/home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [I 2024-12-17 09:28:26,143] Trial 78 finished with value: 0.7351360765718764 and parameters: {'n_epochs': 1551, 'lr': 2.4847442162826367e-06, 'weight_decay': 2.6301784102808062e-08, 'batch_size': 128, 'n_genotype': 71, 'n_history': 4, 'n_phenotype': 46, 'n_behaviour': 46}. Best is trial 51 with value: 0.7392800990119694.
# Optuna Trials:  16%|█▌        | 79/500 [9:19:07<42:42:34, 365.21s/it]/home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# [I 2024-12-19 04:41:46,989] Trial 489 finished with value: 0.7364624731705757 and parameters: {'n_epochs': 1780, 'lr': 2.6154202576109755e-06, 'weight_decay': 2.3974196733936754e-08, 'batch_size': 256, 'n_genotype': 67, 'n_history': 9, 'n_phenotype': 46, 'n_behaviour': 42}. Best is trial 292 with value: 0.7415440699513642.
# Optuna Trials:  98%|█████████▊| 490/500 [52:32:28<47:00, 282.04s/it][I 2024-12-19 04:45:52,650] Trial 490 finished with value: 0.7342380148350781 and parameters: {'n_epochs': 2189, 'lr': 4.4244053510038565e-06, 'weight_decay': 1.7443286674593411e-07, 'batch_size': 256, 'n_genotype': 70, 'n_history': 7, 'n_phenotype': 29, 'n_behaviour': 41}. Best is trial 292 with value: 0.7415440699513642.
# Optuna Trials:  98%|█████████▊| 491/500 [52:36:34<40:40, 271.13s/it][I 2024-12-19 04:50:17,735] Trial 491 finished with value: 0.7343845447531008 and parameters: {'n_epochs': 2277, 'lr': 3.5947734053076532e-06, 'weight_decay': 1.0201807620263095e-07, 'batch_size': 256, 'n_genotype': 83, 'n_history': 7, 'n_phenotype': 48, 'n_behaviour': 38}. Best is trial 292 with value: 0.7415440699513642.
# Optuna Trials:  98%|█████████▊| 492/500 [52:40:59<35:54, 269.31s/it][I 2024-12-19 04:54:23,912] Trial 492 finished with value: 0.7358772378561554 and parameters: {'n_epochs': 2094, 'lr': 5.163860451097438e-06, 'weight_decay': 3.2474233294236967e-08, 'batch_size': 256, 'n_genotype': 61, 'n_history': 8, 'n_phenotype': 51, 'n_behaviour': 43}. Best is trial 292 with value: 0.7415440699513642.
# Optuna Trials:  99%|█████████▊| 493/500 [52:45:05<30:36, 262.37s/it][I 2024-12-19 04:59:10,488] Trial 493 finished with value: 0.7338560265751826 and parameters: {'n_epochs': 2226, 'lr': 1.8890718043680793e-06, 'weight_decay': 1.848712773394732e-08, 'batch_size': 256, 'n_genotype': 116, 'n_history': 4, 'n_phenotype': 49, 'n_behaviour': 31}. Best is trial 292 with value: 0.7415440699513642.
# Optuna Trials:  99%|█████████▉| 494/500 [52:49:52<26:57, 269.63s/it][I 2024-12-19 05:03:15,289] Trial 494 finished with value: 0.7266964409623726 and parameters: {'n_epochs': 2157, 'lr': 1.1355861118408973e-05, 'weight_decay': 6.53417942422943e-08, 'batch_size': 256, 'n_genotype': 54, 'n_history': 7, 'n_phenotype': 54, 'n_behaviour': 39}. Best is trial 292 with value: 0.7415440699513642.
# Optuna Trials:  99%|█████████▉| 495/500 [52:53:57<21:50, 262.18s/it][I 2024-12-19 05:07:06,615] Trial 495 finished with value: 0.734364768230165 and parameters: {'n_epochs': 2050, 'lr': 2.556713094205527e-06, 'weight_decay': 4.421075558002672e-08, 'batch_size': 256, 'n_genotype': 65, 'n_history': 6, 'n_phenotype': 44, 'n_behaviour': 33}. Best is trial 292 with value: 0.7415440699513642.
# Optuna Trials:  99%|█████████▉| 496/500 [52:57:48<16:51, 252.93s/it]/home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/h_wu4/ml_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [I 2024-12-19 05:11:40,398] Trial 496 finished with value: 0.7365681867030159 and parameters: {'n_epochs': 2281, 'lr': 3.1009754731581075e-06, 'weight_decay': 1.3907425258771783e-08, 'batch_size': 256, 'n_genotype': 74, 'n_history': 9, 'n_phenotype': 42, 'n_behaviour': 40}. Best is trial 292 with value: 0.7415440699513642.
# Optuna Trials:  99%|█████████▉| 497/500 [53:02:22<12:57, 259.18s/it][I 2024-12-19 05:15:34,298] Trial 497 finished with value: 0.7367970090832794 and parameters: {'n_epochs': 1958, 'lr': 5.964837676132499e-06, 'weight_decay': 1.2361162052416386e-05, 'batch_size': 256, 'n_genotype': 77, 'n_history': 10, 'n_phenotype': 46, 'n_behaviour': 36}. Best is trial 292 with value: 0.7415440699513642.
# Optuna Trials: 100%|█████████▉| 498/500 [53:06:16<08:23, 251.60s/it][I 2024-12-19 05:19:36,863] Trial 498 finished with value: 0.736779844297087 and parameters: {'n_epochs': 2183, 'lr': 3.94609015025723e-06, 'weight_decay': 2.247944268451216e-08, 'batch_size': 256, 'n_genotype': 68, 'n_history': 7, 'n_phenotype': 40, 'n_behaviour': 37}. Best is trial 292 with value: 0.7415440699513642.
# Optuna Trials: 100%|█████████▉| 499/500 [53:10:18<04:08, 248.89s/it][I 2024-12-19 05:24:54,469] Trial 499 finished with value: 0.7254378693306174 and parameters: {'n_epochs': 2096, 'lr': 8.471726507698802e-06, 'weight_decay': 1.2280663072066772e-08, 'batch_size': 128, 'n_genotype': 47, 'n_history': 8, 'n_phenotype': 47, 'n_behaviour': 37}. Best is trial 292 with value: 0.7415440699513642.
# Optuna Trials: 100%|██████████| 500/500 [53:15:36<00:00, 383.47s/it]
# Number of finished trials:  500
# Best trial:
#   Value (Mean AUC):  0.7415440699513642
#   Params:
#     n_epochs: 2163
#     lr: 4.600641941225531e-06
#     weight_decay: 3.128639842545911e-08
#     batch_size: 256
#     n_genotype: 67
#     n_history: 4
#     n_phenotype: 47
#     n_behaviour: 37
#
# Best Trial Metrics:
# Selected Features: ['rs144414988', 'rs117544024', 'rs77569527', 'rs78391032', 'rs12722', 'rs3196378', 'rs57104447', 'rs144371252', 'class123_SNP_risk_score', 'rs11177', 'rs2277268', 'rs6617', 'rs4988321', 'rs1676303', 'rs25487', 'rs11154027', 'rs35360670', 'rs6481512', 'rs710079', 'class12_SNP_risk_score', 'rs420257', 'rs42522', 'rs71404070', 'rs1249269', 'rs591058', 'rs72758637', 'rs413826', 'rs74544784', 'rs1330363', 'rs25489', 'rs149047058', 'rs3218791', 'rs4903399', 'rs10263021', 'rs761804508', 'rs2234693', 'rs7528684', 'rs17576', 'rs12154667', 'rs2858056', 'rs17583842', 'rs1137101', 'rs2289360', 'rs2525504', 'rs4701616', 'rs1554606', 'rs1887632', 'rs820218', 'rs2252070', 'rs143383', 'rs1011814', 'rs2586488', 'rs42517', 'rs2277698', 'rs4919510', 'rs3753841', 'rs2104772', 'rs13107325', 'rs2306033', 'rs1800012', 'rs1800972', 'rs11232681', 'rs1800469', 'rs2285053', 'rs12574452', 'rs62051384', 'rs3045', 'tracking_period_injury', 'past_month_injury', 'average_run_hours', 'average_run_frequency', 'Mass', 'BMI', 'VILR_asymmetry_10', 'height', 'VALR_asymmetry_10', 'VALR_10', 'calf_size', 'VILR_10', 'ad_ab_ratio_asymmetry', 'VALR_asymmetry_12', 'Duty_factor_10', 'Impact_peak_12', 'VILR_asymmetry_12', 'Duty_factor_12', 'hip_abduction_peak_torque', 'knee_extension_peak_torque', 'lower_leg_lean_mass', 'knee_extension_peak_angle', 'hip_abduction_peak_torque_asymmetry', 'hip_adduction_peak_torque', 'Step_frequency_12', 'Step_frequency_10', 'hip_adduction_peak_angle_asymmetry', 'knee_flexion_peak_torque', 'Impact_peak_asymmetry_12', 'Impact_peak_10', 'Q_angle', 'total_lean_mass', 'Flight_time_12', 'leg_ffmi', 'total_fl_ex_ratio', 'hip_abduction_peak_angle', 'total_ffmi', 'hip_abduction_peak_angle_asymmetry', 'hip_adduction_peak_torque_asymmetry', 'Alt_strike', 'knee_flexion_peak_angle', 'Q_angle_asymmetry', 'navicular_drop', 'Cadence_asymmetry_10', 'Impact_peak_asymmetry_10', 'Contact_time_10', 'fl_ex_ratio_asymmetry', 'knee_extension_peak_torque_asymmetry', 'total_ad_ab_ratio', 'lower_leg_ffmi', 'Cadence_asymmetry_12', 'past_week_ratio_calculated_volume', 'past_week_ratio', 'arginine_intake_BW', 'glycine_intake_BW', 'stretching_past_season', 'barefoot_past_season', 'past_week_ratio_low', 'circuit_training_past_month', 'past_month_ratio', 'resistance_training_past_season', 'stretching_past_month', 'past_month_distance', 'drills_past_season', 'past_month_ratio_calculated_volume', 'vitaminE_intake_BW', 'past_month_volume_very_high', 'circuit_training_past_season', 'protein_intake_BW', 'iron_intake_BW', 'vitaminD_intake_BW', 'resistance_training_past_month', 'barefoot_past_month', 'past_month_min', 'past_month_volume_low', 'SC_past_month', 'past_week_ratio_moderate', 'vitaminC_intake_BW', 'past_week_ratio_high', 'non_running_past_season', 'fat_percentage_avg', 'non_running_past_month', 'core_stability_past_season', 'calcium_intake_BW', 'omega3_intake_BW', 'past_month_calculated_volume', 'drills_past_month', 'plyometrics_past_season']
# Average AUC: 0.7415 ± 0.0366
# Average F1 Score: 0.0352 ± 0.0355
# Average Accuracy: 0.9068 ± 0.0016
# Average Precision: 0.2119 ± 0.1837

# %%
# Print the best trial
print("Best trial:")
trial = study.best_trial

print("  Value (Mean AUC): ", trial.value)
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")

# Extract additional metrics from the best trial
best_trial_metrics = trial.user_attrs
mean_auc = best_trial_metrics.get("mean_auc", None)
std_auc = best_trial_metrics.get("std_auc", None)
mean_f1 = best_trial_metrics.get("mean_f1", None)
std_f1 = best_trial_metrics.get("std_f1", None)
mean_accuracy = best_trial_metrics.get("mean_accuracy", None)
std_accuracy = best_trial_metrics.get("std_accuracy", None)
mean_precision = best_trial_metrics.get("mean_precision", None)
std_precision = best_trial_metrics.get("std_precision", None)
selected_features = best_trial_metrics.get("selected_features", None)

print(f"\nBest Trial Metrics:")
print(f"Selected Features: {selected_features}")
print(f"Average AUC: {mean_auc:.4f} ± {std_auc:.4f}")
print(f"Average F1 Score: {mean_f1:.4f} ± {std_f1:.4f}")
print(f"Average Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}")
print(f"Average Precision: {mean_precision:.4f} ± {std_precision:.4f}")
# Out:
# Best trial:
#   Value (Mean AUC):  0.7415440699513642
#   Params:
#     n_epochs: 2163
#     lr: 4.600641941225531e-06
#     weight_decay: 3.128639842545911e-08
#     batch_size: 256
#     n_genotype: 67
#     n_history: 4
#     n_phenotype: 47
#     n_behaviour: 37
#
# Best Trial Metrics:
# Selected Features: ['rs144414988', 'rs117544024', 'rs77569527', 'rs78391032', 'rs12722', 'rs3196378', 'rs57104447', 'rs144371252', 'class123_SNP_risk_score', 'rs11177', 'rs2277268', 'rs6617', 'rs4988321', 'rs1676303', 'rs25487', 'rs11154027', 'rs35360670', 'rs6481512', 'rs710079', 'class12_SNP_risk_score', 'rs420257', 'rs42522', 'rs71404070', 'rs1249269', 'rs591058', 'rs72758637', 'rs413826', 'rs74544784', 'rs1330363', 'rs25489', 'rs149047058', 'rs3218791', 'rs4903399', 'rs10263021', 'rs761804508', 'rs2234693', 'rs7528684', 'rs17576', 'rs12154667', 'rs2858056', 'rs17583842', 'rs1137101', 'rs2289360', 'rs2525504', 'rs4701616', 'rs1554606', 'rs1887632', 'rs820218', 'rs2252070', 'rs143383', 'rs1011814', 'rs2586488', 'rs42517', 'rs2277698', 'rs4919510', 'rs3753841', 'rs2104772', 'rs13107325', 'rs2306033', 'rs1800012', 'rs1800972', 'rs11232681', 'rs1800469', 'rs2285053', 'rs12574452', 'rs62051384', 'rs3045', 'tracking_period_injury', 'past_month_injury', 'average_run_hours', 'average_run_frequency', 'Mass', 'BMI', 'VILR_asymmetry_10', 'height', 'VALR_asymmetry_10', 'VALR_10', 'calf_size', 'VILR_10', 'ad_ab_ratio_asymmetry', 'VALR_asymmetry_12', 'Duty_factor_10', 'Impact_peak_12', 'VILR_asymmetry_12', 'Duty_factor_12', 'hip_abduction_peak_torque', 'knee_extension_peak_torque', 'lower_leg_lean_mass', 'knee_extension_peak_angle', 'hip_abduction_peak_torque_asymmetry', 'hip_adduction_peak_torque', 'Step_frequency_12', 'Step_frequency_10', 'hip_adduction_peak_angle_asymmetry', 'knee_flexion_peak_torque', 'Impact_peak_asymmetry_12', 'Impact_peak_10', 'Q_angle', 'total_lean_mass', 'Flight_time_12', 'leg_ffmi', 'total_fl_ex_ratio', 'hip_abduction_peak_angle', 'total_ffmi', 'hip_abduction_peak_angle_asymmetry', 'hip_adduction_peak_torque_asymmetry', 'Alt_strike', 'knee_flexion_peak_angle', 'Q_angle_asymmetry', 'navicular_drop', 'Cadence_asymmetry_10', 'Impact_peak_asymmetry_10', 'Contact_time_10', 'fl_ex_ratio_asymmetry', 'knee_extension_peak_torque_asymmetry', 'total_ad_ab_ratio', 'lower_leg_ffmi', 'Cadence_asymmetry_12', 'past_week_ratio_calculated_volume', 'past_week_ratio', 'arginine_intake_BW', 'glycine_intake_BW', 'stretching_past_season', 'barefoot_past_season', 'past_week_ratio_low', 'circuit_training_past_month', 'past_month_ratio', 'resistance_training_past_season', 'stretching_past_month', 'past_month_distance', 'drills_past_season', 'past_month_ratio_calculated_volume', 'vitaminE_intake_BW', 'past_month_volume_very_high', 'circuit_training_past_season', 'protein_intake_BW', 'iron_intake_BW', 'vitaminD_intake_BW', 'resistance_training_past_month', 'barefoot_past_month', 'past_month_min', 'past_month_volume_low', 'SC_past_month', 'past_week_ratio_moderate', 'vitaminC_intake_BW', 'past_week_ratio_high', 'non_running_past_season', 'fat_percentage_avg', 'non_running_past_month', 'core_stability_past_season', 'calcium_intake_BW', 'omega3_intake_BW', 'past_month_calculated_volume', 'drills_past_month', 'plyometrics_past_season']
# Average AUC: 0.7415 ± 0.0366
# Average F1 Score: 0.0352 ± 0.0355
# Average Accuracy: 0.9068 ± 0.0016
# Average Precision: 0.2119 ± 0.1837

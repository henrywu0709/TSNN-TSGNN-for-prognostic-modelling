# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score, precision_score
from imblearn.over_sampling import RandomOverSampler, ADASYN, SMOTE
import optuna
from joblib import Parallel, delayed
from tqdm import tqdm
import random
import warnings
from optuna.exceptions import TrialPruned

import os

# Limit each parallel process to one thread per library
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'
os.environ['NUMEXPR_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['VECLIB_MAXIMUM_THREADS'] = '1'
os.environ['TORCH_NUM_THREADS'] = '1'  # For PyTorch

# Additional control for PyTorch if needed
import torch
torch.set_num_threads(1)

# # For reproducibility
# def set_seed(seed=42):
#     random.seed(seed)
#     np.random.seed(seed)
#     torch.manual_seed(seed)

# set_seed()

# Suppress warnings for cleaner output
warnings.filterwarnings("ignore")

# Load the dataset
data = pd.read_excel("class123_dataset.xlsx")

# Define feature groups (as provided)
feature_groups = {
    'Genotype': [
        'rs11225395', 'rs1144393', 'rs650108', 'rs591058', 'rs2252070', 'rs4986938', 'rs1800012', 'rs4789932', 'rs9340799', 'rs970547', 
        'rs1800795', 'rs13946', 'rs12722', 'class1_SNP_risk_score', 'rs7528684', 'rs4919510', 'rs1937810', 'rs6481512', 'rs1249269', 
        'rs12574452', 'rs12429486', 'rs4454832', 'rs2761884', 'rs62051384', 'rs4362400', 'rs2586488', 'rs2277698', 'rs1045485', 
        'rs143383', 'rs17576', 'rs2305948', 'rs1011814', 'rs11154027', 'rs2234693', 'rs1643821', 'rs2010963', 'rs10263021', 'rs149047058', 
        'rs420257', 'rs42517', 'rs42522', 'rs42531', 'rs413826', 'rs2104772', 'rs1330363', 'class12_SNP_risk_score', 'rs3753841', 
        'rs57104447', 'rs1887632', 'rs4654760', 'rs1137101', 'rs2306033', 'rs2277268', 'rs4988321', 'rs11232681', 'rs1718119', 'rs3751143', 
        'rs1544410', 'rs2228570', 'rs4328262', 'rs1021188', 'rs74544784', 'rs78391032', 'rs77569527', 'rs117544024', 'rs912336', 
        'rs3218791', 'rs911263', 'rs2525504', 'rs17756404', 'rs4903399', 'rs10132091', 'rs17583842', 'rs1676303', 'rs11629171', 
        'rs2281518', 'rs2285053', 'rs71404070', 'rs710079', 'rs2858056', 'rs820218', 'rs3018362', 'rs1800470', 'rs1800469', 'rs25487', 
        'rs25489', 'rs2289360', 'rs183364169', 'rs11177', 'rs6617', 'rs3219008', 'rs13107325', 'rs60713544', 'rs145648292', 'rs4244032', 
        'rs12656106', 'rs3045', 'rs187483', 'rs4701616', 'rs144414988', 'rs1800629', 'rs10484958', 'rs4730153', 'rs1800797', 'rs1554606', 
        'rs2237352', 'rs4725069', 'rs12154667', 'rs1548456', 'rs3216902', 'rs35360670', 'rs13317', 'rs1800972', 'rs7035322', 'rs7021589', 
        'rs72758637', 'rs10759753', 'rs3789870', 'rs1138545', 'rs3196378', 'rs1134170', 'rs10992075', 'rs1590', 'rs144371252', 
        'rs761804508', 'class123_SNP_risk_score', 'sex'
    ],
    'History': [
        'Age', 'lower_limb_days_total', 'average_run_hours', 'average_interval_training_frequency', 'EDEQ_total', 'tracking_period_injury',
        'past_stress_injury', 'LEAF-Q', 'Athlete_Score', 'average_run_frequency', 'past_month_injury'
    ],
    'Phenotype': [
        'hip_abduction_peak_torque', 'total_ad_ab_ratio', 'knee_extension_peak_torque', 'knee_flexion_peak_torque', 'navicular_drop', 
        'navicular_drop_asymmetry', 'Q_angle', 'Q_angle_asymmetry', 'VALR_12', 'Impact_peak_12', 'Duty_factor_12', 'BMI', 'BMD_spine',
        'hip_abduction_peak_torque_asymmetry', 'hip_adduction_peak_torque', 'hip_adduction_peak_torque_asymmetry', 
        'knee_extension_peak_torque_asymmetry', 'knee_flexion_peak_torque_asymmetry', 'total_fl_ex_ratio', 'leg_lean_mass', 
        'hip_abduction_peak_angle', 'hip_abduction_peak_angle_asymmetry', 'hip_adduction_peak_angle', 'hip_adduction_peak_angle_asymmetry', 
        'ad_ab_ratio_asymmetry', 'knee_extension_peak_angle', 'knee_extension_peak_angle_asymmetry', 'knee_flexion_peak_angle', 
        'knee_flexion_peak_angle_asymmetry', 'fl_ex_ratio_asymmetry', 'VILR_10', 'VALR_10', 'VILR_asymmetry_10', 'VALR_asymmetry_10', 
        'Impact_peak_10', 'Impact_peak_asymmetry_10', 'Flight_time_10', 'Contact_time_10', 'Duty_factor_10', 'Step_frequency_10', 
        'Cadence_asymmetry_10', 'Duty_factor_asymmetry_10', 'VILR_12', 'VILR_asymmetry_12', 'VALR_asymmetry_12', 
        'Impact_peak_asymmetry_12', 'Flight_time_12', 'Contact_time_12', 'Step_frequency_12', 'Cadence_asymmetry_12', 
        'Duty_factor_asymmetry_12', 'Alt_strike', 'height', 'Mass', 'thigh_lean_mass', 'thigh_ffmi', 'lower_leg_lean_mass', 
        'lower_leg_ffmi', 'leg_ffmi', 'total_lean_mass', 'total_ffmi', 'calf_size', 'BMD_hip', 'BMD_body',
    ],
    'Behaviour': [
        'fat_intake_avg', 'past_month_distance', 'past_month_ratio', 'SC_past_season', 'non_running_past_season', 'fat_intake_BW', 
        'fat_percentage_avg', 'average_energy_availability', 'protein_intake_BW', 'omega3_intake_BW', 'vitaminD_intake_BW', 
        'vitaminC_intake_BW', 'vitaminE_intake_BW', 'calcium_intake_BW', 'copper_intake_BW', 'iron_intake_BW', 'glycine_intake_BW', 
        'arginine_intake_BW', 'past_month_min', 'past_week_ratio', 'past_month_volume_low', 'past_week_ratio_low', 'past_month_ratio_low', 
        'past_month_volume_moderate', 'past_week_ratio_moderate', 'past_month_ratio_moderate', 'past_month_volume_high', 
        'past_week_ratio_high', 'past_month_ratio_high', 'past_month_volume_very_high', 'past_week_ratio_very_high', 
        'past_month_ratio_very_high', 'past_month_calculated_volume', 'past_week_ratio_calculated_volume', 
        'past_month_ratio_calculated_volume', 'resistance_training_past_month', 'resistance_training_past_season', 
        'bodyweight_exercises_past_month', 'bodyweight_exercises_past_season', 'core_stability_past_month', 'core_stability_past_season', 
        'balance_training_past_month', 'balance_training_past_season', 'plyometrics_past_month', 'plyometrics_past_season', 
        'drills_past_month', 'drills_past_season', 'circuit_training_past_month', 'circuit_training_past_season', 'barefoot_past_month', 
        'barefoot_past_season', 'stretching_past_month', 'stretching_past_season', 'SC_past_month', 'non_running_past_month'
    ]
}

# Define predictors and outcome
X = data.drop(columns=['RRI'])  # Predictors
y = data['RRI']  # Outcome

# Ensure that the feature groups exist in the dataset
for group in feature_groups:
    feature_groups[group] = [feature for feature in feature_groups[group] if feature in X.columns]

num_features = len(X)
feature_to_idx = {feature: idx for idx, feature in enumerate(X)}

# Initialize adjacency matrix with zeros
adjacency = np.zeros((num_features, num_features), dtype=np.float32)

# Define groups
genotype_features = feature_groups['Genotype']
history_features = feature_groups['History']
phenotype_features = feature_groups['Phenotype']
behaviour_features = feature_groups['Behaviour']

# Get indices for each group
genotype_indices = [feature_to_idx[feat] for feat in genotype_features]
history_indices = [feature_to_idx[feat] for feat in history_features]
phenotype_indices = [feature_to_idx[feat] for feat in phenotype_features]
behaviour_indices = [feature_to_idx[feat] for feat in behaviour_features]

# Genotype nodes: connect to every node except themselves
for i in genotype_indices:
    for j in range(num_features):
        if j != i:
            adjacency[i, j] = 1.0

# History nodes: connect to every node except genotype nodes and themselves
for i in history_indices:
    for j in range(num_features):
        if j not in genotype_indices and j != i:
            adjacency[i, j] = 1.0

# Phenotype nodes: connect to every node except genotype, history nodes, and themselves
for i in phenotype_indices:
    for j in range(num_features):
        if j not in genotype_indices and j not in history_indices and j != i:
            adjacency[i, j] = 1.0

# Behaviour nodes: connect to all other behaviour nodes except themselves
for i in behaviour_indices:
    for j in behaviour_indices:
        if j != i:
            adjacency[i, j] = 1.0

# Convert adjacency to tensor
adjacency_mask = torch.tensor(adjacency, dtype=torch.float32)

class CustomDataset(Dataset):
    def __init__(self, X, y):
        if isinstance(X, pd.DataFrame):
            self.X = X.values.astype(np.float32)
        elif isinstance(X, np.ndarray):
            self.X = X.astype(np.float32)
        else:
            raise TypeError("X should be a pandas DataFrame or a NumPy array.")
        self.y = y.astype(np.float32)
    
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

class CustomNetwork(nn.Module):
    def __init__(self, num_features, adjacency_mask):
        super(CustomNetwork, self).__init__()
        self.num_features = num_features

        # Register the fixed adjacency mask as a buffer (non-trainable)
        self.register_buffer('mask', adjacency_mask.float())  # Shape: (num_features, num_features)

        # Initialize connection weights (W_ij: from node j to node i)
        self.W = nn.Parameter(torch.randn(num_features, num_features) * 0.01)

        # Initialize bias for each node
        self.bias = nn.Parameter(torch.zeros(num_features))

        # Initialize output weights (from each node to the final output)
        self.output_weights = nn.Parameter(torch.randn(num_features) * 0.01)

        # Add Batch Normalization
        self.batch_norm = nn.BatchNorm1d(num_features)

    def forward(self, x, threshold=None):
        """
        x: input tensor of shape (batch_size, num_features)
        threshold: if provided, apply binary thresholding to gating
        """
        # Use the fixed mask directly
        learnable_mask = self.mask

        # Apply the learnable mask to connection weights
        W_masked = self.W * learnable_mask  # Shape: (num_features, num_features)

        # Compute incoming messages: (batch_size, num_features) @ (num_features, num_features) = (batch_size, num_features)
        incoming = torch.matmul(x, W_masked)

        # Element-wise multiplication with own feature value
        node_input = incoming * x  # Shape: (batch_size, num_features)

        node_input = self.batch_norm(node_input)

        # Add bias
        node_input += self.bias  # Broadcasting over batch

        # Apply Leaky ReLU activation
        node_output = F.leaky_relu(node_input)  # Shape: (batch_size, num_features)

        # Aggregate node outputs to final output
        output = torch.matmul(node_output, self.output_weights)  # Shape: (batch_size,)

        return output  # Raw scores (logits)

# Import ReliefF for feature selection
from skrebate import ReliefF

def train_evaluate_fold(fold, train_index, val_index, X, y, selected_features, adjacency, feature_to_idx, 
                       n_epochs, lr, weight_decay, batch_size, threshold):
    """
    Function to train and evaluate the model on a single fold.
    This function is intended to be run in parallel.
    """
    # Split data
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]

    # Encode labels for binary classification
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y_train_enc = le.fit_transform(y_train)
    y_val_enc = le.transform(y_val)
    y_train_final = y_train_enc
    y_val_final = y_val_enc

    # Create datasets
    train_dataset = CustomDataset(X_train[selected_features], y_train_final)
    val_dataset = CustomDataset(X_val[selected_features], y_val_final)

    # Create dataloaders with drop_last=True for training and drop_last=False for validation
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

    # Map selected_features to their indices
    selected_feature_indices = [feature_to_idx[feat] for feat in selected_features]

    # Select the corresponding adjacency submatrix using integer indices
    selected_adjacency = adjacency[np.ix_(selected_feature_indices, selected_feature_indices)]
    selected_adjacency_mask = torch.tensor(selected_adjacency, dtype=torch.float32)

    device = torch.device('cpu')

    # Initialize the model with the number of selected features and the selected adjacency mask
    model = CustomNetwork(num_features=len(selected_features), 
                          adjacency_mask=selected_adjacency_mask).to(device)

    # Define loss and optimizer
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    # Training Loop
    for epoch in range(1, n_epochs + 1):
        model.train()
        epoch_loss = 0.0

        for batch_X, batch_y in train_loader:
            batch_X = batch_X.to(device).float()  # Ensure float type
            batch_y = batch_y.to(device).float()  # BCEWithLogitsLoss expects float targets

            optimizer.zero_grad()
            outputs = model(batch_X)  # Forward pass
            loss = criterion(outputs, batch_y)

            # Total loss
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item() * batch_X.size(0)

        epoch_loss /= len(train_loader.dataset)

    # Validation
    model.eval()
    all_outputs = []
    all_labels = []
    all_preds = []  # Initialize a list to accumulate predictions

    with torch.no_grad():
        for batch_X, batch_y in val_loader:
            batch_X = batch_X.to(device).float()

            outputs = model(batch_X)  # Forward pass
            probs = torch.sigmoid(outputs).cpu().numpy()
            preds = (probs >= threshold).astype(int).flatten()

            all_outputs.extend(probs)
            all_labels.extend(batch_y.numpy())
            all_preds.extend(preds)  # Accumulate predictions

    # Compute metrics
    roc_auc = roc_auc_score(all_labels, all_outputs)
    f1 = f1_score(all_labels, all_preds, average='binary')
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='binary')

    return {
        'roc_auc': roc_auc,
        'f1': f1,
        'accuracy': accuracy,
        'precision': precision
    }

def global_feature_ranking(X, y):
    """
    Perform global feature ranking using ReliefF.
    """
    # Initialize ReliefF without random_state
    relief = ReliefF(n_features_to_select='all')

    # Convert X and y to NumPy arrays to avoid KeyError
    X_array = X.values
    y_array = y.values
    
    # Fit ReliefF on the entire dataset
    relief.fit(X_array, y_array)
    
    # Get feature scores
    feature_scores = relief.feature_importances_
    
    # Create a DataFrame for easy handling
    feature_score_df = pd.DataFrame({
        'feature': X.columns,
        'score': feature_scores
    })
    
    # Sort features by score in descending order
    feature_score_df = feature_score_df.sort_values(by='score', ascending=False)
    
    return feature_score_df

def objective(trial, X, y, feature_groups, feature_to_idx, global_feature_score_df, adjacency, threshold=0.5):
    # ====================
    # Hyperparameters to Tune
    # ====================

    # 1. Number of Epochs
    n_epochs = trial.suggest_int('n_epochs', 500, 3000)

    # 2. Learning Rate
    lr = trial.suggest_loguniform('lr', 1e-6, 1e-2)

    # 3. Weight Decay
    weight_decay = trial.suggest_loguniform('weight_decay', 1e-8, 1e-3)

    # 4. Batch Size
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128, 256, 512])

    # 5. Number of Features per Group
    n_genotype = trial.suggest_int('n_genotype', 1, len(feature_groups['Genotype']))
    n_history = trial.suggest_int('n_history', 1, len(feature_groups['History']))
    n_phenotype = trial.suggest_int('n_phenotype', 1, len(feature_groups['Phenotype']))
    n_behaviour = trial.suggest_int('n_behaviour', 1, len(feature_groups['Behaviour']))

    # ====================
    # Feature Selection Using Global Rankings
    # ====================

    # Initialize selected features list
    selected_features = []

    # For each group, select the top N features based on global ReliefF scores
    for group, n_select in zip(['Genotype', 'History', 'Phenotype', 'Behaviour'],
                               [n_genotype, n_history, n_phenotype, n_behaviour]):
        group_features = feature_groups[group]
        # Filter the features present in the group
        group_feature_scores = global_feature_score_df[global_feature_score_df['feature'].isin(group_features)]
        # Select top N features
        top_features = group_feature_scores.head(n_select)['feature'].tolist()
        selected_features.extend(top_features)

    # Ensure that selected_features are unique
    selected_features = list(dict.fromkeys(selected_features))

    # ====================
    # Data Preparation
    # ====================

    X_selected = X[selected_features].copy()
    y_selected = y.copy()

    # Initialize Stratified K-Fold
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

    # Get all fold indices
    fold_indices = list(skf.split(X_selected, y_selected))

    # ====================
    # Parallel Training and Evaluation
    # ====================

    # Define a wrapper for joblib's Parallel
    results = Parallel(n_jobs=10)(
        delayed(train_evaluate_fold)(
            fold=fold,
            train_index=train_idx,
            val_index=val_idx,
            X=X_selected,
            y=y_selected,
            selected_features=selected_features,
            adjacency=adjacency,  # Pass the numpy adjacency matrix
            feature_to_idx=feature_to_idx,  # Pass the feature_to_idx mapping
            n_epochs=n_epochs,
            lr=lr,
            weight_decay=weight_decay,
            batch_size=batch_size,
            threshold=threshold
        )
        for fold, (train_idx, val_idx) in enumerate(fold_indices)
    )

    # ====================
    # Collect Metrics
    # ====================

    aucs = []
    f1s = []
    accuracies = []
    precisions = []

    for res in results:
        aucs.append(res['roc_auc'])
        f1s.append(res['f1'])
        accuracies.append(res['accuracy'])
        precisions.append(res['precision'])

    # ====================
    # Final Metrics Calculation
    # ====================

    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_f1 = np.mean(f1s)
    std_f1 = np.std(f1s)
    mean_accuracy = np.mean(accuracies)
    std_accuracy = np.std(accuracies)
    mean_precision = np.mean(precisions)
    std_precision = np.std(precisions)

    # ====================
    # Objective Metric
    # ====================

    # Since it's binary classification, we aim to maximize the mean AUC
    trial.set_user_attr("mean_auc", mean_auc)
    trial.set_user_attr("std_auc", std_auc)
    trial.set_user_attr("mean_f1", mean_f1)
    trial.set_user_attr("std_f1", std_f1)
    trial.set_user_attr("mean_accuracy", mean_accuracy)
    trial.set_user_attr("std_accuracy", std_accuracy)
    trial.set_user_attr("mean_precision", mean_precision)
    trial.set_user_attr("std_precision", std_precision)
    trial.set_user_attr("selected_features", selected_features)

    return mean_auc

def run_hyperparameter_tuning(X, y, feature_groups, feature_to_idx, adjacency, threshold=0.5):
    # Generate the global feature ranking before the study starts
    global_feature_score_df = global_feature_ranking(X, y)

    def objective_wrapper(trial):
        return objective(trial, X, y, feature_groups, feature_to_idx, global_feature_score_df, adjacency, threshold)

    study = optuna.create_study(
        direction='maximize',
        study_name='CustomNetwork_Hyperparameter_Tuning',
        sampler=optuna.samplers.TPESampler(seed=42)
    )

    # Integrate a progress bar for the Optuna study
    with tqdm(total=500, desc="Optuna Trials") as pbar:
        def callback(study, trial):
            pbar.update(1)

        # Set n_jobs=1 to ensure serial execution of hyperparameter trials
        study.optimize(objective_wrapper, n_trials=500, timeout=None, callbacks=[callback], n_jobs=1)

    print("Number of finished trials: ", len(study.trials))
    print("Best trial:")
    trial = study.best_trial

    print("  Value (Mean AUC): ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

    # Extract additional metrics from the best trial
    best_trial_metrics = trial.user_attrs
    mean_auc = best_trial_metrics.get("mean_auc", None)
    std_auc = best_trial_metrics.get("std_auc", None)
    mean_f1 = best_trial_metrics.get("mean_f1", None)
    std_f1 = best_trial_metrics.get("std_f1", None)
    mean_accuracy = best_trial_metrics.get("mean_accuracy", None)
    std_accuracy = best_trial_metrics.get("std_accuracy", None)
    mean_precision = best_trial_metrics.get("mean_precision", None)
    std_precision = best_trial_metrics.get("std_precision", None)
    selected_features = best_trial_metrics.get("selected_features", None)

    print(f"\nBest Trial Metrics:")
    print(f"Selected Features: {selected_features}")
    print(f"Average AUC: {mean_auc:.4f} ± {std_auc:.4f}")
    print(f"Average F1 Score: {mean_f1:.4f} ± {std_f1:.4f}")
    print(f"Average Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}")
    print(f"Average Precision: {mean_precision:.4f} ± {std_precision:.4f}")

    return study

if __name__ == "__main__":
    # Run hyperparameter tuning
    study = run_hyperparameter_tuning(X, y, feature_groups, feature_to_idx, adjacency)
# Out:
# [I 2024-12-17 00:23:42,947] A new study created in memory with name: CustomNetwork_Hyperparameter_Tuning
# Optuna Trials:   0%|          | 0/500 [00:00<?, ?it/s][I 2024-12-17 00:26:21,899] Trial 0 finished with value: 0.6514276814368467 and parameters: {'n_epochs': 1436, 'lr': 0.006351221010640704, 'weight_decay': 4.570563099801451e-05, 'batch_size': 512, 'n_genotype': 77, 'n_history': 8, 'n_phenotype': 2, 'n_behaviour': 54}. Best is trial 0 with value: 0.6514276814368467.
# Optuna Trials:   0%|          | 1/500 [02:38<22:01:41, 158.92s/it][I 2024-12-17 00:34:54,768] Trial 1 finished with value: 0.7428976624363924 and parameters: {'n_epochs': 2581, 'lr': 7.068974950624607e-06, 'weight_decay': 8.111941985431907e-08, 'batch_size': 128, 'n_genotype': 78, 'n_history': 2, 'n_phenotype': 19, 'n_behaviour': 21}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   0%|          | 2/500 [11:11<50:47:08, 367.13s/it][I 2024-12-17 00:39:19,701] Trial 2 finished with value: 0.6596899747159558 and parameters: {'n_epochs': 1640, 'lr': 0.0013826232179369874, 'weight_decay': 9.9625132220551e-08, 'batch_size': 256, 'n_genotype': 9, 'n_history': 11, 'n_phenotype': 62, 'n_behaviour': 45}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   1%|          | 3/500 [15:36<44:14:29, 320.46s/it][I 2024-12-17 00:41:32,222] Trial 3 finished with value: 0.6949080672640935 and parameters: {'n_epochs': 1261, 'lr': 2.4586032763280077e-06, 'weight_decay': 2.6373339933815247e-05, 'batch_size': 512, 'n_genotype': 33, 'n_history': 8, 'n_phenotype': 20, 'n_behaviour': 29}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   1%|          | 4/500 [17:49<33:55:47, 246.27s/it][I 2024-12-17 00:50:25,167] Trial 4 finished with value: 0.7186238981479747 and parameters: {'n_epochs': 1867, 'lr': 5.4880470007660465e-06, 'weight_decay': 0.00070456836384545, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 3, 'n_behaviour': 18}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   1%|          | 5/500 [26:42<48:04:33, 349.64s/it][I 2024-12-17 00:52:54,311] Trial 5 finished with value: 0.7342282956945939 and parameters: {'n_epochs': 1472, 'lr': 1.2172958098369984e-05, 'weight_decay': 0.00013921548533046482, 'batch_size': 512, 'n_genotype': 10, 'n_history': 11, 'n_phenotype': 50, 'n_behaviour': 11}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   1%|          | 6/500 [29:11<38:37:28, 281.47s/it][I 2024-12-17 00:55:55,984] Trial 6 finished with value: 0.7193250974951668 and parameters: {'n_epochs': 513, 'lr': 0.0018274508859816032, 'weight_decay': 3.422052903270691e-05, 'batch_size': 64, 'n_genotype': 110, 'n_history': 7, 'n_phenotype': 22, 'n_behaviour': 4}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   1%|▏         | 7/500 [32:13<34:04:41, 248.85s/it][I 2024-12-17 01:03:58,413] Trial 7 finished with value: 0.7215168075692877 and parameters: {'n_epochs': 1277, 'lr': 1.99863407785289e-05, 'weight_decay': 4.446628955475447e-05, 'batch_size': 64, 'n_genotype': 97, 'n_history': 7, 'n_phenotype': 50, 'n_behaviour': 28}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   2%|▏         | 8/500 [40:15<44:10:18, 323.21s/it][I 2024-12-17 01:11:34,097] Trial 8 finished with value: 0.6965950939906461 and parameters: {'n_epochs': 1807, 'lr': 5.1305517605898387e-05, 'weight_decay': 1.3399717231179682e-08, 'batch_size': 128, 'n_genotype': 116, 'n_history': 3, 'n_phenotype': 27, 'n_behaviour': 42}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   2%|▏         | 9/500 [47:51<49:43:49, 364.62s/it][I 2024-12-17 01:18:25,987] Trial 9 finished with value: 0.7354831667863272 and parameters: {'n_epochs': 1072, 'lr': 2.031980983842497e-06, 'weight_decay': 2.810329644763601e-07, 'batch_size': 64, 'n_genotype': 103, 'n_history': 3, 'n_phenotype': 58, 'n_behaviour': 30}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   2%|▏         | 10/500 [54:43<51:36:55, 379.21s/it][I 2024-12-17 01:28:13,284] Trial 10 finished with value: 0.7208992176817034 and parameters: {'n_epochs': 2858, 'lr': 0.0001855989166023879, 'weight_decay': 1.412166785354856e-06, 'batch_size': 128, 'n_genotype': 51, 'n_history': 1, 'n_phenotype': 39, 'n_behaviour': 19}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   2%|▏         | 11/500 [1:04:30<60:09:37, 442.90s/it][I 2024-12-17 01:55:34,724] Trial 11 finished with value: 0.7344371193197945 and parameters: {'n_epochs': 2868, 'lr': 1.0434562273815538e-06, 'weight_decay': 3.773559344253666e-07, 'batch_size': 32, 'n_genotype': 78, 'n_history': 4, 'n_phenotype': 14, 'n_behaviour': 31}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   2%|▏         | 12/500 [1:31:51<109:27:43, 807.51s/it][I 2024-12-17 02:04:01,663] Trial 12 finished with value: 0.7296115014566504 and parameters: {'n_epochs': 2225, 'lr': 1.0502627192422206e-06, 'weight_decay': 5.208914709991481e-08, 'batch_size': 128, 'n_genotype': 91, 'n_history': 1, 'n_phenotype': 38, 'n_behaviour': 21}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   3%|▎         | 13/500 [1:40:18<96:55:13, 716.45s/it] [I 2024-12-17 02:06:41,738] Trial 13 finished with value: 0.7190227042078843 and parameters: {'n_epochs': 771, 'lr': 0.0001546589398260416, 'weight_decay': 1.751939442456446e-06, 'batch_size': 256, 'n_genotype': 125, 'n_history': 5, 'n_phenotype': 64, 'n_behaviour': 37}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   3%|▎         | 14/500 [1:42:58<74:02:02, 548.40s/it][I 2024-12-17 02:27:46,882] Trial 14 finished with value: 0.7402465096231072 and parameters: {'n_epochs': 2420, 'lr': 5.209005708108076e-06, 'weight_decay': 2.3571765468088392e-07, 'batch_size': 32, 'n_genotype': 58, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 11}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   3%|▎         | 15/500 [2:04:03<102:59:18, 764.45s/it][I 2024-12-17 02:48:19,389] Trial 15 finished with value: 0.7310847790335576 and parameters: {'n_epochs': 2402, 'lr': 4.6524241050632366e-05, 'weight_decay': 1.5314214564614656e-08, 'batch_size': 32, 'n_genotype': 55, 'n_history': 1, 'n_phenotype': 12, 'n_behaviour': 1}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   3%|▎         | 16/500 [2:24:36<121:43:02, 905.33s/it][I 2024-12-17 03:09:44,001] Trial 16 finished with value: 0.7423134547157759 and parameters: {'n_epochs': 2501, 'lr': 7.934124943368784e-06, 'weight_decay': 4.939308620037068e-06, 'batch_size': 32, 'n_genotype': 37, 'n_history': 5, 'n_phenotype': 10, 'n_behaviour': 10}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   3%|▎         | 17/500 [2:46:01<136:46:02, 1019.38s/it][I 2024-12-17 03:17:50,236] Trial 17 finished with value: 0.7404348856568854 and parameters: {'n_epochs': 2599, 'lr': 1.53461914187997e-05, 'weight_decay': 6.494777614419829e-06, 'batch_size': 128, 'n_genotype': 30, 'n_history': 5, 'n_phenotype': 28, 'n_behaviour': 9}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   4%|▎         | 18/500 [2:54:07<115:02:03, 859.18s/it] [I 2024-12-17 03:35:17,306] Trial 18 finished with value: 0.7275320850328699 and parameters: {'n_epochs': 2024, 'lr': 0.0004073926494111889, 'weight_decay': 5.967519615628635e-06, 'batch_size': 32, 'n_genotype': 34, 'n_history': 5, 'n_phenotype': 6, 'n_behaviour': 21}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   4%|▍         | 19/500 [3:11:34<122:20:08, 915.61s/it][I 2024-12-17 03:45:45,609] Trial 19 finished with value: 0.7322065096308179 and parameters: {'n_epochs': 2996, 'lr': 6.027867798440728e-06, 'weight_decay': 7.67325893618266e-07, 'batch_size': 128, 'n_genotype': 77, 'n_history': 9, 'n_phenotype': 18, 'n_behaviour': 14}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   4%|▍         | 20/500 [3:22:02<110:34:47, 829.35s/it][I 2024-12-17 04:08:28,125] Trial 20 finished with value: 0.7389195519541173 and parameters: {'n_epochs': 2591, 'lr': 4.1332069094414594e-05, 'weight_decay': 6.296415299024957e-06, 'batch_size': 32, 'n_genotype': 39, 'n_history': 6, 'n_phenotype': 34, 'n_behaviour': 7}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   4%|▍         | 21/500 [3:44:45<131:38:37, 989.39s/it][I 2024-12-17 04:16:35,582] Trial 21 finished with value: 0.7416018250654198 and parameters: {'n_epochs': 2625, 'lr': 1.5394057657173038e-05, 'weight_decay': 7.288609142190054e-06, 'batch_size': 128, 'n_genotype': 22, 'n_history': 5, 'n_phenotype': 26, 'n_behaviour': 8}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   4%|▍         | 22/500 [3:52:52<111:22:02, 838.75s/it][I 2024-12-17 04:23:17,417] Trial 22 finished with value: 0.7379238312953043 and parameters: {'n_epochs': 2195, 'lr': 1.0191448058501447e-05, 'weight_decay': 3.2524997046538607e-06, 'batch_size': 128, 'n_genotype': 21, 'n_history': 4, 'n_phenotype': 25, 'n_behaviour': 14}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   5%|▍         | 23/500 [3:59:34<93:45:44, 707.64s/it] [I 2024-12-17 04:31:50,955] Trial 23 finished with value: 0.7385163167527677 and parameters: {'n_epochs': 2684, 'lr': 3.4189864935516893e-06, 'weight_decay': 1.3158543799680028e-05, 'batch_size': 128, 'n_genotype': 46, 'n_history': 6, 'n_phenotype': 8, 'n_behaviour': 24}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   5%|▍         | 24/500 [4:08:07<85:51:53, 649.40s/it][I 2024-12-17 04:39:02,024] Trial 24 finished with value: 0.7285365325133044 and parameters: {'n_epochs': 2361, 'lr': 2.426037658736405e-05, 'weight_decay': 0.00016625692776278442, 'batch_size': 128, 'n_genotype': 17, 'n_history': 4, 'n_phenotype': 16, 'n_behaviour': 1}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   5%|▌         | 25/500 [4:15:19<77:02:28, 583.89s/it][I 2024-12-17 04:43:31,880] Trial 25 finished with value: 0.7297251505590118 and parameters: {'n_epochs': 2135, 'lr': 9.115990867561129e-05, 'weight_decay': 5.545086773455689e-08, 'batch_size': 256, 'n_genotype': 2, 'n_history': 2, 'n_phenotype': 30, 'n_behaviour': 15}. Best is trial 1 with value: 0.7428976624363924.
# Optuna Trials:   5%|▌         | 26/500 [4:19:48<64:28:24, 489.67s/it][I 2024-12-17 05:07:55,055] Trial 26 finished with value: 0.7464342928252368 and parameters: {'n_epochs': 2747, 'lr': 1.046865608640262e-05, 'weight_decay': 9.378459687105873e-07, 'batch_size': 32, 'n_genotype': 63, 'n_history': 2, 'n_phenotype': 23, 'n_behaviour': 7}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   5%|▌         | 27/500 [4:44:12<102:42:43, 781.74s/it][I 2024-12-17 05:33:03,300] Trial 27 finished with value: 0.7288419652087252 and parameters: {'n_epochs': 2782, 'lr': 7.3611484294966924e-06, 'weight_decay': 7.27239250666467e-07, 'batch_size': 32, 'n_genotype': 71, 'n_history': 2, 'n_phenotype': 9, 'n_behaviour': 25}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   6%|▌         | 28/500 [5:09:20<131:04:19, 999.70s/it][I 2024-12-17 05:54:59,212] Trial 28 finished with value: 0.7385926788515812 and parameters: {'n_epochs': 2499, 'lr': 2.5270519732721424e-06, 'weight_decay': 1.1506902459359188e-07, 'batch_size': 32, 'n_genotype': 63, 'n_history': 2, 'n_phenotype': 22, 'n_behaviour': 5}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   6%|▌         | 29/500 [5:31:16<143:12:21, 1094.57s/it][I 2024-12-17 06:14:38,720] Trial 29 finished with value: 0.6789337281479592 and parameters: {'n_epochs': 1927, 'lr': 0.007864923248113765, 'weight_decay': 3.1942546691146735e-08, 'batch_size': 32, 'n_genotype': 84, 'n_history': 3, 'n_phenotype': 33, 'n_behaviour': 53}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   6%|▌         | 30/500 [5:50:55<146:13:43, 1120.05s/it][I 2024-12-17 06:20:20,670] Trial 30 finished with value: 0.7272757919198373 and parameters: {'n_epochs': 2986, 'lr': 3.017762546106777e-05, 'weight_decay': 6.836997327103207e-07, 'batch_size': 512, 'n_genotype': 68, 'n_history': 10, 'n_phenotype': 3, 'n_behaviour': 34}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   6%|▌         | 31/500 [5:56:37<115:30:23, 886.62s/it] [I 2024-12-17 06:29:03,312] Trial 31 finished with value: 0.7404964191145647 and parameters: {'n_epochs': 2690, 'lr': 1.0495934118136131e-05, 'weight_decay': 2.536519429847974e-06, 'batch_size': 128, 'n_genotype': 26, 'n_history': 6, 'n_phenotype': 24, 'n_behaviour': 7}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   6%|▋         | 32/500 [6:05:20<101:03:54, 777.42s/it][I 2024-12-17 06:48:16,432] Trial 32 finished with value: 0.7284901894387932 and parameters: {'n_epochs': 2284, 'lr': 8.42307531974931e-05, 'weight_decay': 1.579237927837522e-05, 'batch_size': 32, 'n_genotype': 43, 'n_history': 4, 'n_phenotype': 17, 'n_behaviour': 12}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   7%|▋         | 33/500 [6:24:33<115:28:12, 890.13s/it][I 2024-12-17 06:54:19,690] Trial 33 finished with value: 0.7333174822654291 and parameters: {'n_epochs': 2533, 'lr': 1.667952552388742e-05, 'weight_decay': 1.263083702288229e-05, 'batch_size': 256, 'n_genotype': 59, 'n_history': 7, 'n_phenotype': 20, 'n_behaviour': 17}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   7%|▋         | 34/500 [6:30:36<94:45:44, 732.07s/it] [I 2024-12-17 06:59:14,901] Trial 34 finished with value: 0.7303025513587638 and parameters: {'n_epochs': 2762, 'lr': 3.844559355532274e-06, 'weight_decay': 1.2237732290245184e-07, 'batch_size': 512, 'n_genotype': 49, 'n_history': 5, 'n_phenotype': 39, 'n_behaviour': 4}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   7%|▋         | 35/500 [6:35:31<77:37:50, 601.01s/it][I 2024-12-17 07:04:27,024] Trial 35 finished with value: 0.7330164179988033 and parameters: {'n_epochs': 1601, 'lr': 1.6300853534105365e-06, 'weight_decay': 0.0001539526113431447, 'batch_size': 128, 'n_genotype': 86, 'n_history': 8, 'n_phenotype': 1, 'n_behaviour': 9}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   7%|▋         | 36/500 [6:40:44<66:17:35, 514.34s/it][I 2024-12-17 07:22:03,002] Trial 36 finished with value: 0.7303311048831663 and parameters: {'n_epochs': 2009, 'lr': 6.957028952385758e-06, 'weight_decay': 3.6935565154161448e-06, 'batch_size': 32, 'n_genotype': 38, 'n_history': 3, 'n_phenotype': 12, 'n_behaviour': 24}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   7%|▋         | 37/500 [6:58:20<87:02:54, 676.84s/it][I 2024-12-17 07:26:32,587] Trial 37 finished with value: 0.7360668988914393 and parameters: {'n_epochs': 2638, 'lr': 0.003869150543480355, 'weight_decay': 2.3868918231518425e-05, 'batch_size': 512, 'n_genotype': 22, 'n_history': 2, 'n_phenotype': 44, 'n_behaviour': 8}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   8%|▊         | 38/500 [7:02:49<71:10:52, 554.66s/it][I 2024-12-17 07:40:21,943] Trial 38 finished with value: 0.7192848467010295 and parameters: {'n_epochs': 2863, 'lr': 1.0659098827711093e-05, 'weight_decay': 9.068029024746475e-05, 'batch_size': 64, 'n_genotype': 3, 'n_history': 8, 'n_phenotype': 20, 'n_behaviour': 16}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   8%|▊         | 39/500 [7:16:38<81:34:48, 637.07s/it][I 2024-12-17 07:48:15,751] Trial 39 finished with value: 0.7253571890325372 and parameters: {'n_epochs': 2486, 'lr': 2.664966274718337e-05, 'weight_decay': 1.4862447035132858e-06, 'batch_size': 128, 'n_genotype': 15, 'n_history': 7, 'n_phenotype': 31, 'n_behaviour': 12}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   8%|▊         | 40/500 [7:24:32<75:08:41, 588.09s/it][I 2024-12-17 08:09:01,046] Trial 40 finished with value: 0.738274874091713 and parameters: {'n_epochs': 2292, 'lr': 3.835539193968903e-06, 'weight_decay': 0.000984474933724538, 'batch_size': 32, 'n_genotype': 71, 'n_history': 3, 'n_phenotype': 27, 'n_behaviour': 4}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   8%|▊         | 41/500 [7:45:18<100:07:10, 785.25s/it][I 2024-12-17 08:17:16,798] Trial 41 finished with value: 0.7412651594405861 and parameters: {'n_epochs': 2726, 'lr': 1.0073655008768422e-05, 'weight_decay': 3.3236051526889193e-06, 'batch_size': 128, 'n_genotype': 26, 'n_history': 6, 'n_phenotype': 24, 'n_behaviour': 6}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   8%|▊         | 42/500 [7:53:33<88:51:08, 698.40s/it] [I 2024-12-17 08:26:03,975] Trial 42 finished with value: 0.7408253827790149 and parameters: {'n_epochs': 2767, 'lr': 1.582329126757315e-05, 'weight_decay': 7.281388942047281e-06, 'batch_size': 128, 'n_genotype': 29, 'n_history': 6, 'n_phenotype': 23, 'n_behaviour': 5}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   9%|▊         | 43/500 [8:02:20<82:08:14, 647.03s/it][I 2024-12-17 08:35:54,397] Trial 43 finished with value: 0.7346708401472595 and parameters: {'n_epochs': 2896, 'lr': 8.433189338398022e-06, 'weight_decay': 5.088547539520293e-07, 'batch_size': 128, 'n_genotype': 99, 'n_history': 5, 'n_phenotype': 16, 'n_behaviour': 1}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   9%|▉         | 44/500 [8:12:11<79:48:23, 630.05s/it][I 2024-12-17 08:44:11,195] Trial 44 finished with value: 0.7231307385571789 and parameters: {'n_epochs': 2709, 'lr': 1.6582807919663112e-06, 'weight_decay': 1.9334743641941976e-07, 'batch_size': 128, 'n_genotype': 10, 'n_history': 4, 'n_phenotype': 26, 'n_behaviour': 19}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   9%|▉         | 45/500 [8:20:28<74:34:44, 590.07s/it][I 2024-12-17 08:52:39,121] Trial 45 finished with value: 0.7385530808425806 and parameters: {'n_epochs': 1705, 'lr': 4.802915335252436e-06, 'weight_decay': 7.059411687155628e-05, 'batch_size': 64, 'n_genotype': 36, 'n_history': 7, 'n_phenotype': 19, 'n_behaviour': 11}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   9%|▉         | 46/500 [8:28:56<71:18:25, 565.43s/it][I 2024-12-17 08:57:58,783] Trial 46 finished with value: 0.7333706239140584 and parameters: {'n_epochs': 2464, 'lr': 0.0004625992129465821, 'weight_decay': 1.0680529498515801e-06, 'batch_size': 256, 'n_genotype': 20, 'n_history': 6, 'n_phenotype': 35, 'n_behaviour': 6}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:   9%|▉         | 47/500 [8:34:15<61:52:20, 491.70s/it][I 2024-12-17 09:06:12,258] Trial 47 finished with value: 0.7329567202291701 and parameters: {'n_epochs': 2584, 'lr': 6.258903947129267e-05, 'weight_decay': 2.1500741393710096e-06, 'batch_size': 128, 'n_genotype': 53, 'n_history': 1, 'n_phenotype': 13, 'n_behaviour': 10}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  10%|▉         | 48/500 [8:42:29<61:48:09, 492.23s/it][I 2024-12-17 09:09:41,089] Trial 48 finished with value: 0.731594934667153 and parameters: {'n_epochs': 981, 'lr': 2.486831380745227e-06, 'weight_decay': 0.0003549769780940641, 'batch_size': 128, 'n_genotype': 78, 'n_history': 4, 'n_phenotype': 29, 'n_behaviour': 13}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  10%|▉         | 49/500 [8:45:58<51:00:52, 407.21s/it][I 2024-12-17 09:29:53,905] Trial 49 finished with value: 0.7119135578851403 and parameters: {'n_epochs': 2356, 'lr': 3.670435719803995e-05, 'weight_decay': 2.299843617620228e-05, 'batch_size': 32, 'n_genotype': 42, 'n_history': 9, 'n_phenotype': 6, 'n_behaviour': 20}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  10%|█         | 50/500 [9:06:10<81:06:41, 648.89s/it][I 2024-12-17 09:44:07,287] Trial 50 finished with value: 0.6945440438856672 and parameters: {'n_epochs': 2871, 'lr': 1.9392342047815876e-05, 'weight_decay': 4.199126321127566e-06, 'batch_size': 64, 'n_genotype': 27, 'n_history': 5, 'n_phenotype': 15, 'n_behaviour': 41}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  10%|█         | 51/500 [9:20:24<88:34:57, 710.24s/it][I 2024-12-17 09:52:50,666] Trial 51 finished with value: 0.7352852702944426 and parameters: {'n_epochs': 2767, 'lr': 1.4974332761021696e-05, 'weight_decay': 8.6444538631684e-06, 'batch_size': 128, 'n_genotype': 31, 'n_history': 6, 'n_phenotype': 23, 'n_behaviour': 3}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  10%|█         | 52/500 [9:29:07<81:24:33, 654.18s/it][I 2024-12-17 10:01:55,668] Trial 52 finished with value: 0.7425240723946557 and parameters: {'n_epochs': 2967, 'lr': 1.3065462251006786e-05, 'weight_decay': 8.192503849747774e-06, 'batch_size': 128, 'n_genotype': 25, 'n_history': 6, 'n_phenotype': 22, 'n_behaviour': 6}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  11%|█         | 53/500 [9:38:12<77:09:38, 621.43s/it][I 2024-12-17 10:10:41,797] Trial 53 finished with value: 0.7195584497740249 and parameters: {'n_epochs': 2997, 'lr': 5.655910657509181e-06, 'weight_decay': 4.6798129987753886e-05, 'batch_size': 128, 'n_genotype': 8, 'n_history': 5, 'n_phenotype': 10, 'n_behaviour': 8}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  11%|█         | 54/500 [9:46:58<73:26:45, 592.84s/it][I 2024-12-17 10:18:44,423] Trial 54 finished with value: 0.7353874472904941 and parameters: {'n_epochs': 2620, 'lr': 1.154107685275741e-05, 'weight_decay': 1.1314225342013623e-06, 'batch_size': 128, 'n_genotype': 23, 'n_history': 7, 'n_phenotype': 20, 'n_behaviour': 3}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  11%|█         | 55/500 [9:55:01<69:11:39, 559.77s/it][I 2024-12-17 10:27:35,669] Trial 55 finished with value: 0.7393665123325406 and parameters: {'n_epochs': 2913, 'lr': 2.2020371291494704e-05, 'weight_decay': 4.425570797270876e-06, 'batch_size': 128, 'n_genotype': 14, 'n_history': 6, 'n_phenotype': 22, 'n_behaviour': 9}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  11%|█         | 56/500 [10:03:52<67:58:59, 551.22s/it][I 2024-12-17 10:53:23,491] Trial 56 finished with value: 0.7436337938122117 and parameters: {'n_epochs': 2802, 'lr': 8.19009427210651e-06, 'weight_decay': 2.4525818305605583e-06, 'batch_size': 32, 'n_genotype': 90, 'n_history': 3, 'n_phenotype': 26, 'n_behaviour': 6}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  11%|█▏        | 57/500 [10:29:40<104:37:17, 850.20s/it][I 2024-12-17 11:06:11,297] Trial 57 finished with value: 0.722559623354413 and parameters: {'n_epochs': 1336, 'lr': 0.00013913686512495216, 'weight_decay': 3.6641214531493363e-07, 'batch_size': 32, 'n_genotype': 87, 'n_history': 1, 'n_phenotype': 27, 'n_behaviour': 27}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  12%|█▏        | 58/500 [10:42:28<101:21:02, 825.48s/it][I 2024-12-17 11:33:57,787] Trial 58 finished with value: 0.7409556935773567 and parameters: {'n_epochs': 2810, 'lr': 4.336010979587786e-06, 'weight_decay': 1.0113709663583931e-05, 'batch_size': 32, 'n_genotype': 109, 'n_history': 3, 'n_phenotype': 36, 'n_behaviour': 15}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  12%|█▏        | 59/500 [11:10:14<132:01:42, 1077.78s/it][I 2024-12-17 11:54:52,211] Trial 59 finished with value: 0.7440569082809726 and parameters: {'n_epochs': 2104, 'lr': 3.029485895161721e-06, 'weight_decay': 1.6788307016104874e-05, 'batch_size': 32, 'n_genotype': 81, 'n_history': 2, 'n_phenotype': 57, 'n_behaviour': 22}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  12%|█▏        | 60/500 [11:31:09<138:12:21, 1130.78s/it][I 2024-12-17 12:16:18,503] Trial 60 finished with value: 0.7371612905152867 and parameters: {'n_epochs': 2080, 'lr': 3.0105685413059616e-06, 'weight_decay': 3.382655848553452e-05, 'batch_size': 32, 'n_genotype': 94, 'n_history': 2, 'n_phenotype': 57, 'n_behaviour': 31}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  12%|█▏        | 61/500 [11:52:35<143:34:51, 1177.43s/it][I 2024-12-17 12:40:45,153] Trial 61 finished with value: 0.7393251544517754 and parameters: {'n_epochs': 2544, 'lr': 1.7420707024408032e-06, 'weight_decay': 1.5048916052105492e-05, 'batch_size': 32, 'n_genotype': 82, 'n_history': 2, 'n_phenotype': 42, 'n_behaviour': 21}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  12%|█▏        | 62/500 [12:17:02<153:48:37, 1264.20s/it][I 2024-12-17 13:03:53,817] Trial 62 finished with value: 0.7408948571723807 and parameters: {'n_epochs': 2425, 'lr': 6.671047337635956e-06, 'weight_decay': 5.69134993767205e-06, 'batch_size': 32, 'n_genotype': 90, 'n_history': 1, 'n_phenotype': 51, 'n_behaviour': 10}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  13%|█▎        | 63/500 [12:40:10<157:59:31, 1301.54s/it][I 2024-12-17 13:28:34,303] Trial 63 finished with value: 0.7403549605406364 and parameters: {'n_epochs': 2646, 'lr': 1.2304192974893262e-06, 'weight_decay': 1.901809127676169e-08, 'batch_size': 32, 'n_genotype': 74, 'n_history': 3, 'n_phenotype': 30, 'n_behaviour': 23}. Best is trial 26 with value: 0.7464342928252368.
# Optuna Trials:  13%|█▎        | 64/500 [13:04:51<164:07:56, 1355.22s/it][I 2024-12-17 13:49:51,579] Trial 64 finished with value: 0.7475003340288477 and parameters: {'n_epochs': 2193, 'lr': 7.947827018576797e-06, 'weight_decay': 2.1998395512351047e-06, 'batch_size': 32, 'n_genotype': 101, 'n_history': 2, 'n_phenotype': 25, 'n_behaviour': 17}. Best is trial 64 with value: 0.7475003340288477.
# Optuna Trials:  13%|█▎        | 65/500 [13:26:08<160:55:49, 1331.84s/it][I 2024-12-17 14:09:33,551] Trial 65 finished with value: 0.7378534656383284 and parameters: {'n_epochs': 1930, 'lr': 7.636800718382128e-06, 'weight_decay': 7.166350125507902e-08, 'batch_size': 32, 'n_genotype': 102, 'n_history': 1, 'n_phenotype': 57, 'n_behaviour': 18}. Best is trial 64 with value: 0.7475003340288477.
# Optuna Trials:  13%|█▎        | 66/500 [13:45:50<155:08:25, 1286.88s/it][I 2024-12-17 14:30:46,524] Trial 66 finished with value: 0.7434754646749072 and parameters: {'n_epochs': 2230, 'lr': 2.8288389972905766e-06, 'weight_decay': 1.7173990819985864e-06, 'batch_size': 32, 'n_genotype': 110, 'n_history': 2, 'n_phenotype': 17, 'n_behaviour': 17}. Best is trial 64 with value: 0.7475003340288477.
# Optuna Trials:  13%|█▎        | 67/500 [14:07:03<154:16:51, 1282.71s/it][I 2024-12-17 14:52:37,895] Trial 67 finished with value: 0.7421393167908129 and parameters: {'n_epochs': 2181, 'lr': 3.1271247278579403e-06, 'weight_decay': 1.8837503135009801e-06, 'batch_size': 32, 'n_genotype': 121, 'n_history': 2, 'n_phenotype': 21, 'n_behaviour': 26}. Best is trial 64 with value: 0.7475003340288477.
# Optuna Trials:  14%|█▎        | 68/500 [14:28:54<154:57:24, 1291.31s/it][I 2024-12-17 15:10:09,636] Trial 68 finished with value: 0.7395740981551003 and parameters: {'n_epochs': 1819, 'lr': 2.2285765339202014e-06, 'weight_decay': 2.571471029339698e-06, 'batch_size': 32, 'n_genotype': 109, 'n_history': 2, 'n_phenotype': 18, 'n_behaviour': 18}. Best is trial 64 with value: 0.7475003340288477.
# Optuna Trials:  14%|█▍        | 69/500 [14:46:26<145:59:37, 1219.44s/it][I 2024-12-17 15:33:57,816] Trial 69 finished with value: 0.7456798446134684 and parameters: {'n_epochs': 2351, 'lr': 5.116386806997484e-06, 'weight_decay': 9.733192642607772e-07, 'batch_size': 32, 'n_genotype': 115, 'n_history': 2, 'n_phenotype': 31, 'n_behaviour': 23}. Best is trial 64 with value: 0.7475003340288477.
# Optuna Trials:  14%|█▍        | 70/500 [15:10:14<153:08:05, 1282.06s/it][I 2024-12-17 15:58:05,365] Trial 70 finished with value: 0.7475525723408947 and parameters: {'n_epochs': 2261, 'lr': 4.889624639353741e-06, 'weight_decay': 5.278382848876653e-07, 'batch_size': 32, 'n_genotype': 116, 'n_history': 2, 'n_phenotype': 53, 'n_behaviour': 22}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  14%|█▍        | 71/500 [15:34:22<158:41:42, 1331.71s/it][I 2024-12-17 16:23:10,173] Trial 71 finished with value: 0.7437285841362944 and parameters: {'n_epochs': 2297, 'lr': 5.231817406103776e-06, 'weight_decay': 9.385196728685999e-07, 'batch_size': 32, 'n_genotype': 117, 'n_history': 2, 'n_phenotype': 60, 'n_behaviour': 23}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  14%|█▍        | 72/500 [15:59:27<164:29:56, 1383.64s/it][I 2024-12-17 16:48:05,737] Trial 72 finished with value: 0.7450157085968898 and parameters: {'n_epochs': 2285, 'lr': 4.244633789811858e-06, 'weight_decay': 9.152266469766264e-07, 'batch_size': 32, 'n_genotype': 113, 'n_history': 2, 'n_phenotype': 60, 'n_behaviour': 23}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  15%|█▍        | 73/500 [16:24:22<168:05:50, 1417.21s/it][I 2024-12-17 17:10:51,776] Trial 73 finished with value: 0.7454851458198086 and parameters: {'n_epochs': 2111, 'lr': 4.865899864966135e-06, 'weight_decay': 5.39088686149038e-07, 'batch_size': 32, 'n_genotype': 117, 'n_history': 2, 'n_phenotype': 60, 'n_behaviour': 22}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  15%|█▍        | 74/500 [16:47:08<165:53:13, 1401.86s/it][I 2024-12-17 17:33:56,672] Trial 74 finished with value: 0.733492303182802 and parameters: {'n_epochs': 2106, 'lr': 5.2894359236111805e-06, 'weight_decay': 4.5531010498526663e-07, 'batch_size': 32, 'n_genotype': 115, 'n_history': 1, 'n_phenotype': 60, 'n_behaviour': 29}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  15%|█▌        | 75/500 [17:10:13<164:53:48, 1396.77s/it][I 2024-12-17 17:58:29,003] Trial 75 finished with value: 0.747148405781742 and parameters: {'n_epochs': 2298, 'lr': 4.285658394726854e-06, 'weight_decay': 9.891064075277858e-07, 'batch_size': 32, 'n_genotype': 127, 'n_history': 3, 'n_phenotype': 55, 'n_behaviour': 23}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  15%|█▌        | 76/500 [17:34:46<167:10:42, 1419.44s/it][I 2024-12-17 18:20:04,680] Trial 76 finished with value: 0.7365558668057346 and parameters: {'n_epochs': 1956, 'lr': 1.2895118091449884e-06, 'weight_decay': 2.0695469594812243e-07, 'batch_size': 32, 'n_genotype': 127, 'n_history': 2, 'n_phenotype': 53, 'n_behaviour': 23}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  15%|█▌        | 77/500 [17:56:21<162:25:17, 1382.31s/it][I 2024-12-17 18:43:05,976] Trial 77 finished with value: 0.7315538988813753 and parameters: {'n_epochs': 2065, 'lr': 4.058210181484602e-06, 'weight_decay': 5.829145416845737e-07, 'batch_size': 32, 'n_genotype': 122, 'n_history': 1, 'n_phenotype': 64, 'n_behaviour': 28}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  16%|█▌        | 78/500 [18:19:22<162:00:06, 1382.01s/it][I 2024-12-17 19:06:09,596] Trial 78 finished with value: 0.7415511082460307 and parameters: {'n_epochs': 2174, 'lr': 3.554559625035503e-06, 'weight_decay': 1.57152246816442e-07, 'batch_size': 32, 'n_genotype': 113, 'n_history': 3, 'n_phenotype': 54, 'n_behaviour': 26}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  16%|█▌        | 79/500 [18:42:26<161:40:28, 1382.49s/it][I 2024-12-17 19:30:07,641] Trial 79 finished with value: 0.7423296699104986 and parameters: {'n_epochs': 2362, 'lr': 2.0475070345527366e-06, 'weight_decay': 3.971231029854274e-07, 'batch_size': 32, 'n_genotype': 105, 'n_history': 3, 'n_phenotype': 47, 'n_behaviour': 21}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  16%|█▌        | 80/500 [19:06:24<163:14:05, 1399.16s/it][I 2024-12-17 19:35:46,668] Trial 80 finished with value: 0.7368576067613671 and parameters: {'n_epochs': 2247, 'lr': 4.558206179181827e-06, 'weight_decay': 2.9865240527240916e-07, 'batch_size': 512, 'n_genotype': 120, 'n_history': 2, 'n_phenotype': 60, 'n_behaviour': 21}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  16%|█▌        | 81/500 [19:12:03<125:49:48, 1081.12s/it][I 2024-12-17 20:00:45,361] Trial 81 finished with value: 0.7427452054340213 and parameters: {'n_epochs': 2323, 'lr': 5.328564944976513e-06, 'weight_decay': 9.856427141249245e-07, 'batch_size': 32, 'n_genotype': 116, 'n_history': 2, 'n_phenotype': 61, 'n_behaviour': 22}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  16%|█▋        | 82/500 [19:37:02<140:04:31, 1206.39s/it][I 2024-12-17 20:22:37,766] Trial 82 finished with value: 0.7355399823945652 and parameters: {'n_epochs': 2012, 'lr': 6.409887201680272e-06, 'weight_decay': 8.329697787367907e-07, 'batch_size': 32, 'n_genotype': 124, 'n_history': 2, 'n_phenotype': 55, 'n_behaviour': 25}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  17%|█▋        | 83/500 [19:58:54<143:25:27, 1238.19s/it][I 2024-12-17 20:46:56,276] Trial 83 finished with value: 0.7256388610743496 and parameters: {'n_epochs': 2275, 'lr': 8.53496474262756e-06, 'weight_decay': 1.276684006363386e-06, 'batch_size': 32, 'n_genotype': 104, 'n_history': 1, 'n_phenotype': 58, 'n_behaviour': 31}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  17%|█▋        | 84/500 [20:23:13<150:43:04, 1304.29s/it][I 2024-12-17 21:06:45,190] Trial 84 finished with value: 0.7453153516311823 and parameters: {'n_epochs': 1872, 'lr': 3.2134920113205826e-06, 'weight_decay': 6.553597821975477e-07, 'batch_size': 32, 'n_genotype': 117, 'n_history': 3, 'n_phenotype': 52, 'n_behaviour': 23}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  17%|█▋        | 85/500 [20:43:02<146:21:55, 1269.68s/it][I 2024-12-17 21:26:26,442] Trial 85 finished with value: 0.7433156616412734 and parameters: {'n_epochs': 1884, 'lr': 2.3084177361549725e-06, 'weight_decay': 6.049941254882638e-07, 'batch_size': 32, 'n_genotype': 119, 'n_history': 3, 'n_phenotype': 51, 'n_behaviour': 19}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  17%|█▋        | 86/500 [21:02:43<142:57:43, 1243.15s/it][I 2024-12-17 21:31:45,508] Trial 86 finished with value: 0.735996983064483 and parameters: {'n_epochs': 1743, 'lr': 2.9222074798677017e-06, 'weight_decay': 3.115241281283306e-07, 'batch_size': 256, 'n_genotype': 112, 'n_history': 3, 'n_phenotype': 48, 'n_behaviour': 33}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  17%|█▋        | 87/500 [21:08:02<110:48:46, 965.92s/it] [I 2024-12-17 21:54:52,599] Trial 87 finished with value: 0.7392121156555728 and parameters: {'n_epochs': 2170, 'lr': 1.5587226336143403e-06, 'weight_decay': 1.410822413676222e-06, 'batch_size': 32, 'n_genotype': 124, 'n_history': 2, 'n_phenotype': 55, 'n_behaviour': 27}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  18%|█▊        | 88/500 [21:31:09<125:00:17, 1092.27s/it][I 2024-12-17 22:17:32,966] Trial 88 finished with value: 0.7387710292503544 and parameters: {'n_epochs': 2121, 'lr': 9.14397096168447e-06, 'weight_decay': 7.216771287920017e-07, 'batch_size': 32, 'n_genotype': 106, 'n_history': 4, 'n_phenotype': 63, 'n_behaviour': 24}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  18%|█▊        | 89/500 [21:53:49<133:53:00, 1172.70s/it][I 2024-12-17 22:34:04,585] Trial 89 finished with value: 0.7284348915969867 and parameters: {'n_epochs': 1583, 'lr': 0.000277864996459804, 'weight_decay': 5.025402904056729e-07, 'batch_size': 32, 'n_genotype': 99, 'n_history': 3, 'n_phenotype': 62, 'n_behaviour': 25}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  18%|█▊        | 90/500 [22:10:21<127:22:14, 1118.38s/it][I 2024-12-17 22:53:44,019] Trial 90 finished with value: 0.7389527392146162 and parameters: {'n_epochs': 2033, 'lr': 3.3630845381645587e-06, 'weight_decay': 2.5720446015000184e-07, 'batch_size': 32, 'n_genotype': 64, 'n_history': 1, 'n_phenotype': 58, 'n_behaviour': 19}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  18%|█▊        | 91/500 [22:30:01<129:08:27, 1136.69s/it][I 2024-12-17 23:19:15,756] Trial 91 finished with value: 0.746331461801973 and parameters: {'n_epochs': 2396, 'lr': 4.166015189806689e-06, 'weight_decay': 8.860585490510513e-07, 'batch_size': 32, 'n_genotype': 117, 'n_history': 2, 'n_phenotype': 59, 'n_behaviour': 23}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  18%|█▊        | 92/500 [22:55:32<142:15:24, 1255.21s/it][I 2024-12-17 23:44:50,605] Trial 92 finished with value: 0.7404809910478519 and parameters: {'n_epochs': 2416, 'lr': 4.0793638619883125e-06, 'weight_decay': 8.13949766396089e-07, 'batch_size': 32, 'n_genotype': 113, 'n_history': 2, 'n_phenotype': 56, 'n_behaviour': 22}. Best is trial 70 with value: 0.7475525723408947.
# Optuna Trials:  19%|█▊        | 93/500 [23:21:07<151:23:33, 1339.10s/it][I 2024-12-18 00:08:19,340] Trial 93 finished with value: 0.7484475864221741 and parameters: {'n_epochs': 2210, 'lr': 6.2254561579453456e-06, 'weight_decay': 1.6635294947645884e-06, 'batch_size': 32, 'n_genotype': 127, 'n_history': 2, 'n_phenotype': 53, 'n_behaviour': 20}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  19%|█▉        | 94/500 [23:44:36<153:22:36, 1359.99s/it][I 2024-12-18 00:33:18,700] Trial 94 finished with value: 0.7330438360675764 and parameters: {'n_epochs': 2386, 'lr': 1.2670440332455213e-05, 'weight_decay': 1.5004435725301646e-06, 'batch_size': 32, 'n_genotype': 126, 'n_history': 1, 'n_phenotype': 53, 'n_behaviour': 20}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  19%|█▉        | 95/500 [24:09:35<157:42:09, 1401.80s/it][I 2024-12-18 00:47:07,521] Trial 95 finished with value: 0.7414708526880475 and parameters: {'n_epochs': 2218, 'lr': 6.520740757635885e-06, 'weight_decay': 1.2193630882323922e-06, 'batch_size': 64, 'n_genotype': 119, 'n_history': 2, 'n_phenotype': 49, 'n_behaviour': 16}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  19%|█▉        | 96/500 [24:23:24<138:01:22, 1229.91s/it][I 2024-12-18 01:13:19,002] Trial 96 finished with value: 0.7317444602722607 and parameters: {'n_epochs': 2451, 'lr': 0.0010781255662906989, 'weight_decay': 2.0194884917746686e-06, 'batch_size': 32, 'n_genotype': 123, 'n_history': 3, 'n_phenotype': 45, 'n_behaviour': 29}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  19%|█▉        | 97/500 [24:49:36<149:09:08, 1332.38s/it][I 2024-12-18 01:18:45,976] Trial 97 finished with value: 0.7408837234570876 and parameters: {'n_epochs': 2309, 'lr': 6.164944471467377e-06, 'weight_decay': 3.929458121479675e-07, 'batch_size': 512, 'n_genotype': 118, 'n_history': 2, 'n_phenotype': 52, 'n_behaviour': 20}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  20%|█▉        | 98/500 [24:55:02<115:06:04, 1030.76s/it][I 2024-12-18 01:45:39,232] Trial 98 finished with value: 0.740235461064502 and parameters: {'n_epochs': 2534, 'lr': 4.441928904472657e-06, 'weight_decay': 2.649468277538331e-06, 'batch_size': 32, 'n_genotype': 107, 'n_history': 3, 'n_phenotype': 59, 'n_behaviour': 25}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  20%|█▉        | 99/500 [25:21:56<134:16:48, 1205.51s/it][I 2024-12-18 01:47:28,103] Trial 99 finished with value: 0.7124204195348274 and parameters: {'n_epochs': 572, 'lr': 1.976254769364398e-06, 'weight_decay': 5.799413177891823e-07, 'batch_size': 256, 'n_genotype': 116, 'n_history': 1, 'n_phenotype': 62, 'n_behaviour': 24}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  20%|██        | 100/500 [25:23:45<97:23:26, 876.52s/it] [I 2024-12-18 02:08:54,676] Trial 100 finished with value: 0.7322580738437143 and parameters: {'n_epochs': 1966, 'lr': 9.895718810146575e-06, 'weight_decay': 1.6153748064226738e-07, 'batch_size': 32, 'n_genotype': 112, 'n_history': 11, 'n_phenotype': 54, 'n_behaviour': 27}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  20%|██        | 101/500 [25:45:11<110:46:53, 999.53s/it][I 2024-12-18 02:32:10,937] Trial 101 finished with value: 0.7421606582293618 and parameters: {'n_epochs': 2144, 'lr': 2.5882175177829053e-06, 'weight_decay': 1.0467413661111472e-06, 'batch_size': 32, 'n_genotype': 126, 'n_history': 2, 'n_phenotype': 56, 'n_behaviour': 22}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  20%|██        | 102/500 [26:08:27<123:39:43, 1118.55s/it][I 2024-12-18 02:50:08,101] Trial 102 finished with value: 0.7406436325715107 and parameters: {'n_epochs': 1847, 'lr': 3.759718299478363e-06, 'weight_decay': 7.939684591067374e-07, 'batch_size': 32, 'n_genotype': 101, 'n_history': 2, 'n_phenotype': 33, 'n_behaviour': 17}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  21%|██        | 103/500 [26:26:25<121:58:55, 1106.14s/it][I 2024-12-18 03:12:52,886] Trial 103 finished with value: 0.7175250057397793 and parameters: {'n_epochs': 2242, 'lr': 3.37863502561815e-06, 'weight_decay': 1.6861463391667021e-06, 'batch_size': 32, 'n_genotype': 58, 'n_history': 2, 'n_phenotype': 59, 'n_behaviour': 53}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  21%|██        | 104/500 [26:49:09<130:12:37, 1183.73s/it][I 2024-12-18 03:35:36,198] Trial 104 finished with value: 0.7465986581507912 and parameters: {'n_epochs': 2087, 'lr': 4.908466094641313e-06, 'weight_decay': 3.280440238705922e-06, 'batch_size': 32, 'n_genotype': 122, 'n_history': 3, 'n_phenotype': 57, 'n_behaviour': 23}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  21%|██        | 105/500 [27:11:53<135:47:33, 1237.60s/it][I 2024-12-18 03:57:45,731] Trial 105 finished with value: 0.7420737169273881 and parameters: {'n_epochs': 2055, 'lr': 7.1033487062016765e-06, 'weight_decay': 3.2214836549210105e-06, 'batch_size': 32, 'n_genotype': 122, 'n_history': 4, 'n_phenotype': 50, 'n_behaviour': 23}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  21%|██        | 106/500 [27:34:02<138:28:02, 1265.18s/it][I 2024-12-18 04:22:50,934] Trial 106 finished with value: 0.7467994208558232 and parameters: {'n_epochs': 2346, 'lr': 4.753575663174279e-06, 'weight_decay': 6.180139196739028e-07, 'batch_size': 32, 'n_genotype': 114, 'n_history': 3, 'n_phenotype': 63, 'n_behaviour': 20}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  21%|██▏       | 107/500 [27:59:07<145:58:35, 1337.19s/it][I 2024-12-18 04:44:20,566] Trial 107 finished with value: 0.7428801147928847 and parameters: {'n_epochs': 1984, 'lr': 5.343045914808924e-06, 'weight_decay': 6.366229428554958e-07, 'batch_size': 32, 'n_genotype': 121, 'n_history': 3, 'n_phenotype': 63, 'n_behaviour': 15}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  22%|██▏       | 108/500 [28:20:37<144:03:05, 1322.92s/it][I 2024-12-18 05:09:24,591] Trial 108 finished with value: 0.7098426303013387 and parameters: {'n_epochs': 2344, 'lr': 7.870257629978378e-06, 'weight_decay': 4.385425488641751e-07, 'batch_size': 32, 'n_genotype': 116, 'n_history': 4, 'n_phenotype': 31, 'n_behaviour': 49}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  22%|██▏       | 109/500 [28:45:41<149:35:05, 1377.25s/it][I 2024-12-18 05:33:43,422] Trial 109 finished with value: 0.7408785447976803 and parameters: {'n_epochs': 2206, 'lr': 1.989256840011481e-05, 'weight_decay': 4.078011014279069e-06, 'batch_size': 32, 'n_genotype': 127, 'n_history': 3, 'n_phenotype': 64, 'n_behaviour': 20}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  22%|██▏       | 110/500 [29:10:00<151:51:13, 1401.73s/it][I 2024-12-18 05:49:05,944] Trial 110 finished with value: 0.7377128976821308 and parameters: {'n_epochs': 2474, 'lr': 1.1851619409225065e-05, 'weight_decay': 2.1618672683212087e-06, 'batch_size': 64, 'n_genotype': 118, 'n_history': 3, 'n_phenotype': 41, 'n_behaviour': 26}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  22%|██▏       | 111/500 [29:25:22<135:55:48, 1257.97s/it][I 2024-12-18 06:13:02,964] Trial 111 finished with value: 0.746825792302198 and parameters: {'n_epochs': 2273, 'lr': 4.565971712294551e-06, 'weight_decay': 1.1891409715303898e-06, 'batch_size': 32, 'n_genotype': 114, 'n_history': 2, 'n_phenotype': 61, 'n_behaviour': 18}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  22%|██▏       | 112/500 [29:49:19<141:22:12, 1311.68s/it][I 2024-12-18 06:38:06,826] Trial 112 finished with value: 0.7447774240863799 and parameters: {'n_epochs': 2406, 'lr': 4.621127137313862e-06, 'weight_decay': 1.21530500263241e-06, 'batch_size': 32, 'n_genotype': 107, 'n_history': 3, 'n_phenotype': 62, 'n_behaviour': 18}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  23%|██▎       | 113/500 [30:14:23<147:12:12, 1369.34s/it][I 2024-12-18 07:00:15,341] Trial 113 finished with value: 0.7416085937800456 and parameters: {'n_epochs': 2132, 'lr': 5.824445149888001e-06, 'weight_decay': 1.50125411767085e-06, 'batch_size': 32, 'n_genotype': 114, 'n_history': 2, 'n_phenotype': 56, 'n_behaviour': 13}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  23%|██▎       | 114/500 [30:36:32<145:30:36, 1357.09s/it][I 2024-12-18 07:24:26,577] Trial 114 finished with value: 0.742868031684854 and parameters: {'n_epochs': 2273, 'lr': 2.550774048091777e-06, 'weight_decay': 3.31742098943323e-07, 'batch_size': 32, 'n_genotype': 124, 'n_history': 3, 'n_phenotype': 58, 'n_behaviour': 19}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  23%|██▎       | 115/500 [31:00:43<148:09:13, 1385.33s/it][I 2024-12-18 07:44:55,911] Trial 115 finished with value: 0.7437673942223565 and parameters: {'n_epochs': 2203, 'lr': 9.079815948842653e-06, 'weight_decay': 2.784006803080661e-06, 'batch_size': 32, 'n_genotype': 69, 'n_history': 2, 'n_phenotype': 37, 'n_behaviour': 17}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  23%|██▎       | 116/500 [31:21:12<142:46:36, 1338.53s/it][I 2024-12-18 08:05:00,189] Trial 116 finished with value: 0.7386295432514018 and parameters: {'n_epochs': 1884, 'lr': 4.926268336782077e-06, 'weight_decay': 4.945798258218511e-07, 'batch_size': 32, 'n_genotype': 110, 'n_history': 1, 'n_phenotype': 61, 'n_behaviour': 21}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  23%|██▎       | 117/500 [31:41:17<138:07:12, 1298.26s/it][I 2024-12-18 08:30:12,687] Trial 117 finished with value: 0.7405364005273936 and parameters: {'n_epochs': 2341, 'lr': 3.586625968217128e-06, 'weight_decay': 7.059527528543787e-07, 'batch_size': 32, 'n_genotype': 121, 'n_history': 2, 'n_phenotype': 54, 'n_behaviour': 24}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  24%|██▎       | 118/500 [32:06:29<144:34:46, 1362.53s/it][I 2024-12-18 08:50:56,983] Trial 118 finished with value: 0.746158483727 and parameters: {'n_epochs': 2084, 'lr': 6.9826602418070066e-06, 'weight_decay': 5.0198277470871145e-06, 'batch_size': 32, 'n_genotype': 119, 'n_history': 3, 'n_phenotype': 25, 'n_behaviour': 18}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  24%|██▍       | 119/500 [32:27:14<140:26:49, 1327.06s/it][I 2024-12-18 08:55:28,421] Trial 119 finished with value: 0.7452491346053425 and parameters: {'n_epochs': 2070, 'lr': 1.4531929764271401e-05, 'weight_decay': 5.6772717438262674e-06, 'batch_size': 512, 'n_genotype': 111, 'n_history': 4, 'n_phenotype': 27, 'n_behaviour': 16}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  24%|██▍       | 120/500 [32:31:45<106:39:01, 1010.37s/it][I 2024-12-18 09:18:21,550] Trial 120 finished with value: 0.7417419977435484 and parameters: {'n_epochs': 2514, 'lr': 7.23238134633685e-06, 'weight_decay': 1.908530287020137e-06, 'batch_size': 32, 'n_genotype': 60, 'n_history': 2, 'n_phenotype': 29, 'n_behaviour': 20}. Best is trial 93 with value: 0.7484475864221741.
# Optuna Trials:  24%|██▍       | 121/500 [32:54:38<117:49:36, 1119.20s/it][I 2024-12-18 09:40:12,145] Trial 121 finished with value: 0.7447836405246087 and parameters: {'n_epochs': 2153, 'lr': 6.0172295320068395e-06, 'weight_decay': 9.919377966345976e-07, 'batch_size': 32, 'n_genotype': 119, 'n_history': 3, 'n_phenotype': 25, 'n_behaviour': 22}. Best is trial 93 with value: 0.7484475864221741.
# ...
# Optuna Trials:  68%|██████▊   | 342/500 [69:32:19<18:59:17, 432.64s/it][I 2024-12-19 22:03:19,879] Trial 342 finished with value: 0.7368872877921169 and parameters: {'n_epochs': 2027, 'lr': 5.294111109772195e-06, 'weight_decay': 1.560946933828757e-06, 'batch_size': 64, 'n_genotype': 127, 'n_history': 10, 'n_phenotype': 48, 'n_behaviour': 22}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  69%|██████▊   | 343/500 [69:39:36<18:55:44, 434.04s/it][I 2024-12-19 22:10:41,110] Trial 343 finished with value: 0.7482638437270281 and parameters: {'n_epochs': 2109, 'lr': 1.9253760891332864e-05, 'weight_decay': 1.8502614949704712e-08, 'batch_size': 64, 'n_genotype': 122, 'n_history': 3, 'n_phenotype': 43, 'n_behaviour': 19}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  69%|██████▉   | 344/500 [69:46:58<18:54:07, 436.20s/it][I 2024-12-19 22:18:33,660] Trial 344 finished with value: 0.7476113569863914 and parameters: {'n_epochs': 2255, 'lr': 1.5105635055928456e-05, 'weight_decay': 3.0217544046819668e-06, 'batch_size': 64, 'n_genotype': 124, 'n_history': 5, 'n_phenotype': 46, 'n_behaviour': 17}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  69%|██████▉   | 345/500 [69:54:50<19:15:01, 447.10s/it][I 2024-12-19 22:23:40,407] Trial 345 finished with value: 0.7459974465672685 and parameters: {'n_epochs': 2195, 'lr': 6.565488615777737e-06, 'weight_decay': 2.272313843651615e-06, 'batch_size': 128, 'n_genotype': 119, 'n_history': 3, 'n_phenotype': 45, 'n_behaviour': 21}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  69%|██████▉   | 346/500 [69:59:57<17:19:29, 405.00s/it][I 2024-12-19 22:31:54,749] Trial 346 finished with value: 0.7513029017989051 and parameters: {'n_epochs': 2145, 'lr': 0.002070293921476609, 'weight_decay': 4.3465264229700375e-06, 'batch_size': 64, 'n_genotype': 127, 'n_history': 3, 'n_phenotype': 48, 'n_behaviour': 19}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  69%|██████▉   | 347/500 [70:08:11<18:21:05, 431.80s/it][I 2024-12-19 22:34:55,711] Trial 347 finished with value: 0.738243303814627 and parameters: {'n_epochs': 2072, 'lr': 8.104935506602265e-05, 'weight_decay': 4.831189706821934e-06, 'batch_size': 256, 'n_genotype': 122, 'n_history': 3, 'n_phenotype': 4, 'n_behaviour': 20}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  70%|██████▉   | 348/500 [70:11:12<15:03:15, 356.55s/it][I 2024-12-19 22:42:11,924] Trial 348 finished with value: 0.7389298466723326 and parameters: {'n_epochs': 2128, 'lr': 0.00013344145072370032, 'weight_decay': 3.4460304769405786e-06, 'batch_size': 64, 'n_genotype': 124, 'n_history': 3, 'n_phenotype': 49, 'n_behaviour': 18}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  70%|██████▉   | 349/500 [70:18:28<15:57:27, 380.45s/it][I 2024-12-19 22:50:34,238] Trial 349 finished with value: 0.6986671976707839 and parameters: {'n_epochs': 2293, 'lr': 0.000602638785961305, 'weight_decay': 5.858906401212281e-06, 'batch_size': 64, 'n_genotype': 127, 'n_history': 3, 'n_phenotype': 51, 'n_behaviour': 42}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  70%|███████   | 350/500 [70:26:51<17:22:31, 417.01s/it][I 2024-12-19 22:58:13,605] Trial 350 finished with value: 0.7305603600024922 and parameters: {'n_epochs': 2231, 'lr': 1.2770525768034732e-05, 'weight_decay': 3.833052760056335e-06, 'batch_size': 64, 'n_genotype': 120, 'n_history': 8, 'n_phenotype': 48, 'n_behaviour': 15}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  70%|███████   | 351/500 [70:34:30<17:47:07, 429.72s/it][I 2024-12-19 23:05:32,891] Trial 351 finished with value: 0.7323201698621749 and parameters: {'n_epochs': 2195, 'lr': 4.109619776498673e-05, 'weight_decay': 4.687512896233509e-06, 'batch_size': 64, 'n_genotype': 125, 'n_history': 3, 'n_phenotype': 47, 'n_behaviour': 21}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  70%|███████   | 352/500 [70:41:49<17:47:02, 432.59s/it][I 2024-12-19 23:12:42,817] Trial 352 finished with value: 0.7463739322344978 and parameters: {'n_epochs': 2136, 'lr': 1.0040215957537193e-05, 'weight_decay': 2.723731186177105e-06, 'batch_size': 64, 'n_genotype': 123, 'n_history': 3, 'n_phenotype': 41, 'n_behaviour': 19}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  71%|███████   | 353/500 [70:48:59<17:37:52, 431.79s/it][I 2024-12-19 23:19:31,431] Trial 353 finished with value: 0.7426254013016378 and parameters: {'n_epochs': 2054, 'lr': 4.372583425655571e-06, 'weight_decay': 1.926091426951757e-06, 'batch_size': 64, 'n_genotype': 127, 'n_history': 3, 'n_phenotype': 49, 'n_behaviour': 17}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  71%|███████   | 354/500 [70:55:48<17:13:46, 424.84s/it][I 2024-12-19 23:27:28,206] Trial 354 finished with value: 0.7320700971620123 and parameters: {'n_epochs': 2262, 'lr': 0.0002540964119143962, 'weight_decay': 1.1134354005723902e-06, 'batch_size': 64, 'n_genotype': 121, 'n_history': 3, 'n_phenotype': 50, 'n_behaviour': 20}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  71%|███████   | 355/500 [71:03:45<17:44:20, 440.42s/it][I 2024-12-19 23:34:39,339] Trial 355 finished with value: 0.746893022861548 and parameters: {'n_epochs': 2099, 'lr': 5.555016830154877e-06, 'weight_decay': 2.1791243183166217e-06, 'batch_size': 64, 'n_genotype': 125, 'n_history': 6, 'n_phenotype': 44, 'n_behaviour': 22}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  71%|███████   | 356/500 [71:10:56<17:30:19, 437.63s/it][I 2024-12-19 23:42:17,319] Trial 356 finished with value: 0.7488769131557905 and parameters: {'n_epochs': 2329, 'lr': 8.502773087312812e-06, 'weight_decay': 8.737803890397713e-07, 'batch_size': 64, 'n_genotype': 117, 'n_history': 3, 'n_phenotype': 47, 'n_behaviour': 19}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  71%|███████▏  | 357/500 [71:18:34<17:37:34, 443.74s/it][I 2024-12-19 23:49:39,866] Trial 357 finished with value: 0.7146085214296518 and parameters: {'n_epochs': 2184, 'lr': 0.0012937338649078598, 'weight_decay': 1.6980842336796361e-06, 'batch_size': 64, 'n_genotype': 123, 'n_history': 11, 'n_phenotype': 48, 'n_behaviour': 18}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  72%|███████▏  | 358/500 [71:25:56<17:29:19, 443.38s/it][I 2024-12-19 23:56:38,765] Trial 358 finished with value: 0.7454105001698046 and parameters: {'n_epochs': 1989, 'lr': 1.1489977026496634e-05, 'weight_decay': 3.977295545886603e-06, 'batch_size': 64, 'n_genotype': 125, 'n_history': 3, 'n_phenotype': 46, 'n_behaviour': 23}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  72%|███████▏  | 359/500 [71:32:55<17:04:41, 436.04s/it][I 2024-12-20 00:04:15,704] Trial 359 finished with value: 0.7482846764115012 and parameters: {'n_epochs': 2229, 'lr': 6.733311966550345e-06, 'weight_decay': 2.8713875624463725e-06, 'batch_size': 64, 'n_genotype': 127, 'n_history': 4, 'n_phenotype': 44, 'n_behaviour': 20}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  72%|███████▏  | 360/500 [71:40:32<17:12:02, 442.31s/it][I 2024-12-20 00:11:26,451] Trial 360 finished with value: 0.7295232255695219 and parameters: {'n_epochs': 2153, 'lr': 0.0003704224630410283, 'weight_decay': 1.2648818951029637e-06, 'batch_size': 64, 'n_genotype': 121, 'n_history': 3, 'n_phenotype': 42, 'n_behaviour': 16}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  72%|███████▏  | 361/500 [71:47:43<16:56:38, 438.84s/it][I 2024-12-20 00:17:43,470] Trial 361 finished with value: 0.738718730026931 and parameters: {'n_epochs': 2276, 'lr': 9.35514989365791e-06, 'weight_decay': 1.5317792519738925e-06, 'batch_size': 64, 'n_genotype': 18, 'n_history': 3, 'n_phenotype': 45, 'n_behaviour': 21}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  72%|███████▏  | 362/500 [71:54:00<16:06:40, 420.29s/it][I 2024-12-20 00:20:41,489] Trial 362 finished with value: 0.7020924401306551 and parameters: {'n_epochs': 2103, 'lr': 0.0015595641484629338, 'weight_decay': 2.223639022605383e-06, 'batch_size': 512, 'n_genotype': 124, 'n_history': 9, 'n_phenotype': 49, 'n_behaviour': 19}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  73%|███████▎  | 363/500 [71:56:58<13:13:42, 347.61s/it][I 2024-12-20 00:28:15,082] Trial 363 finished with value: 0.7376255515629488 and parameters: {'n_epochs': 2205, 'lr': 0.0001679763762607827, 'weight_decay': 0.00020191584240094308, 'batch_size': 64, 'n_genotype': 119, 'n_history': 3, 'n_phenotype': 47, 'n_behaviour': 18}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  73%|███████▎  | 364/500 [72:04:32<14:19:59, 379.41s/it][I 2024-12-20 00:35:43,091] Trial 364 finished with value: 0.7313264453675469 and parameters: {'n_epochs': 2156, 'lr': 0.0037921595274269726, 'weight_decay': 6.212753715429464e-07, 'batch_size': 64, 'n_genotype': 127, 'n_history': 3, 'n_phenotype': 46, 'n_behaviour': 32}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  73%|███████▎  | 365/500 [72:12:00<14:59:58, 399.99s/it][I 2024-12-20 00:43:39,595] Trial 365 finished with value: 0.7447818982406313 and parameters: {'n_epochs': 2374, 'lr': 0.0029337796943379483, 'weight_decay': 1.0315499475979407e-06, 'batch_size': 64, 'n_genotype': 122, 'n_history': 3, 'n_phenotype': 48, 'n_behaviour': 17}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  73%|███████▎  | 366/500 [72:19:56<15:44:34, 422.94s/it][I 2024-12-20 00:51:12,492] Trial 366 finished with value: 0.7451219049488718 and parameters: {'n_epochs': 2238, 'lr': 1.5723438926170155e-05, 'weight_decay': 1.8698693332238887e-06, 'batch_size': 64, 'n_genotype': 125, 'n_history': 4, 'n_phenotype': 43, 'n_behaviour': 20}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  73%|███████▎  | 367/500 [72:27:29<15:57:26, 431.93s/it][I 2024-12-20 00:58:17,837] Trial 367 finished with value: 0.7451503860354384 and parameters: {'n_epochs': 2043, 'lr': 4.815240166452987e-06, 'weight_decay': 1.1899959126624658e-06, 'batch_size': 64, 'n_genotype': 123, 'n_history': 3, 'n_phenotype': 51, 'n_behaviour': 21}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  74%|███████▎  | 368/500 [72:34:34<15:45:53, 429.95s/it][I 2024-12-20 01:06:07,553] Trial 368 finished with value: 0.7462224696873591 and parameters: {'n_epochs': 2304, 'lr': 3.836577032963891e-06, 'weight_decay': 2.5638178837630468e-06, 'batch_size': 64, 'n_genotype': 127, 'n_history': 3, 'n_phenotype': 47, 'n_behaviour': 18}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  74%|███████▍  | 369/500 [72:42:24<16:04:46, 441.88s/it][I 2024-12-20 01:13:10,593] Trial 369 finished with value: 0.7426906064831899 and parameters: {'n_epochs': 2182, 'lr': 0.0019936732357940896, 'weight_decay': 9.343722830213077e-08, 'batch_size': 64, 'n_genotype': 118, 'n_history': 3, 'n_phenotype': 44, 'n_behaviour': 19}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  74%|███████▍  | 370/500 [72:49:27<15:45:09, 436.23s/it][I 2024-12-20 01:20:27,391] Trial 370 finished with value: 0.7480078113504594 and parameters: {'n_epochs': 2114, 'lr': 7.696057183565726e-06, 'weight_decay': 1.466337845490504e-06, 'batch_size': 64, 'n_genotype': 124, 'n_history': 5, 'n_phenotype': 50, 'n_behaviour': 22}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  74%|███████▍  | 371/500 [72:56:44<15:38:15, 436.40s/it][I 2024-12-20 01:27:58,325] Trial 371 finished with value: 0.7493073045964229 and parameters: {'n_epochs': 2225, 'lr': 6.642150791197026e-06, 'weight_decay': 8.644691787915182e-07, 'batch_size': 64, 'n_genotype': 121, 'n_history': 3, 'n_phenotype': 45, 'n_behaviour': 20}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  74%|███████▍  | 372/500 [73:04:15<15:40:17, 440.76s/it][I 2024-12-20 01:36:11,603] Trial 372 finished with value: 0.7389401765661227 and parameters: {'n_epochs': 2268, 'lr': 1.012954790146179e-05, 'weight_decay': 5.118472850677042e-07, 'batch_size': 64, 'n_genotype': 115, 'n_history': 4, 'n_phenotype': 45, 'n_behaviour': 24}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  75%|███████▍  | 373/500 [73:12:28<16:06:17, 456.52s/it][I 2024-12-20 01:39:53,814] Trial 373 finished with value: 0.7473695115948154 and parameters: {'n_epochs': 2222, 'lr': 6.853823636958621e-06, 'weight_decay': 7.43430147241468e-07, 'batch_size': 256, 'n_genotype': 120, 'n_history': 3, 'n_phenotype': 42, 'n_behaviour': 20}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  75%|███████▍  | 374/500 [73:16:10<13:31:04, 386.22s/it][I 2024-12-20 01:46:23,868] Trial 374 finished with value: 0.7431659268706716 and parameters: {'n_epochs': 2321, 'lr': 1.1987364508290092e-05, 'weight_decay': 7.597791263205575e-07, 'batch_size': 128, 'n_genotype': 121, 'n_history': 3, 'n_phenotype': 44, 'n_behaviour': 21}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  75%|███████▌  | 375/500 [73:22:40<13:27:01, 387.37s/it][I 2024-12-20 01:54:53,465] Trial 375 finished with value: 0.7501423276292304 and parameters: {'n_epochs': 2200, 'lr': 8.527564612002176e-06, 'weight_decay': 9.266945112724656e-07, 'batch_size': 64, 'n_genotype': 117, 'n_history': 3, 'n_phenotype': 46, 'n_behaviour': 20}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  75%|███████▌  | 376/500 [73:31:10<14:36:20, 424.04s/it][I 2024-12-20 02:02:34,285] Trial 376 finished with value: 0.7412047515516165 and parameters: {'n_epochs': 2251, 'lr': 0.0008054638694106044, 'weight_decay': 5.589931263370474e-07, 'batch_size': 64, 'n_genotype': 117, 'n_history': 3, 'n_phenotype': 46, 'n_behaviour': 23}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  75%|███████▌  | 377/500 [73:38:51<14:51:54, 435.07s/it][I 2024-12-20 02:09:44,685] Trial 377 finished with value: 0.7451313838719775 and parameters: {'n_epochs': 2167, 'lr': 8.674386093106396e-06, 'weight_decay': 8.366713594056486e-07, 'batch_size': 64, 'n_genotype': 118, 'n_history': 6, 'n_phenotype': 48, 'n_behaviour': 22}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  76%|███████▌  | 378/500 [73:46:01<14:41:47, 433.67s/it][I 2024-12-20 02:16:43,524] Trial 378 finished with value: 0.7422266182946471 and parameters: {'n_epochs': 2083, 'lr': 7.602974597933035e-06, 'weight_decay': 9.373292225262089e-07, 'batch_size': 64, 'n_genotype': 121, 'n_history': 3, 'n_phenotype': 46, 'n_behaviour': 21}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  76%|███████▌  | 379/500 [73:53:00<14:25:35, 429.22s/it][I 2024-12-20 02:24:08,116] Trial 379 finished with value: 0.7460790747675958 and parameters: {'n_epochs': 2204, 'lr': 9.797873796372956e-06, 'weight_decay': 4.4797050281292497e-07, 'batch_size': 64, 'n_genotype': 120, 'n_history': 4, 'n_phenotype': 45, 'n_behaviour': 20}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  76%|███████▌  | 380/500 [74:00:25<14:27:39, 433.83s/it][I 2024-12-20 02:30:09,443] Trial 380 finished with value: 0.7446221608879438 and parameters: {'n_epochs': 1772, 'lr': 6.193864570115906e-06, 'weight_decay': 1.0086156875778698e-06, 'batch_size': 64, 'n_genotype': 123, 'n_history': 3, 'n_phenotype': 49, 'n_behaviour': 16}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  76%|███████▌  | 381/500 [74:06:26<13:37:17, 412.08s/it][I 2024-12-20 02:36:28,778] Trial 381 finished with value: 0.7499169750113829 and parameters: {'n_epochs': 1933, 'lr': 8.411098275431087e-06, 'weight_decay': 7.016371976086997e-07, 'batch_size': 64, 'n_genotype': 116, 'n_history': 3, 'n_phenotype': 46, 'n_behaviour': 18}. Best is trial 195 with value: 0.7532256092485068.
# Optuna Trials:  76%|███████▋  | 382/500 [74:12:45<13:11:06, 402.26s/it]

# %%
    trial = study.best_trial

    print("  Value (Mean AUC): ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

    # Extract additional metrics from the best trial
    best_trial_metrics = trial.user_attrs
    mean_auc = best_trial_metrics.get("mean_auc", None)
    std_auc = best_trial_metrics.get("std_auc", None)
    mean_f1 = best_trial_metrics.get("mean_f1", None)
    std_f1 = best_trial_metrics.get("std_f1", None)
    mean_accuracy = best_trial_metrics.get("mean_accuracy", None)
    std_accuracy = best_trial_metrics.get("std_accuracy", None)
    mean_precision = best_trial_metrics.get("mean_precision", None)
    std_precision = best_trial_metrics.get("std_precision", None)
    selected_features = best_trial_metrics.get("selected_features", None)

    print(f"\nBest Trial Metrics:")
    print(f"Selected Features: {selected_features}")
    print(f"Average AUC: {mean_auc:.4f} ± {std_auc:.4f}")
    print(f"Average F1 Score: {mean_f1:.4f} ± {std_f1:.4f}")
    print(f"Average Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}")
    print(f"Average Precision: {mean_precision:.4f} ± {std_precision:.4f}")
# Out:
#   Value (Mean AUC):  0.7532256092485068
#   Params:
#     n_epochs: 2059
#     lr: 1.185885489910591e-05
#     weight_decay: 9.916744984817729e-07
#     batch_size: 64
#     n_genotype: 125
#     n_history: 3
#     n_phenotype: 44
#     n_behaviour: 20
#
# Best Trial Metrics:
# Selected Features: ['rs591058', 'rs1800797', 'rs13946', 'rs25487', 'rs2228570', 'rs12722', 'rs2104772', 'rs1144393', 'rs3196378', 'rs1544410', 'rs2237352', 'rs1137101', 'rs10263021', 'rs4454832', 'rs7528684', 'rs2234693', 'rs10132091', 'rs7035322', 'rs1330363', 'rs1011814', 'rs1249269', 'rs4725069', 'rs820218', 'rs62051384', 'rs11232681', 'rs4701616', 'rs1800629', 'rs11177', 'rs143383', 'rs6617', 'rs6481512', 'rs17756404', 'rs4986938', 'rs13317', 'rs4730153', 'rs911263', 'rs970547', 'rs11225395', 'rs3018362', 'rs11629171', 'rs10992075', 'rs4789932', 'rs2252070', 'rs3789870', 'rs1590', 'rs42531', 'rs11154027', 'rs10759753', 'rs2761884', 'rs4362400', 'rs3219008', 'rs3218791', 'rs17576', 'rs2289360', 'rs1134170', 'rs2525504', 'rs4919510', 'rs1937810', 'rs1718119', 'rs10484958', 'rs2285053', 'class12_SNP_risk_score', 'rs1800972', 'rs4328262', 'rs1800469', 'rs2306033', 'rs9340799', 'rs17583842', 'rs4244032', 'rs1643821', 'rs1800470', 'rs3045', 'rs4903399', 'rs3753841', 'rs2277698', 'rs1800012', 'rs12656106', 'rs187483', 'class1_SNP_risk_score', 'rs2281518', 'sex', 'class123_SNP_risk_score', 'rs1045485', 'rs1554606', 'rs78391032', 'rs2305948', 'rs4654760', 'rs1887632', 'rs1800795', 'rs1021188', 'rs72758637', 'rs12154667', 'rs1138545', 'rs3751143', 'rs1676303', 'rs7021589', 'rs12574452', 'rs13107325', 'rs1548456', 'rs2277268', 'rs912336', 'rs35360670', 'rs420257', 'rs74544784', 'rs60713544', 'rs12429486', 'rs42517', 'rs2010963', 'rs71404070', 'rs117544024', 'rs2586488', 'rs25489', 'rs413826', 'rs650108', 'rs57104447', 'rs42522', 'rs710079', 'rs761804508', 'rs145648292', 'rs77569527', 'rs144371252', 'rs4988321', 'rs149047058', 'rs144414988', 'rs2858056', 'Age', 'tracking_period_injury', 'Athlete_Score', 'Q_angle', 'hip_abduction_peak_torque_asymmetry', 'total_ad_ab_ratio', 'Step_frequency_10', 'thigh_ffmi', 'hip_adduction_peak_torque_asymmetry', 'BMD_hip', 'calf_size', 'Flight_time_12', 'total_fl_ex_ratio', 'navicular_drop', 'Step_frequency_12', 'knee_extension_peak_angle_asymmetry', 'VALR_10', 'VALR_12', 'Q_angle_asymmetry', 'VILR_12', 'VILR_10', 'hip_adduction_peak_torque', 'thigh_lean_mass', 'total_lean_mass', 'leg_ffmi', 'BMD_spine', 'knee_flexion_peak_torque', 'total_ffmi', 'Flight_time_10', 'knee_extension_peak_torque', 'knee_flexion_peak_torque_asymmetry', 'leg_lean_mass', 'hip_abduction_peak_torque', 'VALR_asymmetry_12', 'knee_flexion_peak_angle_asymmetry', 'Impact_peak_12', 'VILR_asymmetry_12', 'BMD_body', 'BMI', 'knee_flexion_peak_angle', 'hip_adduction_peak_angle', 'Duty_factor_10', 'knee_extension_peak_torque_asymmetry', 'lower_leg_lean_mass', 'Duty_factor_asymmetry_12', 'Duty_factor_asymmetry_10', 'Impact_peak_10', 'fat_intake_BW', 'fat_percentage_avg', 'fat_intake_avg', 'glycine_intake_BW', 'arginine_intake_BW', 'calcium_intake_BW', 'average_energy_availability', 'protein_intake_BW', 'SC_past_season', 'SC_past_month', 'vitaminD_intake_BW', 'resistance_training_past_season', 'past_month_volume_low', 'copper_intake_BW', 'past_month_distance', 'drills_past_season', 'non_running_past_season', 'past_month_min', 'bodyweight_exercises_past_season', 'non_running_past_month']
# Average AUC: 0.7532 ± 0.0225
# Average F1 Score: 0.2214 ± 0.0522
# Average Accuracy: 0.9073 ± 0.0063
# Average Precision: 0.4877 ± 0.1276

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score, precision_score
from imblearn.over_sampling import RandomOverSampler, ADASYN, SMOTE
import optuna
from joblib import Parallel, delayed
from tqdm import tqdm
import random
import warnings
from optuna.exceptions import TrialPruned

import os

# Limit each parallel process to one thread per library
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'
os.environ['NUMEXPR_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['VECLIB_MAXIMUM_THREADS'] = '1'
os.environ['TORCH_NUM_THREADS'] = '1'  # For PyTorch

# Additional control for PyTorch if needed
import torch
torch.set_num_threads(1)

# # For reproducibility
# def set_seed(seed=42):
#     random.seed(seed)
#     np.random.seed(seed)
#     torch.manual_seed(seed)

# set_seed()

# Suppress warnings for cleaner output
warnings.filterwarnings("ignore")

# Load the dataset
data = pd.read_excel("class123_dataset.xlsx")

# Define feature groups (as provided)
feature_groups = {
    'Genotype': [
        'rs11225395', 'rs1144393', 'rs650108', 'rs591058', 'rs2252070', 'rs4986938', 'rs1800012', 'rs4789932', 'rs9340799', 'rs970547', 
        'rs1800795', 'rs13946', 'rs12722', 'class1_SNP_risk_score', 'rs7528684', 'rs4919510', 'rs1937810', 'rs6481512', 'rs1249269', 
        'rs12574452', 'rs12429486', 'rs4454832', 'rs2761884', 'rs62051384', 'rs4362400', 'rs2586488', 'rs2277698', 'rs1045485', 
        'rs143383', 'rs17576', 'rs2305948', 'rs1011814', 'rs11154027', 'rs2234693', 'rs1643821', 'rs2010963', 'rs10263021', 'rs149047058', 
        'rs420257', 'rs42517', 'rs42522', 'rs42531', 'rs413826', 'rs2104772', 'rs1330363', 'class12_SNP_risk_score', 'rs3753841', 
        'rs57104447', 'rs1887632', 'rs4654760', 'rs1137101', 'rs2306033', 'rs2277268', 'rs4988321', 'rs11232681', 'rs1718119', 'rs3751143', 
        'rs1544410', 'rs2228570', 'rs4328262', 'rs1021188', 'rs74544784', 'rs78391032', 'rs77569527', 'rs117544024', 'rs912336', 
        'rs3218791', 'rs911263', 'rs2525504', 'rs17756404', 'rs4903399', 'rs10132091', 'rs17583842', 'rs1676303', 'rs11629171', 
        'rs2281518', 'rs2285053', 'rs71404070', 'rs710079', 'rs2858056', 'rs820218', 'rs3018362', 'rs1800470', 'rs1800469', 'rs25487', 
        'rs25489', 'rs2289360', 'rs183364169', 'rs11177', 'rs6617', 'rs3219008', 'rs13107325', 'rs60713544', 'rs145648292', 'rs4244032', 
        'rs12656106', 'rs3045', 'rs187483', 'rs4701616', 'rs144414988', 'rs1800629', 'rs10484958', 'rs4730153', 'rs1800797', 'rs1554606', 
        'rs2237352', 'rs4725069', 'rs12154667', 'rs1548456', 'rs3216902', 'rs35360670', 'rs13317', 'rs1800972', 'rs7035322', 'rs7021589', 
        'rs72758637', 'rs10759753', 'rs3789870', 'rs1138545', 'rs3196378', 'rs1134170', 'rs10992075', 'rs1590', 'rs144371252', 
        'rs761804508', 'class123_SNP_risk_score', 'sex'
    ],
    'History': [
        'Age', 'lower_limb_days_total', 'average_run_hours', 'average_interval_training_frequency', 'EDEQ_total', 'tracking_period_injury',
        'past_stress_injury', 'LEAF-Q', 'Athlete_Score', 'average_run_frequency', 'past_month_injury'
    ],
    'Phenotype': [
        'hip_abduction_peak_torque', 'total_ad_ab_ratio', 'knee_extension_peak_torque', 'knee_flexion_peak_torque', 'navicular_drop', 
        'navicular_drop_asymmetry', 'Q_angle', 'Q_angle_asymmetry', 'VALR_12', 'Impact_peak_12', 'Duty_factor_12', 'BMI', 'BMD_spine',
        'hip_abduction_peak_torque_asymmetry', 'hip_adduction_peak_torque', 'hip_adduction_peak_torque_asymmetry', 
        'knee_extension_peak_torque_asymmetry', 'knee_flexion_peak_torque_asymmetry', 'total_fl_ex_ratio', 'leg_lean_mass', 
        'hip_abduction_peak_angle', 'hip_abduction_peak_angle_asymmetry', 'hip_adduction_peak_angle', 'hip_adduction_peak_angle_asymmetry', 
        'ad_ab_ratio_asymmetry', 'knee_extension_peak_angle', 'knee_extension_peak_angle_asymmetry', 'knee_flexion_peak_angle', 
        'knee_flexion_peak_angle_asymmetry', 'fl_ex_ratio_asymmetry', 'VILR_10', 'VALR_10', 'VILR_asymmetry_10', 'VALR_asymmetry_10', 
        'Impact_peak_10', 'Impact_peak_asymmetry_10', 'Flight_time_10', 'Contact_time_10', 'Duty_factor_10', 'Step_frequency_10', 
        'Cadence_asymmetry_10', 'Duty_factor_asymmetry_10', 'VILR_12', 'VILR_asymmetry_12', 'VALR_asymmetry_12', 
        'Impact_peak_asymmetry_12', 'Flight_time_12', 'Contact_time_12', 'Step_frequency_12', 'Cadence_asymmetry_12', 
        'Duty_factor_asymmetry_12', 'Alt_strike', 'height', 'Mass', 'thigh_lean_mass', 'thigh_ffmi', 'lower_leg_lean_mass', 
        'lower_leg_ffmi', 'leg_ffmi', 'total_lean_mass', 'total_ffmi', 'calf_size', 'BMD_hip', 'BMD_body',
    ],
    'Behaviour': [
        'fat_intake_avg', 'past_month_distance', 'past_month_ratio', 'SC_past_season', 'non_running_past_season', 'fat_intake_BW', 
        'fat_percentage_avg', 'average_energy_availability', 'protein_intake_BW', 'omega3_intake_BW', 'vitaminD_intake_BW', 
        'vitaminC_intake_BW', 'vitaminE_intake_BW', 'calcium_intake_BW', 'copper_intake_BW', 'iron_intake_BW', 'glycine_intake_BW', 
        'arginine_intake_BW', 'past_month_min', 'past_week_ratio', 'past_month_volume_low', 'past_week_ratio_low', 'past_month_ratio_low', 
        'past_month_volume_moderate', 'past_week_ratio_moderate', 'past_month_ratio_moderate', 'past_month_volume_high', 
        'past_week_ratio_high', 'past_month_ratio_high', 'past_month_volume_very_high', 'past_week_ratio_very_high', 
        'past_month_ratio_very_high', 'past_month_calculated_volume', 'past_week_ratio_calculated_volume', 
        'past_month_ratio_calculated_volume', 'resistance_training_past_month', 'resistance_training_past_season', 
        'bodyweight_exercises_past_month', 'bodyweight_exercises_past_season', 'core_stability_past_month', 'core_stability_past_season', 
        'balance_training_past_month', 'balance_training_past_season', 'plyometrics_past_month', 'plyometrics_past_season', 
        'drills_past_month', 'drills_past_season', 'circuit_training_past_month', 'circuit_training_past_season', 'barefoot_past_month', 
        'barefoot_past_season', 'stretching_past_month', 'stretching_past_season', 'SC_past_month', 'non_running_past_month'
    ]
}

# Define predictors and outcome
X = data.drop(columns=['RRI'])  # Predictors
y = data['RRI']  # Outcome

# Ensure that the feature groups exist in the dataset
for group in feature_groups:
    feature_groups[group] = [feature for feature in feature_groups[group] if feature in X.columns]

num_features = len(X)
feature_to_idx = {feature: idx for idx, feature in enumerate(X)}

# Initialize adjacency matrix with zeros
adjacency = np.zeros((num_features, num_features), dtype=np.float32)

# Define groups
genotype_features = feature_groups['Genotype']
history_features = feature_groups['History']
phenotype_features = feature_groups['Phenotype']
behaviour_features = feature_groups['Behaviour']

# Get indices for each group
genotype_indices = [feature_to_idx[feat] for feat in genotype_features]
history_indices = [feature_to_idx[feat] for feat in history_features]
phenotype_indices = [feature_to_idx[feat] for feat in phenotype_features]
behaviour_indices = [feature_to_idx[feat] for feat in behaviour_features]

# Genotype nodes: connect to every node except themselves
for i in genotype_indices:
    for j in range(num_features):
        if j != i:
            adjacency[i, j] = 1.0

# History nodes: connect to every node except genotype nodes and themselves
for i in history_indices:
    for j in range(num_features):
        if j not in genotype_indices and j != i:
            adjacency[i, j] = 1.0

# Phenotype nodes: connect to every node except genotype, history nodes, and themselves
for i in phenotype_indices:
    for j in range(num_features):
        if j not in genotype_indices and j not in history_indices and j != i:
            adjacency[i, j] = 1.0

# Behaviour nodes: connect to all other behaviour nodes except themselves
for i in behaviour_indices:
    for j in behaviour_indices:
        if j != i:
            adjacency[i, j] = 1.0

# Convert adjacency to tensor
adjacency_mask = torch.tensor(adjacency, dtype=torch.float32)

class CustomDataset(Dataset):
    def __init__(self, X, y):
        if isinstance(X, pd.DataFrame):
            self.X = X.values.astype(np.float32)
        elif isinstance(X, np.ndarray):
            self.X = X.astype(np.float32)
        else:
            raise TypeError("X should be a pandas DataFrame or a NumPy array.")
        self.y = y.astype(np.float32)
    
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

class CustomNetwork(nn.Module):
    def __init__(self, num_features, adjacency_mask):
        super(CustomNetwork, self).__init__()
        self.num_features = num_features

        # Register the fixed adjacency mask as a buffer (non-trainable)
        self.register_buffer('mask', adjacency_mask.float())  # Shape: (num_features, num_features)

        # Initialize connection weights (W_ij: from node j to node i)
        self.W = nn.Parameter(torch.randn(num_features, num_features) * 0.01)

        # Initialize bias for each node
        self.bias = nn.Parameter(torch.zeros(num_features))

        # Initialize output weights (from each node to the final output)
        self.output_weights = nn.Parameter(torch.randn(num_features) * 0.01)

        # Add Batch Normalization
        self.batch_norm = nn.BatchNorm1d(num_features)

    def forward(self, x, threshold=None):
        """
        x: input tensor of shape (batch_size, num_features)
        threshold: if provided, apply binary thresholding to gating
        """
        # Use the fixed mask directly
        learnable_mask = self.mask

        # Apply the learnable mask to connection weights
        W_masked = self.W * learnable_mask  # Shape: (num_features, num_features)

        # Compute incoming messages: (batch_size, num_features) @ (num_features, num_features) = (batch_size, num_features)
        incoming = torch.matmul(x, W_masked)  # Sum over j for each i: sum_j (x_j * W_ij)

        # Element-wise multiplication with own feature value
        node_input = incoming * x  # Shape: (batch_size, num_features)

        node_input = self.batch_norm(node_input)

        # Add bias
        node_input += self.bias  # Broadcasting over batch

        # Apply Leaky ReLU activation
        node_output = F.leaky_relu(node_input)  # Shape: (batch_size, num_features)

        # Aggregate node outputs to final output
        output = torch.matmul(node_output, self.output_weights)  # Shape: (batch_size,)

        return output  # Raw scores (logits)

# Import ReliefF for feature selection
from skrebate import ReliefF

def train_evaluate_fold(fold, train_index, val_index, X, y, selected_features, adjacency, feature_to_idx, 
                       n_epochs, lr, weight_decay, batch_size, threshold):
    """
    Function to train and evaluate the model on a single fold.
    This function is intended to be run in parallel.
    """
    # Split data
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]

    # Encode labels for binary classification
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y_train_enc = le.fit_transform(y_train)
    y_val_enc = le.transform(y_val)
    y_train_final = y_train_enc
    y_val_final = y_val_enc

    # Create datasets
    train_dataset = CustomDataset(X_train[selected_features], y_train_final)
    val_dataset = CustomDataset(X_val[selected_features], y_val_final)

    # Create dataloaders with drop_last=True for training and drop_last=False for validation
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

    # Map selected_features to their indices
    selected_feature_indices = [feature_to_idx[feat] for feat in selected_features]

    # Select the corresponding adjacency submatrix using integer indices
    selected_adjacency = adjacency[np.ix_(selected_feature_indices, selected_feature_indices)]
    selected_adjacency_mask = torch.tensor(selected_adjacency, dtype=torch.float32)

    device = torch.device('cpu')

    # Initialize the model with the number of selected features and the selected adjacency mask
    model = CustomNetwork(num_features=len(selected_features), 
                          adjacency_mask=selected_adjacency_mask).to(device)

    # Define loss and optimizer
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    # Training Loop
    for epoch in range(1, n_epochs + 1):
        model.train()
        epoch_loss = 0.0

        for batch_X, batch_y in train_loader:
            batch_X = batch_X.to(device).float()  # Ensure float type
            batch_y = batch_y.to(device).float()  # BCEWithLogitsLoss expects float targets

            optimizer.zero_grad()
            outputs = model(batch_X)  # Forward pass
            loss = criterion(outputs, batch_y)

            # Total loss
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item() * batch_X.size(0)

        epoch_loss /= len(train_loader.dataset)

    # Validation
    model.eval()
    all_outputs = []
    all_labels = []
    all_preds = []  # Initialize a list to accumulate predictions

    with torch.no_grad():
        for batch_X, batch_y in val_loader:
            batch_X = batch_X.to(device).float()

            outputs = model(batch_X)  # Forward pass
            probs = torch.sigmoid(outputs).cpu().numpy()
            preds = (probs >= threshold).astype(int).flatten()

            all_outputs.extend(probs)
            all_labels.extend(batch_y.numpy())
            all_preds.extend(preds)  # Accumulate predictions

    # Compute metrics
    roc_auc = roc_auc_score(all_labels, all_outputs)
    f1 = f1_score(all_labels, all_preds, average='binary')
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='binary')

    return {
        'roc_auc': roc_auc,
        'f1': f1,
        'accuracy': accuracy,
        'precision': precision
    }

def group_feature_ranking(X, y, feature_groups):
    """
    Perform group-wise feature ranking using ReliefF.
    Returns a dictionary with group names as keys and DataFrames with feature and score sorted descendingly.
    """
    group_rankings = {}
    for group, features in feature_groups.items():
        # Ensure features are in X
        valid_features = [feat for feat in features if feat in X.columns]
        if not valid_features:
            continue
        relief = ReliefF(n_features_to_select='all')
        X_group = X[valid_features].values
        y_group = y.values
        relief.fit(X_group, y_group)
        feature_scores = relief.feature_importances_
        group_score_df = pd.DataFrame({
            'feature': valid_features,
            'score': feature_scores
        }).sort_values(by='score', ascending=False)
        group_rankings[group] = group_score_df
        
    return group_rankings

def objective(trial, X, y, feature_groups, feature_to_idx, group_feature_rankings, adjacency, threshold=0.5):
    # ====================
    # Hyperparameters to Tune
    # ====================

    # 1. Number of Epochs
    n_epochs = trial.suggest_int('n_epochs', 500, 3000)

    # 2. Learning Rate
    lr = trial.suggest_loguniform('lr', 1e-6, 1e-2)

    # 3. Weight Decay
    weight_decay = trial.suggest_loguniform('weight_decay', 1e-8, 1e-3)

    # 4. Batch Size
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128, 256, 512])

    # 5. Number of Features per Group
    n_genotype = trial.suggest_int('n_genotype', 1, len(feature_groups['Genotype']))
    n_history = trial.suggest_int('n_history', 1, len(feature_groups['History']))
    n_phenotype = trial.suggest_int('n_phenotype', 1, len(feature_groups['Phenotype']))
    n_behaviour = trial.suggest_int('n_behaviour', 1, len(feature_groups['Behaviour']))

    # ====================
    # Feature Selection Using Global Rankings
    # ====================

    # Initialize selected features list
    selected_features = []
    
    # For each group, select the top N features based on group-specific ReliefF scores
    for group, n_select in zip(['Genotype', 'History', 'Phenotype', 'Behaviour'],
                               [n_genotype, n_history, n_phenotype, n_behaviour]):
        if group not in group_feature_rankings:
            continue  # Skip if the group has no features
        group_feature_scores = group_feature_rankings[group]
        # Select top N features
        top_features = group_feature_scores.head(n_select)['feature'].tolist()
        selected_features.extend(top_features)
    
    # Ensure that selected_features are unique
    selected_features = list(dict.fromkeys(selected_features))

    # ====================
    # Data Preparation
    # ====================

    X_selected = X[selected_features].copy()
    y_selected = y.copy()

    # Initialize Stratified K-Fold
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

    # Get all fold indices
    fold_indices = list(skf.split(X_selected, y_selected))

    # ====================
    # Parallel Training and Evaluation
    # ====================

    # Define a wrapper for joblib's Parallel
    results = Parallel(n_jobs=10)(
        delayed(train_evaluate_fold)(
            fold=fold,
            train_index=train_idx,
            val_index=val_idx,
            X=X_selected,
            y=y_selected,
            selected_features=selected_features,
            adjacency=adjacency,  # Pass the numpy adjacency matrix
            feature_to_idx=feature_to_idx,  # Pass the feature_to_idx mapping
            n_epochs=n_epochs,
            lr=lr,
            weight_decay=weight_decay,
            batch_size=batch_size,
            threshold=threshold
        )
        for fold, (train_idx, val_idx) in enumerate(fold_indices)
    )

    # ====================
    # Collect Metrics
    # ====================

    aucs = []
    f1s = []
    accuracies = []
    precisions = []

    for res in results:
        aucs.append(res['roc_auc'])
        f1s.append(res['f1'])
        accuracies.append(res['accuracy'])
        precisions.append(res['precision'])

    # ====================
    # Final Metrics Calculation
    # ====================

    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_f1 = np.mean(f1s)
    std_f1 = np.std(f1s)
    mean_accuracy = np.mean(accuracies)
    std_accuracy = np.std(accuracies)
    mean_precision = np.mean(precisions)
    std_precision = np.std(precisions)

    # ====================
    # Objective Metric
    # ====================

    # Since it's binary classification, we aim to maximize the mean AUC
    trial.set_user_attr("mean_auc", mean_auc)
    trial.set_user_attr("std_auc", std_auc)
    trial.set_user_attr("mean_f1", mean_f1)
    trial.set_user_attr("std_f1", std_f1)
    trial.set_user_attr("mean_accuracy", mean_accuracy)
    trial.set_user_attr("std_accuracy", std_accuracy)
    trial.set_user_attr("mean_precision", mean_precision)
    trial.set_user_attr("std_precision", std_precision)
    trial.set_user_attr("selected_features", selected_features)

    return mean_auc

def run_hyperparameter_tuning(X, y, feature_groups, feature_to_idx, adjacency, threshold=0.5):
    # Generate the group-wise feature ranking before the study starts
    group_feature_rankings = group_feature_ranking(X, y, feature_groups)

    def objective_wrapper(trial):
        return objective(trial, X, y, feature_groups, feature_to_idx, group_feature_rankings, adjacency, threshold)

    study = optuna.create_study(
        direction='maximize',
        study_name='CustomNetwork_Hyperparameter_Tuning',
        sampler=optuna.samplers.TPESampler(seed=42)
    )

    # Integrate a progress bar for the Optuna study
    with tqdm(total=500, desc="Optuna Trials") as pbar:
        def callback(study, trial):
            pbar.update(1)

        # Set n_jobs=1 to ensure serial execution of hyperparameter trials
        study.optimize(objective_wrapper, n_trials=500, timeout=None, callbacks=[callback], n_jobs=1)

    print("Number of finished trials: ", len(study.trials))
    print("Best trial:")
    trial = study.best_trial

    print("  Value (Mean AUC): ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

    # Extract additional metrics from the best trial
    best_trial_metrics = trial.user_attrs
    mean_auc = best_trial_metrics.get("mean_auc", None)
    std_auc = best_trial_metrics.get("std_auc", None)
    mean_f1 = best_trial_metrics.get("mean_f1", None)
    std_f1 = best_trial_metrics.get("std_f1", None)
    mean_accuracy = best_trial_metrics.get("mean_accuracy", None)
    std_accuracy = best_trial_metrics.get("std_accuracy", None)
    mean_precision = best_trial_metrics.get("mean_precision", None)
    std_precision = best_trial_metrics.get("std_precision", None)
    selected_features = best_trial_metrics.get("selected_features", None)

    print(f"\nBest Trial Metrics:")
    print(f"Selected Features: {selected_features}")
    print(f"Average AUC: {mean_auc:.4f} ± {std_auc:.4f}")
    print(f"Average F1 Score: {mean_f1:.4f} ± {std_f1:.4f}")
    print(f"Average Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}")
    print(f"Average Precision: {mean_precision:.4f} ± {std_precision:.4f}")

    return study

if __name__ == "__main__":
    # Run hyperparameter tuning
    study = run_hyperparameter_tuning(X, y, feature_groups, feature_to_idx, adjacency)
# Out:
# [I 2024-12-17 00:27:39,786] A new study created in memory with name: CustomNetwork_Hyperparameter_Tuning
# Optuna Trials:   0%|          | 0/500 [00:00<?, ?it/s][I 2024-12-17 00:30:40,775] Trial 0 finished with value: 0.6602240308111644 and parameters: {'n_epochs': 1436, 'lr': 0.006351221010640704, 'weight_decay': 4.570563099801451e-05, 'batch_size': 512, 'n_genotype': 77, 'n_history': 8, 'n_phenotype': 2, 'n_behaviour': 54}. Best is trial 0 with value: 0.6602240308111644.
# Optuna Trials:   0%|          | 1/500 [03:00<25:05:05, 180.97s/it][I 2024-12-17 00:39:36,388] Trial 1 finished with value: 0.7214010121606692 and parameters: {'n_epochs': 2581, 'lr': 7.068974950624607e-06, 'weight_decay': 8.111941985431907e-08, 'batch_size': 128, 'n_genotype': 78, 'n_history': 2, 'n_phenotype': 19, 'n_behaviour': 21}. Best is trial 1 with value: 0.7214010121606692.
# Optuna Trials:   0%|          | 2/500 [11:56<53:53:33, 389.58s/it][I 2024-12-17 00:43:52,173] Trial 2 finished with value: 0.663946746896469 and parameters: {'n_epochs': 1640, 'lr': 0.0013826232179369874, 'weight_decay': 9.9625132220551e-08, 'batch_size': 256, 'n_genotype': 9, 'n_history': 11, 'n_phenotype': 62, 'n_behaviour': 45}. Best is trial 1 with value: 0.7214010121606692.
# Optuna Trials:   1%|          | 3/500 [16:12<45:20:59, 328.49s/it][I 2024-12-17 00:46:05,212] Trial 3 finished with value: 0.6774349761018338 and parameters: {'n_epochs': 1261, 'lr': 2.4586032763280077e-06, 'weight_decay': 2.6373339933815247e-05, 'batch_size': 512, 'n_genotype': 33, 'n_history': 8, 'n_phenotype': 20, 'n_behaviour': 29}. Best is trial 1 with value: 0.7214010121606692.
# Optuna Trials:   1%|          | 4/500 [18:25<34:37:38, 251.33s/it][I 2024-12-17 00:54:49,473] Trial 4 finished with value: 0.7125191054047664 and parameters: {'n_epochs': 1867, 'lr': 5.4880470007660465e-06, 'weight_decay': 0.00070456836384545, 'batch_size': 64, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 3, 'n_behaviour': 18}. Best is trial 1 with value: 0.7214010121606692.
# Optuna Trials:   1%|          | 5/500 [27:09<48:05:25, 349.75s/it][I 2024-12-17 00:57:21,837] Trial 5 finished with value: 0.7323621269697865 and parameters: {'n_epochs': 1472, 'lr': 1.2172958098369984e-05, 'weight_decay': 0.00013921548533046482, 'batch_size': 512, 'n_genotype': 10, 'n_history': 11, 'n_phenotype': 50, 'n_behaviour': 11}. Best is trial 5 with value: 0.7323621269697865.
# Optuna Trials:   1%|          | 6/500 [29:42<38:47:03, 282.64s/it][I 2024-12-17 01:00:15,259] Trial 6 finished with value: 0.7339436830144773 and parameters: {'n_epochs': 513, 'lr': 0.0018274508859816032, 'weight_decay': 3.422052903270691e-05, 'batch_size': 64, 'n_genotype': 110, 'n_history': 7, 'n_phenotype': 22, 'n_behaviour': 4}. Best is trial 6 with value: 0.7339436830144773.
# Optuna Trials:   1%|▏         | 7/500 [32:35<33:48:57, 246.93s/it][I 2024-12-17 01:08:06,141] Trial 7 finished with value: 0.7057417793211151 and parameters: {'n_epochs': 1277, 'lr': 1.99863407785289e-05, 'weight_decay': 4.446628955475447e-05, 'batch_size': 64, 'n_genotype': 97, 'n_history': 7, 'n_phenotype': 50, 'n_behaviour': 28}. Best is trial 6 with value: 0.7339436830144773.
# Optuna Trials:   2%|▏         | 8/500 [40:26<43:29:27, 318.23s/it][I 2024-12-17 01:15:37,512] Trial 8 finished with value: 0.6820425666108929 and parameters: {'n_epochs': 1807, 'lr': 5.1305517605898387e-05, 'weight_decay': 1.3399717231179682e-08, 'batch_size': 128, 'n_genotype': 116, 'n_history': 3, 'n_phenotype': 27, 'n_behaviour': 42}. Best is trial 6 with value: 0.7339436830144773.
# Optuna Trials:   2%|▏         | 9/500 [47:57<49:04:46, 359.85s/it][I 2024-12-17 01:22:29,588] Trial 9 finished with value: 0.7306841670954112 and parameters: {'n_epochs': 1072, 'lr': 2.031980983842497e-06, 'weight_decay': 2.810329644763601e-07, 'batch_size': 64, 'n_genotype': 103, 'n_history': 3, 'n_phenotype': 58, 'n_behaviour': 30}. Best is trial 6 with value: 0.7339436830144773.
# Optuna Trials:   2%|▏         | 10/500 [54:49<51:10:27, 375.97s/it][I 2024-12-17 01:27:57,547] Trial 10 finished with value: 0.7322947699174797 and parameters: {'n_epochs': 551, 'lr': 0.0005800693677313923, 'weight_decay': 3.0675727454645503e-06, 'batch_size': 32, 'n_genotype': 125, 'n_history': 5, 'n_phenotype': 38, 'n_behaviour': 1}. Best is trial 6 with value: 0.7339436830144773.
# Optuna Trials:   2%|▏         | 11/500 [1:00:17<49:04:25, 361.28s/it][I 2024-12-17 01:29:10,188] Trial 11 finished with value: 0.7300871307731207 and parameters: {'n_epochs': 667, 'lr': 0.0002477685796922282, 'weight_decay': 0.0008562441787121946, 'batch_size': 512, 'n_genotype': 47, 'n_history': 11, 'n_phenotype': 42, 'n_behaviour': 1}. Best is trial 6 with value: 0.7339436830144773.
# Optuna Trials:   2%|▏         | 12/500 [1:01:30<37:04:14, 273.47s/it][I 2024-12-17 01:51:03,744] Trial 12 finished with value: 0.736054893288912 and parameters: {'n_epochs': 2433, 'lr': 0.009808851444223075, 'weight_decay': 5.979277361358625e-06, 'batch_size': 32, 'n_genotype': 43, 'n_history': 9, 'n_phenotype': 30, 'n_behaviour': 11}. Best is trial 12 with value: 0.736054893288912.
# Optuna Trials:   3%|▎         | 13/500 [1:23:23<79:37:03, 588.55s/it][I 2024-12-17 02:13:14,418] Trial 13 finished with value: 0.7410703008663494 and parameters: {'n_epochs': 2519, 'lr': 0.009545212646261635, 'weight_decay': 3.518399607532582e-06, 'batch_size': 32, 'n_genotype': 42, 'n_history': 9, 'n_phenotype': 27, 'n_behaviour': 9}. Best is trial 13 with value: 0.7410703008663494.
# Optuna Trials:   3%|▎         | 14/500 [1:45:34<109:42:55, 812.71s/it][I 2024-12-17 02:38:09,611] Trial 14 finished with value: 0.7318333853176658 and parameters: {'n_epochs': 2798, 'lr': 0.00983118888537086, 'weight_decay': 2.3797437742851333e-06, 'batch_size': 32, 'n_genotype': 45, 'n_history': 9, 'n_phenotype': 32, 'n_behaviour': 12}. Best is trial 13 with value: 0.7410703008663494.
# Optuna Trials:   3%|▎         | 15/500 [2:10:29<137:12:18, 1018.43s/it][I 2024-12-17 02:57:11,614] Trial 15 finished with value: 0.734195193839198 and parameters: {'n_epochs': 2284, 'lr': 0.0028849513275110276, 'weight_decay': 1.1913327527919067e-06, 'batch_size': 32, 'n_genotype': 34, 'n_history': 9, 'n_phenotype': 11, 'n_behaviour': 10}. Best is trial 13 with value: 0.7410703008663494.
# Optuna Trials:   3%|▎         | 16/500 [2:29:31<141:55:22, 1055.63s/it][I 2024-12-17 03:18:11,106] Trial 16 finished with value: 0.7017877262490981 and parameters: {'n_epochs': 2288, 'lr': 0.000327212548033475, 'weight_decay': 7.28443471883338e-06, 'batch_size': 32, 'n_genotype': 60, 'n_history': 5, 'n_phenotype': 36, 'n_behaviour': 20}. Best is trial 13 with value: 0.7410703008663494.
# Optuna Trials:   3%|▎         | 17/500 [2:50:31<149:51:16, 1116.93s/it][I 2024-12-17 03:43:30,206] Trial 17 finished with value: 0.7452873593261196 and parameters: {'n_epochs': 2959, 'lr': 9.549106673741274e-05, 'weight_decay': 6.730168120660913e-07, 'batch_size': 32, 'n_genotype': 26, 'n_history': 9, 'n_phenotype': 28, 'n_behaviour': 8}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   4%|▎         | 18/500 [3:15:50<165:43:28, 1237.78s/it][I 2024-12-17 03:49:56,243] Trial 18 finished with value: 0.685870784628676 and parameters: {'n_epochs': 2962, 'lr': 7.468712456900604e-05, 'weight_decay': 5.701886177572081e-07, 'batch_size': 256, 'n_genotype': 23, 'n_history': 10, 'n_phenotype': 10, 'n_behaviour': 37}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   4%|▍         | 19/500 [3:22:16<131:12:04, 981.96s/it] [I 2024-12-17 04:09:19,854] Trial 19 finished with value: 0.73822000883992 and parameters: {'n_epochs': 2084, 'lr': 0.00016674798484938962, 'weight_decay': 1.5434228952042576e-07, 'batch_size': 32, 'n_genotype': 68, 'n_history': 6, 'n_phenotype': 42, 'n_behaviour': 7}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   4%|▍         | 20/500 [3:41:40<138:12:00, 1036.50s/it][I 2024-12-17 04:31:59,564] Trial 20 finished with value: 0.7002779523241469 and parameters: {'n_epochs': 2699, 'lr': 3.5185721837025465e-05, 'weight_decay': 1.9404246275425712e-08, 'batch_size': 32, 'n_genotype': 25, 'n_history': 10, 'n_phenotype': 14, 'n_behaviour': 18}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   4%|▍         | 21/500 [4:04:19<150:49:14, 1133.52s/it][I 2024-12-17 04:50:46,303] Trial 21 finished with value: 0.7416542010987848 and parameters: {'n_epochs': 2038, 'lr': 0.0001424773429480315, 'weight_decay': 1.4522974383995544e-07, 'batch_size': 32, 'n_genotype': 66, 'n_history': 6, 'n_phenotype': 45, 'n_behaviour': 7}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   4%|▍         | 22/500 [4:23:06<150:14:09, 1131.48s/it][I 2024-12-17 05:17:11,993] Trial 22 finished with value: 0.6961417002082664 and parameters: {'n_epochs': 2927, 'lr': 0.0006663579137571078, 'weight_decay': 7.023032296161166e-07, 'batch_size': 32, 'n_genotype': 60, 'n_history': 5, 'n_phenotype': 26, 'n_behaviour': 15}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   5%|▍         | 23/500 [4:49:32<167:58:52, 1267.78s/it][I 2024-12-17 05:36:35,391] Trial 23 finished with value: 0.7390304134418614 and parameters: {'n_epochs': 2004, 'lr': 0.00011726076586409686, 'weight_decay': 3.375632855633949e-08, 'batch_size': 32, 'n_genotype': 84, 'n_history': 7, 'n_phenotype': 49, 'n_behaviour': 6}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   5%|▍         | 24/500 [5:08:55<163:29:15, 1236.46s/it][I 2024-12-17 05:58:49,623] Trial 24 finished with value: 0.7421378364356919 and parameters: {'n_epochs': 2484, 'lr': 2.690201666153061e-05, 'weight_decay': 2.836077295093391e-07, 'batch_size': 32, 'n_genotype': 50, 'n_history': 7, 'n_phenotype': 42, 'n_behaviour': 6}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   5%|▌         | 25/500 [5:31:09<167:00:53, 1265.80s/it][I 2024-12-17 06:04:38,603] Trial 25 finished with value: 0.7089093037590773 and parameters: {'n_epochs': 2208, 'lr': 3.8034831948617373e-05, 'weight_decay': 3.2464179424593673e-07, 'batch_size': 256, 'n_genotype': 56, 'n_history': 8, 'n_phenotype': 45, 'n_behaviour': 23}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   5%|▌         | 26/500 [5:36:58<130:26:43, 990.73s/it] [I 2024-12-17 06:35:29,899] Trial 26 finished with value: 0.6953592210380494 and parameters: {'n_epochs': 2696, 'lr': 1.9558016769372293e-05, 'weight_decay': 5.8665195532688984e-08, 'batch_size': 32, 'n_genotype': 89, 'n_history': 6, 'n_phenotype': 55, 'n_behaviour': 15}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   5%|▌         | 27/500 [6:07:50<164:05:36, 1248.91s/it][I 2024-12-17 06:44:09,311] Trial 27 finished with value: 0.7404255243334769 and parameters: {'n_epochs': 2456, 'lr': 9.115130955983848e-05, 'weight_decay': 2.5649599599047483e-07, 'batch_size': 128, 'n_genotype': 70, 'n_history': 4, 'n_phenotype': 45, 'n_behaviour': 4}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   6%|▌         | 28/500 [6:16:29<135:03:05, 1030.05s/it][I 2024-12-17 07:09:49,862] Trial 28 finished with value: 0.7342739442005525 and parameters: {'n_epochs': 2820, 'lr': 1.0024170599329978e-06, 'weight_decay': 1.201224907304858e-06, 'batch_size': 32, 'n_genotype': 54, 'n_history': 7, 'n_phenotype': 35, 'n_behaviour': 24}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   6%|▌         | 29/500 [6:42:10<154:48:10, 1183.21s/it][I 2024-12-17 07:28:35,834] Trial 29 finished with value: 0.6523656178673573 and parameters: {'n_epochs': 2061, 'lr': 0.00031756999014234476, 'weight_decay': 3.795663356172548e-08, 'batch_size': 32, 'n_genotype': 24, 'n_history': 8, 'n_phenotype': 38, 'n_behaviour': 53}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   6%|▌         | 30/500 [7:00:56<152:13:57, 1166.04s/it][I 2024-12-17 07:49:03,548] Trial 30 finished with value: 0.7049831004018696 and parameters: {'n_epochs': 2362, 'lr': 2.0979402403052293e-05, 'weight_decay': 1.1175221030981977e-05, 'batch_size': 32, 'n_genotype': 1, 'n_history': 1, 'n_phenotype': 54, 'n_behaviour': 15}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   6%|▌         | 31/500 [7:21:23<154:19:09, 1184.54s/it][I 2024-12-17 08:11:26,991] Trial 31 finished with value: 0.7414090106491608 and parameters: {'n_epochs': 2543, 'lr': 0.0032286696643431785, 'weight_decay': 1.931754293100724e-06, 'batch_size': 32, 'n_genotype': 39, 'n_history': 6, 'n_phenotype': 27, 'n_behaviour': 7}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   6%|▋         | 32/500 [7:43:47<160:11:14, 1232.21s/it][I 2024-12-17 08:35:02,552] Trial 32 finished with value: 0.7430201475636427 and parameters: {'n_epochs': 2658, 'lr': 0.000737897801823421, 'weight_decay': 1.230578585811055e-06, 'batch_size': 32, 'n_genotype': 36, 'n_history': 6, 'n_phenotype': 31, 'n_behaviour': 6}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   7%|▋         | 33/500 [8:07:22<166:58:50, 1287.22s/it][I 2024-12-17 08:44:22,803] Trial 33 finished with value: 0.7434187147476152 and parameters: {'n_epochs': 2635, 'lr': 0.000897046624692467, 'weight_decay': 1.313192732802457e-07, 'batch_size': 128, 'n_genotype': 71, 'n_history': 6, 'n_phenotype': 42, 'n_behaviour': 4}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   7%|▋         | 34/500 [8:16:43<138:23:32, 1069.13s/it][I 2024-12-17 08:53:30,550] Trial 34 finished with value: 0.741520437529618 and parameters: {'n_epochs': 2671, 'lr': 0.0005674599061186161, 'weight_decay': 5.784579380342927e-07, 'batch_size': 128, 'n_genotype': 76, 'n_history': 4, 'n_phenotype': 32, 'n_behaviour': 1}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   7%|▋         | 35/500 [8:25:50<117:53:30, 912.71s/it] [I 2024-12-17 09:02:55,212] Trial 35 finished with value: 0.7343124090890251 and parameters: {'n_epochs': 2830, 'lr': 0.0009686077290372314, 'weight_decay': 9.252831319023582e-08, 'batch_size': 128, 'n_genotype': 52, 'n_history': 8, 'n_phenotype': 22, 'n_behaviour': 5}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   7%|▋         | 36/500 [8:35:15<104:10:49, 808.30s/it][I 2024-12-17 09:12:51,210] Trial 36 finished with value: 0.7339763944110567 and parameters: {'n_epochs': 2982, 'lr': 6.957028952385758e-06, 'weight_decay': 1.1292312444102856e-06, 'batch_size': 128, 'n_genotype': 31, 'n_history': 5, 'n_phenotype': 41, 'n_behaviour': 13}. Best is trial 17 with value: 0.7452873593261196.
# Optuna Trials:   7%|▋         | 37/500 [8:45:11<95:45:52, 744.61s/it] [I 2024-12-17 09:16:54,196] Trial 37 finished with value: 0.745542632347484 and parameters: {'n_epochs': 2659, 'lr': 0.003869150543480355, 'weight_decay': 3.393377753699877e-07, 'batch_size': 512, 'n_genotype': 13, 'n_history': 7, 'n_phenotype': 16, 'n_behaviour': 4}. Best is trial 37 with value: 0.745542632347484.
# Optuna Trials:   8%|▊         | 38/500 [8:49:14<76:14:43, 594.12s/it][I 2024-12-17 09:19:32,987] Trial 38 finished with value: 0.7505204258084011 and parameters: {'n_epochs': 1634, 'lr': 0.0035783115159431136, 'weight_decay': 4.7074525574265794e-07, 'batch_size': 512, 'n_genotype': 18, 'n_history': 4, 'n_phenotype': 18, 'n_behaviour': 3}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:   8%|▊         | 39/500 [8:51:53<59:21:23, 463.52s/it][I 2024-12-17 09:22:08,994] Trial 39 finished with value: 0.7387249320570854 and parameters: {'n_epochs': 1692, 'lr': 0.004352499575795549, 'weight_decay': 1.5466046519099328e-07, 'batch_size': 512, 'n_genotype': 15, 'n_history': 4, 'n_phenotype': 18, 'n_behaviour': 3}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:   8%|▊         | 40/500 [8:54:29<47:26:22, 371.27s/it][I 2024-12-17 09:24:28,289] Trial 40 finished with value: 0.6764588464495779 and parameters: {'n_epochs': 1543, 'lr': 0.001551749702089299, 'weight_decay': 0.00014632481835142813, 'batch_size': 512, 'n_genotype': 1, 'n_history': 2, 'n_phenotype': 1, 'n_behaviour': 9}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:   8%|▊         | 41/500 [8:56:48<38:27:48, 301.68s/it][I 2024-12-17 09:26:28,438] Trial 41 finished with value: 0.7378072457280119 and parameters: {'n_epochs': 1247, 'lr': 0.0021858040485364955, 'weight_decay': 4.457474101087519e-07, 'batch_size': 512, 'n_genotype': 16, 'n_history': 10, 'n_phenotype': 16, 'n_behaviour': 3}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:   8%|▊         | 42/500 [8:58:48<31:27:05, 247.22s/it][I 2024-12-17 09:30:25,691] Trial 42 finished with value: 0.731217518337683 and parameters: {'n_epochs': 2620, 'lr': 0.004405780352119698, 'weight_decay': 9.203837245996283e-07, 'batch_size': 512, 'n_genotype': 17, 'n_history': 5, 'n_phenotype': 9, 'n_behaviour': 9}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:   9%|▊         | 43/500 [9:02:45<31:00:12, 244.23s/it][I 2024-12-17 09:33:16,262] Trial 43 finished with value: 0.730861372300684 and parameters: {'n_epochs': 1880, 'lr': 0.0011852907915426735, 'weight_decay': 6.63428913664585e-08, 'batch_size': 512, 'n_genotype': 7, 'n_history': 6, 'n_phenotype': 5, 'n_behaviour': 1}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:   9%|▉         | 44/500 [9:05:36<28:08:11, 222.13s/it][I 2024-12-17 09:34:58,493] Trial 44 finished with value: 0.6698557010679654 and parameters: {'n_epochs': 944, 'lr': 0.0007742816280729835, 'weight_decay': 1.886839613054542e-06, 'batch_size': 512, 'n_genotype': 29, 'n_history': 7, 'n_phenotype': 22, 'n_behaviour': 32}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:   9%|▉         | 45/500 [9:07:18<23:31:43, 186.16s/it][I 2024-12-17 09:42:06,554] Trial 45 finished with value: 0.7398624824219506 and parameters: {'n_epochs': 1394, 'lr': 0.004898807553647348, 'weight_decay': 2.0054649934986911e-07, 'batch_size': 64, 'n_genotype': 36, 'n_history': 4, 'n_phenotype': 24, 'n_behaviour': 4}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:   9%|▉         | 46/500 [9:14:26<32:37:43, 258.73s/it][I 2024-12-17 09:50:41,429] Trial 46 finished with value: 0.7071111946540949 and parameters: {'n_epochs': 2791, 'lr': 0.0022213341876339667, 'weight_decay': 4.001345860380681e-07, 'batch_size': 128, 'n_genotype': 7, 'n_history': 3, 'n_phenotype': 29, 'n_behaviour': 13}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:   9%|▉         | 47/500 [9:23:01<42:13:35, 335.57s/it][I 2024-12-17 09:55:16,220] Trial 47 finished with value: 0.6863742069219521 and parameters: {'n_epochs': 2905, 'lr': 0.0004398178411933014, 'weight_decay': 5.470948811353542e-06, 'batch_size': 512, 'n_genotype': 20, 'n_history': 8, 'n_phenotype': 18, 'n_behaviour': 18}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  10%|▉         | 48/500 [9:27:36<39:50:37, 317.34s/it][I 2024-12-17 09:58:20,891] Trial 48 finished with value: 0.7432561772601904 and parameters: {'n_epochs': 1552, 'lr': 0.006893737074545959, 'weight_decay': 1.1967222396091616e-07, 'batch_size': 256, 'n_genotype': 12, 'n_history': 2, 'n_phenotype': 15, 'n_behaviour': 3}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  10%|▉         | 49/500 [9:30:41<34:46:10, 277.54s/it][I 2024-12-17 10:01:36,296] Trial 49 finished with value: 0.7435295675905148 and parameters: {'n_epochs': 1609, 'lr': 0.007182182072833425, 'weight_decay': 3.963965912284638e-08, 'batch_size': 256, 'n_genotype': 11, 'n_history': 2, 'n_phenotype': 14, 'n_behaviour': 2}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  10%|█         | 50/500 [9:33:56<31:36:44, 252.90s/it][I 2024-12-17 10:05:10,301] Trial 50 finished with value: 0.7322996587261761 and parameters: {'n_epochs': 1795, 'lr': 0.003167193048043443, 'weight_decay': 2.082748979444007e-08, 'batch_size': 256, 'n_genotype': 6, 'n_history': 1, 'n_phenotype': 7, 'n_behaviour': 9}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  10%|█         | 51/500 [9:37:30<30:05:12, 241.23s/it][I 2024-12-17 10:08:22,650] Trial 51 finished with value: 0.7354709694073613 and parameters: {'n_epochs': 1520, 'lr': 0.008176603581074108, 'weight_decay': 3.880842392749831e-08, 'batch_size': 256, 'n_genotype': 27, 'n_history': 2, 'n_phenotype': 13, 'n_behaviour': 2}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  10%|█         | 52/500 [9:40:42<28:11:41, 226.57s/it][I 2024-12-17 10:11:39,732] Trial 52 finished with value: 0.7374979131643122 and parameters: {'n_epochs': 1633, 'lr': 0.005949983326334215, 'weight_decay': 1.0975196777732834e-08, 'batch_size': 256, 'n_genotype': 12, 'n_history': 3, 'n_phenotype': 14, 'n_behaviour': 4}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  11%|█         | 53/500 [9:43:59<27:02:01, 217.72s/it][I 2024-12-17 10:14:27,925] Trial 53 finished with value: 0.734576337487835 and parameters: {'n_epochs': 1323, 'lr': 0.0069869189648326165, 'weight_decay': 1.0188142306011453e-07, 'batch_size': 256, 'n_genotype': 21, 'n_history': 2, 'n_phenotype': 20, 'n_behaviour': 1}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  11%|█         | 54/500 [9:46:48<25:07:56, 202.86s/it][I 2024-12-17 10:16:50,647] Trial 54 finished with value: 0.7269417685371186 and parameters: {'n_epochs': 1137, 'lr': 0.0036539491384640597, 'weight_decay': 1.1599526644093401e-07, 'batch_size': 256, 'n_genotype': 11, 'n_history': 1, 'n_phenotype': 16, 'n_behaviour': 11}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  11%|█         | 55/500 [9:49:10<22:50:45, 184.82s/it][I 2024-12-17 10:20:45,211] Trial 55 finished with value: 0.7433722546696032 and parameters: {'n_epochs': 1902, 'lr': 0.0061393127512549646, 'weight_decay': 6.11210021617403e-08, 'batch_size': 256, 'n_genotype': 17, 'n_history': 2, 'n_phenotype': 12, 'n_behaviour': 7}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  11%|█         | 56/500 [9:53:05<24:38:06, 199.74s/it][I 2024-12-17 10:29:32,258] Trial 56 finished with value: 0.7398629683218392 and parameters: {'n_epochs': 1856, 'lr': 0.0020944834473460017, 'weight_decay': 5.4427464616886086e-08, 'batch_size': 64, 'n_genotype': 17, 'n_history': 3, 'n_phenotype': 10, 'n_behaviour': 8}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  11%|█▏        | 57/500 [10:01:52<36:39:44, 297.93s/it][I 2024-12-17 10:34:17,660] Trial 57 finished with value: 0.666470439126629 and parameters: {'n_epochs': 1944, 'lr': 0.0002066633251999625, 'weight_decay': 2.0038999035620748e-08, 'batch_size': 256, 'n_genotype': 4, 'n_history': 2, 'n_phenotype': 64, 'n_behaviour': 46}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  12%|█▏        | 58/500 [10:06:37<36:07:05, 294.17s/it][I 2024-12-17 10:38:27,588] Trial 58 finished with value: 0.7442076334327995 and parameters: {'n_epochs': 2138, 'lr': 5.787352546862992e-05, 'weight_decay': 2.52122900777819e-07, 'batch_size': 512, 'n_genotype': 99, 'n_history': 9, 'n_phenotype': 12, 'n_behaviour': 5}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  12%|█▏        | 59/500 [10:10:47<34:24:37, 280.90s/it][I 2024-12-17 10:42:52,862] Trial 59 finished with value: 0.7361833343166595 and parameters: {'n_epochs': 2224, 'lr': 6.247424964906173e-05, 'weight_decay': 1.8659364950770618e-07, 'batch_size': 512, 'n_genotype': 100, 'n_history': 9, 'n_phenotype': 5, 'n_behaviour': 11}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  12%|█▏        | 60/500 [10:15:13<33:45:33, 276.21s/it][I 2024-12-17 10:46:21,096] Trial 60 finished with value: 0.7384418414161399 and parameters: {'n_epochs': 1638, 'lr': 4.775611897705909e-05, 'weight_decay': 6.410120743607664e-07, 'batch_size': 512, 'n_genotype': 110, 'n_history': 11, 'n_phenotype': 25, 'n_behaviour': 5}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  12%|█▏        | 61/500 [10:18:41<31:11:44, 255.82s/it][I 2024-12-17 10:50:50,564] Trial 61 finished with value: 0.7331295787171255 and parameters: {'n_epochs': 2145, 'lr': 0.0057643951520185595, 'weight_decay': 2.2851036325488436e-07, 'batch_size': 512, 'n_genotype': 122, 'n_history': 9, 'n_phenotype': 12, 'n_behaviour': 7}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  12%|█▏        | 62/500 [10:23:10<31:37:22, 259.91s/it][I 2024-12-17 10:54:00,030] Trial 62 finished with value: 0.7446274488499846 and parameters: {'n_epochs': 1751, 'lr': 9.051645686599187e-05, 'weight_decay': 3.6636238378209344e-07, 'batch_size': 512, 'n_genotype': 85, 'n_history': 10, 'n_phenotype': 7, 'n_behaviour': 5}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  13%|█▎        | 63/500 [10:26:20<28:59:06, 238.78s/it][I 2024-12-17 10:58:21,741] Trial 63 finished with value: 0.74188666206435 and parameters: {'n_epochs': 2345, 'lr': 0.00010819590572937437, 'weight_decay': 3.5876970612834505e-07, 'batch_size': 512, 'n_genotype': 93, 'n_history': 10, 'n_phenotype': 7, 'n_behaviour': 5}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  13%|█▎        | 64/500 [10:30:41<29:45:07, 245.66s/it][I 2024-12-17 11:01:34,825] Trial 64 finished with value: 0.7322230448338416 and parameters: {'n_epochs': 1716, 'lr': 0.0001502151027808903, 'weight_decay': 8.844966330399948e-07, 'batch_size': 512, 'n_genotype': 79, 'n_history': 10, 'n_phenotype': 20, 'n_behaviour': 2}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  13%|█▎        | 65/500 [10:33:55<27:46:40, 229.89s/it][I 2024-12-17 11:04:03,491] Trial 65 finished with value: 0.7340116987641998 and parameters: {'n_epochs': 1390, 'lr': 1.2309832613686178e-05, 'weight_decay': 4.106798062028548e-07, 'batch_size': 512, 'n_genotype': 86, 'n_history': 9, 'n_phenotype': 3, 'n_behaviour': 14}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  13%|█▎        | 66/500 [10:36:23<24:46:35, 205.52s/it][I 2024-12-17 11:14:16,199] Trial 66 finished with value: 0.7216716730055039 and parameters: {'n_epochs': 2863, 'lr': 3.602448791220095e-05, 'weight_decay': 2.2534998314999366e-07, 'batch_size': 128, 'n_genotype': 106, 'n_history': 11, 'n_phenotype': 7, 'n_behaviour': 10}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  13%|█▎        | 67/500 [10:46:36<39:24:43, 327.68s/it][I 2024-12-17 11:19:17,047] Trial 67 finished with value: 0.7383588457405018 and parameters: {'n_epochs': 2751, 'lr': 7.942964271995522e-05, 'weight_decay': 2.807484018129642e-08, 'batch_size': 512, 'n_genotype': 77, 'n_history': 10, 'n_phenotype': 17, 'n_behaviour': 3}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  14%|█▎        | 68/500 [10:51:37<38:21:19, 319.63s/it][I 2024-12-17 11:24:18,153] Trial 68 finished with value: 0.7364041577314745 and parameters: {'n_epochs': 2585, 'lr': 0.00021280674608232608, 'weight_decay': 5.512963095269712e-07, 'batch_size': 512, 'n_genotype': 94, 'n_history': 8, 'n_phenotype': 23, 'n_behaviour': 5}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  14%|█▍        | 69/500 [10:56:38<37:36:04, 314.07s/it][I 2024-12-17 11:32:41,669] Trial 69 finished with value: 0.7439439671615778 and parameters: {'n_epochs': 2406, 'lr': 5.756094794125255e-05, 'weight_decay': 1.7270751826978356e-06, 'batch_size': 128, 'n_genotype': 72, 'n_history': 7, 'n_phenotype': 20, 'n_behaviour': 8}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  14%|█▍        | 70/500 [11:05:01<44:18:09, 370.90s/it][I 2024-12-17 11:45:33,525] Trial 70 finished with value: 0.6923283324437292 and parameters: {'n_epochs': 2393, 'lr': 6.077677512902418e-05, 'weight_decay': 2.4644953031632214e-06, 'batch_size': 64, 'n_genotype': 89, 'n_history': 7, 'n_phenotype': 10, 'n_behaviour': 17}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  14%|█▍        | 71/500 [11:17:53<58:32:00, 491.19s/it][I 2024-12-17 11:53:16,641] Trial 71 finished with value: 0.7447666950392455 and parameters: {'n_epochs': 2297, 'lr': 0.00011581292956836032, 'weight_decay': 3.8879727655782746e-06, 'batch_size': 128, 'n_genotype': 70, 'n_history': 8, 'n_phenotype': 19, 'n_behaviour': 8}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  14%|█▍        | 72/500 [11:25:36<57:23:44, 482.77s/it][I 2024-12-17 12:00:24,526] Trial 72 finished with value: 0.7444841976135013 and parameters: {'n_epochs': 2136, 'lr': 4.910343440346371e-05, 'weight_decay': 4.224301793108477e-06, 'batch_size': 128, 'n_genotype': 63, 'n_history': 8, 'n_phenotype': 20, 'n_behaviour': 8}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  15%|█▍        | 73/500 [11:32:44<55:18:31, 466.30s/it][I 2024-12-17 12:07:42,823] Trial 73 finished with value: 0.7317120490604593 and parameters: {'n_epochs': 2157, 'lr': 2.6530513895924938e-05, 'weight_decay': 9.30445762084625e-06, 'batch_size': 128, 'n_genotype': 62, 'n_history': 8, 'n_phenotype': 20, 'n_behaviour': 12}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  15%|█▍        | 74/500 [11:40:03<54:11:05, 457.90s/it][I 2024-12-17 12:15:36,426] Trial 74 finished with value: 0.7436367958587227 and parameters: {'n_epochs': 2253, 'lr': 4.9344336295878176e-05, 'weight_decay': 4.399163364860306e-06, 'batch_size': 128, 'n_genotype': 73, 'n_history': 7, 'n_phenotype': 29, 'n_behaviour': 8}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  15%|█▌        | 75/500 [11:47:56<54:36:50, 462.61s/it][I 2024-12-17 12:22:39,001] Trial 75 finished with value: 0.7469657922821656 and parameters: {'n_epochs': 1984, 'lr': 1.318270053431148e-05, 'weight_decay': 1.3470596152450437e-05, 'batch_size': 128, 'n_genotype': 83, 'n_history': 8, 'n_phenotype': 22, 'n_behaviour': 10}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  15%|█▌        | 76/500 [11:54:59<53:04:14, 450.60s/it][I 2024-12-17 12:29:39,010] Trial 76 finished with value: 0.7430497562559222 and parameters: {'n_epochs': 1974, 'lr': 5.14250076063939e-06, 'weight_decay': 2.415838864198116e-05, 'batch_size': 128, 'n_genotype': 83, 'n_history': 8, 'n_phenotype': 23, 'n_behaviour': 10}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  15%|█▌        | 77/500 [12:01:59<51:52:01, 441.42s/it][I 2024-12-17 12:37:14,700] Trial 77 finished with value: 0.7350466348231133 and parameters: {'n_epochs': 2147, 'lr': 4.171304674724374e-06, 'weight_decay': 1.8787672383705078e-05, 'batch_size': 128, 'n_genotype': 82, 'n_history': 9, 'n_phenotype': 17, 'n_behaviour': 16}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  16%|█▌        | 78/500 [12:09:34<52:14:46, 445.70s/it][I 2024-12-17 12:43:13,271] Trial 78 finished with value: 0.7411627031266229 and parameters: {'n_epochs': 1765, 'lr': 0.00010235434051103116, 'weight_decay': 9.864628007597536e-05, 'batch_size': 128, 'n_genotype': 67, 'n_history': 9, 'n_phenotype': 26, 'n_behaviour': 6}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  16%|█▌        | 79/500 [12:15:33<49:03:56, 419.56s/it][I 2024-12-17 12:47:26,402] Trial 79 finished with value: 0.7416672445794995 and parameters: {'n_epochs': 2081, 'lr': 1.3069447115548314e-05, 'weight_decay': 8.869209972466168e-06, 'batch_size': 512, 'n_genotype': 89, 'n_history': 8, 'n_phenotype': 22, 'n_behaviour': 12}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  16%|█▌        | 80/500 [12:19:46<43:07:26, 369.63s/it][I 2024-12-17 12:54:43,425] Trial 80 finished with value: 0.7276779266424 and parameters: {'n_epochs': 1986, 'lr': 1.6988887778793344e-05, 'weight_decay': 1.515120965201272e-05, 'batch_size': 128, 'n_genotype': 98, 'n_history': 9, 'n_phenotype': 19, 'n_behaviour': 26}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  16%|█▌        | 81/500 [12:27:03<45:22:27, 389.85s/it][I 2024-12-17 13:02:59,545] Trial 81 finished with value: 0.7456717385314391 and parameters: {'n_epochs': 2488, 'lr': 2.7619055204784728e-05, 'weight_decay': 1.6477533198657213e-06, 'batch_size': 128, 'n_genotype': 58, 'n_history': 7, 'n_phenotype': 21, 'n_behaviour': 7}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  16%|█▋        | 82/500 [12:35:19<48:58:03, 421.73s/it][I 2024-12-17 13:10:44,299] Trial 82 finished with value: 0.7415572823543307 and parameters: {'n_epochs': 2322, 'lr': 2.9273333942450277e-05, 'weight_decay': 4.152057285643898e-06, 'batch_size': 128, 'n_genotype': 56, 'n_history': 8, 'n_phenotype': 28, 'n_behaviour': 6}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  17%|█▋        | 83/500 [12:43:04<50:20:44, 434.64s/it][I 2024-12-17 13:18:05,922] Trial 83 finished with value: 0.747269056910169 and parameters: {'n_epochs': 2187, 'lr': 4.096409145861931e-05, 'weight_decay': 4.292929382223414e-05, 'batch_size': 128, 'n_genotype': 62, 'n_history': 8, 'n_phenotype': 24, 'n_behaviour': 8}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  17%|█▋        | 84/500 [12:50:26<50:28:01, 436.73s/it][I 2024-12-17 13:27:32,348] Trial 84 finished with value: 0.7166143115995339 and parameters: {'n_epochs': 2555, 'lr': 9.020755161690125e-06, 'weight_decay': 2.536357792497977e-06, 'batch_size': 128, 'n_genotype': 63, 'n_history': 7, 'n_phenotype': 35, 'n_behaviour': 34}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  17%|█▋        | 85/500 [12:59:52<54:49:51, 475.64s/it][I 2024-12-17 13:36:13,167] Trial 85 finished with value: 0.6966191025128176 and parameters: {'n_epochs': 2511, 'lr': 7.970820765718239e-05, 'weight_decay': 3.556585616434835e-05, 'batch_size': 128, 'n_genotype': 58, 'n_history': 8, 'n_phenotype': 24, 'n_behaviour': 20}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  17%|█▋        | 86/500 [13:08:33<56:15:26, 489.19s/it][I 2024-12-17 13:44:32,812] Trial 86 finished with value: 0.742653963272153 and parameters: {'n_epochs': 2468, 'lr': 1.5493386688680922e-05, 'weight_decay': 1.475125002812596e-06, 'batch_size': 128, 'n_genotype': 47, 'n_history': 8, 'n_phenotype': 26, 'n_behaviour': 10}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  17%|█▋        | 87/500 [13:16:53<56:28:52, 492.33s/it][I 2024-12-17 13:50:31,046] Trial 87 finished with value: 0.7428387189046131 and parameters: {'n_epochs': 1829, 'lr': 2.3391302497464377e-05, 'weight_decay': 0.00011376017775519707, 'batch_size': 128, 'n_genotype': 64, 'n_history': 7, 'n_phenotype': 21, 'n_behaviour': 8}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  18%|█▊        | 88/500 [13:22:51<51:44:25, 452.10s/it][I 2024-12-17 13:58:25,004] Trial 88 finished with value: 0.7407128114006192 and parameters: {'n_epochs': 2293, 'lr': 8.786764156573835e-06, 'weight_decay': 8.690717145743465e-07, 'batch_size': 128, 'n_genotype': 80, 'n_history': 7, 'n_phenotype': 18, 'n_behaviour': 8}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  18%|█▊        | 89/500 [13:30:45<52:21:48, 458.66s/it][I 2024-12-17 14:05:12,412] Trial 89 finished with value: 0.7134362345885075 and parameters: {'n_epochs': 2029, 'lr': 0.000277864996459804, 'weight_decay': 3.2185096086966786e-06, 'batch_size': 128, 'n_genotype': 51, 'n_history': 8, 'n_phenotype': 33, 'n_behaviour': 12}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  18%|█▊        | 90/500 [13:37:32<50:29:06, 443.28s/it][I 2024-12-17 14:12:14,833] Trial 90 finished with value: 0.7387822994448905 and parameters: {'n_epochs': 2207, 'lr': 4.219917723263528e-05, 'weight_decay': 6.744728096992497e-05, 'batch_size': 128, 'n_genotype': 43, 'n_history': 6, 'n_phenotype': 24, 'n_behaviour': 3}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  18%|█▊        | 91/500 [13:44:35<49:39:02, 437.02s/it][I 2024-12-17 14:15:56,260] Trial 91 finished with value: 0.7403463580259191 and parameters: {'n_epochs': 2081, 'lr': 0.00011483319482546185, 'weight_decay': 4.911408862927936e-07, 'batch_size': 512, 'n_genotype': 68, 'n_history': 10, 'n_phenotype': 16, 'n_behaviour': 6}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  18%|█▊        | 92/500 [13:48:16<42:11:56, 372.35s/it][I 2024-12-17 14:19:27,852] Trial 92 finished with value: 0.7406732553737666 and parameters: {'n_epochs': 1914, 'lr': 3.043614878247128e-05, 'weight_decay': 6.950738501527659e-06, 'batch_size': 512, 'n_genotype': 76, 'n_history': 9, 'n_phenotype': 13, 'n_behaviour': 5}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  19%|█▊        | 93/500 [13:51:48<36:38:36, 324.12s/it][I 2024-12-17 14:24:35,976] Trial 93 finished with value: 0.7429197198071904 and parameters: {'n_epochs': 2737, 'lr': 6.5996630593507e-05, 'weight_decay': 2.815170246868722e-07, 'batch_size': 512, 'n_genotype': 74, 'n_history': 9, 'n_phenotype': 18, 'n_behaviour': 9}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  19%|█▉        | 94/500 [13:56:56<36:00:44, 319.32s/it][I 2024-12-17 14:32:45,480] Trial 94 finished with value: 0.6820871068378314 and parameters: {'n_epochs': 2152, 'lr': 0.00014240916231254968, 'weight_decay': 8.231433505054146e-07, 'batch_size': 128, 'n_genotype': 105, 'n_history': 7, 'n_phenotype': 28, 'n_behaviour': 14}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  19%|█▉        | 95/500 [14:05:05<41:40:02, 370.38s/it][I 2024-12-17 14:44:15,289] Trial 95 finished with value: 0.7402893713093766 and parameters: {'n_epochs': 2240, 'lr': 3.937565973574344e-05, 'weight_decay': 0.00022631877819646534, 'batch_size': 64, 'n_genotype': 60, 'n_history': 8, 'n_phenotype': 22, 'n_behaviour': 4}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  19%|█▉        | 96/500 [14:16:35<52:19:07, 466.21s/it][I 2024-12-17 15:00:48,651] Trial 96 finished with value: 0.7464225946612079 and parameters: {'n_epochs': 1737, 'lr': 1.7669106717811505e-05, 'weight_decay': 1.3099559095941994e-05, 'batch_size': 32, 'n_genotype': 116, 'n_history': 10, 'n_phenotype': 16, 'n_behaviour': 7}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  19%|█▉        | 97/500 [14:33:08<69:53:34, 624.35s/it][I 2024-12-17 15:17:22,209] Trial 97 finished with value: 0.7453590339318141 and parameters: {'n_epochs': 1706, 'lr': 1.7352065486072774e-05, 'weight_decay': 1.603089581920656e-05, 'batch_size': 32, 'n_genotype': 122, 'n_history': 10, 'n_phenotype': 25, 'n_behaviour': 7}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  20%|█▉        | 98/500 [14:49:42<82:05:15, 735.11s/it][I 2024-12-17 15:34:16,120] Trial 98 finished with value: 0.7332757736722596 and parameters: {'n_epochs': 1703, 'lr': 1.0341656747644077e-05, 'weight_decay': 5.2375605780090986e-05, 'batch_size': 32, 'n_genotype': 119, 'n_history': 11, 'n_phenotype': 25, 'n_behaviour': 10}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  20%|█▉        | 99/500 [15:06:36<91:12:00, 818.75s/it][I 2024-12-17 15:51:11,615] Trial 99 finished with value: 0.7329493569579013 and parameters: {'n_epochs': 1685, 'lr': 1.7342908905531985e-05, 'weight_decay': 1.4709360903484958e-05, 'batch_size': 32, 'n_genotype': 125, 'n_history': 10, 'n_phenotype': 31, 'n_behaviour': 2}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  20%|██        | 100/500 [15:23:31<97:31:50, 877.78s/it][I 2024-12-17 16:05:43,168] Trial 100 finished with value: 0.7459700454900868 and parameters: {'n_epochs': 1477, 'lr': 7.218504166223935e-06, 'weight_decay': 1.230489725341587e-05, 'batch_size': 32, 'n_genotype': 113, 'n_history': 10, 'n_phenotype': 30, 'n_behaviour': 7}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  20%|██        | 101/500 [15:38:03<97:04:47, 875.91s/it][I 2024-12-17 16:20:15,607] Trial 101 finished with value: 0.7393299879135931 and parameters: {'n_epochs': 1446, 'lr': 3.0806205617637194e-06, 'weight_decay': 2.3481059030038715e-05, 'batch_size': 32, 'n_genotype': 115, 'n_history': 10, 'n_phenotype': 33, 'n_behaviour': 6}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  20%|██        | 102/500 [15:52:35<96:43:17, 874.87s/it][I 2024-12-17 16:35:31,531] Trial 102 finished with value: 0.7456160684147998 and parameters: {'n_epochs': 1551, 'lr': 6.950786909873267e-06, 'weight_decay': 1.2506077692229396e-05, 'batch_size': 32, 'n_genotype': 116, 'n_history': 10, 'n_phenotype': 30, 'n_behaviour': 7}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  21%|██        | 103/500 [16:07:51<97:50:12, 887.18s/it][I 2024-12-17 16:50:24,461] Trial 103 finished with value: 0.7450858545555723 and parameters: {'n_epochs': 1496, 'lr': 7.096204859876162e-06, 'weight_decay': 3.0574263199704946e-05, 'batch_size': 32, 'n_genotype': 116, 'n_history': 10, 'n_phenotype': 29, 'n_behaviour': 7}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  21%|██        | 104/500 [16:22:44<97:46:47, 888.91s/it][I 2024-12-17 17:05:34,323] Trial 104 finished with value: 0.7391526965579719 and parameters: {'n_epochs': 1520, 'lr': 5.787418341173227e-06, 'weight_decay': 3.092248289009092e-05, 'batch_size': 32, 'n_genotype': 113, 'n_history': 11, 'n_phenotype': 30, 'n_behaviour': 7}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  21%|██        | 105/500 [16:37:54<98:13:21, 895.19s/it][I 2024-12-17 17:22:07,564] Trial 105 finished with value: 0.7424867886701866 and parameters: {'n_epochs': 1578, 'lr': 7.32090704235172e-06, 'weight_decay': 1.1881201890022299e-05, 'batch_size': 32, 'n_genotype': 127, 'n_history': 10, 'n_phenotype': 37, 'n_behaviour': 13}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  21%|██        | 106/500 [16:54:27<101:11:35, 924.61s/it][I 2024-12-17 17:37:55,436] Trial 106 finished with value: 0.7271663445100721 and parameters: {'n_epochs': 1477, 'lr': 2.874947744010018e-06, 'weight_decay': 4.88175213074665e-05, 'batch_size': 32, 'n_genotype': 117, 'n_history': 10, 'n_phenotype': 27, 'n_behaviour': 44}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  21%|██▏       | 107/500 [17:10:15<101:41:53, 931.59s/it][I 2024-12-17 17:52:07,429] Trial 107 finished with value: 0.7295270492737385 and parameters: {'n_epochs': 1384, 'lr': 1.3655351981673924e-05, 'weight_decay': 1.887559173778043e-05, 'batch_size': 32, 'n_genotype': 121, 'n_history': 11, 'n_phenotype': 34, 'n_behaviour': 11}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  22%|██▏       | 108/500 [17:24:27<98:50:22, 907.71s/it] [I 2024-12-17 18:05:14,715] Trial 108 finished with value: 0.7329856309247691 and parameters: {'n_epochs': 1313, 'lr': 1.6961544983925655e-06, 'weight_decay': 3.9696242396189676e-05, 'batch_size': 32, 'n_genotype': 114, 'n_history': 10, 'n_phenotype': 30, 'n_behaviour': 4}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  22%|██▏       | 109/500 [17:37:34<94:39:48, 871.58s/it][I 2024-12-17 18:17:14,481] Trial 109 finished with value: 0.7462999124911194 and parameters: {'n_epochs': 1218, 'lr': 2.1587335668075914e-05, 'weight_decay': 5.590226972783712e-06, 'batch_size': 32, 'n_genotype': 111, 'n_history': 10, 'n_phenotype': 28, 'n_behaviour': 7}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  22%|██▏       | 110/500 [17:49:34<89:29:14, 826.04s/it][I 2024-12-17 18:27:00,189] Trial 110 finished with value: 0.7367527605950064 and parameters: {'n_epochs': 995, 'lr': 2.3624809787507404e-05, 'weight_decay': 6.007668624362786e-06, 'batch_size': 32, 'n_genotype': 111, 'n_history': 11, 'n_phenotype': 31, 'n_behaviour': 2}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  22%|██▏       | 111/500 [17:59:20<81:28:02, 753.94s/it][I 2024-12-17 18:38:50,597] Trial 111 finished with value: 0.7476632723588394 and parameters: {'n_epochs': 1205, 'lr': 1.075668389442453e-05, 'weight_decay': 1.1179421828225117e-05, 'batch_size': 32, 'n_genotype': 108, 'n_history': 10, 'n_phenotype': 28, 'n_behaviour': 9}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  22%|██▏       | 112/500 [18:11:10<79:51:01, 740.88s/it][I 2024-12-17 18:46:26,442] Trial 112 finished with value: 0.744967080352094 and parameters: {'n_epochs': 786, 'lr': 1.0401738248175637e-05, 'weight_decay': 1.126591567266713e-05, 'batch_size': 32, 'n_genotype': 107, 'n_history': 10, 'n_phenotype': 26, 'n_behaviour': 9}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  23%|██▎       | 113/500 [18:18:46<70:27:07, 655.37s/it][I 2024-12-17 18:57:13,499] Trial 113 finished with value: 0.7382853688337476 and parameters: {'n_epochs': 1100, 'lr': 1.988954057690879e-05, 'weight_decay': 9.164560668471245e-06, 'batch_size': 32, 'n_genotype': 103, 'n_history': 9, 'n_phenotype': 28, 'n_behaviour': 10}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  23%|██▎       | 114/500 [18:29:33<70:00:09, 652.88s/it][I 2024-12-17 19:09:19,625] Trial 114 finished with value: 0.7477977989597537 and parameters: {'n_epochs': 1223, 'lr': 1.5396240941307907e-05, 'weight_decay': 1.605652329869813e-05, 'batch_size': 32, 'n_genotype': 122, 'n_history': 10, 'n_phenotype': 25, 'n_behaviour': 7}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  23%|██▎       | 115/500 [18:41:39<72:10:17, 674.85s/it][I 2024-12-17 19:21:38,496] Trial 115 finished with value: 0.7368671313928468 and parameters: {'n_epochs': 1274, 'lr': 1.4776321141750039e-05, 'weight_decay': 1.4695736742251759e-05, 'batch_size': 32, 'n_genotype': 119, 'n_history': 11, 'n_phenotype': 24, 'n_behaviour': 6}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  23%|██▎       | 116/500 [18:53:58<74:01:57, 694.06s/it][I 2024-12-17 19:31:46,350] Trial 116 finished with value: 0.7421231664324252 and parameters: {'n_epochs': 1019, 'lr': 1.0969456960032662e-05, 'weight_decay': 1.9564074542487967e-05, 'batch_size': 32, 'n_genotype': 122, 'n_history': 10, 'n_phenotype': 25, 'n_behaviour': 4}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  23%|██▎       | 117/500 [19:04:06<71:05:19, 668.20s/it][I 2024-12-17 19:43:36,655] Trial 117 finished with value: 0.7374625549050976 and parameters: {'n_epochs': 1187, 'lr': 4.580799034730687e-06, 'weight_decay': 5.509797358091148e-06, 'batch_size': 32, 'n_genotype': 125, 'n_history': 6, 'n_phenotype': 21, 'n_behaviour': 7}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  24%|██▎       | 118/500 [19:15:56<72:14:36, 680.83s/it][I 2024-12-17 19:56:40,464] Trial 118 finished with value: 0.712962061679945 and parameters: {'n_epochs': 1215, 'lr': 8.334823167939303e-06, 'weight_decay': 6.631294134711894e-06, 'batch_size': 32, 'n_genotype': 110, 'n_history': 10, 'n_phenotype': 23, 'n_behaviour': 51}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  24%|██▍       | 119/500 [19:29:00<75:19:26, 711.72s/it][I 2024-12-17 20:09:38,738] Trial 119 finished with value: 0.7404830711763328 and parameters: {'n_epochs': 1341, 'lr': 1.8368490093614876e-05, 'weight_decay': 1.290643524767678e-05, 'batch_size': 32, 'n_genotype': 112, 'n_history': 5, 'n_phenotype': 27, 'n_behaviour': 9}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  24%|██▍       | 120/500 [19:41:58<77:14:01, 731.69s/it][I 2024-12-17 20:20:46,946] Trial 120 finished with value: 0.7356221615795313 and parameters: {'n_epochs': 1173, 'lr': 5.986716794606762e-06, 'weight_decay': 7.665186323825167e-06, 'batch_size': 32, 'n_genotype': 108, 'n_history': 11, 'n_phenotype': 15, 'n_behaviour': 1}. Best is trial 38 with value: 0.7505204258084011.
# Optuna Trials:  24%|██▍       | 121/500 [19:53:07<75:01:32, 712.64s/it][I 2024-12-17 20:36:51,185] Trial 121 finished with value: 0.7383041039013186 and parameters: {'n_epochs': 1594, 'lr': 3.270284524299342e-05, 'weight_decay': 1.725294194315397e-05, 'batch_size': 32, 'n_genotype': 117, 'n_history': 9, 'n_phenotype': 32, 'n_behaviour': 11}. Best is trial 38 with value: 0.7505204258084011.
# ...
# Optuna Trials:  94%|█████████▎| 468/500 [42:42:32<1:31:35, 171.73s/it][I 2024-12-18 19:11:53,831] Trial 468 finished with value: 0.7439950326563677 and parameters: {'n_epochs': 699, 'lr': 7.94302865969912e-05, 'weight_decay': 0.0006023252167604369, 'batch_size': 256, 'n_genotype': 116, 'n_history': 10, 'n_phenotype': 23, 'n_behaviour': 9}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  94%|█████████▍| 469/500 [42:44:14<1:17:50, 150.65s/it][I 2024-12-18 19:16:10,352] Trial 469 finished with value: 0.7448737538883716 and parameters: {'n_epochs': 1716, 'lr': 4.5640755158419924e-05, 'weight_decay': 0.00029215027709967857, 'batch_size': 256, 'n_genotype': 123, 'n_history': 10, 'n_phenotype': 37, 'n_behaviour': 7}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  94%|█████████▍| 470/500 [42:48:30<1:31:12, 182.41s/it][I 2024-12-18 19:17:41,430] Trial 470 finished with value: 0.7450600680770189 and parameters: {'n_epochs': 769, 'lr': 6.0284932547780825e-05, 'weight_decay': 1.971309374623066e-07, 'batch_size': 512, 'n_genotype': 119, 'n_history': 10, 'n_phenotype': 19, 'n_behaviour': 11}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  94%|█████████▍| 471/500 [42:50:01<1:14:55, 155.01s/it][I 2024-12-18 19:19:23,859] Trial 471 finished with value: 0.7475818053302132 and parameters: {'n_epochs': 671, 'lr': 3.7586820730848784e-05, 'weight_decay': 0.0004309722112041829, 'batch_size': 256, 'n_genotype': 127, 'n_history': 10, 'n_phenotype': 29, 'n_behaviour': 8}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  94%|█████████▍| 472/500 [42:51:44<1:04:58, 139.24s/it][I 2024-12-18 19:21:32,818] Trial 472 finished with value: 0.7372514708517539 and parameters: {'n_epochs': 816, 'lr': 5.08865629864001e-05, 'weight_decay': 0.00019187496970773317, 'batch_size': 256, 'n_genotype': 122, 'n_history': 11, 'n_phenotype': 36, 'n_behaviour': 10}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  95%|█████████▍| 473/500 [42:53:53<1:01:16, 136.15s/it][I 2024-12-18 19:24:09,436] Trial 473 finished with value: 0.7383714054080145 and parameters: {'n_epochs': 1502, 'lr': 6.921691297282846e-05, 'weight_decay': 0.0006967612149411844, 'batch_size': 256, 'n_genotype': 1, 'n_history': 10, 'n_phenotype': 26, 'n_behaviour': 5}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  95%|█████████▍| 474/500 [42:56:29<1:01:39, 142.29s/it][I 2024-12-18 19:28:03,581] Trial 474 finished with value: 0.7364342699114302 and parameters: {'n_epochs': 1632, 'lr': 3.437164140790996e-05, 'weight_decay': 4.39820107090571e-07, 'batch_size': 256, 'n_genotype': 125, 'n_history': 9, 'n_phenotype': 21, 'n_behaviour': 2}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  95%|█████████▌| 475/500 [43:00:23<1:10:46, 169.85s/it][I 2024-12-18 19:30:47,413] Trial 475 finished with value: 0.7454807599025921 and parameters: {'n_epochs': 1424, 'lr': 4.2589542965581176e-05, 'weight_decay': 0.0009960897419262265, 'batch_size': 256, 'n_genotype': 53, 'n_history': 10, 'n_phenotype': 24, 'n_behaviour': 9}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  95%|█████████▌| 476/500 [43:03:07<1:07:13, 168.04s/it][I 2024-12-18 19:33:59,323] Trial 476 finished with value: 0.7448869255512657 and parameters: {'n_epochs': 1233, 'lr': 5.46178925784475e-05, 'weight_decay': 0.0001215372267339385, 'batch_size': 256, 'n_genotype': 122, 'n_history': 10, 'n_phenotype': 61, 'n_behaviour': 7}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  95%|█████████▌| 477/500 [43:06:19<1:07:09, 175.20s/it][I 2024-12-18 19:38:18,683] Trial 477 finished with value: 0.741488654907325 and parameters: {'n_epochs': 1279, 'lr': 9.732090036484602e-05, 'weight_decay': 0.0004047072278502134, 'batch_size': 128, 'n_genotype': 125, 'n_history': 9, 'n_phenotype': 38, 'n_behaviour': 6}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  96%|█████████▌| 478/500 [43:10:38<1:13:29, 200.45s/it][I 2024-12-18 19:39:45,800] Trial 478 finished with value: 0.7418711517225642 and parameters: {'n_epochs': 715, 'lr': 3.301175993713394e-05, 'weight_decay': 0.0005496874980930661, 'batch_size': 512, 'n_genotype': 119, 'n_history': 10, 'n_phenotype': 31, 'n_behaviour': 11}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  96%|█████████▌| 479/500 [43:12:05<58:15, 166.45s/it]  [I 2024-12-18 19:42:46,826] Trial 479 finished with value: 0.7471042436425496 and parameters: {'n_epochs': 1519, 'lr': 4.3497220606051825e-05, 'weight_decay': 0.0002504954819439029, 'batch_size': 256, 'n_genotype': 26, 'n_history': 10, 'n_phenotype': 40, 'n_behaviour': 8}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  96%|█████████▌| 480/500 [43:15:07<56:56, 170.82s/it][I 2024-12-18 19:44:29,426] Trial 480 finished with value: 0.7490103670010405 and parameters: {'n_epochs': 642, 'lr': 6.610442204157756e-05, 'weight_decay': 0.000767255336807949, 'batch_size': 256, 'n_genotype': 127, 'n_history': 8, 'n_phenotype': 35, 'n_behaviour': 9}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  96%|█████████▌| 481/500 [43:16:49<47:36, 150.36s/it][I 2024-12-18 19:46:07,688] Trial 481 finished with value: 0.7423625048190539 and parameters: {'n_epochs': 634, 'lr': 0.0013957146681342766, 'weight_decay': 0.0008038577319493, 'batch_size': 256, 'n_genotype': 123, 'n_history': 8, 'n_phenotype': 36, 'n_behaviour': 9}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  96%|█████████▋| 482/500 [43:18:27<40:25, 134.73s/it][I 2024-12-18 19:47:46,135] Trial 482 finished with value: 0.7469694855187841 and parameters: {'n_epochs': 657, 'lr': 8.581518234820684e-05, 'weight_decay': 0.000741908065174188, 'batch_size': 256, 'n_genotype': 113, 'n_history': 8, 'n_phenotype': 35, 'n_behaviour': 7}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  97%|█████████▋| 483/500 [43:20:06<35:05, 123.84s/it][I 2024-12-18 19:49:38,247] Trial 483 finished with value: 0.7438281658903636 and parameters: {'n_epochs': 707, 'lr': 0.0005055764446367758, 'weight_decay': 1.1271024223567856e-08, 'batch_size': 256, 'n_genotype': 117, 'n_history': 8, 'n_phenotype': 34, 'n_behaviour': 8}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  97%|█████████▋| 484/500 [43:21:58<32:05, 120.32s/it][I 2024-12-18 19:51:10,628] Trial 484 finished with value: 0.73540928168392 and parameters: {'n_epochs': 606, 'lr': 7.429398191464118e-05, 'weight_decay': 0.0006046512787341972, 'batch_size': 256, 'n_genotype': 125, 'n_history': 7, 'n_phenotype': 35, 'n_behaviour': 10}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  97%|█████████▋| 485/500 [43:23:30<27:59, 111.94s/it][I 2024-12-18 19:52:33,799] Trial 485 finished with value: 0.7175637332526703 and parameters: {'n_epochs': 744, 'lr': 0.0034687302123617343, 'weight_decay': 0.0008028531630873655, 'batch_size': 512, 'n_genotype': 127, 'n_history': 9, 'n_phenotype': 33, 'n_behaviour': 12}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  97%|█████████▋| 486/500 [43:24:53<24:06, 103.31s/it][I 2024-12-18 19:53:54,627] Trial 486 finished with value: 0.7500003467874461 and parameters: {'n_epochs': 536, 'lr': 6.458090841733953e-05, 'weight_decay': 0.0005114838329532173, 'batch_size': 256, 'n_genotype': 121, 'n_history': 9, 'n_phenotype': 37, 'n_behaviour': 9}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  97%|█████████▋| 487/500 [43:26:14<20:55, 96.57s/it] [I 2024-12-18 19:55:17,943] Trial 487 finished with value: 0.7418496639178526 and parameters: {'n_epochs': 546, 'lr': 9.19659087948704e-05, 'weight_decay': 0.0005332846619131966, 'batch_size': 256, 'n_genotype': 119, 'n_history': 9, 'n_phenotype': 36, 'n_behaviour': 5}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  98%|█████████▊| 488/500 [43:27:38<18:31, 92.59s/it][I 2024-12-18 19:56:40,973] Trial 488 finished with value: 0.7497362221407262 and parameters: {'n_epochs': 532, 'lr': 7.02774854002973e-05, 'weight_decay': 0.0006704043812800558, 'batch_size': 256, 'n_genotype': 115, 'n_history': 9, 'n_phenotype': 32, 'n_behaviour': 9}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  98%|█████████▊| 489/500 [43:29:01<16:26, 89.72s/it][I 2024-12-18 19:58:03,915] Trial 489 finished with value: 0.7462664409444073 and parameters: {'n_epochs': 582, 'lr': 8.213021131658782e-05, 'weight_decay': 0.0009984808933078855, 'batch_size': 256, 'n_genotype': 117, 'n_history': 9, 'n_phenotype': 32, 'n_behaviour': 7}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  98%|█████████▊| 490/500 [43:30:24<14:36, 87.69s/it][I 2024-12-18 19:59:20,594] Trial 490 finished with value: 0.7500672323479388 and parameters: {'n_epochs': 537, 'lr': 0.0001163432019077036, 'weight_decay': 0.0006598826176386105, 'batch_size': 256, 'n_genotype': 114, 'n_history': 9, 'n_phenotype': 30, 'n_behaviour': 8}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  98%|█████████▊| 491/500 [43:31:40<12:39, 84.39s/it][I 2024-12-18 20:00:33,163] Trial 491 finished with value: 0.7449851424135411 and parameters: {'n_epochs': 515, 'lr': 0.00010566286496162125, 'weight_decay': 0.0005812497578230645, 'batch_size': 256, 'n_genotype': 111, 'n_history': 9, 'n_phenotype': 30, 'n_behaviour': 6}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  98%|█████████▊| 492/500 [43:32:53<10:46, 80.84s/it][I 2024-12-18 20:01:48,502] Trial 492 finished with value: 0.7413278674544278 and parameters: {'n_epochs': 529, 'lr': 6.793733744591855e-05, 'weight_decay': 0.0007096748705152042, 'batch_size': 256, 'n_genotype': 107, 'n_history': 9, 'n_phenotype': 30, 'n_behaviour': 4}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  99%|█████████▊| 493/500 [43:34:08<09:14, 79.19s/it][I 2024-12-18 20:03:00,510] Trial 493 finished with value: 0.7421584643267762 and parameters: {'n_epochs': 505, 'lr': 0.0009887664140479906, 'weight_decay': 0.00047552427774388357, 'batch_size': 256, 'n_genotype': 115, 'n_history': 9, 'n_phenotype': 29, 'n_behaviour': 7}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  99%|█████████▉| 494/500 [43:35:20<07:42, 77.04s/it][I 2024-12-18 20:04:18,568] Trial 494 finished with value: 0.7447984224140257 and parameters: {'n_epochs': 528, 'lr': 6.242112892865052e-05, 'weight_decay': 0.0006154631809566226, 'batch_size': 256, 'n_genotype': 111, 'n_history': 9, 'n_phenotype': 30, 'n_behaviour': 8}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  99%|█████████▉| 495/500 [43:36:38<06:26, 77.34s/it][I 2024-12-18 20:06:32,975] Trial 495 finished with value: 0.7459951860894425 and parameters: {'n_epochs': 877, 'lr': 7.616464775913727e-05, 'weight_decay': 0.0008195127966454699, 'batch_size': 256, 'n_genotype': 116, 'n_history': 9, 'n_phenotype': 31, 'n_behaviour': 6}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  99%|█████████▉| 496/500 [43:38:53<06:17, 94.46s/it][I 2024-12-18 20:08:39,544] Trial 496 finished with value: 0.7490961075639029 and parameters: {'n_epochs': 858, 'lr': 0.000140548697078327, 'weight_decay': 4.179373312794718e-06, 'batch_size': 256, 'n_genotype': 113, 'n_history': 9, 'n_phenotype': 28, 'n_behaviour': 8}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials:  99%|█████████▉| 497/500 [43:40:59<05:12, 104.09s/it][I 2024-12-18 20:10:01,591] Trial 497 finished with value: 0.7463931625423642 and parameters: {'n_epochs': 558, 'lr': 0.00014851954098369562, 'weight_decay': 8.518186656453849e-07, 'batch_size': 256, 'n_genotype': 113, 'n_history': 9, 'n_phenotype': 28, 'n_behaviour': 9}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials: 100%|█████████▉| 498/500 [43:42:21<03:14, 97.48s/it] [I 2024-12-18 20:11:12,909] Trial 498 finished with value: 0.7381602859803642 and parameters: {'n_epochs': 505, 'lr': 0.0001183975177486875, 'weight_decay': 3.436955500092043e-05, 'batch_size': 256, 'n_genotype': 110, 'n_history': 9, 'n_phenotype': 28, 'n_behaviour': 11}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials: 100%|█████████▉| 499/500 [43:43:33<01:29, 89.63s/it][I 2024-12-18 20:13:13,413] Trial 499 finished with value: 0.7457929073568843 and parameters: {'n_epochs': 840, 'lr': 5.460496653069133e-05, 'weight_decay': 5.805044517577899e-06, 'batch_size': 256, 'n_genotype': 113, 'n_history': 9, 'n_phenotype': 29, 'n_behaviour': 10}. Best is trial 218 with value: 0.7530759131312909.
# Optuna Trials: 100%|██████████| 500/500 [43:45:33<00:00, 315.07s/it]
# Number of finished trials:  500
# Best trial:
#   Value (Mean AUC):  0.7530759131312909
#   Params:
#     n_epochs: 730
#     lr: 4.86593416133986e-05
#     weight_decay: 0.0003438008978072548
#     batch_size: 256
#     n_genotype: 126
#     n_history: 10
#     n_phenotype: 32
#     n_behaviour: 9
#
# Best Trial Metrics:
# Selected Features: ['rs591058', 'rs2104772', 'rs25487', 'rs1249269', 'rs1800797', 'rs1137101', 'rs1330363', 'rs1144393', 'rs7528684', 'rs4701616', 'rs10132091', 'rs2237352', 'rs143383', 'rs4789932', 'rs2228570', 'rs13946', 'rs10263021', 'rs6481512', 'rs2234693', 'rs6617', 'rs4730153', 'rs7035322', 'rs11177', 'rs12722', 'rs820218', 'rs17756404', 'rs3018362', 'rs4725069', 'rs13317', 'rs4454832', 'rs3196378', 'rs1544410', 'rs62051384', 'rs970547', 'rs4986938', 'rs42531', 'rs17576', 'rs11232681', 'rs911263', 'rs10992075', 'rs1011814', 'rs2252070', 'rs11225395', 'rs11154027', 'rs1800629', 'rs1590', 'rs2761884', 'rs1800469', 'rs4362400', 'rs2525504', 'rs4903399', 'rs3219008', 'rs1800972', 'rs1937810', 'rs3753841', 'rs4919510', 'rs10759753', 'rs3045', 'rs4328262', 'rs1718119', 'rs2306033', 'rs3789870', 'rs4244032', 'rs11629171', 'rs9340799', 'rs2285053', 'rs2289360', 'rs3218791', 'rs17583842', 'rs1800470', 'rs2281518', 'rs10484958', 'class12_SNP_risk_score', 'rs1643821', 'rs12656106', 'sex', 'rs2277698', 'rs1134170', 'class1_SNP_risk_score', 'rs187483', 'rs1800012', 'rs1045485', 'rs1554606', 'class123_SNP_risk_score', 'rs72758637', 'rs1887632', 'rs2305948', 'rs1676303', 'rs1800795', 'rs12154667', 'rs4654760', 'rs1138545', 'rs1021188', 'rs78391032', 'rs3751143', 'rs7021589', 'rs1548456', 'rs2277268', 'rs13107325', 'rs12574452', 'rs912336', 'rs420257', 'rs35360670', 'rs42517', 'rs2010963', 'rs2586488', 'rs60713544', 'rs74544784', 'rs71404070', 'rs12429486', 'rs25489', 'rs117544024', 'rs650108', 'rs761804508', 'rs57104447', 'rs145648292', 'rs42522', 'rs710079', 'rs413826', 'rs4988321', 'rs77569527', 'rs144371252', 'rs144414988', 'rs149047058', 'rs2858056', 'rs3216902', 'Age', 'Athlete_Score', 'average_run_hours', 'average_run_frequency', 'average_interval_training_frequency', 'EDEQ_total', 'LEAF-Q', 'tracking_period_injury', 'lower_limb_days_total', 'past_stress_injury', 'Duty_factor_10', 'Flight_time_10', 'Step_frequency_10', 'Contact_time_10', 'Q_angle_asymmetry', 'Impact_peak_10', 'Cadence_asymmetry_10', 'total_ad_ab_ratio', 'knee_extension_peak_torque', 'hip_abduction_peak_torque', 'hip_adduction_peak_torque', 'Impact_peak_12', 'Duty_factor_12', 'Q_angle', 'Flight_time_12', 'BMI', 'BMD_body', 'knee_flexion_peak_angle', 'knee_flexion_peak_angle_asymmetry', 'hip_adduction_peak_angle', 'Contact_time_12', 'knee_flexion_peak_torque', 'hip_abduction_peak_torque_asymmetry', 'Impact_peak_asymmetry_10', 'knee_flexion_peak_torque_asymmetry', 'Duty_factor_asymmetry_10', 'Cadence_asymmetry_12', 'knee_extension_peak_angle_asymmetry', 'knee_extension_peak_torque_asymmetry', 'knee_extension_peak_angle', 'BMD_hip', 'height', 'fat_intake_BW', 'fat_percentage_avg', 'fat_intake_avg', 'arginine_intake_BW', 'protein_intake_BW', 'average_energy_availability', 'glycine_intake_BW', 'calcium_intake_BW', 'past_month_distance']
# Average AUC: 0.7531 ± 0.0378
# Average F1 Score: 0.0925 ± 0.0424
# Average Accuracy: 0.9068 ± 0.0033
# Average Precision: 0.4604 ± 0.2347

# %%
# Access the best trial
print("Number of finished trials: ", len(study.trials))
print("Best trial:")
trial = study.best_trial

print("  Value (Mean AUC): ", trial.value)
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")

# Extract additional metrics from the best trial
best_trial_metrics = trial.user_attrs
mean_auc = best_trial_metrics.get("mean_auc", None)
std_auc = best_trial_metrics.get("std_auc", None)
mean_f1 = best_trial_metrics.get("mean_f1", None)
std_f1 = best_trial_metrics.get("std_f1", None)
mean_accuracy = best_trial_metrics.get("mean_accuracy", None)
std_accuracy = best_trial_metrics.get("std_accuracy", None)
mean_precision = best_trial_metrics.get("mean_precision", None)
std_precision = best_trial_metrics.get("std_precision", None)
selected_features = best_trial_metrics.get("selected_features", None)

print(f"\nBest Trial Metrics:")
print(f"Selected Features ({len(selected_features)} features):")
print(selected_features)
print(f"\nAverage AUC: {mean_auc:.4f} ± {std_auc:.4f}")
print(f"Average F1 Score: {mean_f1:.4f} ± {std_f1:.4f}")
print(f"Average Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}")
print(f"Average Precision: {mean_precision:.4f} ± {std_precision:.4f}")
# Out:
# Number of finished trials:  500
# Best trial:
#   Value (Mean AUC):  0.7530759131312909
#   Params:
#     n_epochs: 730
#     lr: 4.86593416133986e-05
#     weight_decay: 0.0003438008978072548
#     batch_size: 256
#     n_genotype: 126
#     n_history: 10
#     n_phenotype: 32
#     n_behaviour: 9
#
# Best Trial Metrics:
# Selected Features (177 features):
# ['rs591058', 'rs2104772', 'rs25487', 'rs1249269', 'rs1800797', 'rs1137101', 'rs1330363', 'rs1144393', 'rs7528684', 'rs4701616', 'rs10132091', 'rs2237352', 'rs143383', 'rs4789932', 'rs2228570', 'rs13946', 'rs10263021', 'rs6481512', 'rs2234693', 'rs6617', 'rs4730153', 'rs7035322', 'rs11177', 'rs12722', 'rs820218', 'rs17756404', 'rs3018362', 'rs4725069', 'rs13317', 'rs4454832', 'rs3196378', 'rs1544410', 'rs62051384', 'rs970547', 'rs4986938', 'rs42531', 'rs17576', 'rs11232681', 'rs911263', 'rs10992075', 'rs1011814', 'rs2252070', 'rs11225395', 'rs11154027', 'rs1800629', 'rs1590', 'rs2761884', 'rs1800469', 'rs4362400', 'rs2525504', 'rs4903399', 'rs3219008', 'rs1800972', 'rs1937810', 'rs3753841', 'rs4919510', 'rs10759753', 'rs3045', 'rs4328262', 'rs1718119', 'rs2306033', 'rs3789870', 'rs4244032', 'rs11629171', 'rs9340799', 'rs2285053', 'rs2289360', 'rs3218791', 'rs17583842', 'rs1800470', 'rs2281518', 'rs10484958', 'class12_SNP_risk_score', 'rs1643821', 'rs12656106', 'sex', 'rs2277698', 'rs1134170', 'class1_SNP_risk_score', 'rs187483', 'rs1800012', 'rs1045485', 'rs1554606', 'class123_SNP_risk_score', 'rs72758637', 'rs1887632', 'rs2305948', 'rs1676303', 'rs1800795', 'rs12154667', 'rs4654760', 'rs1138545', 'rs1021188', 'rs78391032', 'rs3751143', 'rs7021589', 'rs1548456', 'rs2277268', 'rs13107325', 'rs12574452', 'rs912336', 'rs420257', 'rs35360670', 'rs42517', 'rs2010963', 'rs2586488', 'rs60713544', 'rs74544784', 'rs71404070', 'rs12429486', 'rs25489', 'rs117544024', 'rs650108', 'rs761804508', 'rs57104447', 'rs145648292', 'rs42522', 'rs710079', 'rs413826', 'rs4988321', 'rs77569527', 'rs144371252', 'rs144414988', 'rs149047058', 'rs2858056', 'rs3216902', 'Age', 'Athlete_Score', 'average_run_hours', 'average_run_frequency', 'average_interval_training_frequency', 'EDEQ_total', 'LEAF-Q', 'tracking_period_injury', 'lower_limb_days_total', 'past_stress_injury', 'Duty_factor_10', 'Flight_time_10', 'Step_frequency_10', 'Contact_time_10', 'Q_angle_asymmetry', 'Impact_peak_10', 'Cadence_asymmetry_10', 'total_ad_ab_ratio', 'knee_extension_peak_torque', 'hip_abduction_peak_torque', 'hip_adduction_peak_torque', 'Impact_peak_12', 'Duty_factor_12', 'Q_angle', 'Flight_time_12', 'BMI', 'BMD_body', 'knee_flexion_peak_angle', 'knee_flexion_peak_angle_asymmetry', 'hip_adduction_peak_angle', 'Contact_time_12', 'knee_flexion_peak_torque', 'hip_abduction_peak_torque_asymmetry', 'Impact_peak_asymmetry_10', 'knee_flexion_peak_torque_asymmetry', 'Duty_factor_asymmetry_10', 'Cadence_asymmetry_12', 'knee_extension_peak_angle_asymmetry', 'knee_extension_peak_torque_asymmetry', 'knee_extension_peak_angle', 'BMD_hip', 'height', 'fat_intake_BW', 'fat_percentage_avg', 'fat_intake_avg', 'arginine_intake_BW', 'protein_intake_BW', 'average_energy_availability', 'glycine_intake_BW', 'calcium_intake_BW', 'past_month_distance']
#
# Average AUC: 0.7531 ± 0.0378
# Average F1 Score: 0.0925 ± 0.0424
# Average Accuracy: 0.9068 ± 0.0033
# Average Precision: 0.4604 ± 0.2347
